# %%
import os, time, ast, json, csv
import pandas as pd
import numpy as np
from scipy.special import softmax
from tqdm.notebook import tqdm
import joblib
from joblib import Parallel, delayed
from sklearn.tree import DecisionTreeClassifier
from lightgbm import Dataset
import lightgbm
from sklearn.model_selection import train_test_split, RandomizedSearchCV, KFold, cross_val_score
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix, classification_report, matthews_corrcoef
import numpy as np
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.feature_selection import VarianceThreshold
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder, OrdinalEncoder
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline
from imblearn.under_sampling import  RandomUnderSampler
from imblearn.over_sampling import SMOTE, RandomOverSampler
from sklearn.base import BaseEstimator, TransformerMixin

# %% [markdown]
# ### This tests all 499 of the LGBM model ensembles in sequence.

# %%
file_path = '../data/negone_median.json'

# Read the JSON.
with open(file_path, 'r') as file:
    data = json.load(file)

# Extract the lists.
negone_features = data.get('NEGONE_FEATURES', [])
median_features = data.get('MEDIAN_FEATURES', [])
print('NEGONE_FEATURES:', negone_features)
print('MEDIAN_FEATURES:', median_features)
# Out:
# NEGONE_FEATURES: ['feature487', 'feature489', 'feature491', 'feature492', 'feature493', 'feature494', 'feature495', 'feature496', 'feature497', 'feature498', 'feature499', 'feature458', 'feature4', 'feature6', 'feature10', 'feature13', 'feature31', 'feature35', 'feature36', 'feature46', 'feature47', 'feature48', 'feature49', 'feature45', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60', 'feature61', 'feature62', 'feature63', 'feature64', 'feature65', 'feature66', 'feature67', 'feature68', 'feature69', 'feature70', 'feature71', 'feature72', 'feature73', 'feature74', 'feature75', 'feature76', 'feature77', 'feature84', 'feature85', 'feature86', 'feature87', 'feature88', 'feature89', 'feature90', 'feature91', 'feature92', 'feature93', 'feature94', 'feature95', 'feature96', 'feature97', 'feature98', 'feature99', 'feature100', 'feature101', 'feature102', 'feature103', 'feature105', 'feature107', 'feature108', 'feature109', 'feature110', 'feature111', 'feature112', 'feature113', 'feature114', 'feature115', 'feature116', 'feature117', 'feature118', 'feature119', 'feature120', 'feature121', 'feature122', 'feature123', 'feature124', 'feature125', 'feature126', 'feature127', 'feature128', 'feature129', 'feature130', 'feature131', 'feature132', 'feature133', 'feature134', 'feature135', 'feature136', 'feature137', 'feature138', 'feature139', 'feature140', 'feature141', 'feature142', 'feature143', 'feature144', 'feature145', 'feature146', 'feature147', 'feature148', 'feature149', 'feature150', 'feature151', 'feature152', 'feature153', 'feature154', 'feature155', 'feature156', 'feature157', 'feature158', 'feature159', 'feature160', 'feature161', 'feature162', 'feature163', 'feature164', 'feature165', 'feature166', 'feature167', 'feature168', 'feature169', 'feature170', 'feature171', 'feature172', 'feature173', 'feature174', 'feature175', 'feature176', 'feature177', 'feature178', 'feature179', 'feature180', 'feature181', 'feature182', 'feature183', 'feature184', 'feature185', 'feature186', 'feature187', 'feature188', 'feature189', 'feature190', 'feature191', 'feature192', 'feature193', 'feature194', 'feature195', 'feature196', 'feature197', 'feature198', 'feature199', 'feature200', 'feature201', 'feature202', 'feature203', 'feature204', 'feature205', 'feature206', 'feature207', 'feature208', 'feature209', 'feature210', 'feature211', 'feature212', 'feature213', 'feature214', 'feature215', 'feature216', 'feature217', 'feature218', 'feature219', 'feature220', 'feature221', 'feature222', 'feature223', 'feature224', 'feature225', 'feature226', 'feature227', 'feature228', 'feature229', 'feature230', 'feature231', 'feature232', 'feature233', 'feature234', 'feature235', 'feature236', 'feature237', 'feature238', 'feature239', 'feature240', 'feature241', 'feature242', 'feature243', 'feature244', 'feature245', 'feature246', 'feature247', 'feature248', 'feature249', 'feature250', 'feature251', 'feature252', 'feature253', 'feature254', 'feature255', 'feature256', 'feature257', 'feature258', 'feature259', 'feature260', 'feature261', 'feature262', 'feature263', 'feature264', 'feature265', 'feature266', 'feature267', 'feature268', 'feature269', 'feature270', 'feature271', 'feature272', 'feature273', 'feature274', 'feature275', 'feature276', 'feature277', 'feature278', 'feature279', 'feature280', 'feature281', 'feature282', 'feature283', 'feature284', 'feature285', 'feature286', 'feature287', 'feature288', 'feature289', 'feature290', 'feature291', 'feature292', 'feature293', 'feature294', 'feature295', 'feature296', 'feature297', 'feature298', 'feature299', 'feature300', 'feature301', 'feature302', 'feature303', 'feature304', 'feature305', 'feature306', 'feature307', 'feature308', 'feature309', 'feature310', 'feature311', 'feature312', 'feature313', 'feature314', 'feature315', 'feature316', 'feature317', 'feature318', 'feature319', 'feature320', 'feature321', 'feature ...
# MEDIAN_FEATURES: ['feature3', 'feature5', 'feature7', 'feature8', 'feature9', 'feature11', 'feature12', 'feature14', 'feature15', 'feature16', 'feature17', 'feature18', 'feature19', 'feature20', 'feature21', 'feature22', 'feature23', 'feature24', 'feature25', 'feature26', 'feature27', 'feature28', 'feature29', 'feature30', 'feature32', 'feature33', 'feature34', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature42', 'feature43', 'feature79', 'feature80', 'feature81', 'feature82', 'feature350', 'feature351', 'feature352', 'feature353', 'feature354', 'feature370', 'feature371', 'feature372', 'feature378', 'feature379', 'feature380', 'feature381', 'feature382', 'feature383', 'feature384', 'feature385', 'feature386', 'feature387', 'feature388', 'feature389', 'feature390', 'feature391', 'feature392', 'feature393', 'feature394', 'feature395', 'feature396', 'feature397', 'feature398', 'feature399', 'feature400', 'feature401', 'feature402', 'feature403', 'feature404', 'feature405', 'feature406', 'feature407', 'feature408', 'feature409', 'feature410', 'feature411', 'feature412', 'feature413', 'feature414', 'feature415', 'feature416', 'feature417', 'feature418', 'feature419', 'feature420', 'feature449', 'feature450', 'feature451', 'feature452', 'feature453', 'feature454', 'feature455', 'feature456', 'feature457', 'feature469', 'feature470']

# %%
file_path = '../data/patterns.json'

# Read the JSON.
with open(file_path, 'r') as file:
    data = json.load(file)

# Extract keys and convert to integer numbers.
keys_list = [int(key.replace('feature', '')) for key in data.keys()]
drop_numbers = keys_list
print('Extracted Keys:', drop_numbers)
print('Length:', len(drop_numbers))
# Out:
# Extracted Keys: [35, 36, 60, 61, 62, 63, 64, 65, 66, 67, 68, 69, 70, 71, 87, 88, 89, 90, 91, 92, 93, 94, 95, 96, 97, 98]
# Length: 26

# %%
class RemoveBeforeAfterTransformer(BaseEstimator, TransformerMixin):
    def __init__(self):
        self.drop_cols = None

    def fit(self, X, y=None):
        print(X.shape)
        self.drop_cols = [col for col in X.columns if any(f'feature{num}' == col for num in drop_numbers)]
        print(f"Columns to be dropped: {self.drop_cols}")
        return self

    def transform(self, X, y=None):
        print(f"Columns being dropped: {[col for col in self.drop_cols if col in X.columns]}")
        X = X.drop(columns=self.drop_cols, errors='ignore')
        print(X.shape)
        return X

    def get_feature_names_out(self, input_features=None):
        return [f for f in input_features if f not in self.drop_cols]

# %%
def preprocess(preprocessor, train_data, train_labels, quiet=False):
    for k, v in preprocessor.steps:
        print(f"Applying step: {k}")
        print(f"Input shape: {train_data.shape}")
        print(f"Input columns: {train_data.columns}")
        
        if k == 'initial':
            start = time.time()
            v.fit(train_data)
            train_data = pd.DataFrame(v.transform(train_data), columns=v.get_feature_names_out())
            end = time.time()
            if not quiet:
                print(k + ' took ' + str(end - start) + ' to run.')
        elif k == 'oversampling' or k == 'undersampling':
            start = time.time()
            input_features = train_data.columns
            train_data, train_labels = v.fit_resample(train_data, train_labels)
            train_data = pd.DataFrame(train_data, columns=input_features)
            end = time.time()
            if not quiet:
                print(k + ' took ' + str(end - start) + ' to run.')
        else:
            start = time.time()
            v.fit(train_data)
            input_features = train_data.columns
            train_data = pd.DataFrame(v.transform(train_data), columns=v.get_feature_names_out(input_features))
            end = time.time()
            if not quiet:
                print(k + ' took ' + str(end - start) + ' to run.')
        
        print(f"Output shape: {train_data.shape}")
        print(f"Output columns: {train_data.columns}")
        print("---")

    for col in train_data.columns:
        try:
            train_data[col] = train_data[col].astype('float')
        except:
            train_data[col] = train_data[col].astype('category')

    return train_data, train_labels

def transform(test_data, preprocessor, quiet=False):
    for k, v in preprocessor.steps:
        if k == 'initial':
            test_data = pd.DataFrame(v.transform(test_data), columns=v.get_feature_names_out())
        elif k == 'oversampling' or k == 'undersampling':
            continue
        else:
            test_data = v.transform(test_data)
    test_data = pd.DataFrame(test_data)

    for col in test_data.columns:
        try:
            test_data[col] = test_data[col].astype('float')
        except:
            test_data[col] = test_data[col].astype('category')

    return test_data.to_numpy()

# %%
# This is the soft-voting function used to aggregate the predictions.
def soft_vote(preds):
    summed_preds = [[np.sum(preds[:, j][:, i]) for i in range(3)] for j in range(len(preds[0]))]
    return [softmax(np.log(sp)) for sp in summed_preds]

# This is used to drop columns that only contain NaN values.
def drop_allnan(data):
    for col in data.columns:
        if data[col].isna().sum() == len(data):
            data = data.drop(columns=col)
    return data

# %%
NEGONE_FEATURES = ['feature487', 'feature489', 'feature491', 'feature492', 'feature493', 'feature494', 'feature495', 'feature496', 'feature497', 'feature498', 'feature499', 'feature458', 'feature4', 'feature6', 'feature10', 'feature13', 'feature31', 'feature35', 'feature36', 'feature46', 'feature47', 'feature48', 'feature49', 'feature45', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60', 'feature61', 'feature62', 'feature63', 'feature64', 'feature65', 'feature66', 'feature67', 'feature68', 'feature69', 'feature70', 'feature71', 'feature72', 'feature73', 'feature74', 'feature75', 'feature76', 'feature77', 'feature84', 'feature85', 'feature86', 'feature87', 'feature88', 'feature89', 'feature90', 'feature91', 'feature92', 'feature93', 'feature94', 'feature95', 'feature96', 'feature97', 'feature98', 'feature99', 'feature100', 'feature101', 'feature102', 'feature103', 'feature105', 'feature107', 'feature108', 'feature109', 'feature110', 'feature111', 'feature112', 'feature113', 'feature114', 'feature115', 'feature116', 'feature117', 'feature118', 'feature119', 'feature120', 'feature121', 'feature122', 'feature123', 'feature124', 'feature125', 'feature126', 'feature127', 'feature128', 'feature129', 'feature130', 'feature131', 'feature132', 'feature133', 'feature134', 'feature135', 'feature136', 'feature137', 'feature138', 'feature139', 'feature140', 'feature141', 'feature142', 'feature143', 'feature144', 'feature145', 'feature146', 'feature147', 'feature148', 'feature149', 'feature150', 'feature151', 'feature152', 'feature153', 'feature154', 'feature155', 'feature156', 'feature157', 'feature158', 'feature159', 'feature160', 'feature161', 'feature162', 'feature163', 'feature164', 'feature165', 'feature166', 'feature167', 'feature168', 'feature169', 'feature170', 'feature171', 'feature172', 'feature173', 'feature174', 'feature175', 'feature176', 'feature177', 'feature178', 'feature179', 'feature180', 'feature181', 'feature182', 'feature183', 'feature184', 'feature185', 'feature186', 'feature187', 'feature188', 'feature189', 'feature190', 'feature191', 'feature192', 'feature193', 'feature194', 'feature195', 'feature196', 'feature197', 'feature198', 'feature199', 'feature200', 'feature201', 'feature202', 'feature203', 'feature204', 'feature205', 'feature206', 'feature207', 'feature208', 'feature209', 'feature210', 'feature211', 'feature212', 'feature213', 'feature214', 'feature215', 'feature216', 'feature217', 'feature218', 'feature219', 'feature220', 'feature221', 'feature222', 'feature223', 'feature224', 'feature225', 'feature226', 'feature227', 'feature228', 'feature229', 'feature230', 'feature231', 'feature232', 'feature233', 'feature234', 'feature235', 'feature236', 'feature237', 'feature238', 'feature239', 'feature240', 'feature241', 'feature242', 'feature243', 'feature244', 'feature245', 'feature246', 'feature247', 'feature248', 'feature249', 'feature250', 'feature251', 'feature252', 'feature253', 'feature254', 'feature255', 'feature256', 'feature257', 'feature258', 'feature259', 'feature260', 'feature261', 'feature262', 'feature263', 'feature264', 'feature265', 'feature266', 'feature267', 'feature268', 'feature269', 'feature270', 'feature271', 'feature272', 'feature273', 'feature274', 'feature275', 'feature276', 'feature277', 'feature278', 'feature279', 'feature280', 'feature281', 'feature282', 'feature283', 'feature284', 'feature285', 'feature286', 'feature287', 'feature288', 'feature289', 'feature290', 'feature291', 'feature292', 'feature293', 'feature294', 'feature295', 'feature296', 'feature297', 'feature298', 'feature299', 'feature300', 'feature301', 'feature302', 'feature303', 'feature304', 'feature305', 'feature306', 'feature307', 'feature308', 'feature309', 'feature310', 'feature311', 'feature312', 'feature313', 'feature314', 'feature315', 'feature316', 'feature317', 'feature318', 'feature319', 'feature320', 'feature321', 'feature322', 'feature323', 'feature324', 'feature325', 'feature326', 'feature327', 'feature328', 'feature329', 'feature330', 'feature331', 'feature332', 'feature333', 'feature334', 'feature335', 'feature336', 'feature337', 'feature338', 'feature339', 'feature340', 'feature341', 'feature342', 'feature343', 'feature344', 'feature345', 'feature346', 'feature347', 'feature348', 'feature349', 'feature355', 'feature356', 'feature357', 'feature358', 'feature359', 'feature360', 'feature361', 'feature362', 'feature363', 'feature364', 'feature365', 'feature366', 'feature367', 'feature368', 'feature369', 'feature373', 'feature374', 'feature375', 'feature376', 'feature421', 'feature422', 'feature423', 'feature424', 'feature425', 'feature426', 'feature427', 'feature428', 'feature429', 'feature430', 'feature431', 'feature432', 'feature433', 'feature434', 'feature435', 'feature436', 'feature437', 'feature438', 'feature439', 'feature440', 'feature441', 'feature442', 'feature443', 'feature444', 'feature445', 'feature446', 'feature447', 'feature448', 'feature459', 'feature460', 'feature461', 'feature462', 'feature463', 'feature464', 'feature465', 'feature466', 'feature467', 'feature471', 'feature472', 'feature473', 'feature474', 'feature475', 'feature476', 'feature477', 'feature478', 'feature479', 'feature480', 'feature481', 'feature482', 'feature483', 'feature484', 'feature485', 'feature486']
MEDIAN_FEATURES = ['feature3', 'feature5', 'feature7', 'feature8', 'feature9', 'feature11', 'feature12', 'feature14', 'feature15', 'feature16', 'feature17', 'feature18', 'feature19', 'feature20', 'feature21', 'feature22', 'feature23', 'feature24', 'feature25', 'feature26', 'feature27', 'feature28', 'feature29', 'feature30', 'feature32', 'feature33', 'feature34', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature42', 'feature43', 'feature79', 'feature80', 'feature81', 'feature82', 'feature350', 'feature351', 'feature352', 'feature353', 'feature354', 'feature370', 'feature371', 'feature372', 'feature378', 'feature379', 'feature380', 'feature381', 'feature382', 'feature383', 'feature384', 'feature385', 'feature386', 'feature387', 'feature388', 'feature389', 'feature390', 'feature391', 'feature392', 'feature393', 'feature394', 'feature395', 'feature396', 'feature397', 'feature398', 'feature399', 'feature400', 'feature401', 'feature402', 'feature403', 'feature404', 'feature405', 'feature406', 'feature407', 'feature408', 'feature409', 'feature410', 'feature411', 'feature412', 'feature413', 'feature414', 'feature415', 'feature416', 'feature417', 'feature418', 'feature419', 'feature420', 'feature449', 'feature450', 'feature451', 'feature452', 'feature453', 'feature454', 'feature455', 'feature456', 'feature457', 'feature469', 'feature470']

# %%
""" Iterate through the entire testing script for each subeset DataFrame in the dictionary. """

for number in range(1, 500):  
    print(f"Processing model {number}")
    
    # Load both datasets.
    data = pd.read_csv(f'../data/ranked_subsets/test_features_csv/test_{number}_features.csv', low_memory=False)
    print(f'Shape of data: {data.shape}')
    X_train = pd.read_csv(f'../data/ranked_subsets/train_features_csv/top_{number}_features.csv', low_memory=False)
    print(f'Shape of X_train: {X_train.shape}')

    model_name = f'lgbm_df{number}'
    model_path = f'models/{model_name}'
    output_path = f'results/{model_name}.csv'
    metrics_path = f'metrics/{model_name}_metrics.csv'
    report_path = f'metrics/report/{model_name}_report.csv'
    matrix_path = f'metrics/matrix/{model_name}_matrix.csv'

    # These lists are used to determine imputation strategies for the specified features (inherited from LoGoFunc)
    NEGONE_FEATURES = ['feature487', 'feature489', 'feature491', 'feature492', 'feature493', 'feature494', 'feature495', 'feature496', 'feature497', 'feature498', 'feature499', 'feature458', 'feature4', 'feature6', 'feature10', 'feature13', 'feature31', 'feature35', 'feature36', 'feature46', 'feature47', 'feature48', 'feature49', 'feature45', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60', 'feature61', 'feature62', 'feature63', 'feature64', 'feature65', 'feature66', 'feature67', 'feature68', 'feature69', 'feature70', 'feature71', 'feature72', 'feature73', 'feature74', 'feature75', 'feature76', 'feature77', 'feature84', 'feature85', 'feature86', 'feature87', 'feature88', 'feature89', 'feature90', 'feature91', 'feature92', 'feature93', 'feature94', 'feature95', 'feature96', 'feature97', 'feature98', 'feature99', 'feature100', 'feature101', 'feature102', 'feature103', 'feature105', 'feature107', 'feature108', 'feature109', 'feature110', 'feature111', 'feature112', 'feature113', 'feature114', 'feature115', 'feature116', 'feature117', 'feature118', 'feature119', 'feature120', 'feature121', 'feature122', 'feature123', 'feature124', 'feature125', 'feature126', 'feature127', 'feature128', 'feature129', 'feature130', 'feature131', 'feature132', 'feature133', 'feature134', 'feature135', 'feature136', 'feature137', 'feature138', 'feature139', 'feature140', 'feature141', 'feature142', 'feature143', 'feature144', 'feature145', 'feature146', 'feature147', 'feature148', 'feature149', 'feature150', 'feature151', 'feature152', 'feature153', 'feature154', 'feature155', 'feature156', 'feature157', 'feature158', 'feature159', 'feature160', 'feature161', 'feature162', 'feature163', 'feature164', 'feature165', 'feature166', 'feature167', 'feature168', 'feature169', 'feature170', 'feature171', 'feature172', 'feature173', 'feature174', 'feature175', 'feature176', 'feature177', 'feature178', 'feature179', 'feature180', 'feature181', 'feature182', 'feature183', 'feature184', 'feature185', 'feature186', 'feature187', 'feature188', 'feature189', 'feature190', 'feature191', 'feature192', 'feature193', 'feature194', 'feature195', 'feature196', 'feature197', 'feature198', 'feature199', 'feature200', 'feature201', 'feature202', 'feature203', 'feature204', 'feature205', 'feature206', 'feature207', 'feature208', 'feature209', 'feature210', 'feature211', 'feature212', 'feature213', 'feature214', 'feature215', 'feature216', 'feature217', 'feature218', 'feature219', 'feature220', 'feature221', 'feature222', 'feature223', 'feature224', 'feature225', 'feature226', 'feature227', 'feature228', 'feature229', 'feature230', 'feature231', 'feature232', 'feature233', 'feature234', 'feature235', 'feature236', 'feature237', 'feature238', 'feature239', 'feature240', 'feature241', 'feature242', 'feature243', 'feature244', 'feature245', 'feature246', 'feature247', 'feature248', 'feature249', 'feature250', 'feature251', 'feature252', 'feature253', 'feature254', 'feature255', 'feature256', 'feature257', 'feature258', 'feature259', 'feature260', 'feature261', 'feature262', 'feature263', 'feature264', 'feature265', 'feature266', 'feature267', 'feature268', 'feature269', 'feature270', 'feature271', 'feature272', 'feature273', 'feature274', 'feature275', 'feature276', 'feature277', 'feature278', 'feature279', 'feature280', 'feature281', 'feature282', 'feature283', 'feature284', 'feature285', 'feature286', 'feature287', 'feature288', 'feature289', 'feature290', 'feature291', 'feature292', 'feature293', 'feature294', 'feature295', 'feature296', 'feature297', 'feature298', 'feature299', 'feature300', 'feature301', 'feature302', 'feature303', 'feature304', 'feature305', 'feature306', 'feature307', 'feature308', 'feature309', 'feature310', 'feature311', 'feature312', 'feature313', 'feature314', 'feature315', 'feature316', 'feature317', 'feature318', 'feature319', 'feature320', 'feature321', 'feature322', 'feature323', 'feature324', 'feature325', 'feature326', 'feature327', 'feature328', 'feature329', 'feature330', 'feature331', 'feature332', 'feature333', 'feature334', 'feature335', 'feature336', 'feature337', 'feature338', 'feature339', 'feature340', 'feature341', 'feature342', 'feature343', 'feature344', 'feature345', 'feature346', 'feature347', 'feature348', 'feature349', 'feature355', 'feature356', 'feature357', 'feature358', 'feature359', 'feature360', 'feature361', 'feature362', 'feature363', 'feature364', 'feature365', 'feature366', 'feature367', 'feature368', 'feature369', 'feature373', 'feature374', 'feature375', 'feature376', 'feature421', 'feature422', 'feature423', 'feature424', 'feature425', 'feature426', 'feature427', 'feature428', 'feature429', 'feature430', 'feature431', 'feature432', 'feature433', 'feature434', 'feature435', 'feature436', 'feature437', 'feature438', 'feature439', 'feature440', 'feature441', 'feature442', 'feature443', 'feature444', 'feature445', 'feature446', 'feature447', 'feature448', 'feature459', 'feature460', 'feature461', 'feature462', 'feature463', 'feature464', 'feature465', 'feature466', 'feature467', 'feature471', 'feature472', 'feature473', 'feature474', 'feature475', 'feature476', 'feature477', 'feature478', 'feature479', 'feature480', 'feature481', 'feature482', 'feature483', 'feature484', 'feature485', 'feature486']
    MEDIAN_FEATURES = ['feature3', 'feature5', 'feature7', 'feature8', 'feature9', 'feature11', 'feature12', 'feature14', 'feature15', 'feature16', 'feature17', 'feature18', 'feature19', 'feature20', 'feature21', 'feature22', 'feature23', 'feature24', 'feature25', 'feature26', 'feature27', 'feature28', 'feature29', 'feature30', 'feature32', 'feature33', 'feature34', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature42', 'feature43', 'feature79', 'feature80', 'feature81', 'feature82', 'feature350', 'feature351', 'feature352', 'feature353', 'feature354', 'feature370', 'feature371', 'feature372', 'feature378', 'feature379', 'feature380', 'feature381', 'feature382', 'feature383', 'feature384', 'feature385', 'feature386', 'feature387', 'feature388', 'feature389', 'feature390', 'feature391', 'feature392', 'feature393', 'feature394', 'feature395', 'feature396', 'feature397', 'feature398', 'feature399', 'feature400', 'feature401', 'feature402', 'feature403', 'feature404', 'feature405', 'feature406', 'feature407', 'feature408', 'feature409', 'feature410', 'feature411', 'feature412', 'feature413', 'feature414', 'feature415', 'feature416', 'feature417', 'feature418', 'feature419', 'feature420', 'feature449', 'feature450', 'feature451', 'feature452', 'feature453', 'feature454', 'feature455', 'feature456', 'feature457', 'feature469', 'feature470']


    # Filter NEGONE_FEATURES and MEDIAN_FEATURES based on current X_train columns.
    negone_features_filtered = [feature for feature in NEGONE_FEATURES if feature in X_train.columns]
    median_features_filtered = [feature for feature in MEDIAN_FEATURES if feature in X_train.columns]

    # Redefine NEGONE_FEATURES and MEDIAN_FEATURES with updated values.
    NEGONE_FEATURES = negone_features_filtered
    MEDIAN_FEATURES = median_features_filtered

    print("Filtered NEGONE_FEATURES:", NEGONE_FEATURES)
    print("Filtered MEDIAN_FEATURES:", MEDIAN_FEATURES)

    def generate_preprocessor(numeric_features, categorical_features, N_JOBS, cat_encode_type, 
                            do_specificimpute, do_featureselection, 
                            do_sampling, do_pca, var_thresh, oversample_technique, 
                            negone_features=NEGONE_FEATURES, median_features=MEDIAN_FEATURES,
                            prefix='', do_feature_subset=False, max_features=1, do_removeppi=False, do_removegtex=False):
        cat_encoders = [OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1, encoded_missing_value=-1), 
                        OneHotEncoder(sparse=False, handle_unknown='infrequent_if_exist', min_frequency=10)]
        categorical_transformer = cat_encoders[cat_encode_type]

        numeric_transformer = Pipeline(steps=[
            ('imputer', SimpleImputer(strategy='median')),
            ('scaler', MinMaxScaler(feature_range =(0, 1), clip=True))])

        median_transformer = Pipeline(steps=[
            ('imputer', SimpleImputer(strategy='median')),
            ('scaler', MinMaxScaler(feature_range =(0, 1), clip=True))])

        negone_transformer = Pipeline(steps=[
            ('scaler', MinMaxScaler(feature_range =(0, 1), clip=True)),
            ('imputer', SimpleImputer(strategy='constant', fill_value=-1)),
        ])

        preprocessor = None
        if do_specificimpute:
            preprocessor = ColumnTransformer(
                transformers=[
                    ('median', median_transformer, median_features),
                    ('negone', negone_transformer, negone_features),
                    ('cat', categorical_transformer, categorical_features),
            ])
        else:
            preprocessor = ColumnTransformer(
                transformers=[
                    ('numeric', numeric_transformer, numeric_features),
                    ('cat', categorical_transformer, categorical_features),
                ])

        vt = VarianceThreshold(threshold=var_thresh)
        steps = [('initial', preprocessor), ('removeba', RemoveBeforeAfterTransformer()), ('variance_threshold', vt)]
        if do_sampling == 1:
            steps.append(('undersampling', RandomUnderSampler(random_state=42)))
        if do_sampling == 2:
            oversamplers = [SMOTE(n_jobs=N_JOBS,random_state=42), RandomOverSampler(random_state=42)]
            steps.append(('oversampling', oversamplers[oversample_technique]))
        if do_pca:
            steps.append(('pca', PCA()))

        preprocessor = Pipeline(steps=steps)
        return preprocessor

    X_test = data
    y_test = pd.read_csv('../data/y_test_id.csv', low_memory=False)
    model_type = 'lgb'
    num_models = 27

    features = X_test.columns.tolist()
    print(features)

    # Load training data and extract columns (features).
    X_train = drop_allnan(X_train)
    columns = X_train.columns.tolist()

    # Pre-processor generation with multiple parameters that can be tweaked. I used the same values as LoGoFunc
    preprocessor = joblib.load(f'{model_path}/preprocessor.joblib')

    # Iterate over the models in the ensemble.
    models = []
    num_models = 27  
    for i in range(num_models):
        models.append(joblib.load(f'{model_path}/{model_type}_model_{i}.joblib'))

    # This encodes the IMPACT feature's column, then drops the ID column.
    if 'feature1' in features:
        feature1_vals = {'LOW': 0, 'MODIFIER': 1, 'MODERATE': 1.5, 'HIGH': 2}
        encoded_feature1s = [feature1_vals[imp] for imp in X_test['feature1']]
        X_test = X_test.drop(columns=['feature1'])
        X_test['feature1'] = encoded_feature1s
    X_test = X_test[columns]
    ids = X_test['feature0'].tolist()
    X_test = X_test.drop(columns='feature0')

    # Make sure the data types are the same, because NumPy arrays are not tolerated in places where DataFrames are expected.
    for col in X_test.columns:
        X_test[col] = X_test[col].astype(X_train[col].dtype)

    # Pre-process the test data.
    X_test = transform(X_test, preprocessor)

    # Pool the predictions into a list.
    all_preds = []
    for i in range(num_models):
        preds = models[i].predict(X_test)  
        all_preds.append(preds)

    # Apply the soft-voting function.
    y_pred_proba = soft_vote(np.array(all_preds))
    y_pred = [np.argmax(p) for p in y_pred_proba]

    # Map the labels to numbers.
    label_mapping = {'Neutral': 0, 'GOF': 1, 'LOF': 2}
    y_test_numeric = [label_mapping[label] for label in y_test['label']]

    # Compute class-wise MCC.
    mcc_per_class = {}
    for i, class_name in enumerate(['Neutral', 'GOF', 'LOF']):
        y_true_binary = (np.array(y_test_numeric) == i).astype(int)
        y_pred_binary = (np.array(y_pred) == i).astype(int)
        mcc_per_class[class_name] = matthews_corrcoef(y_true_binary, y_pred_binary)

    overall_mcc = matthews_corrcoef(y_test_numeric, y_pred)

    print("Per-class MCC:")
    for class_name, mcc_value in mcc_per_class.items():
        print(f"{class_name}: {mcc_value:.4f}")
    print(f"Overall MCC: {overall_mcc:.4f}")
    
    def format_confusion_matrix(conf_matrix):
        return "\n".join([",".join(map(str, row)) for row in conf_matrix])

    # Perform the evaluation using SciKit-learn's metrics.
    accuracy = accuracy_score(y_test_numeric, y_pred)
    precision = precision_score(y_test_numeric, y_pred, average='weighted')
    recall = recall_score(y_test_numeric, y_pred, average='weighted')
    f1 = f1_score(y_test_numeric, y_pred, average='weighted')
    roc_auc = roc_auc_score(y_test_numeric, y_pred_proba, multi_class='ovo')
    conf_matrix = confusion_matrix(y_test_numeric, y_pred)

    # Print the recorded metrics.
    print(f'Model {number} - Test Accuracy: {accuracy}')
    print(f'Model {number} - Test Precision: {precision}')
    print(f'Model {number} - Test Recall: {recall}')
    print(f'Model {number} - Test F1 Score: {f1}')
    print(f'Model {number} - Test ROC AUC Score: {roc_auc}')

    # Compute the remaining class-wise metrics.
    report = classification_report(y_test_numeric, y_pred, target_names=['Neutral', 'GOF', 'LOF'])
    print(report)
    custom_report = classification_report(y_test_numeric, y_pred, target_names=['Neutral', 'GOF', 'LOF'])
    custom_report += "\n\nPer-class MCC:\n"
    for class_name, mcc_value in mcc_per_class.items():
        custom_report += f"{class_name}: {mcc_value:.4f}\n"
    print(custom_report)

    # Export the metrics to a CSV.
    metrics_df = pd.DataFrame({
        'Model': [number],
        'Accuracy': [accuracy],
        'Precision': [precision],
        'Recall': [recall],
        'F1 Score': [f1],
        'ROC AUC Score': [roc_auc],
        'Overall MCC': [overall_mcc]
    })
    metrics_df.to_csv(metrics_path, index=False)
    print(f"Metrics for model {number} saved to {metrics_path}")

    # Export classification report to CSV.
    report_df = pd.DataFrame({
        'Classification Report': [custom_report]
    })
    report_df.to_csv(report_path, index=False, quoting=0)
    print(f"Report for model {number} saved to {report_path}")

    # Generate the confusion matrix.
    matrix_df = pd.DataFrame(conf_matrix, 
                            columns=['Predicted Neutral', 'Predicted GOF', 'Predicted LOF'],
                            index=['Actual Neutral', 'Actual GOF', 'Actual LOF'])

    # Export matrix to CSV.
    matrix_df.to_csv(matrix_path, quoting=0)
    print(f"Confusion Matrix for model {number} saved to {matrix_path}")

    out = []
    for i in range(len(y_pred)):
        out.append([ids[i], ['Neutral', 'GOF', 'LOF'][y_pred[i]], *y_pred_proba[i]])
    out = pd.DataFrame(out, columns=['feature0', 'prediction', 'LoGoFunc_Neutral', 'LoGoFunc_GOF', 'LoGoFunc_LOF'])
    out.to_csv(output_path, index=None)

    print(f"Results for model {number} saved to {output_path}")
    print("---------------------------------------------------")
# Out:
# Processing model 1
# Shape of data: (2831, 2)
# Shape of X_train: (25546, 2)
# Filtered NEGONE_FEATURES: []
# Filtered MEDIAN_FEATURES: []
# ['feature0', 'feature35']
# Columns being dropped: []
# (2831, 1)
# Per-class MCC:
# Neutral: 0.1988
# GOF: 0.0877
# LOF: 0.0088
# Overall MCC: 0.1123
# Model 1 - Test Accuracy: 0.18014835747085836
# Model 1 - Test Precision: 0.5728082844099459
# Model 1 - Test Recall: 0.18014835747085836
# Model 1 - Test F1 Score: 0.19498821732382018
# Model 1 - Test ROC AUC Score: 0.5661263520454407
#               precision    recall  f1-score   support
#
#      Neutral       0.68      0.26      0.38      1339
#          GOF       0.06      0.95      0.12       152
#          LOF       0.52      0.01      0.02      1340
#
#     accuracy                           0.18      2831
#    macro avg       0.42      0.41      0.17      2831
# weighted avg       0.57      0.18      0.19      2831
#
#               precision    recall  f1-score   support
#
#      Neutral       0.68      0.26      0.38      1339
#          GOF       0.06      0.95      0.12       152
#          LOF       0.52      0.01      0.02      1340
#
#     accuracy                           0.18      2831
#    macro avg       0.42      0.41      0.17      2831
# weighted avg       0.57      0.18      0.19      2831
#
#
# Per-class MCC:
# Neutral: 0.1988
# GOF: 0.0877
# LOF: 0.0088
#
# Metrics for model 1 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/lgbm_df1_metrics.csv
# Report for model 1 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/report/lgbm_df1_report.csv
# Confusion Matrix for model 1 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/matrix/lgbm_df1_matrix.csv
# Results for model 1 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/results/lgbm_df1.csv
# ---------------------------------------------------
# Processing model 2
# Shape of data: (2831, 3)
# Shape of X_train: (25546, 3)
# Filtered NEGONE_FEATURES: []
# Filtered MEDIAN_FEATURES: []
# ['feature0', 'feature35', 'feature95']
# Columns being dropped: []
# (2831, 2)
# Per-class MCC:
# Neutral: 0.5189
# GOF: 0.0752
# LOF: 0.2240
# Overall MCC: 0.3131
# Model 2 - Test Accuracy: 0.5411515365595196
# Model 2 - Test Precision: 0.6737149977125438
# Model 2 - Test Recall: 0.5411515365595196
# Model 2 - Test F1 Score: 0.5777248303722698
# Model 2 - Test ROC AUC Score: 0.685172193110545
#               precision    recall  f1-score   support
#
#      Neutral       0.75      0.75      0.75      1339
#          GOF       0.08      0.42      0.14       152
#          LOF       0.67      0.35      0.46      1340
#
#     accuracy                           0.54      2831
#    macro avg       0.50      0.51      0.45      2831
# weighted avg       0.67      0.54      0.58      2831
#
#               precision    recall  f1-score   support
#
#      Neutral       0.75      0.75      0.75      1339
#          GOF       0.08      0.42      0.14       152
#          LOF       0.67      0.35      0.46      1340
#
#     accuracy                           0.54      2831
#    macro avg       0.50      0.51      0.45      2831
# weighted avg       0.67      0.54      0.58      2831
#
#
# Per-class MCC:
# Neutral: 0.5189
# GOF: 0.0752
# LOF: 0.2240
#
# Metrics for model 2 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/lgbm_df2_metrics.csv
# Report for model 2 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/report/lgbm_df2_report.csv
# Confusion Matrix for model 2 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/matrix/lgbm_df2_matrix.csv
# Results for model 2 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/results/lgbm_df2.csv
# ---------------------------------------------------
# Processing model 3
# Shape of data: (2831, 4)
# Shape of X_train: (25546, 4)
# Filtered NEGONE_FEATURES: []
# Filtered MEDIAN_FEATURES: []
# ['feature0', 'feature35', 'feature95', 'feature351']
# Columns being dropped: []
# (2831, 3)
# Per-class MCC:
# Neutral: 0.4760
# GOF: 0.3051
# LOF: 0.3675
# Overall MCC: 0.3870
# Model 3 - Test Accuracy: 0.596255740021194
# Model 3 - Test Precision: 0.720940316982882
# Model 3 - Test Recall: 0.596255740021194
# Model 3 - Test F1 Score: 0.635409211897755
# Model 3 - Test ROC AUC Score: 0.8185862902039859
#               precision    recall  f1-score   support
#
#      Neutral       0.81      0.57      0.67      1339
#          GOF       0.17      0.82      0.28       152
#          LOF       0.69      0.60      0.64      1340
#
#     accuracy                           0.60      2831
#    macro avg       0.56      0.66      0.53      2831
# weighted avg       0.72      0.60      0.64      2831
#
#               precision    recall  f1-score   support
#
#      Neutral       0.81      0.57      0.67      1339
#          GOF       0.17      0.82      0.28       152
#          LOF       0.69      0.60      0.64      1340
#
#     accuracy                           0.60      2831
#    macro avg       0.56      0.66      0.53      2831
# weighted avg       0.72      0.60      0.64      2831
#
#
# Per-class MCC:
# Neutral: 0.4760
# GOF: 0.3051
# LOF: 0.3675
#
# Metrics for model 3 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/lgbm_df3_metrics.csv
# Report for model 3 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/report/lgbm_df3_report.csv
# Confusion Matrix for model 3 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/matrix/lgbm_df3_matrix.csv
# Results for model 3 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/results/lgbm_df3.csv
# ---------------------------------------------------
# Processing model 4
# Shape of data: (2831, 5)
# Shape of X_train: (25546, 5)
# Filtered NEGONE_FEATURES: []
# Filtered MEDIAN_FEATURES: []
# ['feature0', 'feature35', 'feature95', 'feature351', 'feature453']
# Columns being dropped: []
# (2831, 4)
# Per-class MCC:
# Neutral: 0.5560
# GOF: 0.3900
# LOF: 0.3734
# Overall MCC: 0.4439
# Model 4 - Test Accuracy: 0.6541858000706464
# Model 4 - Test Precision: 0.7254384689670919
# Model 4 - Test Recall: 0.6541858000706464
# Model 4 - Test F1 Score: 0.6759063928716673
# Model 4 - Test ROC AUC Score: 0.8459142284822105
#               precision    recall  f1-score   support
#
#      Neutral       0.80      0.72      0.75      1339
#          GOF       0.23      0.84      0.36       152
#          LOF       0.71      0.57      0.63      1340
#
#     accuracy                           0.65      2831
#    macro avg       0.58      0.71      0.58      2831
# weighted avg       0.73      0.65      0.68      2831
#
#               precision    recall  f1-score   support
#
#      Neutral       0.80      0.72      0.75      1339
#          GOF       0.23      0.84      0.36       152
#          LOF       0.71      0.57      0.63      1340
#
#     accuracy                           0.65      2831
#    macro avg       0.58      0.71      0.58      2831
# weighted avg       0.73      0.65      0.68      2831
#
#
# Per-class MCC:
# Neutral: 0.5560
# GOF: 0.3900
# LOF: 0.3734
#
# Metrics for model 4 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/lgbm_df4_metrics.csv
# Report for model 4 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/report/lgbm_df4_report.csv
# Confusion Matrix for model 4 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/matrix/lgbm_df4_matrix.csv
# Results for model 4 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/results/lgbm_df4.csv
# ---------------------------------------------------
# Processing model 5
# Shape of data: (2831, 6)
# Shape of X_train: (25546, 6)
# Filtered NEGONE_FEATURES: []
# Filtered MEDIAN_FEATURES: []
# ['feature0', 'feature35', 'feature95', 'feature351', 'feature453', 'feature458']
# Columns being dropped: []
# (2831, 5)
# Per-class MCC:
# Neutral: 0.5652
# GOF: 0.3899
# LOF: 0.4000
# Overall MCC: 0.4597
# Model 5 - Test Accuracy: 0.6623101377605086
# Model 5 - Test Precision: 0.7343294524234736
# Model 5 - Test Recall: 0.6623101377605086
# Model 5 - Test F1 Score: 0.6796461750265318
# Model 5 - Test ROC AUC Score: 0.8599229021699021
#               precision    recall  f1-score   support
#
#      Neutral       0.77      0.78      0.77      1339
#          GOF       0.23      0.84      0.37       152
#          LOF       0.76      0.53      0.62      1340
#
#     accuracy                           0.66      2831
#    macro avg       0.59      0.71      0.59      2831
# weighted avg       0.73      0.66      0.68      2831
#
#               precision    recall  f1-score   support
#
#      Neutral       0.77      0.78      0.77      1339
#          GOF       0.23      0.84      0.37       152
#          LOF       0.76      0.53      0.62      1340
#
#     accuracy                           0.66      2831
#    macro avg       0.59      0.71      0.59      2831
# weighted avg       0.73      0.66      0.68      2831
#
#
# Per-class MCC:
# Neutral: 0.5652
# GOF: 0.3899
# LOF: 0.4000
#
# Metrics for model 5 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/lgbm_df5_metrics.csv
# Report for model 5 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/report/lgbm_df5_report.csv
# Confusion Matrix for model 5 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/matrix/lgbm_df5_matrix.csv
# Results for model 5 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/results/lgbm_df5.csv
# ---------------------------------------------------
# Processing model 6
# Shape of data: (2831, 7)
# Shape of X_train: (25546, 7)
# Filtered NEGONE_FEATURES: []
# Filtered MEDIAN_FEATURES: []
# ['feature0', 'feature35', 'feature95', 'feature351', 'feature453', 'feature458', 'feature10']
# Columns being dropped: []
# (2831, 6)
# Per-class MCC:
# Neutral: 0.5675
# GOF: 0.3954
# LOF: 0.3968
# Overall MCC: 0.4607
# Model 6 - Test Accuracy: 0.6640762981278701
# Model 6 - Test Precision: 0.7330045134280004
# Model 6 - Test Recall: 0.6640762981278701
# Model 6 - Test F1 Score: 0.6801729801355892
# Model 6 - Test ROC AUC Score: 0.8610925677760718
#               precision    recall  f1-score   support
#
#      Neutral       0.77      0.78      0.77      1339
#          GOF       0.24      0.84      0.37       152
#          LOF       0.75      0.53      0.62      1340
#
#     accuracy                           0.66      2831
#    macro avg       0.59      0.71      0.59      2831
# weighted avg       0.73      0.66      0.68      2831
#
#               precision    recall  f1-score   support
#
#      Neutral       0.77      0.78      0.77      1339
#          GOF       0.24      0.84      0.37       152
#          LOF       0.75      0.53      0.62      1340
#
#     accuracy                           0.66      2831
#    macro avg       0.59      0.71      0.59      2831
# weighted avg       0.73      0.66      0.68      2831
#
#
# Per-class MCC:
# Neutral: 0.5675
# GOF: 0.3954
# LOF: 0.3968
#
# Metrics for model 6 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/lgbm_df6_metrics.csv
# Report for model 6 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/report/lgbm_df6_report.csv
# Confusion Matrix for model 6 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/matrix/lgbm_df6_matrix.csv
# Results for model 6 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/results/lgbm_df6.csv
# ---------------------------------------------------
# Processing model 7
# Shape of data: (2831, 8)
# Shape of X_train: (25546, 8)
# Filtered NEGONE_FEATURES: []
# Filtered MEDIAN_FEATURES: []
# ['feature0', 'feature35', 'feature95', 'feature351', 'feature453', 'feature458', 'feature10', 'feature93']
# Columns being dropped: []
# (2831, 7)
# Per-class MCC:
# Neutral: 0.5620
# GOF: 0.3999
# LOF: 0.3959
# Overall MCC: 0.4590
# Model 7 - Test Accuracy: 0.6640762981278701
# Model 7 - Test Precision: 0.7306525324001661
# Model 7 - Test Recall: 0.6640762981278701
# Model 7 - Test F1 Score: 0.6793070177334081
# Model 7 - Test ROC AUC Score: 0.8609831789863621
#               precision    recall  f1-score   support
#
#      Neutral       0.76      0.78      0.77      1339
#          GOF       0.24      0.84      0.38       152
#          LOF       0.75      0.53      0.62      1340
#
#     accuracy                           0.66      2831
#    macro avg       0.59      0.71      0.59      2831
# weighted avg       0.73      0.66      0.68      2831
#
#               precision    recall  f1-score   support
#
#      Neutral       0.76      0.78      0.77      1339
#          GOF       0.24      0.84      0.38       152
#          LOF       0.75      0.53      0.62      1340
#
#     accuracy                           0.66      2831
#    macro avg       0.59      0.71      0.59      2831
# weighted avg       0.73      0.66      0.68      2831
#
#
# Per-class MCC:
# Neutral: 0.5620
# GOF: 0.3999
# LOF: 0.3959
#
# Metrics for model 7 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/lgbm_df7_metrics.csv
# Report for model 7 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/report/lgbm_df7_report.csv
# Confusion Matrix for model 7 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/matrix/lgbm_df7_matrix.csv
# Results for model 7 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/results/lgbm_df7.csv
# ---------------------------------------------------
# Processing model 8
# Shape of data: (2831, 9)
# Shape of X_train: (25546, 9)
# Filtered NEGONE_FEATURES: []
# Filtered MEDIAN_FEATURES: []
# ['feature0', 'feature35', 'feature95', 'feature351', 'feature453', 'feature458', 'feature10', 'feature93', 'feature492']
# Columns being dropped: []
# (2831, 8)
# Per-class MCC:
# Neutral: 0.5645
# GOF: 0.4005
# LOF: 0.3972
# Overall MCC: 0.4606
# Model 8 - Test Accuracy: 0.6654892264217591
# Model 8 - Test Precision: 0.7315235455042575
# Model 8 - Test Recall: 0.6654892264217591
# Model 8 - Test F1 Score: 0.6812657756709599
# Model 8 - Test ROC AUC Score: 0.8612378208110424
#               precision    recall  f1-score   support
#
#      Neutral       0.77      0.78      0.77      1339
#          GOF       0.24      0.84      0.38       152
#          LOF       0.75      0.54      0.63      1340
#
#     accuracy                           0.67      2831
#    macro avg       0.59      0.72      0.59      2831
# weighted avg       0.73      0.67      0.68      2831
#
#               precision    recall  f1-score   support
#
#      Neutral       0.77      0.78      0.77      1339
#          GOF       0.24      0.84      0.38       152
#          LOF       0.75      0.54      0.63      1340
#
#     accuracy                           0.67      2831
#    macro avg       0.59      0.72      0.59      2831
# weighted avg       0.73      0.67      0.68      2831
#
#
# Per-class MCC:
# Neutral: 0.5645
# GOF: 0.4005
# LOF: 0.3972
#
# Metrics for model 8 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/lgbm_df8_metrics.csv
# Report for model 8 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/report/lgbm_df8_report.csv
# Confusion Matrix for model 8 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/matrix/lgbm_df8_matrix.csv
# Results for model 8 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/results/lgbm_df8.csv
# ---------------------------------------------------
# Processing model 9
# Shape of data: (2831, 10)
# Shape of X_train: (25546, 10)
# Filtered NEGONE_FEATURES: []
# Filtered MEDIAN_FEATURES: []
# ['feature0', 'feature35', 'feature95', 'feature351', 'feature453', 'feature458', 'feature10', 'feature93', 'feature492', 'feature97']
# Columns being dropped: []
# (2831, 9)
# Per-class MCC:
# Neutral: 0.5638
# GOF: 0.4030
# LOF: 0.3958
# Overall MCC: 0.4600
# Model 9 - Test Accuracy: 0.6647827622748146
# Model 9 - Test Precision: 0.7312227130255587
# Model 9 - Test Recall: 0.6647827622748146
# Model 9 - Test F1 Score: 0.6805516359339835
# Model 9 - Test ROC AUC Score: 0.8598181174871291
#               precision    recall  f1-score   support
#
#      Neutral       0.77      0.78      0.77      1339
#          GOF       0.24      0.84      0.38       152
#          LOF       0.75      0.53      0.62      1340
#
#     accuracy                           0.66      2831
#    macro avg       0.59      0.72      0.59      2831
# weighted avg       0.73      0.66      0.68      2831
#
#               precision    recall  f1-score   support
#
#      Neutral       0.77      0.78      0.77      1339
#          GOF       0.24      0.84      0.38       152
#          LOF       0.75      0.53      0.62      1340
#
#     accuracy                           0.66      2831
#    macro avg       0.59      0.72      0.59      2831
# weighted avg       0.73      0.66      0.68      2831
#
#
# Per-class MCC:
# Neutral: 0.5638
# GOF: 0.4030
# LOF: 0.3958
#
# Metrics for model 9 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/lgbm_df9_metrics.csv
# Report for model 9 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/report/lgbm_df9_report.csv
# Confusion Matrix for model 9 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/matrix/lgbm_df9_matrix.csv
# Results for model 9 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/results/lgbm_df9.csv
# ---------------------------------------------------
# Processing model 10
# Shape of data: (2831, 11)
# Shape of X_train: (25546, 11)
# Filtered NEGONE_FEATURES: []
# Filtered MEDIAN_FEATURES: []
# ['feature0', 'feature35', 'feature95', 'feature351', 'feature453', 'feature458', 'feature10', 'feature93', 'feature492', 'feature97', 'feature60']
# Columns being dropped: []
# (2831, 10)
# Per-class MCC:
# Neutral: 0.5609
# GOF: 0.4110
# LOF: 0.3886
# Overall MCC: 0.4580
# Model 10 - Test Accuracy: 0.6658424584952314
# Model 10 - Test Precision: 0.7263963807804675
# Model 10 - Test Recall: 0.6658424584952314
# Model 10 - Test F1 Score: 0.6789307029300361
# Model 10 - Test ROC AUC Score: 0.8608892867381579
#               precision    recall  f1-score   support
#
#      Neutral       0.76      0.78      0.77      1339
#          GOF       0.25      0.84      0.39       152
#          LOF       0.75      0.53      0.62      1340
#
#     accuracy                           0.67      2831
#    macro avg       0.59      0.72      0.59      2831
# weighted avg       0.73      0.67      0.68      2831
#
#               precision    recall  f1-score   support
#
#      Neutral       0.76      0.78      0.77      1339
#          GOF       0.25      0.84      0.39       152
#          LOF       0.75      0.53      0.62      1340
#
#     accuracy                           0.67      2831
#    macro avg       0.59      0.72      0.59      2831
# weighted avg       0.73      0.67      0.68      2831
#
#
# Per-class MCC:
# Neutral: 0.5609
# GOF: 0.4110
# LOF: 0.3886
#
# Metrics for model 10 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/lgbm_df10_metrics.csv
# Report for model 10 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/report/lgbm_df10_report.csv
# Confusion Matrix for model 10 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/matrix/lgbm_df10_matrix.csv
# Results for model 10 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/results/lgbm_df10.csv
# ---------------------------------------------------
# Processing model 11
# Shape of data: (2831, 12)
# Shape of X_train: (25546, 12)
# Filtered NEGONE_FEATURES: []
# Filtered MEDIAN_FEATURES: []
# ['feature0', 'feature35', 'feature95', 'feature351', 'feature453', 'feature458', 'feature10', 'feature93', 'feature492', 'feature97', 'feature60', 'feature404']
# Columns being dropped: []
# (2831, 11)
# Per-class MCC:
# Neutral: 0.5758
# GOF: 0.4099
# LOF: 0.4060
# Overall MCC: 0.4712
# Model 11 - Test Accuracy: 0.6732603320381491
# Model 11 - Test Precision: 0.7359665942594403
# Model 11 - Test Recall: 0.6732603320381491
# Model 11 - Test F1 Score: 0.6870821010286194
# Model 11 - Test ROC AUC Score: 0.8611415311761229
#               precision    recall  f1-score   support
#
#      Neutral       0.77      0.79      0.78      1339
#          GOF       0.25      0.84      0.39       152
#          LOF       0.76      0.54      0.63      1340
#
#     accuracy                           0.67      2831
#    macro avg       0.59      0.72      0.60      2831
# weighted avg       0.74      0.67      0.69      2831
#
#               precision    recall  f1-score   support
#
#      Neutral       0.77      0.79      0.78      1339
#          GOF       0.25      0.84      0.39       152
#          LOF       0.76      0.54      0.63      1340
#
#     accuracy                           0.67      2831
#    macro avg       0.59      0.72      0.60      2831
# weighted avg       0.74      0.67      0.69      2831
#
#
# Per-class MCC:
# Neutral: 0.5758
# GOF: 0.4099
# LOF: 0.4060
#
# Metrics for model 11 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/lgbm_df11_metrics.csv
# Report for model 11 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/report/lgbm_df11_report.csv
# Confusion Matrix for model 11 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/matrix/lgbm_df11_matrix.csv
# Results for model 11 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/results/lgbm_df11.csv
# ---------------------------------------------------
# Processing model 12
# Shape of data: (2831, 13)
# Shape of X_train: (25546, 13)
# Filtered NEGONE_FEATURES: []
# Filtered MEDIAN_FEATURES: []
# ['feature0', 'feature35', 'feature95', 'feature351', 'feature453', 'feature458', 'feature10', 'feature93', 'feature492', 'feature97', 'feature60', 'feature404', 'feature66']
# Columns being dropped: []
# (2831, 12)
# Per-class MCC:
# Neutral: 0.5837
# GOF: 0.4165
# LOF: 0.4182
# Overall MCC: 0.4810
# Model 12 - Test Accuracy: 0.6803249735075945
# Model 12 - Test Precision: 0.7410352244910668
# Model 12 - Test Recall: 0.6803249735075945
# Model 12 - Test F1 Score: 0.6936152381134372
# Model 12 - Test ROC AUC Score: 0.8617989089134337
#               precision    recall  f1-score   support
#
#      Neutral       0.77      0.80      0.78      1339
#          GOF       0.26      0.84      0.40       152
#          LOF       0.77      0.55      0.64      1340
#
#     accuracy                           0.68      2831
#    macro avg       0.60      0.73      0.61      2831
# weighted avg       0.74      0.68      0.69      2831
#
#               precision    recall  f1-score   support
#
#      Neutral       0.77      0.80      0.78      1339
#          GOF       0.26      0.84      0.40       152
#          LOF       0.77      0.55      0.64      1340
#
#     accuracy                           0.68      2831
#    macro avg       0.60      0.73      0.61      2831
# weighted avg       0.74      0.68      0.69      2831
#
#
# Per-class MCC:
# Neutral: 0.5837
# GOF: 0.4165
# LOF: 0.4182
#
# Metrics for model 12 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/lgbm_df12_metrics.csv
# Report for model 12 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/report/lgbm_df12_report.csv
# Confusion Matrix for model 12 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/matrix/lgbm_df12_matrix.csv
# Results for model 12 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/results/lgbm_df12.csv
# ---------------------------------------------------
# Processing model 13
# Shape of data: (2831, 14)
# Shape of X_train: (25546, 14)
# Filtered NEGONE_FEATURES: []
# Filtered MEDIAN_FEATURES: []
# ['feature0', 'feature35', 'feature95', 'feature351', 'feature453', 'feature458', 'feature10', 'feature93', 'feature492', 'feature97', 'feature60', 'feature404', 'feature66', 'feature67']
# Columns being dropped: []
# (2831, 13)
# Per-class MCC:
# Neutral: 0.5807
# GOF: 0.4088
# LOF: 0.4215
# Overall MCC: 0.4799
# Model 13 - Test Accuracy: 0.6799717414341222
# Model 13 - Test Precision: 0.7410287230702491
# Model 13 - Test Recall: 0.6799717414341222
# Model 13 - Test F1 Score: 0.693943122511423
# Model 13 - Test ROC AUC Score: 0.8639252668744248
#               precision    recall  f1-score   support
#
#      Neutral       0.77      0.79      0.78      1339
#          GOF       0.26      0.82      0.39       152
#          LOF       0.77      0.55      0.64      1340
#
#     accuracy                           0.68      2831
#    macro avg       0.60      0.72      0.60      2831
# weighted avg       0.74      0.68      0.69      2831
#
#               precision    recall  f1-score   support
#
#      Neutral       0.77      0.79      0.78      1339
#          GOF       0.26      0.82      0.39       152
#          LOF       0.77      0.55      0.64      1340
#
#     accuracy                           0.68      2831
#    macro avg       0.60      0.72      0.60      2831
# weighted avg       0.74      0.68      0.69      2831
#
#
# Per-class MCC:
# Neutral: 0.5807
# GOF: 0.4088
# LOF: 0.4215
#
# Metrics for model 13 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/lgbm_df13_metrics.csv
# Report for model 13 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/report/lgbm_df13_report.csv
# Confusion Matrix for model 13 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/matrix/lgbm_df13_matrix.csv
# Results for model 13 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/results/lgbm_df13.csv
# ---------------------------------------------------
# Processing model 14
# Shape of data: (2831, 15)
# Shape of X_train: (25546, 15)
# Filtered NEGONE_FEATURES: []
# Filtered MEDIAN_FEATURES: []
# ['feature0', 'feature35', 'feature95', 'feature351', 'feature453', 'feature458', 'feature10', 'feature93', 'feature492', 'feature97', 'feature60', 'feature404', 'feature66', 'feature67', 'feature498']
# Columns being dropped: []
# (2831, 14)
# Per-class MCC:
# Neutral: 0.5861
# GOF: 0.4047
# LOF: 0.4224
# Overall MCC: 0.4819
# Model 14 - Test Accuracy: 0.6813846697280113
# Model 14 - Test Precision: 0.7424196231008997
# Model 14 - Test Recall: 0.6813846697280113
# Model 14 - Test F1 Score: 0.6959375989203548
# Model 14 - Test ROC AUC Score: 0.862928717277963
#               precision    recall  f1-score   support
#
#      Neutral       0.78      0.79      0.78      1339
#          GOF       0.25      0.82      0.39       152
#          LOF       0.77      0.55      0.64      1340
#
#     accuracy                           0.68      2831
#    macro avg       0.60      0.72      0.60      2831
# weighted avg       0.74      0.68      0.70      2831
#
#               precision    recall  f1-score   support
#
#      Neutral       0.78      0.79      0.78      1339
#          GOF       0.25      0.82      0.39       152
#          LOF       0.77      0.55      0.64      1340
#
#     accuracy                           0.68      2831
#    macro avg       0.60      0.72      0.60      2831
# weighted avg       0.74      0.68      0.70      2831
#
#
# Per-class MCC:
# Neutral: 0.5861
# GOF: 0.4047
# LOF: 0.4224
#
# Metrics for model 14 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/lgbm_df14_metrics.csv
# Report for model 14 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/report/lgbm_df14_report.csv
# Confusion Matrix for model 14 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/matrix/lgbm_df14_matrix.csv
# Results for model 14 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/results/lgbm_df14.csv
# ---------------------------------------------------
# Processing model 15
# Shape of data: (2831, 16)
# Shape of X_train: (25546, 16)
# Filtered NEGONE_FEATURES: []
# Filtered MEDIAN_FEATURES: []
# ['feature0', 'feature35', 'feature95', 'feature351', 'feature453', 'feature458', 'feature10', 'feature93', 'feature492', 'feature97', 'feature60', 'feature404', 'feature66', 'feature67', 'feature498', 'feature101']
# Columns being dropped: []
# (2831, 15)
# Per-class MCC:
# Neutral: 0.5848
# GOF: 0.4127
# LOF: 0.4272
# Overall MCC: 0.4848
# Model 15 - Test Accuracy: 0.6838572942423172
# Model 15 - Test Precision: 0.7432475825772107
# Model 15 - Test Recall: 0.6838572942423172
# Model 15 - Test F1 Score: 0.6978571765227083
# Model 15 - Test ROC AUC Score: 0.8628551316224584
#               precision    recall  f1-score   support
#
#      Neutral       0.77      0.79      0.78      1339
#          GOF       0.26      0.82      0.39       152
#          LOF       0.77      0.56      0.65      1340
#
#     accuracy                           0.68      2831
#    macro avg       0.60      0.72      0.61      2831
# weighted avg       0.74      0.68      0.70      2831
#
#               precision    recall  f1-score   support
#
#      Neutral       0.77      0.79      0.78      1339
#          GOF       0.26      0.82      0.39       152
#          LOF       0.77      0.56      0.65      1340
#
#     accuracy                           0.68      2831
#    macro avg       0.60      0.72      0.61      2831
# weighted avg       0.74      0.68      0.70      2831
#
#
# Per-class MCC:
# Neutral: 0.5848
# GOF: 0.4127
# LOF: 0.4272
#
# Metrics for model 15 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/lgbm_df15_metrics.csv
# Report for model 15 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/report/lgbm_df15_report.csv
# Confusion Matrix for model 15 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/matrix/lgbm_df15_matrix.csv
# Results for model 15 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/results/lgbm_df15.csv
# ---------------------------------------------------
# Processing model 16
# Shape of data: (2831, 17)
# Shape of X_train: (25546, 17)
# Filtered NEGONE_FEATURES: []
# Filtered MEDIAN_FEATURES: []
# ['feature0', 'feature35', 'feature95', 'feature351', 'feature453', 'feature458', 'feature10', 'feature93', 'feature492', 'feature97', 'feature60', 'feature404', 'feature66', 'feature67', 'feature498', 'feature101', 'feature96']
# Columns being dropped: []
# (2831, 16)
# Per-class MCC:
# Neutral: 0.5848
# GOF: 0.4138
# LOF: 0.4256
# Overall MCC: 0.4844
# Model 16 - Test Accuracy: 0.6838572942423172
# Model 16 - Test Precision: 0.7425625314505545
# Model 16 - Test Recall: 0.6838572942423172
# Model 16 - Test F1 Score: 0.6976598116760969
# Model 16 - Test ROC AUC Score: 0.8629102134614065
#               precision    recall  f1-score   support
#
#      Neutral       0.77      0.79      0.78      1339
#          GOF       0.26      0.82      0.39       152
#          LOF       0.77      0.56      0.65      1340
#
#     accuracy                           0.68      2831
#    macro avg       0.60      0.72      0.61      2831
# weighted avg       0.74      0.68      0.70      2831
#
#               precision    recall  f1-score   support
#
#      Neutral       0.77      0.79      0.78      1339
#          GOF       0.26      0.82      0.39       152
#          LOF       0.77      0.56      0.65      1340
#
#     accuracy                           0.68      2831
#    macro avg       0.60      0.72      0.61      2831
# weighted avg       0.74      0.68      0.70      2831
#
#
# Per-class MCC:
# Neutral: 0.5848
# GOF: 0.4138
# LOF: 0.4256
#
# Metrics for model 16 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/lgbm_df16_metrics.csv
# Report for model 16 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/report/lgbm_df16_report.csv
# Confusion Matrix for model 16 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/matrix/lgbm_df16_matrix.csv
# Results for model 16 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/results/lgbm_df16.csv
# ---------------------------------------------------
# Processing model 17
# Shape of data: (2831, 18)
# Shape of X_train: (25546, 18)
# Filtered NEGONE_FEATURES: []
# Filtered MEDIAN_FEATURES: []
# ['feature0', 'feature35', 'feature95', 'feature351', 'feature453', 'feature458', 'feature10', 'feature93', 'feature492', 'feature97', 'feature60', 'feature404', 'feature66', 'feature67', 'feature498', 'feature101', 'feature96', 'feature92']
# Columns being dropped: []
# (2831, 17)
# Per-class MCC:
# Neutral: 0.5871
# GOF: 0.4184
# LOF: 0.4279
# Overall MCC: 0.4874
# Model 17 - Test Accuracy: 0.6863299187566231
# Model 17 - Test Precision: 0.7433230246845213
# Model 17 - Test Recall: 0.6863299187566231
# Model 17 - Test F1 Score: 0.699332356944844
# Model 17 - Test ROC AUC Score: 0.8652850049749289
#               precision    recall  f1-score   support
#
#      Neutral       0.77      0.80      0.79      1339
#          GOF       0.26      0.82      0.40       152
#          LOF       0.77      0.56      0.65      1340
#
#     accuracy                           0.69      2831
#    macro avg       0.60      0.73      0.61      2831
# weighted avg       0.74      0.69      0.70      2831
#
#               precision    recall  f1-score   support
#
#      Neutral       0.77      0.80      0.79      1339
#          GOF       0.26      0.82      0.40       152
#          LOF       0.77      0.56      0.65      1340
#
#     accuracy                           0.69      2831
#    macro avg       0.60      0.73      0.61      2831
# weighted avg       0.74      0.69      0.70      2831
#
#
# Per-class MCC:
# Neutral: 0.5871
# GOF: 0.4184
# LOF: 0.4279
#
# Metrics for model 17 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/lgbm_df17_metrics.csv
# Report for model 17 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/report/lgbm_df17_report.csv
# Confusion Matrix for model 17 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/matrix/lgbm_df17_matrix.csv
# Results for model 17 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/results/lgbm_df17.csv
# ---------------------------------------------------
# Processing model 18
# Shape of data: (2831, 19)
# Shape of X_train: (25546, 19)
# Filtered NEGONE_FEATURES: []
# Filtered MEDIAN_FEATURES: []
# ['feature0', 'feature35', 'feature95', 'feature351', 'feature453', 'feature458', 'feature10', 'feature93', 'feature492', 'feature97', 'feature60', 'feature404', 'feature66', 'feature67', 'feature498', 'feature101', 'feature96', 'feature92', 'feature88']
# Columns being dropped: []
# (2831, 18)
# Per-class MCC:
# Neutral: 0.5921
# GOF: 0.4279
# LOF: 0.4377
# Overall MCC: 0.4952
# Model 18 - Test Accuracy: 0.6919816319321794
# Model 18 - Test Precision: 0.7470805977504462
# Model 18 - Test Recall: 0.6919816319321794
# Model 18 - Test F1 Score: 0.7045657360583821
# Model 18 - Test ROC AUC Score: 0.8636164623210741
#               precision    recall  f1-score   support
#
#      Neutral       0.78      0.80      0.79      1339
#          GOF       0.27      0.83      0.41       152
#          LOF       0.77      0.57      0.65      1340
#
#     accuracy                           0.69      2831
#    macro avg       0.61      0.73      0.62      2831
# weighted avg       0.75      0.69      0.70      2831
#
#               precision    recall  f1-score   support
#
#      Neutral       0.78      0.80      0.79      1339
#          GOF       0.27      0.83      0.41       152
#          LOF       0.77      0.57      0.65      1340
#
#     accuracy                           0.69      2831
#    macro avg       0.61      0.73      0.62      2831
# weighted avg       0.75      0.69      0.70      2831
#
#
# Per-class MCC:
# Neutral: 0.5921
# GOF: 0.4279
# LOF: 0.4377
#
# Metrics for model 18 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/lgbm_df18_metrics.csv
# Report for model 18 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/report/lgbm_df18_report.csv
# Confusion Matrix for model 18 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/matrix/lgbm_df18_matrix.csv
# Results for model 18 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/results/lgbm_df18.csv
# ---------------------------------------------------
# Processing model 19
# Shape of data: (2831, 20)
# Shape of X_train: (25546, 20)
# Filtered NEGONE_FEATURES: []
# Filtered MEDIAN_FEATURES: []
# ['feature0', 'feature35', 'feature95', 'feature351', 'feature453', 'feature458', 'feature10', 'feature93', 'feature492', 'feature97', 'feature60', 'feature404', 'feature66', 'feature67', 'feature498', 'feature101', 'feature96', 'feature92', 'feature88', 'feature36']
# Columns being dropped: []
# (2831, 19)
# Per-class MCC:
# Neutral: 0.5895
# GOF: 0.4309
# LOF: 0.4342
# Overall MCC: 0.4933
# Model 19 - Test Accuracy: 0.6912751677852349
# Model 19 - Test Precision: 0.7449952594689806
# Model 19 - Test Recall: 0.6912751677852349
# Model 19 - Test F1 Score: 0.7031169575866322
# Model 19 - Test ROC AUC Score: 0.8658338073106813
#               precision    recall  f1-score   support
#
#      Neutral       0.77      0.80      0.79      1339
#          GOF       0.27      0.83      0.41       152
#          LOF       0.77      0.57      0.65      1340
#
#     accuracy                           0.69      2831
#    macro avg       0.61      0.73      0.62      2831
# weighted avg       0.74      0.69      0.70      2831
#
#               precision    recall  f1-score   support
#
#      Neutral       0.77      0.80      0.79      1339
#          GOF       0.27      0.83      0.41       152
#          LOF       0.77      0.57      0.65      1340
#
#     accuracy                           0.69      2831
#    macro avg       0.61      0.73      0.62      2831
# weighted avg       0.74      0.69      0.70      2831
#
#
# Per-class MCC:
# Neutral: 0.5895
# GOF: 0.4309
# LOF: 0.4342
#
# Metrics for model 19 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/lgbm_df19_metrics.csv
# Report for model 19 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/report/lgbm_df19_report.csv
# Confusion Matrix for model 19 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/matrix/lgbm_df19_matrix.csv
# Results for model 19 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/results/lgbm_df19.csv
# ---------------------------------------------------
# Processing model 20
# Shape of data: (2831, 21)
# Shape of X_train: (25546, 21)
# Filtered NEGONE_FEATURES: []
# Filtered MEDIAN_FEATURES: []
# ['feature0', 'feature35', 'feature95', 'feature351', 'feature453', 'feature458', 'feature10', 'feature93', 'feature492', 'feature97', 'feature60', 'feature404', 'feature66', 'feature67', 'feature498', 'feature101', 'feature96', 'feature92', 'feature88', 'feature36', 'feature68']
# Columns being dropped: []
# (2831, 20)
# Per-class MCC:
# Neutral: 0.5860
# GOF: 0.4194
# LOF: 0.4245
# Overall MCC: 0.4862
# Model 20 - Test Accuracy: 0.6873896149770399
# Model 20 - Test Precision: 0.7405096253648237
# Model 20 - Test Recall: 0.6873896149770399
# Model 20 - Test F1 Score: 0.6992549469299805
# Model 20 - Test ROC AUC Score: 0.8625186792052864
#               precision    recall  f1-score   support
#
#      Neutral       0.77      0.80      0.79      1339
#          GOF       0.27      0.81      0.40       152
#          LOF       0.76      0.56      0.65      1340
#
#     accuracy                           0.69      2831
#    macro avg       0.60      0.72      0.61      2831
# weighted avg       0.74      0.69      0.70      2831
#
#               precision    recall  f1-score   support
#
#      Neutral       0.77      0.80      0.79      1339
#          GOF       0.27      0.81      0.40       152
#          LOF       0.76      0.56      0.65      1340
#
#     accuracy                           0.69      2831
#    macro avg       0.60      0.72      0.61      2831
# weighted avg       0.74      0.69      0.70      2831
#
#
# Per-class MCC:
# Neutral: 0.5860
# GOF: 0.4194
# LOF: 0.4245
#
# Metrics for model 20 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/lgbm_df20_metrics.csv
# Report for model 20 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/report/lgbm_df20_report.csv
# Confusion Matrix for model 20 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/matrix/lgbm_df20_matrix.csv
# Results for model 20 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/results/lgbm_df20.csv
# ---------------------------------------------------
# Processing model 21
# Shape of data: (2831, 22)
# Shape of X_train: (25546, 22)
# Filtered NEGONE_FEATURES: []
# Filtered MEDIAN_FEATURES: []
# ['feature0', 'feature35', 'feature95', 'feature351', 'feature453', 'feature458', 'feature10', 'feature93', 'feature492', 'feature97', 'feature60', 'feature404', 'feature66', 'feature67', 'feature498', 'feature101', 'feature96', 'feature92', 'feature88', 'feature36', 'feature68', 'feature499']
# Columns being dropped: []
# (2831, 21)
# Per-class MCC:
# Neutral: 0.5848
# GOF: 0.4187
# LOF: 0.4293
# Overall MCC: 0.4882
# Model 21 - Test Accuracy: 0.6898622394913458
# Model 21 - Test Precision: 0.7406617400359353
# Model 21 - Test Recall: 0.6898622394913458
# Model 21 - Test F1 Score: 0.7010996954750709
# Model 21 - Test ROC AUC Score: 0.8619390542863686
#               precision    recall  f1-score   support
#
#      Neutral       0.77      0.80      0.79      1339
#          GOF       0.27      0.80      0.41       152
#          LOF       0.77      0.57      0.65      1340
#
#     accuracy                           0.69      2831
#    macro avg       0.60      0.72      0.61      2831
# weighted avg       0.74      0.69      0.70      2831
#
#               precision    recall  f1-score   support
#
#      Neutral       0.77      0.80      0.79      1339
#          GOF       0.27      0.80      0.41       152
#          LOF       0.77      0.57      0.65      1340
#
#     accuracy                           0.69      2831
#    macro avg       0.60      0.72      0.61      2831
# weighted avg       0.74      0.69      0.70      2831
#
#
# Per-class MCC:
# Neutral: 0.5848
# GOF: 0.4187
# LOF: 0.4293
#
# Metrics for model 21 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/lgbm_df21_metrics.csv
# Report for model 21 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/report/lgbm_df21_report.csv
# Confusion Matrix for model 21 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/matrix/lgbm_df21_matrix.csv
# Results for model 21 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/results/lgbm_df21.csv
# ---------------------------------------------------
# Processing model 22
# Shape of data: (2831, 23)
# Shape of X_train: (25546, 23)
# Filtered NEGONE_FEATURES: []
# Filtered MEDIAN_FEATURES: []
# ['feature0', 'feature35', 'feature95', 'feature351', 'feature453', 'feature458', 'feature10', 'feature93', 'feature492', 'feature97', 'feature60', 'feature404', 'feature66', 'feature67', 'feature498', 'feature101', 'feature96', 'feature92', 'feature88', 'feature36', 'feature68', 'feature499', 'feature99']
# Columns being dropped: []
# (2831, 22)
# Per-class MCC:
# Neutral: 0.5937
# GOF: 0.4175
# LOF: 0.4404
# Overall MCC: 0.4966
# Model 22 - Test Accuracy: 0.6955139526669022
# Model 22 - Test Precision: 0.7457635504262055
# Model 22 - Test Recall: 0.6955139526669022
# Model 22 - Test F1 Score: 0.7072402975399925
# Model 22 - Test ROC AUC Score: 0.8658058557249131
#               precision    recall  f1-score   support
#
#      Neutral       0.78      0.80      0.79      1339
#          GOF       0.27      0.79      0.41       152
#          LOF       0.77      0.58      0.66      1340
#
#     accuracy                           0.70      2831
#    macro avg       0.61      0.72      0.62      2831
# weighted avg       0.75      0.70      0.71      2831
#
#               precision    recall  f1-score   support
#
#      Neutral       0.78      0.80      0.79      1339
#          GOF       0.27      0.79      0.41       152
#          LOF       0.77      0.58      0.66      1340
#
#     accuracy                           0.70      2831
#    macro avg       0.61      0.72      0.62      2831
# weighted avg       0.75      0.70      0.71      2831
#
#
# Per-class MCC:
# Neutral: 0.5937
# GOF: 0.4175
# LOF: 0.4404
#
# Metrics for model 22 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/lgbm_df22_metrics.csv
# Report for model 22 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/report/lgbm_df22_report.csv
# Confusion Matrix for model 22 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/matrix/lgbm_df22_matrix.csv
# Results for model 22 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/results/lgbm_df22.csv
# ---------------------------------------------------
# Processing model 23
# Shape of data: (2831, 24)
# Shape of X_train: (25546, 24)
# Filtered NEGONE_FEATURES: []
# Filtered MEDIAN_FEATURES: []
# ['feature0', 'feature35', 'feature95', 'feature351', 'feature453', 'feature458', 'feature10', 'feature93', 'feature492', 'feature97', 'feature60', 'feature404', 'feature66', 'feature67', 'feature498', 'feature101', 'feature96', 'feature92', 'feature88', 'feature36', 'feature68', 'feature499', 'feature99', 'feature460']
# Columns being dropped: []
# (2831, 23)
# Per-class MCC:
# Neutral: 0.5988
# GOF: 0.4181
# LOF: 0.4495
# Overall MCC: 0.5027
# Model 23 - Test Accuracy: 0.6990462734016248
# Model 23 - Test Precision: 0.749869244038657
# Model 23 - Test Recall: 0.6990462734016248
# Model 23 - Test F1 Score: 0.7108235303275772
# Model 23 - Test ROC AUC Score: 0.8668319250168324
#               precision    recall  f1-score   support
#
#      Neutral       0.78      0.81      0.79      1339
#          GOF       0.27      0.79      0.41       152
#          LOF       0.78      0.58      0.66      1340
#
#     accuracy                           0.70      2831
#    macro avg       0.61      0.73      0.62      2831
# weighted avg       0.75      0.70      0.71      2831
#
#               precision    recall  f1-score   support
#
#      Neutral       0.78      0.81      0.79      1339
#          GOF       0.27      0.79      0.41       152
#          LOF       0.78      0.58      0.66      1340
#
#     accuracy                           0.70      2831
#    macro avg       0.61      0.73      0.62      2831
# weighted avg       0.75      0.70      0.71      2831
#
#
# Per-class MCC:
# Neutral: 0.5988
# GOF: 0.4181
# LOF: 0.4495
#
# Metrics for model 23 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/lgbm_df23_metrics.csv
# Report for model 23 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/report/lgbm_df23_report.csv
# Confusion Matrix for model 23 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/matrix/lgbm_df23_matrix.csv
# Results for model 23 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/results/lgbm_df23.csv
# ---------------------------------------------------
# Processing model 24
# Shape of data: (2831, 25)
# Shape of X_train: (25546, 25)
# Filtered NEGONE_FEATURES: []
# Filtered MEDIAN_FEATURES: []
# ['feature0', 'feature35', 'feature95', 'feature351', 'feature453', 'feature458', 'feature10', 'feature93', 'feature492', 'feature97', 'feature60', 'feature404', 'feature66', 'feature67', 'feature498', 'feature101', 'feature96', 'feature92', 'feature88', 'feature36', 'feature68', 'feature499', 'feature99', 'feature460', 'feature489']
# Columns being dropped: []
# (2831, 24)
# Per-class MCC:
# Neutral: 0.5994
# GOF: 0.4231
# LOF: 0.4510
# Overall MCC: 0.5047
# Model 24 - Test Accuracy: 0.7011656658424585
# Model 24 - Test Precision: 0.7498712784887466
# Model 24 - Test Recall: 0.7011656658424585
# Model 24 - Test F1 Score: 0.7125368493093899
# Model 24 - Test ROC AUC Score: 0.8676999935075614
#               precision    recall  f1-score   support
#
#      Neutral       0.78      0.81      0.79      1339
#          GOF       0.28      0.79      0.41       152
#          LOF       0.78      0.59      0.67      1340
#
#     accuracy                           0.70      2831
#    macro avg       0.61      0.73      0.62      2831
# weighted avg       0.75      0.70      0.71      2831
#
#               precision    recall  f1-score   support
#
#      Neutral       0.78      0.81      0.79      1339
#          GOF       0.28      0.79      0.41       152
#          LOF       0.78      0.59      0.67      1340
#
#     accuracy                           0.70      2831
#    macro avg       0.61      0.73      0.62      2831
# weighted avg       0.75      0.70      0.71      2831
#
#
# Per-class MCC:
# Neutral: 0.5994
# GOF: 0.4231
# LOF: 0.4510
#
# Metrics for model 24 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/lgbm_df24_metrics.csv
# Report for model 24 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/report/lgbm_df24_report.csv
# Confusion Matrix for model 24 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/matrix/lgbm_df24_matrix.csv
# Results for model 24 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/results/lgbm_df24.csv
# ---------------------------------------------------
# Processing model 25
# Shape of data: (2831, 26)
# Shape of X_train: (25546, 26)
# Filtered NEGONE_FEATURES: []
# Filtered MEDIAN_FEATURES: []
# ['feature0', 'feature35', 'feature95', 'feature351', 'feature453', 'feature458', 'feature10', 'feature93', 'feature492', 'feature97', 'feature60', 'feature404', 'feature66', 'feature67', 'feature498', 'feature101', 'feature96', 'feature92', 'feature88', 'feature36', 'feature68', 'feature499', 'feature99', 'feature460', 'feature489', 'feature493']
# Columns being dropped: []
# (2831, 25)
# Per-class MCC:
# Neutral: 0.5939
# GOF: 0.4188
# LOF: 0.4453
# Overall MCC: 0.4993
# Model 25 - Test Accuracy: 0.697986577181208
# Model 25 - Test Precision: 0.7466501125570197
# Model 25 - Test Recall: 0.697986577181208
# Model 25 - Test F1 Score: 0.7092296060469754
# Model 25 - Test ROC AUC Score: 0.867829880778686
#               precision    recall  f1-score   support
#
#      Neutral       0.77      0.81      0.79      1339
# ...
# Columns being dropped: []
# (2831, 496)
# Per-class MCC:
# Neutral: 0.8555
# GOF: 0.6239
# LOF: 0.7945
# Overall MCC: 0.8038
# Model 497 - Test Accuracy: 0.8908512892970681
# Model 497 - Test Precision: 0.8959642341311969
# Model 497 - Test Recall: 0.8908512892970681
# Model 497 - Test F1 Score: 0.8928375713296676
# Model 497 - Test ROC AUC Score: 0.9483936934563847
#               precision    recall  f1-score   support
#
#      Neutral       0.93      0.91      0.92      1339
#          GOF       0.57      0.73      0.64       152
#          LOF       0.90      0.89      0.89      1340
#
#     accuracy                           0.89      2831
#    macro avg       0.80      0.84      0.82      2831
# weighted avg       0.90      0.89      0.89      2831
#
#               precision    recall  f1-score   support
#
#      Neutral       0.93      0.91      0.92      1339
#          GOF       0.57      0.73      0.64       152
#          LOF       0.90      0.89      0.89      1340
#
#     accuracy                           0.89      2831
#    macro avg       0.80      0.84      0.82      2831
# weighted avg       0.90      0.89      0.89      2831
#
#
# Per-class MCC:
# Neutral: 0.8555
# GOF: 0.6239
# LOF: 0.7945
#
# Metrics for model 497 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/lgbm_df497_metrics.csv
# Report for model 497 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/report/lgbm_df497_report.csv
# Confusion Matrix for model 497 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/matrix/lgbm_df497_matrix.csv
# Results for model 497 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/results/lgbm_df497.csv
# ---------------------------------------------------
# Processing model 498
# Shape of data: (2831, 499)
# Shape of X_train: (25546, 499)
# Filtered NEGONE_FEATURES: []
# Filtered MEDIAN_FEATURES: []
# ['feature0', 'feature35', 'feature95', 'feature351', 'feature453', 'feature458', 'feature10', 'feature93', 'feature492', 'feature97', 'feature60', 'feature404', 'feature66', 'feature67', 'feature498', 'feature101', 'feature96', 'feature92', 'feature88', 'feature36', 'feature68', 'feature499', 'feature99', 'feature460', 'feature489', 'feature493', 'feature77', 'feature495', 'feature65', 'feature64', 'feature31', 'feature32', 'feature455', 'feature456', 'feature85', 'feature87', 'feature451', 'feature135', 'feature55', 'feature59', 'feature231', 'feature4', 'feature71', 'feature78', 'feature452', 'feature94', 'feature76', 'feature75', 'feature126', 'feature401', 'feature414', 'feature413', 'feature102', 'feature405', 'feature98', 'feature412', 'feature415', 'feature147', 'feature13', 'feature385', 'feature410', 'feature104', 'feature420', 'feature74', 'feature122', 'feature100', 'feature497', 'feature180', 'feature133', 'feature144', 'feature112', 'feature120', 'feature89', 'feature136', 'feature131', 'feature163', 'feature110', 'feature237', 'feature396', 'feature399', 'feature73', 'feature454', 'feature457', 'feature469', 'feature289', 'feature470', 'feature236', 'feature228', 'feature491', 'feature70', 'feature494', 'feature114', 'feature409', 'feature487', 'feature121', 'feature418', 'feature124', 'feature449', 'feature422', 'feature119', 'feature210', 'feature408', 'feature394', 'feature389', 'feature375', 'feature326', 'feature298', 'feature281', 'feature262', 'feature241', 'feature140', 'feature219', 'feature184', 'feature192', 'feature411', 'feature118', 'feature1', 'feature52', 'feature53', 'feature111', 'feature90', 'feature91', 'feature61', 'feature58', 'feature84', 'feature388', 'feature50', 'feature179', 'feature421', 'feature450', 'feature72', 'feature56', 'feature313', 'feature160', 'feature161', 'feature406', 'feature116', 'feature392', 'feature391', 'feature309', 'feature322', 'feature21', 'feature238', 'feature276', 'feature115', 'feature113', 'feature395', 'feature188', 'feature301', 'feature496', 'feature6', 'feature127', 'feature329', 'feature142', 'feature129', 'feature386', 'feature387', 'feature259', 'feature447', 'feature279', 'feature330', 'feature254', 'feature390', 'feature419', 'feature216', 'feature437', 'feature200', 'feature211', 'feature294', 'feature195', 'feature28', 'feature398', 'feature269', 'feature267', 'feature266', 'feature263', 'feature261', 'feature260', 'feature256', 'feature402', 'feature246', 'feature244', 'feature393', 'feature57', 'feature240', 'feature283', 'feature438', 'feature234', 'feature63', 'feature226', 'feature69', 'feature440', 'feature274', 'feature139', 'feature86', 'feature189', 'feature168', 'feature380', 'feature185', 'feature123', 'feature7', 'feature128', 'feature314', 'feature152', 'feature169', 'feature183', 'feature176', 'feature305', 'feature146', 'feature323', 'feature243', 'feature324', 'feature365', 'feature318', 'feature14', 'feature245', 'feature248', 'feature300', 'feature251', 'feature280', 'feature235', 'feature483', 'feature484', 'feature278', 'feature258', 'feature355', 'feature332', 'feature333', 'feature264', 'feature268', 'feature270', 'feature109', 'feature403', 'feature372', 'feature233', 'feature232', 'feature194', 'feature196', 'feature381', 'feature436', 'feature304', 'feature297', 'feature202', 'feature429', 'feature181', 'feature448', 'feature306', 'feature174', 'feature299', 'feature417', 'feature172', 'feature250', 'feature416', 'feature22', 'feature62', 'feature29', 'feature230', 'feature284', 'feature286', 'feature312', 'feature311', 'feature164', 'feature45', 'feature339', 'feature321', 'feature335', 'feature277', 'feature296', 'feature362', 'feature287', 'feature292', 'feature327', 'feature307', 'feature357', 'feature290', 'feature229', 'feature166', 'feature187', 'feature103', 'feature186', 'feature445', 'feature24', 'feature173', 'feature171', 'feature44', 'feature20', 'feature19', 'feature162', 'feature459', 'feature480', 'feature ...
# Columns being dropped: []
# (2831, 497)
# Per-class MCC:
# Neutral: 0.8569
# GOF: 0.6149
# LOF: 0.7938
# Overall MCC: 0.8029
# Model 498 - Test Accuracy: 0.8901448251501236
# Model 498 - Test Precision: 0.896139068230277
# Model 498 - Test Recall: 0.8901448251501236
# Model 498 - Test F1 Score: 0.8924516733215235
# Model 498 - Test ROC AUC Score: 0.9469112626893441
#               precision    recall  f1-score   support
#
#      Neutral       0.93      0.91      0.92      1339
#          GOF       0.56      0.73      0.63       152
#          LOF       0.90      0.88      0.89      1340
#
#     accuracy                           0.89      2831
#    macro avg       0.80      0.84      0.82      2831
# weighted avg       0.90      0.89      0.89      2831
#
#               precision    recall  f1-score   support
#
#      Neutral       0.93      0.91      0.92      1339
#          GOF       0.56      0.73      0.63       152
#          LOF       0.90      0.88      0.89      1340
#
#     accuracy                           0.89      2831
#    macro avg       0.80      0.84      0.82      2831
# weighted avg       0.90      0.89      0.89      2831
#
#
# Per-class MCC:
# Neutral: 0.8569
# GOF: 0.6149
# LOF: 0.7938
#
# Metrics for model 498 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/lgbm_df498_metrics.csv
# Report for model 498 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/report/lgbm_df498_report.csv
# Confusion Matrix for model 498 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/matrix/lgbm_df498_matrix.csv
# Results for model 498 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/results/lgbm_df498.csv
# ---------------------------------------------------
# Processing model 499
# Shape of data: (2831, 500)
# Shape of X_train: (25546, 500)
# Filtered NEGONE_FEATURES: []
# Filtered MEDIAN_FEATURES: []
# ['feature0', 'feature35', 'feature95', 'feature351', 'feature453', 'feature458', 'feature10', 'feature93', 'feature492', 'feature97', 'feature60', 'feature404', 'feature66', 'feature67', 'feature498', 'feature101', 'feature96', 'feature92', 'feature88', 'feature36', 'feature68', 'feature499', 'feature99', 'feature460', 'feature489', 'feature493', 'feature77', 'feature495', 'feature65', 'feature64', 'feature31', 'feature32', 'feature455', 'feature456', 'feature85', 'feature87', 'feature451', 'feature135', 'feature55', 'feature59', 'feature231', 'feature4', 'feature71', 'feature78', 'feature452', 'feature94', 'feature76', 'feature75', 'feature126', 'feature401', 'feature414', 'feature413', 'feature102', 'feature405', 'feature98', 'feature412', 'feature415', 'feature147', 'feature13', 'feature385', 'feature410', 'feature104', 'feature420', 'feature74', 'feature122', 'feature100', 'feature497', 'feature180', 'feature133', 'feature144', 'feature112', 'feature120', 'feature89', 'feature136', 'feature131', 'feature163', 'feature110', 'feature237', 'feature396', 'feature399', 'feature73', 'feature454', 'feature457', 'feature469', 'feature289', 'feature470', 'feature236', 'feature228', 'feature491', 'feature70', 'feature494', 'feature114', 'feature409', 'feature487', 'feature121', 'feature418', 'feature124', 'feature449', 'feature422', 'feature119', 'feature210', 'feature408', 'feature394', 'feature389', 'feature375', 'feature326', 'feature298', 'feature281', 'feature262', 'feature241', 'feature140', 'feature219', 'feature184', 'feature192', 'feature411', 'feature118', 'feature1', 'feature52', 'feature53', 'feature111', 'feature90', 'feature91', 'feature61', 'feature58', 'feature84', 'feature388', 'feature50', 'feature179', 'feature421', 'feature450', 'feature72', 'feature56', 'feature313', 'feature160', 'feature161', 'feature406', 'feature116', 'feature392', 'feature391', 'feature309', 'feature322', 'feature21', 'feature238', 'feature276', 'feature115', 'feature113', 'feature395', 'feature188', 'feature301', 'feature496', 'feature6', 'feature127', 'feature329', 'feature142', 'feature129', 'feature386', 'feature387', 'feature259', 'feature447', 'feature279', 'feature330', 'feature254', 'feature390', 'feature419', 'feature216', 'feature437', 'feature200', 'feature211', 'feature294', 'feature195', 'feature28', 'feature398', 'feature269', 'feature267', 'feature266', 'feature263', 'feature261', 'feature260', 'feature256', 'feature402', 'feature246', 'feature244', 'feature393', 'feature57', 'feature240', 'feature283', 'feature438', 'feature234', 'feature63', 'feature226', 'feature69', 'feature440', 'feature274', 'feature139', 'feature86', 'feature189', 'feature168', 'feature380', 'feature185', 'feature123', 'feature7', 'feature128', 'feature314', 'feature152', 'feature169', 'feature183', 'feature176', 'feature305', 'feature146', 'feature323', 'feature243', 'feature324', 'feature365', 'feature318', 'feature14', 'feature245', 'feature248', 'feature300', 'feature251', 'feature280', 'feature235', 'feature483', 'feature484', 'feature278', 'feature258', 'feature355', 'feature332', 'feature333', 'feature264', 'feature268', 'feature270', 'feature109', 'feature403', 'feature372', 'feature233', 'feature232', 'feature194', 'feature196', 'feature381', 'feature436', 'feature304', 'feature297', 'feature202', 'feature429', 'feature181', 'feature448', 'feature306', 'feature174', 'feature299', 'feature417', 'feature172', 'feature250', 'feature416', 'feature22', 'feature62', 'feature29', 'feature230', 'feature284', 'feature286', 'feature312', 'feature311', 'feature164', 'feature45', 'feature339', 'feature321', 'feature335', 'feature277', 'feature296', 'feature362', 'feature287', 'feature292', 'feature327', 'feature307', 'feature357', 'feature290', 'feature229', 'feature166', 'feature187', 'feature103', 'feature186', 'feature445', 'feature24', 'feature173', 'feature171', 'feature44', 'feature20', 'feature19', 'feature162', 'feature459', 'feature480', 'feature ...
# Columns being dropped: []
# (2831, 498)
# Per-class MCC:
# Neutral: 0.8562
# GOF: 0.6114
# LOF: 0.7902
# Overall MCC: 0.8005
# Model 499 - Test Accuracy: 0.8887318968562345
# Model 499 - Test Precision: 0.8950344488585827
# Model 499 - Test Recall: 0.8887318968562345
# Model 499 - Test F1 Score: 0.8911456467519748
# Model 499 - Test ROC AUC Score: 0.9469386294423092
#               precision    recall  f1-score   support
#
#      Neutral       0.93      0.91      0.92      1339
#          GOF       0.55      0.73      0.63       152
#          LOF       0.90      0.88      0.89      1340
#
#     accuracy                           0.89      2831
#    macro avg       0.79      0.84      0.81      2831
# weighted avg       0.90      0.89      0.89      2831
#
#               precision    recall  f1-score   support
#
#      Neutral       0.93      0.91      0.92      1339
#          GOF       0.55      0.73      0.63       152
#          LOF       0.90      0.88      0.89      1340
#
#     accuracy                           0.89      2831
#    macro avg       0.79      0.84      0.81      2831
# weighted avg       0.90      0.89      0.89      2831
#
#
# Per-class MCC:
# Neutral: 0.8562
# GOF: 0.6114
# LOF: 0.7902
#
# Metrics for model 499 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/lgbm_df499_metrics.csv
# Report for model 499 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/report/lgbm_df499_report.csv
# Confusion Matrix for model 499 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/metrics/matrix/lgbm_df499_matrix.csv
# Results for model 499 saved to /Users/benzenesea/Desktop/XGBoost-499/LightGBM/results/lgbm_df499.csv
# ---------------------------------------------------

# %%
""" This combines all of the individual metrics into one file. """

metrics_dir = 'metrics'

# Init list to hold the df's.
dfs = []

# Iterate over every metric file.
for i in range(1, 500):  
    file_path = os.path.join(metrics_dir, f'lgbm_df{i}_metrics.csv')
    if os.path.exists(file_path):
        df = pd.read_csv(file_path)
        dfs.append(df)

# Combine the df's.
combined_df = pd.concat(dfs, ignore_index=True)

# Sort by the 'Model' column.s
combined_df = combined_df.sort_values('Model')
combined_df.set_index('Model', inplace=True)

# Save new CSV file.
output_path = 'metrics/combined_metrics.csv'
combined_df.to_csv(output_path)

print(f"Saved to {output_path}")
# Out:
# Saved to metrics/combined_metrics.csv

# %%
""" This ranks the models according to accuracy. """

input_path = 'metrics/combined_metrics.csv'
combined_df = pd.read_csv(input_path, index_col='Model')

# Sort ACC from low to high.
sorted_df = combined_df.sort_values('Accuracy', ascending=True)

# New df only needs 'Model' and 'Accuracy' columns.
rankings_df = pd.DataFrame({
    'Model': sorted_df.index,
    'Accuracy': sorted_df['Accuracy']
})

# Reset index so 'Model' is normal column.
rankings_df = rankings_df.reset_index(drop=True)

# Save new CSV file.
output_path = 'metrics/ranked_by_accuracy.csv'
rankings_df.to_csv(output_path, index=False)
print(f"Saved to {output_path}")
# Out:
# Saved to metrics/ranked_by_accuracy.csv

# %%
""" This ranks the models according to precision. """

input_path = 'metrics/combined_metrics.csv'
combined_df = pd.read_csv(input_path, index_col='Model')

# Sort PREC from low to high.
sorted_df = combined_df.sort_values('Precision', ascending=True)

# New df only needs 'Model' and 'Precision' columns.
rankings_df = pd.DataFrame({
    'Model': sorted_df.index,
    'Precision': sorted_df['Precision']
})

# Reset index so 'Model' is normal column.
rankings_df = rankings_df.reset_index(drop=True)

# Save new CSV file.
output_path = 'metrics/ranked_by_precision.csv'
rankings_df.to_csv(output_path, index=False)
print(f"Saved to {output_path}")
# Out:
# Saved to metrics/ranked_by_precision.csv

# %%
""" This ranks the models according to recall. """

input_path = 'metrics/combined_metrics.csv'
combined_df = pd.read_csv(input_path, index_col='Model')

# Sort REC from low to high.
sorted_df = combined_df.sort_values('Recall', ascending=True)

# New df only needs 'Model' and 'Recall' columns.
rankings_df = pd.DataFrame({
    'Model': sorted_df.index,
    'Recall': sorted_df['Recall']
})

# Reset index so 'Model' is normal column.
rankings_df = rankings_df.reset_index(drop=True)

# Save new CSV file.
output_path = 'metrics/ranked_by_recall.csv'
rankings_df.to_csv(output_path, index=False)
print(f"Saved to {output_path}")
# Out:
# Saved to metrics/ranked_by_recall.csv

# %%
""" This ranks the models according to F1-score. """

input_path = 'metrics/combined_metrics.csv'
combined_df = pd.read_csv(input_path, index_col='Model')

# Sort F1 from low to high.
sorted_df = combined_df.sort_values('F1 Score', ascending=True)

# New df only needs 'Model' and 'F1 Score' columns.
rankings_df = pd.DataFrame({
    'Model': sorted_df.index,
    'F1_Score': sorted_df['F1 Score']
})

# Reset index so 'Model' is normal column.
rankings_df = rankings_df.reset_index(drop=True)

# Save new CSV file.
output_path = 'metrics/ranked_by_f1.csv'
rankings_df.to_csv(output_path, index=False)
print(f"Saved to {output_path}")
# Out:
# Saved to metrics/ranked_by_f1.csv

# %%
""" This ranks the models according to ROC AUC. """

input_path = 'metrics/combined_metrics.csv'
combined_df = pd.read_csv(input_path, index_col='Model')

# ROC AUC Score from low to high.
sorted_df = combined_df.sort_values('ROC AUC Score', ascending=True)

# New df only needs 'Model' and 'ROC AUC' columns.
rankings_df = pd.DataFrame({
    'Model': sorted_df.index,
    'ROC_AUC_Score': sorted_df['ROC AUC Score']
})

# Reset index so 'Model' is normal column.
rankings_df = rankings_df.reset_index(drop=True)

# Save new CSV.
output_path = 'metrics/ranked_by_roc_auc.csv'
rankings_df.to_csv(output_path, index=False)
print(f"Saved to {output_path}")
# Out:
# Saved to metrics/ranked_by_roc_auc.csv
