# %%
import pandas as pd
import numpy as np
import glob
import os, re, sys

# %% [markdown]
# ### This processes the metrics collected by the Test script.

# %%
""" This loads all 499 CSV metrics files into pandas. """

# Find the metrics directory.
metrics_dir = '../LightGBM/metrics/individual'


# Identify all relevant CSV files.
pattern = os.path.join(metrics_dir, "lgbm_df*_metrics.csv")
csv_files = glob.glob(pattern)
print(f"Found {len(csv_files)} files:")
for file in csv_files:
    print(f"  - {os.path.basename(file)}")

# Init list for df's.
dfs = []

# Seuqnetially read all CSV files and add to list.
for file in csv_files:
    df = pd.read_csv(file)
    dfs.append(df)
    print(f"read: {os.path.basename(file)}")

    # Concatenate.
    merged_df = pd.concat(dfs, ignore_index=True)

    # Group by the 'Model' column.
    grouped_df = merged_df.groupby('Model').mean().reset_index()

    # Export to CSV.
    output_file = "../LightGBM/metrics/merged_metrics.csv"
    grouped_df.to_csv(output_file, index=False)
    print(f"Merged saved as: {output_file}")
# Out:
# Found 499 files:
#   - lgbm_df100_metrics.csv
#   - lgbm_df101_metrics.csv
#   - lgbm_df102_metrics.csv
#   - lgbm_df103_metrics.csv
#   - lgbm_df104_metrics.csv
#   - lgbm_df105_metrics.csv
#   - lgbm_df106_metrics.csv
#   - lgbm_df107_metrics.csv
#   - lgbm_df108_metrics.csv
#   - lgbm_df109_metrics.csv
#   - lgbm_df10_metrics.csv
#   - lgbm_df110_metrics.csv
#   - lgbm_df111_metrics.csv
#   - lgbm_df112_metrics.csv
#   - lgbm_df113_metrics.csv
#   - lgbm_df114_metrics.csv
#   - lgbm_df115_metrics.csv
#   - lgbm_df116_metrics.csv
#   - lgbm_df117_metrics.csv
#   - lgbm_df118_metrics.csv
#   - lgbm_df119_metrics.csv
#   - lgbm_df11_metrics.csv
#   - lgbm_df120_metrics.csv
#   - lgbm_df121_metrics.csv
#   - lgbm_df122_metrics.csv
#   - lgbm_df123_metrics.csv
#   - lgbm_df124_metrics.csv
#   - lgbm_df125_metrics.csv
#   - lgbm_df126_metrics.csv
#   - lgbm_df127_metrics.csv
#   - lgbm_df128_metrics.csv
#   - lgbm_df129_metrics.csv
#   - lgbm_df12_metrics.csv
#   - lgbm_df130_metrics.csv
#   - lgbm_df131_metrics.csv
#   - lgbm_df132_metrics.csv
#   - lgbm_df133_metrics.csv
#   - lgbm_df134_metrics.csv
#   - lgbm_df135_metrics.csv
#   - lgbm_df136_metrics.csv
#   - lgbm_df137_metrics.csv
#   - lgbm_df138_metrics.csv
#   - lgbm_df139_metrics.csv
#   - lgbm_df13_metrics.csv
#   - lgbm_df140_metrics.csv
#   - lgbm_df141_metrics.csv
#   - lgbm_df142_metrics.csv
#   - lgbm_df143_metrics.csv
#   - lgbm_df144_metrics.csv
#   - lgbm_df145_metrics.csv
#   - lgbm_df146_metrics.csv
#   - lgbm_df147_metrics.csv
#   - lgbm_df148_metrics.csv
#   - lgbm_df149_metrics.csv
#   - lgbm_df14_metrics.csv
#   - lgbm_df150_metrics.csv
#   - lgbm_df151_metrics.csv
#   - lgbm_df152_metrics.csv
#   - lgbm_df153_metrics.csv
#   - lgbm_df154_metrics.csv
#   - lgbm_df155_metrics.csv
#   - lgbm_df156_metrics.csv
#   - lgbm_df157_metrics.csv
#   - lgbm_df158_metrics.csv
#   - lgbm_df159_metrics.csv
#   - lgbm_df15_metrics.csv
#   - lgbm_df160_metrics.csv
#   - lgbm_df161_metrics.csv
#   - lgbm_df162_metrics.csv
#   - lgbm_df163_metrics.csv
#   - lgbm_df164_metrics.csv
#   - lgbm_df165_metrics.csv
#   - lgbm_df166_metrics.csv
#   - lgbm_df167_metrics.csv
#   - lgbm_df168_metrics.csv
#   - lgbm_df169_metrics.csv
#   - lgbm_df16_metrics.csv
#   - lgbm_df170_metrics.csv
#   - lgbm_df171_metrics.csv
#   - lgbm_df172_metrics.csv
#   - lgbm_df173_metrics.csv
#   - lgbm_df174_metrics.csv
#   - lgbm_df175_metrics.csv
#   - lgbm_df176_metrics.csv
#   - lgbm_df177_metrics.csv
#   - lgbm_df178_metrics.csv
#   - lgbm_df179_metrics.csv
#   - lgbm_df17_metrics.csv
#   - lgbm_df180_metrics.csv
#   - lgbm_df181_metrics.csv
#   - lgbm_df182_metrics.csv
#   - lgbm_df183_metrics.csv
#   - lgbm_df184_metrics.csv
#   - lgbm_df185_metrics.csv
#   - lgbm_df186_metrics.csv
#   - lgbm_df187_metrics.csv
#   - lgbm_df188_metrics.csv
#   - lgbm_df189_metrics.csv
#   - lgbm_df18_metrics.csv
#   - lgbm_df190_metrics.csv
#   - lgbm_df191_metrics.csv
#   - lgbm_df192_metrics.csv
#   - lgbm_df193_metrics.csv
#   - lgbm_df194_metrics.csv
#   - lgbm_df195_metrics.csv
#   - lgbm_df196_metrics.csv
#   - lgbm_df197_metrics.csv
#   - lgbm_df198_metrics.csv
#   - lgbm_df199_metrics.csv
#   - lgbm_df19_metrics.csv
#   - lgbm_df1_metrics.csv
#   - lgbm_df200_metrics.csv
#   - lgbm_df201_metrics.csv
#   - lgbm_df202_metrics.csv
#   - lgbm_df203_metrics.csv
#   - lgbm_df204_metrics.csv
#   - lgbm_df205_metrics.csv
#   - lgbm_df206_metrics.csv
#   - lgbm_df207_metrics.csv
#   - lgbm_df208_metrics.csv
#   - lgbm_df209_metrics.csv
#   - lgbm_df20_metrics.csv
#   - lgbm_df210_metrics.csv
#   - lgbm_df211_metrics.csv
#   - lgbm_df212_metrics.csv
#   - lgbm_df213_metrics.csv
#   - lgbm_df214_metrics.csv
#   - lgbm_df215_metrics.csv
#   - lgbm_df216_metrics.csv
#   - lgbm_df217_metrics.csv
#   - lgbm_df218_metrics.csv
#   - lgbm_df219_metrics.csv
#   - lgbm_df21_metrics.csv
#   - lgbm_df220_metrics.csv
#   - lgbm_df221_metrics.csv
#   - lgbm_df222_metrics.csv
#   - lgbm_df223_metrics.csv
#   - lgbm_df224_metrics.csv
#   - lgbm_df225_metrics.csv
#   - lgbm_df226_metrics.csv
#   - lgbm_df227_metrics.csv
#   - lgbm_df228_metrics.csv
#   - lgbm_df229_metrics.csv
#   - lgbm_df22_metrics.csv
#   - lgbm_df230_metrics.csv
#   - lgbm_df231_metrics.csv
#   - lgbm_df232_metrics.csv
#   - lgbm_df233_metrics.csv
#   - lgbm_df234_metrics.csv
#   - lgbm_df235_metrics.csv
#   - lgbm_df236_metrics.csv
#   - lgbm_df237_metrics.csv
#   - lgbm_df238_metrics.csv
#   - lgbm_df239_metrics.csv
#   - lgbm_df23_metrics.csv
#   - lgbm_df240_metrics.csv
#   - lgbm_df241_metrics.csv
#   - lgbm_df242_metrics.csv
#   - lgbm_df243_metrics.csv
#   - lgbm_df244_metrics.csv
#   - lgbm_df245_metrics.csv
#   - lgbm_df246_metrics.csv
#   - lgbm_df247_metrics.csv
#   - lgbm_df248_metrics.csv
#   - lgbm_df249_metrics.csv
#   - lgbm_df24_metrics.csv
#   - lgbm_df250_metrics.csv
#   - lgbm_df251_metrics.csv
#   - lgbm_df252_metrics.csv
#   - lgbm_df253_metrics.csv
#   - lgbm_df254_metrics.csv
#   - lgbm_df255_metrics.csv
#   - lgbm_df256_metrics.csv
#   - lgbm_df257_metrics.csv
#   - lgbm_df258_metrics.csv
#   - lgbm_df259_metrics.csv
#   - lgbm_df25_metrics.csv
#   - lgbm_df260_metrics.csv
#   - lgbm_df261_metrics.csv
#   - lgbm_df262_metrics.csv
#   - lgbm_df263_metrics.csv
#   - lgbm_df264_metrics.csv
#   - lgbm_df265_metrics.csv
#   - lgbm_df266_metrics.csv
#   - lgbm_df267_metrics.csv
#   - lgbm_df268_metrics.csv
#   - lgbm_df269_metrics.csv
#   - lgbm_df26_metrics.csv
#   - lgbm_df270_metrics.csv
#   - lgbm_df271_metrics.csv
#   - lgbm_df272_metrics.csv
#   - lgbm_df273_metrics.csv
#   - lgbm_df274_metrics.csv
#   - lgbm_df275_metrics.csv
#   - lgbm_df276_metrics.csv
#   - lgbm_df277_metrics.csv
#   - lgbm_df278_metrics.csv
#   - lgbm_df279_metrics.csv
#   - lgbm_df27_metrics.csv
#   - lgbm_df280_metrics.csv
#   - lgbm_df281_metrics.csv
#   - lgbm_df282_metrics.csv
#   - lgbm_df283_metrics.csv
#   - lgbm_df284_metrics.csv
#   - lgbm_df285_metrics.csv
#   - lgbm_df286_metrics.csv
#   - lgbm_df287_metrics.csv
#   - lgbm_df288_metrics.csv
#   - lgbm_df289_metrics.csv
#   - lgbm_df28_metrics.csv
#   - lgbm_df290_metrics.csv
#   - lgbm_df291_metrics.csv
#   - lgbm_df292_metrics.csv
#   - lgbm_df293_metrics.csv
#   - lgbm_df294_metrics.csv
#   - lgbm_df295_metrics.csv
#   - lgbm_df296_metrics.csv
#   - lgbm_df297_metrics.csv
#   - lgbm_df298_metrics.csv
#   - lgbm_df299_metrics.csv
#   - lgbm_df29_metrics.csv
#   - lgbm_df2_metrics.csv
#   - lgbm_df300_metrics.csv
#   - lgbm_df301_metrics.csv
#   - lgbm_df302_metrics.csv
#   - lgbm_df303_metrics.csv
#   - lgbm_df304_metrics.csv
#   - lgbm_df305_metrics.csv
#   - lgbm_df306_metrics.csv
#   - lgbm_df307_metrics.csv
#   - lgbm_df308_metrics.csv
#   - lgbm_df309_metrics.csv
#   - lgbm_df30_metrics.csv
#   - lgbm_df310_metrics.csv
#   - lgbm_df311_metrics.csv
#   - lgbm_df312_metrics.csv
#   - lgbm_df313_metrics.csv
#   - lgbm_df314_metrics.csv
#   - lgbm_df315_metrics.csv
#   - lgbm_df316_metrics.csv
#   - lgbm_df317_metrics.csv
#   - lgbm_df318_metrics.csv
#   - lgbm_df319_metrics.csv
#   - lgbm_df31_metrics.csv
#   - lgbm_df320_metrics.csv
#   - lgbm_df321_metrics.csv
#   - lgbm_df322_metrics.csv
#   - lgbm_df323_metrics.csv
#   - lgbm_df324_metrics.csv
#   - lgbm_df325_metrics.csv
#   - lgbm_df326_metrics.csv
#   - lgbm_df327_metrics.csv
#   - lgbm_df328_metrics.csv
#   - lgbm_df329_metrics.csv
#   - lgbm_df32_metrics.csv
#   - lgbm_df330_metrics.csv
#   - lgbm_df331_metrics.csv
#   - lgbm_df332_metrics.csv
#   - lgbm_df333_metrics.csv
#   - lgbm_df334_metrics.csv
#   - lgbm_df335_metrics.csv
#   - lgbm_df336_metrics.csv
#   - lgbm_df337_metrics.csv
#   - lgbm_df338_metrics.csv
#   - lgbm_df339_metrics.csv
#   - lgbm_df33_metrics.csv
#   - lgbm_df340_metrics.csv
#   - lgbm_df341_metrics.csv
#   - lgbm_df342_metrics.csv
#   - lgbm_df343_metrics.csv
#   - lgbm_df344_metrics.csv
#   - lgbm_df345_metrics.csv
#   - lgbm_df346_metrics.csv
#   - lgbm_df347_metrics.csv
#   - lgbm_df348_metrics.csv
#   - lgbm_df349_metrics.csv
#   - lgbm_df34_metrics.csv
#   - lgbm_df350_metrics.csv
#   - lgbm_df351_metrics.csv
#   - lgbm_df352_metrics.csv
#   - lgbm_df353_metrics.csv
#   - lgbm_df354_metrics.csv
#   - lgbm_df355_metrics.csv
#   - lgbm_df356_metrics.csv
#   - lgbm_df357_metrics.csv
#   - lgbm_df358_metrics.csv
#   - lgbm_df359_metrics.csv
#   - lgbm_df35_metrics.csv
#   - lgbm_df360_metrics.csv
#   - lgbm_df361_metrics.csv
#   - lgbm_df362_metrics.csv
#   - lgbm_df363_metrics.csv
#   - lgbm_df364_metrics.csv
#   - lgbm_df365_metrics.csv
#   - lgbm_df366_metrics.csv
#   - lgbm_df367_metrics.csv
#   - lgbm_df368_metrics.csv
#   - lgbm_df369_metrics.csv
#   - lgbm_df36_metrics.csv
#   - lgbm_df370_metrics.csv
#   - lgbm_df371_metrics.csv
#   - lgbm_df372_metrics.csv
#   - lgbm_df373_metrics.csv
#   - lgbm_df374_metrics.csv
#   - lgbm_df375_metrics.csv
#   - lgbm_df376_metrics.csv
#   - lgbm_df377_metrics.csv
#   - lgbm_df378_metrics.csv
#   - lgbm_df379_metrics.csv
#   - lgbm_df37_metrics.csv
#   - lgbm_df380_metrics.csv
#   - lgbm_df381_metrics.csv
#   - lgbm_df382_metrics.csv
#   - lgbm_df383_metrics.csv
#   - lgbm_df384_metrics.csv
#   - lgbm_df385_metrics.csv
#   - lgbm_df386_metrics.csv
#   - lgbm_df387_metrics.csv
#   - lgbm_df388_metrics.csv
#   - lgbm_df389_metrics.csv
#   - lgbm_df38_metrics.csv
#   - lgbm_df390_metrics.csv
#   - lgbm_df391_metrics.csv
#   - lgbm_df392_metrics.csv
#   - lgbm_df393_metrics.csv
#   - lgbm_df394_metrics.csv
#   - lgbm_df395_metrics.csv
#   - lgbm_df396_metrics.csv
#   - lgbm_df397_metrics.csv
#   - lgbm_df398_metrics.csv
#   - lgbm_df399_metrics.csv
#   - lgbm_df39_metrics.csv
#   - lgbm_df3_metrics.csv
#   - lgbm_df400_metrics.csv
#   - lgbm_df401_metrics.csv
#   - lgbm_df402_metrics.csv
#   - lgbm_df403_metrics.csv
#   - lgbm_df404_metrics.csv
#   - lgbm_df405_metrics.csv
#   - lgbm_df406_metrics.csv
#   - lgbm_df407_metrics.csv
#   - lgbm_df408_metrics.csv
#   - lgbm_df409_metrics.csv
#   - lgbm_df40_metrics.csv
#   - lgbm_df410_metrics.csv
#   - lgbm_df411_metrics.csv
#   - lgbm_df412_metrics.csv
#   - lgbm_df413_metrics.csv
#   - lgbm_df414_metrics.csv
#   - lgbm_df415_metrics.csv
#   - lgbm_df416_metrics.csv
#   - lgbm_df417_metrics.csv
#   - lgbm_df418_metrics.csv
#   - lgbm_df419_metrics.csv
#   - lgbm_df41_metrics.csv
#   - lgbm_df420_metrics.csv
#   - lgbm_df421_metrics.csv
#   - lgbm_df422_metrics.csv
#   - lgbm_df423_metrics.csv
#   - lgbm_df424_metrics.csv
#   - lgbm_df425_metrics.csv
#   - lgbm_df426_metrics.csv
#   - lgbm_df427_metrics.csv
#   - lgbm_df428_metrics.csv
#   - lgbm_df429_metrics.csv
#   - lgbm_df42_metrics.csv
#   - lgbm_df430_metrics.csv
#   - lgbm_df431_metrics.csv
#   - lgbm_df432_metrics.csv
#   - lgbm_df433_metrics.csv
#   - lgbm_df434_metrics.csv
#   - lgbm_df435_metrics.csv
#   - lgbm_df436_metrics.csv
#   - lgbm_df437_metrics.csv
#   - lgbm_df438_metrics.csv
#   - lgbm_df439_metrics.csv
#   - lgbm_df43_metrics.csv
#   - lgbm_df440_metrics.csv
#   - lgbm_df441_metrics.csv
#   - lgbm_df442_metrics.csv
#   - lgbm_df443_metrics.csv
#   - lgbm_df444_metrics.csv
#   - lgbm_df445_metrics.csv
#   - lgbm_df446_metrics.csv
#   - lgbm_df447_metrics.csv
#   - lgbm_df448_metrics.csv
#   - lgbm_df449_metrics.csv
#   - lgbm_df44_metrics.csv
#   - lgbm_df450_metrics.csv
#   - lgbm_df451_metrics.csv
#   - lgbm_df452_metrics.csv
#   - lgbm_df453_metrics.csv
#   - lgbm_df454_metrics.csv
#   - lgbm_df455_metrics.csv
#   - lgbm_df456_metrics.csv
#   - lgbm_df457_metrics.csv
#   - lgbm_df458_metrics.csv
#   - lgbm_df459_metrics.csv
#   - lgbm_df45_metrics.csv
#   - lgbm_df460_metrics.csv
#   - lgbm_df461_metrics.csv
#   - lgbm_df462_metrics.csv
#   - lgbm_df463_metrics.csv
#   - lgbm_df464_metrics.csv
#   - lgbm_df465_metrics.csv
#   - lgbm_df466_metrics.csv
#   - lgbm_df467_metrics.csv
#   - lgbm_df468_metrics.csv
#   - lgbm_df469_metrics.csv
#   - lgbm_df46_metrics.csv
#   - lgbm_df470_metrics.csv
#   - lgbm_df471_metrics.csv
#   - lgbm_df472_metrics.csv
#   - lgbm_df473_metrics.csv
#   - lgbm_df474_metrics.csv
#   - lgbm_df475_metrics.csv
#   - lgbm_df476_metrics.csv
#   - lgbm_df477_metrics.csv
#   - lgbm_df478_metrics.csv
#   - lgbm_df479_metrics.csv
#   - lgbm_df47_metrics.csv
#   - lgbm_df480_metrics.csv
#   - lgbm_df481_metrics.csv
#   - lgbm_df482_metrics.csv
#   - lgbm_df483_metrics.csv
#   - lgbm_df484_metrics.csv
#   - lgbm_df485_metrics.csv
#   - lgbm_df486_metrics.csv
#   - lgbm_df487_metrics.csv
#   - lgbm_df488_metrics.csv
#   - lgbm_df489_metrics.csv
#   - lgbm_df48_metrics.csv
#   - lgbm_df490_metrics.csv
#   - lgbm_df491_metrics.csv
#   - lgbm_df492_metrics.csv
#   - lgbm_df493_metrics.csv
#   - lgbm_df494_metrics.csv
#   - lgbm_df495_metrics.csv
#   - lgbm_df496_metrics.csv
#   - lgbm_df497_metrics.csv
#   - lgbm_df498_metrics.csv
#   - lgbm_df499_metrics.csv
#   - lgbm_df49_metrics.csv
#   - lgbm_df4_metrics.csv
#   - lgbm_df50_metrics.csv
#   - lgbm_df51_metrics.csv
#   - lgbm_df52_metrics.csv
#   - lgbm_df53_metrics.csv
#   - lgbm_df54_metrics.csv
#   - lgbm_df55_metrics.csv
#   - lgbm_df56_metrics.csv
#   - lgbm_df57_metrics.csv
#   - lgbm_df58_metrics.csv
#   - lgbm_df59_metrics.csv
#   - lgbm_df5_metrics.csv
#   - lgbm_df60_metrics.csv
#   - lgbm_df61_metrics.csv
#   - lgbm_df62_metrics.csv
#   - lgbm_df63_metrics.csv
#   - lgbm_df64_metrics.csv
#   - lgbm_df65_metrics.csv
#   - lgbm_df66_metrics.csv
#   - lgbm_df67_metrics.csv
#   - lgbm_df68_metrics.csv
#   - lgbm_df69_metrics.csv
#   - lgbm_df6_metrics.csv
#   - lgbm_df70_metrics.csv
#   - lgbm_df71_metrics.csv
#   - lgbm_df72_metrics.csv
#   - lgbm_df73_metrics.csv
#   - lgbm_df74_metrics.csv
#   - lgbm_df75_metrics.csv
#   - lgbm_df76_metrics.csv
#   - lgbm_df77_metrics.csv
#   - lgbm_df78_metrics.csv
#   - lgbm_df79_metrics.csv
#   - lgbm_df7_metrics.csv
#   - lgbm_df80_metrics.csv
#   - lgbm_df81_metrics.csv
#   - lgbm_df82_metrics.csv
#   - lgbm_df83_metrics.csv
#   - lgbm_df84_metrics.csv
#   - lgbm_df85_metrics.csv
#   - lgbm_df86_metrics.csv
#   - lgbm_df87_metrics.csv
#   - lgbm_df88_metrics.csv
#   - lgbm_df89_metrics.csv
#   - lgbm_df8_metrics.csv
#   - lgbm_df90_metrics.csv
#   - lgbm_df91_metrics.csv
#   - lgbm_df92_metrics.csv
#   - lgbm_df93_metrics.csv
#   - lgbm_df94_metrics.csv
#   - lgbm_df95_metrics.csv
#   - lgbm_df96_metrics.csv
#   - lgbm_df97_metrics.csv
#   - lgbm_df98_metrics.csv
#   - lgbm_df99_metrics.csv
#   - lgbm_df9_metrics.csv
# read: lgbm_df100_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df101_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df102_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df103_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df104_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df105_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df106_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df107_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df108_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df109_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df10_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df110_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df111_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df112_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df113_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df114_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df115_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df116_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df117_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df118_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df119_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df11_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df120_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df121_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df122_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df123_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df124_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df125_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df126_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df127_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df128_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df129_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df12_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df130_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df131_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df132_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df133_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df134_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df135_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df136_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df137_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df138_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df139_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df13_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df140_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df141_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df142_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df143_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df144_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df145_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df146_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df147_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df148_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df149_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df14_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df150_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df151_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df152_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df153_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df154_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df155_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df156_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df157_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df158_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df159_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df15_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df160_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df161_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df162_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df163_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df164_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df165_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df166_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df167_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df168_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df169_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df16_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df170_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df171_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df172_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df173_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df174_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df175_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df176_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df177_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df178_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df179_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df17_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df180_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df181_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df182_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df183_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df184_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df185_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df186_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df187_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df188_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df189_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df18_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df190_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df191_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df192_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df193_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df194_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df195_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df196_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df197_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df198_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df199_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df19_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df1_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df200_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df201_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df202_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df203_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df204_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df205_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df206_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df207_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df208_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df209_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df20_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df210_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df211_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df212_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df213_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df214_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df215_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df216_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df217_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df218_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df219_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df21_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df220_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df221_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df222_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df223_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df224_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df225_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df226_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df227_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df228_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df229_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df22_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df230_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df231_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df232_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df233_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df234_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df235_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df236_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df237_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df238_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df239_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df23_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df240_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df241_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df242_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df243_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df244_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df245_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df246_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df247_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df248_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df249_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df24_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df250_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df251_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df252_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df253_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df254_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df255_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df256_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df257_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df258_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df259_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df25_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df260_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df261_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df262_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df263_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df264_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df265_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df266_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df267_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df268_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df269_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df26_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df270_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df271_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df272_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df273_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df274_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df275_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df276_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df277_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df278_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df279_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df27_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df280_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df281_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df282_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df283_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df284_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df285_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df286_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df287_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df288_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df289_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df28_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df290_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df291_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df292_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df293_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df294_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df295_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df296_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df297_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df298_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df299_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df29_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df2_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df300_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df301_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df302_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df303_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df304_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df305_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df306_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df307_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df308_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df309_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df30_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df310_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df311_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df312_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df313_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df314_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df315_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df316_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df317_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df318_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df319_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df31_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df320_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df321_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df322_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df323_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df324_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df325_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df326_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df327_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df328_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df329_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df32_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df330_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df331_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df332_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df333_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df334_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df335_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df336_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df337_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df338_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df339_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df33_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df340_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df341_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df342_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df343_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df344_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df345_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df346_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df347_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df348_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df349_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df34_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df350_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df351_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df352_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df353_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df354_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df355_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df356_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df357_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df358_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df359_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df35_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df360_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df361_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df362_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df363_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df364_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df365_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df366_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df367_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df368_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df369_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df36_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df370_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df371_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df372_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df373_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df374_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df375_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df376_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df377_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df378_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df379_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df37_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df380_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df381_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df382_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df383_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df384_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df385_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df386_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df387_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df388_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df389_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df38_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df390_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df391_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df392_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df393_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df394_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df395_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df396_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df397_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df398_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df399_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df39_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df3_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df400_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df401_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df402_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df403_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df404_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df405_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df406_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df407_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df408_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df409_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df40_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df410_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df411_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df412_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df413_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df414_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df415_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df416_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df417_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df418_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df419_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df41_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df420_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df421_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df422_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df423_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df424_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df425_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df426_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df427_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df428_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df429_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df42_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df430_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df431_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df432_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df433_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df434_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df435_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df436_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df437_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df438_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df439_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df43_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df440_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df441_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df442_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df443_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df444_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df445_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df446_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df447_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df448_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df449_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df44_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df450_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df451_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df452_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df453_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df454_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df455_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df456_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df457_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df458_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df459_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df45_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df460_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df461_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df462_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df463_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df464_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df465_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df466_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df467_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df468_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df469_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df46_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df470_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df471_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df472_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df473_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df474_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df475_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df476_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df477_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df478_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df479_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df47_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df480_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df481_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df482_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df483_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df484_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df485_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df486_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df487_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df488_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df489_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df48_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df490_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df491_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df492_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df493_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df494_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df495_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df496_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df497_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df498_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df499_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df49_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df4_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df50_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df51_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df52_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df53_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df54_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df55_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df56_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df57_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df58_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df59_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df5_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df60_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df61_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df62_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df63_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df64_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df65_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df66_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df67_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df68_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df69_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df6_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df70_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df71_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df72_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df73_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df74_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df75_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df76_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df77_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df78_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df79_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df7_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df80_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df81_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df82_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df83_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df84_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df85_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df86_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df87_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df88_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df89_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df8_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df90_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df91_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df92_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df93_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df94_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df95_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df96_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df97_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df98_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df99_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv
# read: lgbm_df9_metrics.csv
# Merged saved as: ../LightGBM/metrics/merged_metrics.csv

# %%
merged = pd.read_csv('../LightGBM/metrics/merged_metrics.csv')

# %% [markdown]
# ### First, sort overall metrics.

# %%
# Sort by accuracy.
sorted_merged = merged.sort_values('Accuracy', ascending=True)

# Save new CSV file.
sorted_merged.to_csv('../LightGBM/metrics/sorted_accuracy.csv', index=False)
print("Saved.")
# Out:
# Saved.

# %%
# Sort by PREC.
sorted_merged = merged.sort_values('Precision', ascending=True)

# Save new CSV file.
sorted_merged.to_csv('../LightGBM/metrics/sorted_precision.csv', index=False)
print("Saved.")
# Out:
# Saved.

# %%
print(merged.columns)
# Out:
# Index(['Model', 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'ROC AUC Score',
#        'Overall MCC'],
#       dtype='object')

# %%
# Sort by REC.
sorted_merged = merged.sort_values('Recall', ascending=True)

# Save new CSV file.
sorted_merged.to_csv('../LightGBM/metrics/sorted_recall.csv', index=False)
print("Saved.")
# Out:
# Saved.

# %%
# Sort by F1 score.
sorted_merged = merged.sort_values('F1 Score', ascending=True)

# Save new CSV file.
sorted_merged.to_csv('../LightGBM/metrics/sorted_f1.csv', index=False)
print("Saved.")
# Out:
# Saved.

# %%
# Sort by ROC AUC score.
sorted_merged = merged.sort_values('ROC AUC Score', ascending=True)

# Save new CSV file.
sorted_merged.to_csv('../LightGBM/metrics/sorted_roc.csv', index=False)
print("Saved.")
# Out:
# Saved.

# %%
# Sort by MCC.
sorted_merged = merged.sort_values('Overall MCC', ascending=True)

# Save new CSV file.
sorted_merged.to_csv('../LightGBM/metrics/sorted_mcc.csv', index=False)
print("Saved.")
# Out:
# Saved.

# %% [markdown]
# ### Now, need to load and sort class-wise metrics.

# %%
# Find the metrics and report directories.
metrics_dir = '../LightGBM/metrics/report'

# Make CSV list.
csv_files = glob.glob(os.path.join(metrics_dir, "reportlgbm_df*_report.csv"))
print(f"Found {len(csv_files)} report files.")

# Init list for data.
data = []

def extract_precision(content, class_name):
    """ 
    Extract PREC metrics. 
    """
    match = re.search(f"{class_name}\s+(\d+\.\d+)", content)
    return float(match.group(1)) if match else None

# Iterate over each file.
for file in csv_files:
    model_number = re.search(r'df(\d+)_report', file)
    if model_number:
        model_number = int(model_number.group(1))
    else:
        print(f"Error!")
        continue
    try:
        with open(file, 'r') as f:
            content = f.read()
        
        # Get PREC for each class.
        gof_precision = extract_precision(content, "GOF")
        lof_precision = extract_precision(content, "LOF")
        neutral_precision = extract_precision(content, "Neutral")
        
        # Add to list.
        data.append({
            'Model': model_number,
            'GOF Precision': gof_precision,
            'LOF Precision': lof_precision,
            'Neutral Precision': neutral_precision
        })
        print(f"processed: {os.path.basename(file)}")
    except Exception as e:
        print(f"Error! {os.path.basename(file)}: {str(e)}")

# Compile into df.
merged_df = pd.DataFrame(data)

if merged_df.empty:
    print("Error!")
else:
    merged_df.set_index('Model', inplace=True)
    merged_df.sort_index(inplace=True)
    output_file = os.path.join(metrics_dir, "merged_precision_report.csv")
    merged_df.to_csv(output_file)
    print(f"Merged saved as: {output_file}")
# Out:
# Found 499 report files.
# processed: reportlgbm_df100_report.csv
# processed: reportlgbm_df101_report.csv
# processed: reportlgbm_df102_report.csv
# processed: reportlgbm_df103_report.csv
# processed: reportlgbm_df104_report.csv
# processed: reportlgbm_df105_report.csv
# processed: reportlgbm_df106_report.csv
# processed: reportlgbm_df107_report.csv
# processed: reportlgbm_df108_report.csv
# processed: reportlgbm_df109_report.csv
# processed: reportlgbm_df10_report.csv
# processed: reportlgbm_df110_report.csv
# processed: reportlgbm_df111_report.csv
# processed: reportlgbm_df112_report.csv
# processed: reportlgbm_df113_report.csv
# processed: reportlgbm_df114_report.csv
# processed: reportlgbm_df115_report.csv
# processed: reportlgbm_df116_report.csv
# processed: reportlgbm_df117_report.csv
# processed: reportlgbm_df118_report.csv
# processed: reportlgbm_df119_report.csv
# processed: reportlgbm_df11_report.csv
# processed: reportlgbm_df120_report.csv
# processed: reportlgbm_df121_report.csv
# processed: reportlgbm_df122_report.csv
# processed: reportlgbm_df123_report.csv
# processed: reportlgbm_df124_report.csv
# processed: reportlgbm_df125_report.csv
# processed: reportlgbm_df126_report.csv
# processed: reportlgbm_df127_report.csv
# processed: reportlgbm_df128_report.csv
# processed: reportlgbm_df129_report.csv
# processed: reportlgbm_df12_report.csv
# processed: reportlgbm_df130_report.csv
# processed: reportlgbm_df131_report.csv
# processed: reportlgbm_df132_report.csv
# processed: reportlgbm_df133_report.csv
# processed: reportlgbm_df134_report.csv
# processed: reportlgbm_df135_report.csv
# processed: reportlgbm_df136_report.csv
# processed: reportlgbm_df137_report.csv
# processed: reportlgbm_df138_report.csv
# processed: reportlgbm_df139_report.csv
# processed: reportlgbm_df13_report.csv
# processed: reportlgbm_df140_report.csv
# processed: reportlgbm_df141_report.csv
# processed: reportlgbm_df142_report.csv
# processed: reportlgbm_df143_report.csv
# processed: reportlgbm_df144_report.csv
# processed: reportlgbm_df145_report.csv
# processed: reportlgbm_df146_report.csv
# processed: reportlgbm_df147_report.csv
# processed: reportlgbm_df148_report.csv
# processed: reportlgbm_df149_report.csv
# processed: reportlgbm_df14_report.csv
# processed: reportlgbm_df150_report.csv
# processed: reportlgbm_df151_report.csv
# processed: reportlgbm_df152_report.csv
# processed: reportlgbm_df153_report.csv
# processed: reportlgbm_df154_report.csv
# processed: reportlgbm_df155_report.csv
# processed: reportlgbm_df156_report.csv
# processed: reportlgbm_df157_report.csv
# processed: reportlgbm_df158_report.csv
# processed: reportlgbm_df159_report.csv
# processed: reportlgbm_df15_report.csv
# processed: reportlgbm_df160_report.csv
# processed: reportlgbm_df161_report.csv
# processed: reportlgbm_df162_report.csv
# processed: reportlgbm_df163_report.csv
# processed: reportlgbm_df164_report.csv
# processed: reportlgbm_df165_report.csv
# processed: reportlgbm_df166_report.csv
# processed: reportlgbm_df167_report.csv
# processed: reportlgbm_df168_report.csv
# processed: reportlgbm_df169_report.csv
# processed: reportlgbm_df16_report.csv
# processed: reportlgbm_df170_report.csv
# processed: reportlgbm_df171_report.csv
# processed: reportlgbm_df172_report.csv
# processed: reportlgbm_df173_report.csv
# processed: reportlgbm_df174_report.csv
# processed: reportlgbm_df175_report.csv
# processed: reportlgbm_df176_report.csv
# processed: reportlgbm_df177_report.csv
# processed: reportlgbm_df178_report.csv
# processed: reportlgbm_df179_report.csv
# processed: reportlgbm_df17_report.csv
# processed: reportlgbm_df180_report.csv
# processed: reportlgbm_df181_report.csv
# processed: reportlgbm_df182_report.csv
# processed: reportlgbm_df183_report.csv
# processed: reportlgbm_df184_report.csv
# processed: reportlgbm_df185_report.csv
# processed: reportlgbm_df186_report.csv
# processed: reportlgbm_df187_report.csv
# processed: reportlgbm_df188_report.csv
# processed: reportlgbm_df189_report.csv
# processed: reportlgbm_df18_report.csv
# processed: reportlgbm_df190_report.csv
# processed: reportlgbm_df191_report.csv
# processed: reportlgbm_df192_report.csv
# processed: reportlgbm_df193_report.csv
# processed: reportlgbm_df194_report.csv
# processed: reportlgbm_df195_report.csv
# processed: reportlgbm_df196_report.csv
# processed: reportlgbm_df197_report.csv
# processed: reportlgbm_df198_report.csv
# processed: reportlgbm_df199_report.csv
# processed: reportlgbm_df19_report.csv
# processed: reportlgbm_df1_report.csv
# processed: reportlgbm_df200_report.csv
# processed: reportlgbm_df201_report.csv
# processed: reportlgbm_df202_report.csv
# processed: reportlgbm_df203_report.csv
# processed: reportlgbm_df204_report.csv
# processed: reportlgbm_df205_report.csv
# processed: reportlgbm_df206_report.csv
# processed: reportlgbm_df207_report.csv
# processed: reportlgbm_df208_report.csv
# processed: reportlgbm_df209_report.csv
# processed: reportlgbm_df20_report.csv
# processed: reportlgbm_df210_report.csv
# processed: reportlgbm_df211_report.csv
# processed: reportlgbm_df212_report.csv
# processed: reportlgbm_df213_report.csv
# processed: reportlgbm_df214_report.csv
# processed: reportlgbm_df215_report.csv
# processed: reportlgbm_df216_report.csv
# processed: reportlgbm_df217_report.csv
# processed: reportlgbm_df218_report.csv
# processed: reportlgbm_df219_report.csv
# processed: reportlgbm_df21_report.csv
# processed: reportlgbm_df220_report.csv
# processed: reportlgbm_df221_report.csv
# processed: reportlgbm_df222_report.csv
# processed: reportlgbm_df223_report.csv
# processed: reportlgbm_df224_report.csv
# processed: reportlgbm_df225_report.csv
# processed: reportlgbm_df226_report.csv
# processed: reportlgbm_df227_report.csv
# processed: reportlgbm_df228_report.csv
# processed: reportlgbm_df229_report.csv
# processed: reportlgbm_df22_report.csv
# processed: reportlgbm_df230_report.csv
# processed: reportlgbm_df231_report.csv
# processed: reportlgbm_df232_report.csv
# processed: reportlgbm_df233_report.csv
# processed: reportlgbm_df234_report.csv
# processed: reportlgbm_df235_report.csv
# processed: reportlgbm_df236_report.csv
# processed: reportlgbm_df237_report.csv
# processed: reportlgbm_df238_report.csv
# processed: reportlgbm_df239_report.csv
# processed: reportlgbm_df23_report.csv
# processed: reportlgbm_df240_report.csv
# processed: reportlgbm_df241_report.csv
# processed: reportlgbm_df242_report.csv
# processed: reportlgbm_df243_report.csv
# processed: reportlgbm_df244_report.csv
# processed: reportlgbm_df245_report.csv
# processed: reportlgbm_df246_report.csv
# processed: reportlgbm_df247_report.csv
# processed: reportlgbm_df248_report.csv
# processed: reportlgbm_df249_report.csv
# processed: reportlgbm_df24_report.csv
# processed: reportlgbm_df250_report.csv
# processed: reportlgbm_df251_report.csv
# processed: reportlgbm_df252_report.csv
# processed: reportlgbm_df253_report.csv
# processed: reportlgbm_df254_report.csv
# processed: reportlgbm_df255_report.csv
# processed: reportlgbm_df256_report.csv
# processed: reportlgbm_df257_report.csv
# processed: reportlgbm_df258_report.csv
# processed: reportlgbm_df259_report.csv
# processed: reportlgbm_df25_report.csv
# processed: reportlgbm_df260_report.csv
# processed: reportlgbm_df261_report.csv
# processed: reportlgbm_df262_report.csv
# processed: reportlgbm_df263_report.csv
# processed: reportlgbm_df264_report.csv
# processed: reportlgbm_df265_report.csv
# processed: reportlgbm_df266_report.csv
# processed: reportlgbm_df267_report.csv
# processed: reportlgbm_df268_report.csv
# processed: reportlgbm_df269_report.csv
# processed: reportlgbm_df26_report.csv
# processed: reportlgbm_df270_report.csv
# processed: reportlgbm_df271_report.csv
# processed: reportlgbm_df272_report.csv
# processed: reportlgbm_df273_report.csv
# processed: reportlgbm_df274_report.csv
# processed: reportlgbm_df275_report.csv
# processed: reportlgbm_df276_report.csv
# processed: reportlgbm_df277_report.csv
# processed: reportlgbm_df278_report.csv
# processed: reportlgbm_df279_report.csv
# processed: reportlgbm_df27_report.csv
# processed: reportlgbm_df280_report.csv
# processed: reportlgbm_df281_report.csv
# processed: reportlgbm_df282_report.csv
# processed: reportlgbm_df283_report.csv
# processed: reportlgbm_df284_report.csv
# processed: reportlgbm_df285_report.csv
# processed: reportlgbm_df286_report.csv
# processed: reportlgbm_df287_report.csv
# processed: reportlgbm_df288_report.csv
# processed: reportlgbm_df289_report.csv
# processed: reportlgbm_df28_report.csv
# processed: reportlgbm_df290_report.csv
# processed: reportlgbm_df291_report.csv
# processed: reportlgbm_df292_report.csv
# processed: reportlgbm_df293_report.csv
# processed: reportlgbm_df294_report.csv
# processed: reportlgbm_df295_report.csv
# processed: reportlgbm_df296_report.csv
# processed: reportlgbm_df297_report.csv
# processed: reportlgbm_df298_report.csv
# processed: reportlgbm_df299_report.csv
# processed: reportlgbm_df29_report.csv
# processed: reportlgbm_df2_report.csv
# processed: reportlgbm_df300_report.csv
# processed: reportlgbm_df301_report.csv
# processed: reportlgbm_df302_report.csv
# processed: reportlgbm_df303_report.csv
# processed: reportlgbm_df304_report.csv
# processed: reportlgbm_df305_report.csv
# processed: reportlgbm_df306_report.csv
# processed: reportlgbm_df307_report.csv
# processed: reportlgbm_df308_report.csv
# processed: reportlgbm_df309_report.csv
# processed: reportlgbm_df30_report.csv
# processed: reportlgbm_df310_report.csv
# processed: reportlgbm_df311_report.csv
# processed: reportlgbm_df312_report.csv
# processed: reportlgbm_df313_report.csv
# processed: reportlgbm_df314_report.csv
# processed: reportlgbm_df315_report.csv
# processed: reportlgbm_df316_report.csv
# processed: reportlgbm_df317_report.csv
# processed: reportlgbm_df318_report.csv
# processed: reportlgbm_df319_report.csv
# processed: reportlgbm_df31_report.csv
# processed: reportlgbm_df320_report.csv
# processed: reportlgbm_df321_report.csv
# processed: reportlgbm_df322_report.csv
# processed: reportlgbm_df323_report.csv
# processed: reportlgbm_df324_report.csv
# processed: reportlgbm_df325_report.csv
# processed: reportlgbm_df326_report.csv
# processed: reportlgbm_df327_report.csv
# processed: reportlgbm_df328_report.csv
# processed: reportlgbm_df329_report.csv
# processed: reportlgbm_df32_report.csv
# processed: reportlgbm_df330_report.csv
# processed: reportlgbm_df331_report.csv
# processed: reportlgbm_df332_report.csv
# processed: reportlgbm_df333_report.csv
# processed: reportlgbm_df334_report.csv
# processed: reportlgbm_df335_report.csv
# processed: reportlgbm_df336_report.csv
# processed: reportlgbm_df337_report.csv
# processed: reportlgbm_df338_report.csv
# processed: reportlgbm_df339_report.csv
# processed: reportlgbm_df33_report.csv
# processed: reportlgbm_df340_report.csv
# processed: reportlgbm_df341_report.csv
# processed: reportlgbm_df342_report.csv
# processed: reportlgbm_df343_report.csv
# processed: reportlgbm_df344_report.csv
# processed: reportlgbm_df345_report.csv
# processed: reportlgbm_df346_report.csv
# processed: reportlgbm_df347_report.csv
# processed: reportlgbm_df348_report.csv
# processed: reportlgbm_df349_report.csv
# processed: reportlgbm_df34_report.csv
# processed: reportlgbm_df350_report.csv
# processed: reportlgbm_df351_report.csv
# processed: reportlgbm_df352_report.csv
# processed: reportlgbm_df353_report.csv
# processed: reportlgbm_df354_report.csv
# processed: reportlgbm_df355_report.csv
# processed: reportlgbm_df356_report.csv
# processed: reportlgbm_df357_report.csv
# processed: reportlgbm_df358_report.csv
# processed: reportlgbm_df359_report.csv
# processed: reportlgbm_df35_report.csv
# processed: reportlgbm_df360_report.csv
# processed: reportlgbm_df361_report.csv
# processed: reportlgbm_df362_report.csv
# processed: reportlgbm_df363_report.csv
# processed: reportlgbm_df364_report.csv
# processed: reportlgbm_df365_report.csv
# processed: reportlgbm_df366_report.csv
# processed: reportlgbm_df367_report.csv
# processed: reportlgbm_df368_report.csv
# processed: reportlgbm_df369_report.csv
# processed: reportlgbm_df36_report.csv
# processed: reportlgbm_df370_report.csv
# processed: reportlgbm_df371_report.csv
# processed: reportlgbm_df372_report.csv
# processed: reportlgbm_df373_report.csv
# processed: reportlgbm_df374_report.csv
# processed: reportlgbm_df375_report.csv
# processed: reportlgbm_df376_report.csv
# processed: reportlgbm_df377_report.csv
# processed: reportlgbm_df378_report.csv
# processed: reportlgbm_df379_report.csv
# processed: reportlgbm_df37_report.csv
# processed: reportlgbm_df380_report.csv
# processed: reportlgbm_df381_report.csv
# processed: reportlgbm_df382_report.csv
# processed: reportlgbm_df383_report.csv
# processed: reportlgbm_df384_report.csv
# processed: reportlgbm_df385_report.csv
# processed: reportlgbm_df386_report.csv
# processed: reportlgbm_df387_report.csv
# processed: reportlgbm_df388_report.csv
# processed: reportlgbm_df389_report.csv
# processed: reportlgbm_df38_report.csv
# processed: reportlgbm_df390_report.csv
# processed: reportlgbm_df391_report.csv
# processed: reportlgbm_df392_report.csv
# processed: reportlgbm_df393_report.csv
# processed: reportlgbm_df394_report.csv
# processed: reportlgbm_df395_report.csv
# processed: reportlgbm_df396_report.csv
# processed: reportlgbm_df397_report.csv
# processed: reportlgbm_df398_report.csv
# processed: reportlgbm_df399_report.csv
# processed: reportlgbm_df39_report.csv
# processed: reportlgbm_df3_report.csv
# processed: reportlgbm_df400_report.csv
# processed: reportlgbm_df401_report.csv
# processed: reportlgbm_df402_report.csv
# processed: reportlgbm_df403_report.csv
# processed: reportlgbm_df404_report.csv
# processed: reportlgbm_df405_report.csv
# processed: reportlgbm_df406_report.csv
# processed: reportlgbm_df407_report.csv
# processed: reportlgbm_df408_report.csv
# processed: reportlgbm_df409_report.csv
# processed: reportlgbm_df40_report.csv
# processed: reportlgbm_df410_report.csv
# processed: reportlgbm_df411_report.csv
# processed: reportlgbm_df412_report.csv
# processed: reportlgbm_df413_report.csv
# processed: reportlgbm_df414_report.csv
# processed: reportlgbm_df415_report.csv
# processed: reportlgbm_df416_report.csv
# processed: reportlgbm_df417_report.csv
# processed: reportlgbm_df418_report.csv
# processed: reportlgbm_df419_report.csv
# processed: reportlgbm_df41_report.csv
# processed: reportlgbm_df420_report.csv
# processed: reportlgbm_df421_report.csv
# processed: reportlgbm_df422_report.csv
# processed: reportlgbm_df423_report.csv
# processed: reportlgbm_df424_report.csv
# processed: reportlgbm_df425_report.csv
# processed: reportlgbm_df426_report.csv
# processed: reportlgbm_df427_report.csv
# processed: reportlgbm_df428_report.csv
# processed: reportlgbm_df429_report.csv
# processed: reportlgbm_df42_report.csv
# processed: reportlgbm_df430_report.csv
# processed: reportlgbm_df431_report.csv
# processed: reportlgbm_df432_report.csv
# processed: reportlgbm_df433_report.csv
# processed: reportlgbm_df434_report.csv
# processed: reportlgbm_df435_report.csv
# processed: reportlgbm_df436_report.csv
# processed: reportlgbm_df437_report.csv
# processed: reportlgbm_df438_report.csv
# processed: reportlgbm_df439_report.csv
# processed: reportlgbm_df43_report.csv
# processed: reportlgbm_df440_report.csv
# processed: reportlgbm_df441_report.csv
# processed: reportlgbm_df442_report.csv
# processed: reportlgbm_df443_report.csv
# processed: reportlgbm_df444_report.csv
# processed: reportlgbm_df445_report.csv
# processed: reportlgbm_df446_report.csv
# processed: reportlgbm_df447_report.csv
# processed: reportlgbm_df448_report.csv
# processed: reportlgbm_df449_report.csv
# processed: reportlgbm_df44_report.csv
# processed: reportlgbm_df450_report.csv
# processed: reportlgbm_df451_report.csv
# processed: reportlgbm_df452_report.csv
# processed: reportlgbm_df453_report.csv
# processed: reportlgbm_df454_report.csv
# processed: reportlgbm_df455_report.csv
# processed: reportlgbm_df456_report.csv
# processed: reportlgbm_df457_report.csv
# processed: reportlgbm_df458_report.csv
# processed: reportlgbm_df459_report.csv
# processed: reportlgbm_df45_report.csv
# processed: reportlgbm_df460_report.csv
# processed: reportlgbm_df461_report.csv
# processed: reportlgbm_df462_report.csv
# processed: reportlgbm_df463_report.csv
# processed: reportlgbm_df464_report.csv
# processed: reportlgbm_df465_report.csv
# processed: reportlgbm_df466_report.csv
# processed: reportlgbm_df467_report.csv
# processed: reportlgbm_df468_report.csv
# processed: reportlgbm_df469_report.csv
# processed: reportlgbm_df46_report.csv
# processed: reportlgbm_df470_report.csv
# processed: reportlgbm_df471_report.csv
# processed: reportlgbm_df472_report.csv
# processed: reportlgbm_df473_report.csv
# processed: reportlgbm_df474_report.csv
# processed: reportlgbm_df475_report.csv
# processed: reportlgbm_df476_report.csv
# processed: reportlgbm_df477_report.csv
# processed: reportlgbm_df478_report.csv
# processed: reportlgbm_df479_report.csv
# processed: reportlgbm_df47_report.csv
# processed: reportlgbm_df480_report.csv
# processed: reportlgbm_df481_report.csv
# processed: reportlgbm_df482_report.csv
# processed: reportlgbm_df483_report.csv
# processed: reportlgbm_df484_report.csv
# processed: reportlgbm_df485_report.csv
# processed: reportlgbm_df486_report.csv
# processed: reportlgbm_df487_report.csv
# processed: reportlgbm_df488_report.csv
# processed: reportlgbm_df489_report.csv
# processed: reportlgbm_df48_report.csv
# processed: reportlgbm_df490_report.csv
# processed: reportlgbm_df491_report.csv
# processed: reportlgbm_df492_report.csv
# processed: reportlgbm_df493_report.csv
# processed: reportlgbm_df494_report.csv
# processed: reportlgbm_df495_report.csv
# processed: reportlgbm_df496_report.csv
# processed: reportlgbm_df497_report.csv
# processed: reportlgbm_df498_report.csv
# processed: reportlgbm_df499_report.csv
# processed: reportlgbm_df49_report.csv
# processed: reportlgbm_df4_report.csv
# processed: reportlgbm_df50_report.csv
# processed: reportlgbm_df51_report.csv
# processed: reportlgbm_df52_report.csv
# processed: reportlgbm_df53_report.csv
# processed: reportlgbm_df54_report.csv
# processed: reportlgbm_df55_report.csv
# processed: reportlgbm_df56_report.csv
# processed: reportlgbm_df57_report.csv
# processed: reportlgbm_df58_report.csv
# processed: reportlgbm_df59_report.csv
# processed: reportlgbm_df5_report.csv
# processed: reportlgbm_df60_report.csv
# processed: reportlgbm_df61_report.csv
# processed: reportlgbm_df62_report.csv
# processed: reportlgbm_df63_report.csv
# processed: reportlgbm_df64_report.csv
# processed: reportlgbm_df65_report.csv
# processed: reportlgbm_df66_report.csv
# processed: reportlgbm_df67_report.csv
# processed: reportlgbm_df68_report.csv
# processed: reportlgbm_df69_report.csv
# processed: reportlgbm_df6_report.csv
# processed: reportlgbm_df70_report.csv
# processed: reportlgbm_df71_report.csv
# processed: reportlgbm_df72_report.csv
# processed: reportlgbm_df73_report.csv
# processed: reportlgbm_df74_report.csv
# processed: reportlgbm_df75_report.csv
# processed: reportlgbm_df76_report.csv
# processed: reportlgbm_df77_report.csv
# processed: reportlgbm_df78_report.csv
# processed: reportlgbm_df79_report.csv
# processed: reportlgbm_df7_report.csv
# processed: reportlgbm_df80_report.csv
# processed: reportlgbm_df81_report.csv
# processed: reportlgbm_df82_report.csv
# processed: reportlgbm_df83_report.csv
# processed: reportlgbm_df84_report.csv
# processed: reportlgbm_df85_report.csv
# processed: reportlgbm_df86_report.csv
# processed: reportlgbm_df87_report.csv
# processed: reportlgbm_df88_report.csv
# processed: reportlgbm_df89_report.csv
# processed: reportlgbm_df8_report.csv
# processed: reportlgbm_df90_report.csv
# processed: reportlgbm_df91_report.csv
# processed: reportlgbm_df92_report.csv
# processed: reportlgbm_df93_report.csv
# processed: reportlgbm_df94_report.csv
# processed: reportlgbm_df95_report.csv
# processed: reportlgbm_df96_report.csv
# processed: reportlgbm_df97_report.csv
# processed: reportlgbm_df98_report.csv
# processed: reportlgbm_df99_report.csv
# processed: reportlgbm_df9_report.csv
# Merged saved as: ../LightGBM/metrics/report/merged_precision_report.csv

# %%
# Find the metrics and report directories.
metrics_dir = '../LightGBM/metrics/report'

# Make CSV list.
csv_files = glob.glob(os.path.join(metrics_dir, "reportlgbm_df*_report.csv"))
print(f"Found {len(csv_files)} report files.")

# Init list for data.
data = []

def extract_recall(content, class_name):
    """ 
    Extract REC metrics. 
    """
    match = re.search(f"{class_name}\s+\d+\.\d+\s+(\d+\.\d+)", content)
    return float(match.group(1)) if match else None

# Iterate over each file.
for file in csv_files:
    model_number = re.search(r'df(\d+)_report', file)
    if model_number:
        model_number = int(model_number.group(1))
    else:
        print(f"Error!")
        continue
    try:
        with open(file, 'r') as f:
            content = f.read()
        
        # Get REC for each class.
        gof_recall = extract_recall(content, "GOF")
        lof_recall = extract_recall(content, "LOF")
        neutral_recall = extract_recall(content, "Neutral")
        
        # Add to list.
        data.append({
            'Model': model_number,
            'GOF Recall': gof_recall,
            'LOF Recall': lof_recall,
            'Neutral Recall': neutral_recall
        })
        print(f"processed: {os.path.basename(file)}")
    except Exception as e:
        print(f"Error! {os.path.basename(file)}: {str(e)}")

# Compile into df.
merged_df = pd.DataFrame(data)

if merged_df.empty:
    print("Error!")
else:
    merged_df.set_index('Model', inplace=True)
    merged_df.sort_index(inplace=True)
    output_file = os.path.join(metrics_dir, "merged_precision_report.csv")
    merged_df.to_csv(output_file)
    print(f"Merged saved as: {output_file}")
# Out:
# Found 499 report files.
# processed: reportlgbm_df100_report.csv
# processed: reportlgbm_df101_report.csv
# processed: reportlgbm_df102_report.csv
# processed: reportlgbm_df103_report.csv
# processed: reportlgbm_df104_report.csv
# processed: reportlgbm_df105_report.csv
# processed: reportlgbm_df106_report.csv
# processed: reportlgbm_df107_report.csv
# processed: reportlgbm_df108_report.csv
# processed: reportlgbm_df109_report.csv
# processed: reportlgbm_df10_report.csv
# processed: reportlgbm_df110_report.csv
# processed: reportlgbm_df111_report.csv
# processed: reportlgbm_df112_report.csv
# processed: reportlgbm_df113_report.csv
# processed: reportlgbm_df114_report.csv
# processed: reportlgbm_df115_report.csv
# processed: reportlgbm_df116_report.csv
# processed: reportlgbm_df117_report.csv
# processed: reportlgbm_df118_report.csv
# processed: reportlgbm_df119_report.csv
# processed: reportlgbm_df11_report.csv
# processed: reportlgbm_df120_report.csv
# processed: reportlgbm_df121_report.csv
# processed: reportlgbm_df122_report.csv
# processed: reportlgbm_df123_report.csv
# processed: reportlgbm_df124_report.csv
# processed: reportlgbm_df125_report.csv
# processed: reportlgbm_df126_report.csv
# processed: reportlgbm_df127_report.csv
# processed: reportlgbm_df128_report.csv
# processed: reportlgbm_df129_report.csv
# processed: reportlgbm_df12_report.csv
# processed: reportlgbm_df130_report.csv
# processed: reportlgbm_df131_report.csv
# processed: reportlgbm_df132_report.csv
# processed: reportlgbm_df133_report.csv
# processed: reportlgbm_df134_report.csv
# processed: reportlgbm_df135_report.csv
# processed: reportlgbm_df136_report.csv
# processed: reportlgbm_df137_report.csv
# processed: reportlgbm_df138_report.csv
# processed: reportlgbm_df139_report.csv
# processed: reportlgbm_df13_report.csv
# processed: reportlgbm_df140_report.csv
# processed: reportlgbm_df141_report.csv
# processed: reportlgbm_df142_report.csv
# processed: reportlgbm_df143_report.csv
# processed: reportlgbm_df144_report.csv
# processed: reportlgbm_df145_report.csv
# processed: reportlgbm_df146_report.csv
# processed: reportlgbm_df147_report.csv
# processed: reportlgbm_df148_report.csv
# processed: reportlgbm_df149_report.csv
# processed: reportlgbm_df14_report.csv
# processed: reportlgbm_df150_report.csv
# processed: reportlgbm_df151_report.csv
# processed: reportlgbm_df152_report.csv
# processed: reportlgbm_df153_report.csv
# processed: reportlgbm_df154_report.csv
# processed: reportlgbm_df155_report.csv
# processed: reportlgbm_df156_report.csv
# processed: reportlgbm_df157_report.csv
# processed: reportlgbm_df158_report.csv
# processed: reportlgbm_df159_report.csv
# processed: reportlgbm_df15_report.csv
# processed: reportlgbm_df160_report.csv
# processed: reportlgbm_df161_report.csv
# processed: reportlgbm_df162_report.csv
# processed: reportlgbm_df163_report.csv
# processed: reportlgbm_df164_report.csv
# processed: reportlgbm_df165_report.csv
# processed: reportlgbm_df166_report.csv
# processed: reportlgbm_df167_report.csv
# processed: reportlgbm_df168_report.csv
# processed: reportlgbm_df169_report.csv
# processed: reportlgbm_df16_report.csv
# processed: reportlgbm_df170_report.csv
# processed: reportlgbm_df171_report.csv
# processed: reportlgbm_df172_report.csv
# processed: reportlgbm_df173_report.csv
# processed: reportlgbm_df174_report.csv
# processed: reportlgbm_df175_report.csv
# processed: reportlgbm_df176_report.csv
# processed: reportlgbm_df177_report.csv
# processed: reportlgbm_df178_report.csv
# processed: reportlgbm_df179_report.csv
# processed: reportlgbm_df17_report.csv
# processed: reportlgbm_df180_report.csv
# processed: reportlgbm_df181_report.csv
# processed: reportlgbm_df182_report.csv
# processed: reportlgbm_df183_report.csv
# processed: reportlgbm_df184_report.csv
# processed: reportlgbm_df185_report.csv
# processed: reportlgbm_df186_report.csv
# processed: reportlgbm_df187_report.csv
# processed: reportlgbm_df188_report.csv
# processed: reportlgbm_df189_report.csv
# processed: reportlgbm_df18_report.csv
# processed: reportlgbm_df190_report.csv
# processed: reportlgbm_df191_report.csv
# processed: reportlgbm_df192_report.csv
# processed: reportlgbm_df193_report.csv
# processed: reportlgbm_df194_report.csv
# processed: reportlgbm_df195_report.csv
# processed: reportlgbm_df196_report.csv
# processed: reportlgbm_df197_report.csv
# processed: reportlgbm_df198_report.csv
# processed: reportlgbm_df199_report.csv
# processed: reportlgbm_df19_report.csv
# processed: reportlgbm_df1_report.csv
# processed: reportlgbm_df200_report.csv
# processed: reportlgbm_df201_report.csv
# processed: reportlgbm_df202_report.csv
# processed: reportlgbm_df203_report.csv
# processed: reportlgbm_df204_report.csv
# processed: reportlgbm_df205_report.csv
# processed: reportlgbm_df206_report.csv
# processed: reportlgbm_df207_report.csv
# processed: reportlgbm_df208_report.csv
# processed: reportlgbm_df209_report.csv
# processed: reportlgbm_df20_report.csv
# processed: reportlgbm_df210_report.csv
# processed: reportlgbm_df211_report.csv
# processed: reportlgbm_df212_report.csv
# processed: reportlgbm_df213_report.csv
# processed: reportlgbm_df214_report.csv
# processed: reportlgbm_df215_report.csv
# processed: reportlgbm_df216_report.csv
# processed: reportlgbm_df217_report.csv
# processed: reportlgbm_df218_report.csv
# processed: reportlgbm_df219_report.csv
# processed: reportlgbm_df21_report.csv
# processed: reportlgbm_df220_report.csv
# processed: reportlgbm_df221_report.csv
# processed: reportlgbm_df222_report.csv
# processed: reportlgbm_df223_report.csv
# processed: reportlgbm_df224_report.csv
# processed: reportlgbm_df225_report.csv
# processed: reportlgbm_df226_report.csv
# processed: reportlgbm_df227_report.csv
# processed: reportlgbm_df228_report.csv
# processed: reportlgbm_df229_report.csv
# processed: reportlgbm_df22_report.csv
# processed: reportlgbm_df230_report.csv
# processed: reportlgbm_df231_report.csv
# processed: reportlgbm_df232_report.csv
# processed: reportlgbm_df233_report.csv
# processed: reportlgbm_df234_report.csv
# processed: reportlgbm_df235_report.csv
# processed: reportlgbm_df236_report.csv
# processed: reportlgbm_df237_report.csv
# processed: reportlgbm_df238_report.csv
# processed: reportlgbm_df239_report.csv
# processed: reportlgbm_df23_report.csv
# processed: reportlgbm_df240_report.csv
# processed: reportlgbm_df241_report.csv
# processed: reportlgbm_df242_report.csv
# processed: reportlgbm_df243_report.csv
# processed: reportlgbm_df244_report.csv
# processed: reportlgbm_df245_report.csv
# processed: reportlgbm_df246_report.csv
# processed: reportlgbm_df247_report.csv
# processed: reportlgbm_df248_report.csv
# processed: reportlgbm_df249_report.csv
# processed: reportlgbm_df24_report.csv
# processed: reportlgbm_df250_report.csv
# processed: reportlgbm_df251_report.csv
# processed: reportlgbm_df252_report.csv
# processed: reportlgbm_df253_report.csv
# processed: reportlgbm_df254_report.csv
# processed: reportlgbm_df255_report.csv
# processed: reportlgbm_df256_report.csv
# processed: reportlgbm_df257_report.csv
# processed: reportlgbm_df258_report.csv
# processed: reportlgbm_df259_report.csv
# processed: reportlgbm_df25_report.csv
# processed: reportlgbm_df260_report.csv
# processed: reportlgbm_df261_report.csv
# processed: reportlgbm_df262_report.csv
# processed: reportlgbm_df263_report.csv
# processed: reportlgbm_df264_report.csv
# processed: reportlgbm_df265_report.csv
# processed: reportlgbm_df266_report.csv
# processed: reportlgbm_df267_report.csv
# processed: reportlgbm_df268_report.csv
# processed: reportlgbm_df269_report.csv
# processed: reportlgbm_df26_report.csv
# processed: reportlgbm_df270_report.csv
# processed: reportlgbm_df271_report.csv
# processed: reportlgbm_df272_report.csv
# processed: reportlgbm_df273_report.csv
# processed: reportlgbm_df274_report.csv
# processed: reportlgbm_df275_report.csv
# processed: reportlgbm_df276_report.csv
# processed: reportlgbm_df277_report.csv
# processed: reportlgbm_df278_report.csv
# processed: reportlgbm_df279_report.csv
# processed: reportlgbm_df27_report.csv
# processed: reportlgbm_df280_report.csv
# processed: reportlgbm_df281_report.csv
# processed: reportlgbm_df282_report.csv
# processed: reportlgbm_df283_report.csv
# processed: reportlgbm_df284_report.csv
# processed: reportlgbm_df285_report.csv
# processed: reportlgbm_df286_report.csv
# processed: reportlgbm_df287_report.csv
# processed: reportlgbm_df288_report.csv
# processed: reportlgbm_df289_report.csv
# processed: reportlgbm_df28_report.csv
# processed: reportlgbm_df290_report.csv
# processed: reportlgbm_df291_report.csv
# processed: reportlgbm_df292_report.csv
# processed: reportlgbm_df293_report.csv
# processed: reportlgbm_df294_report.csv
# processed: reportlgbm_df295_report.csv
# processed: reportlgbm_df296_report.csv
# processed: reportlgbm_df297_report.csv
# processed: reportlgbm_df298_report.csv
# processed: reportlgbm_df299_report.csv
# processed: reportlgbm_df29_report.csv
# processed: reportlgbm_df2_report.csv
# processed: reportlgbm_df300_report.csv
# processed: reportlgbm_df301_report.csv
# processed: reportlgbm_df302_report.csv
# processed: reportlgbm_df303_report.csv
# processed: reportlgbm_df304_report.csv
# processed: reportlgbm_df305_report.csv
# processed: reportlgbm_df306_report.csv
# processed: reportlgbm_df307_report.csv
# processed: reportlgbm_df308_report.csv
# processed: reportlgbm_df309_report.csv
# processed: reportlgbm_df30_report.csv
# processed: reportlgbm_df310_report.csv
# processed: reportlgbm_df311_report.csv
# processed: reportlgbm_df312_report.csv
# processed: reportlgbm_df313_report.csv
# processed: reportlgbm_df314_report.csv
# processed: reportlgbm_df315_report.csv
# processed: reportlgbm_df316_report.csv
# processed: reportlgbm_df317_report.csv
# processed: reportlgbm_df318_report.csv
# processed: reportlgbm_df319_report.csv
# processed: reportlgbm_df31_report.csv
# processed: reportlgbm_df320_report.csv
# processed: reportlgbm_df321_report.csv
# processed: reportlgbm_df322_report.csv
# processed: reportlgbm_df323_report.csv
# processed: reportlgbm_df324_report.csv
# processed: reportlgbm_df325_report.csv
# processed: reportlgbm_df326_report.csv
# processed: reportlgbm_df327_report.csv
# processed: reportlgbm_df328_report.csv
# processed: reportlgbm_df329_report.csv
# processed: reportlgbm_df32_report.csv
# processed: reportlgbm_df330_report.csv
# processed: reportlgbm_df331_report.csv
# processed: reportlgbm_df332_report.csv
# processed: reportlgbm_df333_report.csv
# processed: reportlgbm_df334_report.csv
# processed: reportlgbm_df335_report.csv
# processed: reportlgbm_df336_report.csv
# processed: reportlgbm_df337_report.csv
# processed: reportlgbm_df338_report.csv
# processed: reportlgbm_df339_report.csv
# processed: reportlgbm_df33_report.csv
# processed: reportlgbm_df340_report.csv
# processed: reportlgbm_df341_report.csv
# processed: reportlgbm_df342_report.csv
# processed: reportlgbm_df343_report.csv
# processed: reportlgbm_df344_report.csv
# processed: reportlgbm_df345_report.csv
# processed: reportlgbm_df346_report.csv
# processed: reportlgbm_df347_report.csv
# processed: reportlgbm_df348_report.csv
# processed: reportlgbm_df349_report.csv
# processed: reportlgbm_df34_report.csv
# processed: reportlgbm_df350_report.csv
# processed: reportlgbm_df351_report.csv
# processed: reportlgbm_df352_report.csv
# processed: reportlgbm_df353_report.csv
# processed: reportlgbm_df354_report.csv
# processed: reportlgbm_df355_report.csv
# processed: reportlgbm_df356_report.csv
# processed: reportlgbm_df357_report.csv
# processed: reportlgbm_df358_report.csv
# processed: reportlgbm_df359_report.csv
# processed: reportlgbm_df35_report.csv
# processed: reportlgbm_df360_report.csv
# processed: reportlgbm_df361_report.csv
# processed: reportlgbm_df362_report.csv
# processed: reportlgbm_df363_report.csv
# processed: reportlgbm_df364_report.csv
# processed: reportlgbm_df365_report.csv
# processed: reportlgbm_df366_report.csv
# processed: reportlgbm_df367_report.csv
# processed: reportlgbm_df368_report.csv
# processed: reportlgbm_df369_report.csv
# processed: reportlgbm_df36_report.csv
# processed: reportlgbm_df370_report.csv
# processed: reportlgbm_df371_report.csv
# processed: reportlgbm_df372_report.csv
# processed: reportlgbm_df373_report.csv
# processed: reportlgbm_df374_report.csv
# processed: reportlgbm_df375_report.csv
# processed: reportlgbm_df376_report.csv
# processed: reportlgbm_df377_report.csv
# processed: reportlgbm_df378_report.csv
# processed: reportlgbm_df379_report.csv
# processed: reportlgbm_df37_report.csv
# processed: reportlgbm_df380_report.csv
# processed: reportlgbm_df381_report.csv
# processed: reportlgbm_df382_report.csv
# processed: reportlgbm_df383_report.csv
# processed: reportlgbm_df384_report.csv
# processed: reportlgbm_df385_report.csv
# processed: reportlgbm_df386_report.csv
# processed: reportlgbm_df387_report.csv
# processed: reportlgbm_df388_report.csv
# processed: reportlgbm_df389_report.csv
# processed: reportlgbm_df38_report.csv
# processed: reportlgbm_df390_report.csv
# processed: reportlgbm_df391_report.csv
# processed: reportlgbm_df392_report.csv
# processed: reportlgbm_df393_report.csv
# processed: reportlgbm_df394_report.csv
# processed: reportlgbm_df395_report.csv
# processed: reportlgbm_df396_report.csv
# processed: reportlgbm_df397_report.csv
# processed: reportlgbm_df398_report.csv
# processed: reportlgbm_df399_report.csv
# processed: reportlgbm_df39_report.csv
# processed: reportlgbm_df3_report.csv
# processed: reportlgbm_df400_report.csv
# processed: reportlgbm_df401_report.csv
# processed: reportlgbm_df402_report.csv
# processed: reportlgbm_df403_report.csv
# processed: reportlgbm_df404_report.csv
# processed: reportlgbm_df405_report.csv
# processed: reportlgbm_df406_report.csv
# processed: reportlgbm_df407_report.csv
# processed: reportlgbm_df408_report.csv
# processed: reportlgbm_df409_report.csv
# processed: reportlgbm_df40_report.csv
# processed: reportlgbm_df410_report.csv
# processed: reportlgbm_df411_report.csv
# processed: reportlgbm_df412_report.csv
# processed: reportlgbm_df413_report.csv
# processed: reportlgbm_df414_report.csv
# processed: reportlgbm_df415_report.csv
# processed: reportlgbm_df416_report.csv
# processed: reportlgbm_df417_report.csv
# processed: reportlgbm_df418_report.csv
# processed: reportlgbm_df419_report.csv
# processed: reportlgbm_df41_report.csv
# processed: reportlgbm_df420_report.csv
# processed: reportlgbm_df421_report.csv
# processed: reportlgbm_df422_report.csv
# processed: reportlgbm_df423_report.csv
# processed: reportlgbm_df424_report.csv
# processed: reportlgbm_df425_report.csv
# processed: reportlgbm_df426_report.csv
# processed: reportlgbm_df427_report.csv
# processed: reportlgbm_df428_report.csv
# processed: reportlgbm_df429_report.csv
# processed: reportlgbm_df42_report.csv
# processed: reportlgbm_df430_report.csv
# processed: reportlgbm_df431_report.csv
# processed: reportlgbm_df432_report.csv
# processed: reportlgbm_df433_report.csv
# processed: reportlgbm_df434_report.csv
# processed: reportlgbm_df435_report.csv
# processed: reportlgbm_df436_report.csv
# processed: reportlgbm_df437_report.csv
# processed: reportlgbm_df438_report.csv
# processed: reportlgbm_df439_report.csv
# processed: reportlgbm_df43_report.csv
# processed: reportlgbm_df440_report.csv
# processed: reportlgbm_df441_report.csv
# processed: reportlgbm_df442_report.csv
# processed: reportlgbm_df443_report.csv
# processed: reportlgbm_df444_report.csv
# processed: reportlgbm_df445_report.csv
# processed: reportlgbm_df446_report.csv
# processed: reportlgbm_df447_report.csv
# processed: reportlgbm_df448_report.csv
# processed: reportlgbm_df449_report.csv
# processed: reportlgbm_df44_report.csv
# processed: reportlgbm_df450_report.csv
# processed: reportlgbm_df451_report.csv
# processed: reportlgbm_df452_report.csv
# processed: reportlgbm_df453_report.csv
# processed: reportlgbm_df454_report.csv
# processed: reportlgbm_df455_report.csv
# processed: reportlgbm_df456_report.csv
# processed: reportlgbm_df457_report.csv
# processed: reportlgbm_df458_report.csv
# processed: reportlgbm_df459_report.csv
# processed: reportlgbm_df45_report.csv
# processed: reportlgbm_df460_report.csv
# processed: reportlgbm_df461_report.csv
# processed: reportlgbm_df462_report.csv
# processed: reportlgbm_df463_report.csv
# processed: reportlgbm_df464_report.csv
# processed: reportlgbm_df465_report.csv
# processed: reportlgbm_df466_report.csv
# processed: reportlgbm_df467_report.csv
# processed: reportlgbm_df468_report.csv
# processed: reportlgbm_df469_report.csv
# processed: reportlgbm_df46_report.csv
# processed: reportlgbm_df470_report.csv
# processed: reportlgbm_df471_report.csv
# processed: reportlgbm_df472_report.csv
# processed: reportlgbm_df473_report.csv
# processed: reportlgbm_df474_report.csv
# processed: reportlgbm_df475_report.csv
# processed: reportlgbm_df476_report.csv
# processed: reportlgbm_df477_report.csv
# processed: reportlgbm_df478_report.csv
# processed: reportlgbm_df479_report.csv
# processed: reportlgbm_df47_report.csv
# processed: reportlgbm_df480_report.csv
# processed: reportlgbm_df481_report.csv
# processed: reportlgbm_df482_report.csv
# processed: reportlgbm_df483_report.csv
# processed: reportlgbm_df484_report.csv
# processed: reportlgbm_df485_report.csv
# processed: reportlgbm_df486_report.csv
# processed: reportlgbm_df487_report.csv
# processed: reportlgbm_df488_report.csv
# processed: reportlgbm_df489_report.csv
# processed: reportlgbm_df48_report.csv
# processed: reportlgbm_df490_report.csv
# processed: reportlgbm_df491_report.csv
# processed: reportlgbm_df492_report.csv
# processed: reportlgbm_df493_report.csv
# processed: reportlgbm_df494_report.csv
# processed: reportlgbm_df495_report.csv
# processed: reportlgbm_df496_report.csv
# processed: reportlgbm_df497_report.csv
# processed: reportlgbm_df498_report.csv
# processed: reportlgbm_df499_report.csv
# processed: reportlgbm_df49_report.csv
# processed: reportlgbm_df4_report.csv
# processed: reportlgbm_df50_report.csv
# processed: reportlgbm_df51_report.csv
# processed: reportlgbm_df52_report.csv
# processed: reportlgbm_df53_report.csv
# processed: reportlgbm_df54_report.csv
# processed: reportlgbm_df55_report.csv
# processed: reportlgbm_df56_report.csv
# processed: reportlgbm_df57_report.csv
# processed: reportlgbm_df58_report.csv
# processed: reportlgbm_df59_report.csv
# processed: reportlgbm_df5_report.csv
# processed: reportlgbm_df60_report.csv
# processed: reportlgbm_df61_report.csv
# processed: reportlgbm_df62_report.csv
# processed: reportlgbm_df63_report.csv
# processed: reportlgbm_df64_report.csv
# processed: reportlgbm_df65_report.csv
# processed: reportlgbm_df66_report.csv
# processed: reportlgbm_df67_report.csv
# processed: reportlgbm_df68_report.csv
# processed: reportlgbm_df69_report.csv
# processed: reportlgbm_df6_report.csv
# processed: reportlgbm_df70_report.csv
# processed: reportlgbm_df71_report.csv
# processed: reportlgbm_df72_report.csv
# processed: reportlgbm_df73_report.csv
# processed: reportlgbm_df74_report.csv
# processed: reportlgbm_df75_report.csv
# processed: reportlgbm_df76_report.csv
# processed: reportlgbm_df77_report.csv
# processed: reportlgbm_df78_report.csv
# processed: reportlgbm_df79_report.csv
# processed: reportlgbm_df7_report.csv
# processed: reportlgbm_df80_report.csv
# processed: reportlgbm_df81_report.csv
# processed: reportlgbm_df82_report.csv
# processed: reportlgbm_df83_report.csv
# processed: reportlgbm_df84_report.csv
# processed: reportlgbm_df85_report.csv
# processed: reportlgbm_df86_report.csv
# processed: reportlgbm_df87_report.csv
# processed: reportlgbm_df88_report.csv
# processed: reportlgbm_df89_report.csv
# processed: reportlgbm_df8_report.csv
# processed: reportlgbm_df90_report.csv
# processed: reportlgbm_df91_report.csv
# processed: reportlgbm_df92_report.csv
# processed: reportlgbm_df93_report.csv
# processed: reportlgbm_df94_report.csv
# processed: reportlgbm_df95_report.csv
# processed: reportlgbm_df96_report.csv
# processed: reportlgbm_df97_report.csv
# processed: reportlgbm_df98_report.csv
# processed: reportlgbm_df99_report.csv
# processed: reportlgbm_df9_report.csv
# Merged saved as: ../LightGBM/metrics/report/merged_precision_report.csv

# %%
# Find the metrics and report directories.
metrics_dir = '../LightGBM/metrics/report'

# Make CSV list.
csv_files = glob.glob(os.path.join(metrics_dir, "reportlgbm_df*_report.csv"))
print(f"Found {len(csv_files)} report files.")

# Init list for data.
data = []

def extract_f1_score(content, class_name):
    match = re.search(f"{class_name}\s+\d+\.\d+\s+\d+\.\d+\s+(\d+\.\d+)", content)
    return float(match.group(1)) if match else None

# Iterate over each file.
for file in csv_files:
    model_number = re.search(r'df(\d+)_report', file)
    if model_number:
        model_number = int(model_number.group(1))
    else:
        print(f"Error!")
        continue
    try:
        with open(file, 'r') as f:
            content = f.read()
        
        # Get REC for each class.
        gof_f1 = extract_f1_score(content, "GOF")
        lof_f1 = extract_f1_score(content, "LOF")
        neutral_f1 = extract_f1_score(content, "Neutral")
        
        # Add to list.
        data.append({
            'Model': model_number,
            'GOF F1': gof_f1,
            'LOF F1': lof_f1,
            'Neutral F1': neutral_f1
        })
        print(f"processed: {os.path.basename(file)}")
    except Exception as e:
        print(f"Error! {os.path.basename(file)}: {str(e)}")

# Compile into df.
merged_df = pd.DataFrame(data)

if merged_df.empty:
    print("Error!")
else:
    merged_df.set_index('Model', inplace=True)
    merged_df.sort_index(inplace=True)
    output_file = os.path.join(metrics_dir, "merged_precision_report.csv")
    merged_df.to_csv(output_file)
    print(f"Merged saved as: {output_file}")
# Out:
# Found 499 report files.
# processed: reportlgbm_df100_report.csv
# processed: reportlgbm_df101_report.csv
# processed: reportlgbm_df102_report.csv
# processed: reportlgbm_df103_report.csv
# processed: reportlgbm_df104_report.csv
# processed: reportlgbm_df105_report.csv
# processed: reportlgbm_df106_report.csv
# processed: reportlgbm_df107_report.csv
# processed: reportlgbm_df108_report.csv
# processed: reportlgbm_df109_report.csv
# processed: reportlgbm_df10_report.csv
# processed: reportlgbm_df110_report.csv
# processed: reportlgbm_df111_report.csv
# processed: reportlgbm_df112_report.csv
# processed: reportlgbm_df113_report.csv
# processed: reportlgbm_df114_report.csv
# processed: reportlgbm_df115_report.csv
# processed: reportlgbm_df116_report.csv
# processed: reportlgbm_df117_report.csv
# processed: reportlgbm_df118_report.csv
# processed: reportlgbm_df119_report.csv
# processed: reportlgbm_df11_report.csv
# processed: reportlgbm_df120_report.csv
# processed: reportlgbm_df121_report.csv
# processed: reportlgbm_df122_report.csv
# processed: reportlgbm_df123_report.csv
# processed: reportlgbm_df124_report.csv
# processed: reportlgbm_df125_report.csv
# processed: reportlgbm_df126_report.csv
# processed: reportlgbm_df127_report.csv
# processed: reportlgbm_df128_report.csv
# processed: reportlgbm_df129_report.csv
# processed: reportlgbm_df12_report.csv
# processed: reportlgbm_df130_report.csv
# processed: reportlgbm_df131_report.csv
# processed: reportlgbm_df132_report.csv
# processed: reportlgbm_df133_report.csv
# processed: reportlgbm_df134_report.csv
# processed: reportlgbm_df135_report.csv
# processed: reportlgbm_df136_report.csv
# processed: reportlgbm_df137_report.csv
# processed: reportlgbm_df138_report.csv
# processed: reportlgbm_df139_report.csv
# processed: reportlgbm_df13_report.csv
# processed: reportlgbm_df140_report.csv
# processed: reportlgbm_df141_report.csv
# processed: reportlgbm_df142_report.csv
# processed: reportlgbm_df143_report.csv
# processed: reportlgbm_df144_report.csv
# processed: reportlgbm_df145_report.csv
# processed: reportlgbm_df146_report.csv
# processed: reportlgbm_df147_report.csv
# processed: reportlgbm_df148_report.csv
# processed: reportlgbm_df149_report.csv
# processed: reportlgbm_df14_report.csv
# processed: reportlgbm_df150_report.csv
# processed: reportlgbm_df151_report.csv
# processed: reportlgbm_df152_report.csv
# processed: reportlgbm_df153_report.csv
# processed: reportlgbm_df154_report.csv
# processed: reportlgbm_df155_report.csv
# processed: reportlgbm_df156_report.csv
# processed: reportlgbm_df157_report.csv
# processed: reportlgbm_df158_report.csv
# processed: reportlgbm_df159_report.csv
# processed: reportlgbm_df15_report.csv
# processed: reportlgbm_df160_report.csv
# processed: reportlgbm_df161_report.csv
# processed: reportlgbm_df162_report.csv
# processed: reportlgbm_df163_report.csv
# processed: reportlgbm_df164_report.csv
# processed: reportlgbm_df165_report.csv
# processed: reportlgbm_df166_report.csv
# processed: reportlgbm_df167_report.csv
# processed: reportlgbm_df168_report.csv
# processed: reportlgbm_df169_report.csv
# processed: reportlgbm_df16_report.csv
# processed: reportlgbm_df170_report.csv
# processed: reportlgbm_df171_report.csv
# processed: reportlgbm_df172_report.csv
# processed: reportlgbm_df173_report.csv
# processed: reportlgbm_df174_report.csv
# processed: reportlgbm_df175_report.csv
# processed: reportlgbm_df176_report.csv
# processed: reportlgbm_df177_report.csv
# processed: reportlgbm_df178_report.csv
# processed: reportlgbm_df179_report.csv
# processed: reportlgbm_df17_report.csv
# processed: reportlgbm_df180_report.csv
# processed: reportlgbm_df181_report.csv
# processed: reportlgbm_df182_report.csv
# processed: reportlgbm_df183_report.csv
# processed: reportlgbm_df184_report.csv
# processed: reportlgbm_df185_report.csv
# processed: reportlgbm_df186_report.csv
# processed: reportlgbm_df187_report.csv
# processed: reportlgbm_df188_report.csv
# processed: reportlgbm_df189_report.csv
# processed: reportlgbm_df18_report.csv
# processed: reportlgbm_df190_report.csv
# processed: reportlgbm_df191_report.csv
# processed: reportlgbm_df192_report.csv
# processed: reportlgbm_df193_report.csv
# processed: reportlgbm_df194_report.csv
# processed: reportlgbm_df195_report.csv
# processed: reportlgbm_df196_report.csv
# processed: reportlgbm_df197_report.csv
# processed: reportlgbm_df198_report.csv
# processed: reportlgbm_df199_report.csv
# processed: reportlgbm_df19_report.csv
# processed: reportlgbm_df1_report.csv
# processed: reportlgbm_df200_report.csv
# processed: reportlgbm_df201_report.csv
# processed: reportlgbm_df202_report.csv
# processed: reportlgbm_df203_report.csv
# processed: reportlgbm_df204_report.csv
# processed: reportlgbm_df205_report.csv
# processed: reportlgbm_df206_report.csv
# processed: reportlgbm_df207_report.csv
# processed: reportlgbm_df208_report.csv
# processed: reportlgbm_df209_report.csv
# processed: reportlgbm_df20_report.csv
# processed: reportlgbm_df210_report.csv
# processed: reportlgbm_df211_report.csv
# processed: reportlgbm_df212_report.csv
# processed: reportlgbm_df213_report.csv
# processed: reportlgbm_df214_report.csv
# processed: reportlgbm_df215_report.csv
# processed: reportlgbm_df216_report.csv
# processed: reportlgbm_df217_report.csv
# processed: reportlgbm_df218_report.csv
# processed: reportlgbm_df219_report.csv
# processed: reportlgbm_df21_report.csv
# processed: reportlgbm_df220_report.csv
# processed: reportlgbm_df221_report.csv
# processed: reportlgbm_df222_report.csv
# processed: reportlgbm_df223_report.csv
# processed: reportlgbm_df224_report.csv
# processed: reportlgbm_df225_report.csv
# processed: reportlgbm_df226_report.csv
# processed: reportlgbm_df227_report.csv
# processed: reportlgbm_df228_report.csv
# processed: reportlgbm_df229_report.csv
# processed: reportlgbm_df22_report.csv
# processed: reportlgbm_df230_report.csv
# processed: reportlgbm_df231_report.csv
# processed: reportlgbm_df232_report.csv
# processed: reportlgbm_df233_report.csv
# processed: reportlgbm_df234_report.csv
# processed: reportlgbm_df235_report.csv
# processed: reportlgbm_df236_report.csv
# processed: reportlgbm_df237_report.csv
# processed: reportlgbm_df238_report.csv
# processed: reportlgbm_df239_report.csv
# processed: reportlgbm_df23_report.csv
# processed: reportlgbm_df240_report.csv
# processed: reportlgbm_df241_report.csv
# processed: reportlgbm_df242_report.csv
# processed: reportlgbm_df243_report.csv
# processed: reportlgbm_df244_report.csv
# processed: reportlgbm_df245_report.csv
# processed: reportlgbm_df246_report.csv
# processed: reportlgbm_df247_report.csv
# processed: reportlgbm_df248_report.csv
# processed: reportlgbm_df249_report.csv
# processed: reportlgbm_df24_report.csv
# processed: reportlgbm_df250_report.csv
# processed: reportlgbm_df251_report.csv
# processed: reportlgbm_df252_report.csv
# processed: reportlgbm_df253_report.csv
# processed: reportlgbm_df254_report.csv
# processed: reportlgbm_df255_report.csv
# processed: reportlgbm_df256_report.csv
# processed: reportlgbm_df257_report.csv
# processed: reportlgbm_df258_report.csv
# processed: reportlgbm_df259_report.csv
# processed: reportlgbm_df25_report.csv
# processed: reportlgbm_df260_report.csv
# processed: reportlgbm_df261_report.csv
# processed: reportlgbm_df262_report.csv
# processed: reportlgbm_df263_report.csv
# processed: reportlgbm_df264_report.csv
# processed: reportlgbm_df265_report.csv
# processed: reportlgbm_df266_report.csv
# processed: reportlgbm_df267_report.csv
# processed: reportlgbm_df268_report.csv
# processed: reportlgbm_df269_report.csv
# processed: reportlgbm_df26_report.csv
# processed: reportlgbm_df270_report.csv
# processed: reportlgbm_df271_report.csv
# processed: reportlgbm_df272_report.csv
# processed: reportlgbm_df273_report.csv
# processed: reportlgbm_df274_report.csv
# processed: reportlgbm_df275_report.csv
# processed: reportlgbm_df276_report.csv
# processed: reportlgbm_df277_report.csv
# processed: reportlgbm_df278_report.csv
# processed: reportlgbm_df279_report.csv
# processed: reportlgbm_df27_report.csv
# processed: reportlgbm_df280_report.csv
# processed: reportlgbm_df281_report.csv
# processed: reportlgbm_df282_report.csv
# processed: reportlgbm_df283_report.csv
# processed: reportlgbm_df284_report.csv
# processed: reportlgbm_df285_report.csv
# processed: reportlgbm_df286_report.csv
# processed: reportlgbm_df287_report.csv
# processed: reportlgbm_df288_report.csv
# processed: reportlgbm_df289_report.csv
# processed: reportlgbm_df28_report.csv
# processed: reportlgbm_df290_report.csv
# processed: reportlgbm_df291_report.csv
# processed: reportlgbm_df292_report.csv
# processed: reportlgbm_df293_report.csv
# processed: reportlgbm_df294_report.csv
# processed: reportlgbm_df295_report.csv
# processed: reportlgbm_df296_report.csv
# processed: reportlgbm_df297_report.csv
# processed: reportlgbm_df298_report.csv
# processed: reportlgbm_df299_report.csv
# processed: reportlgbm_df29_report.csv
# processed: reportlgbm_df2_report.csv
# processed: reportlgbm_df300_report.csv
# processed: reportlgbm_df301_report.csv
# processed: reportlgbm_df302_report.csv
# processed: reportlgbm_df303_report.csv
# processed: reportlgbm_df304_report.csv
# processed: reportlgbm_df305_report.csv
# processed: reportlgbm_df306_report.csv
# processed: reportlgbm_df307_report.csv
# processed: reportlgbm_df308_report.csv
# processed: reportlgbm_df309_report.csv
# processed: reportlgbm_df30_report.csv
# processed: reportlgbm_df310_report.csv
# processed: reportlgbm_df311_report.csv
# processed: reportlgbm_df312_report.csv
# processed: reportlgbm_df313_report.csv
# processed: reportlgbm_df314_report.csv
# processed: reportlgbm_df315_report.csv
# processed: reportlgbm_df316_report.csv
# processed: reportlgbm_df317_report.csv
# processed: reportlgbm_df318_report.csv
# processed: reportlgbm_df319_report.csv
# processed: reportlgbm_df31_report.csv
# processed: reportlgbm_df320_report.csv
# processed: reportlgbm_df321_report.csv
# processed: reportlgbm_df322_report.csv
# processed: reportlgbm_df323_report.csv
# processed: reportlgbm_df324_report.csv
# processed: reportlgbm_df325_report.csv
# processed: reportlgbm_df326_report.csv
# processed: reportlgbm_df327_report.csv
# processed: reportlgbm_df328_report.csv
# processed: reportlgbm_df329_report.csv
# processed: reportlgbm_df32_report.csv
# processed: reportlgbm_df330_report.csv
# processed: reportlgbm_df331_report.csv
# processed: reportlgbm_df332_report.csv
# processed: reportlgbm_df333_report.csv
# processed: reportlgbm_df334_report.csv
# processed: reportlgbm_df335_report.csv
# processed: reportlgbm_df336_report.csv
# processed: reportlgbm_df337_report.csv
# processed: reportlgbm_df338_report.csv
# processed: reportlgbm_df339_report.csv
# processed: reportlgbm_df33_report.csv
# processed: reportlgbm_df340_report.csv
# processed: reportlgbm_df341_report.csv
# processed: reportlgbm_df342_report.csv
# processed: reportlgbm_df343_report.csv
# processed: reportlgbm_df344_report.csv
# processed: reportlgbm_df345_report.csv
# processed: reportlgbm_df346_report.csv
# processed: reportlgbm_df347_report.csv
# processed: reportlgbm_df348_report.csv
# processed: reportlgbm_df349_report.csv
# processed: reportlgbm_df34_report.csv
# processed: reportlgbm_df350_report.csv
# processed: reportlgbm_df351_report.csv
# processed: reportlgbm_df352_report.csv
# processed: reportlgbm_df353_report.csv
# processed: reportlgbm_df354_report.csv
# processed: reportlgbm_df355_report.csv
# processed: reportlgbm_df356_report.csv
# processed: reportlgbm_df357_report.csv
# processed: reportlgbm_df358_report.csv
# processed: reportlgbm_df359_report.csv
# processed: reportlgbm_df35_report.csv
# processed: reportlgbm_df360_report.csv
# processed: reportlgbm_df361_report.csv
# processed: reportlgbm_df362_report.csv
# processed: reportlgbm_df363_report.csv
# processed: reportlgbm_df364_report.csv
# processed: reportlgbm_df365_report.csv
# processed: reportlgbm_df366_report.csv
# processed: reportlgbm_df367_report.csv
# processed: reportlgbm_df368_report.csv
# processed: reportlgbm_df369_report.csv
# processed: reportlgbm_df36_report.csv
# processed: reportlgbm_df370_report.csv
# processed: reportlgbm_df371_report.csv
# processed: reportlgbm_df372_report.csv
# processed: reportlgbm_df373_report.csv
# processed: reportlgbm_df374_report.csv
# processed: reportlgbm_df375_report.csv
# processed: reportlgbm_df376_report.csv
# processed: reportlgbm_df377_report.csv
# processed: reportlgbm_df378_report.csv
# processed: reportlgbm_df379_report.csv
# processed: reportlgbm_df37_report.csv
# processed: reportlgbm_df380_report.csv
# processed: reportlgbm_df381_report.csv
# processed: reportlgbm_df382_report.csv
# processed: reportlgbm_df383_report.csv
# processed: reportlgbm_df384_report.csv
# processed: reportlgbm_df385_report.csv
# processed: reportlgbm_df386_report.csv
# processed: reportlgbm_df387_report.csv
# processed: reportlgbm_df388_report.csv
# processed: reportlgbm_df389_report.csv
# processed: reportlgbm_df38_report.csv
# processed: reportlgbm_df390_report.csv
# processed: reportlgbm_df391_report.csv
# processed: reportlgbm_df392_report.csv
# processed: reportlgbm_df393_report.csv
# processed: reportlgbm_df394_report.csv
# processed: reportlgbm_df395_report.csv
# processed: reportlgbm_df396_report.csv
# processed: reportlgbm_df397_report.csv
# processed: reportlgbm_df398_report.csv
# processed: reportlgbm_df399_report.csv
# processed: reportlgbm_df39_report.csv
# processed: reportlgbm_df3_report.csv
# processed: reportlgbm_df400_report.csv
# processed: reportlgbm_df401_report.csv
# processed: reportlgbm_df402_report.csv
# processed: reportlgbm_df403_report.csv
# processed: reportlgbm_df404_report.csv
# processed: reportlgbm_df405_report.csv
# processed: reportlgbm_df406_report.csv
# processed: reportlgbm_df407_report.csv
# processed: reportlgbm_df408_report.csv
# processed: reportlgbm_df409_report.csv
# processed: reportlgbm_df40_report.csv
# processed: reportlgbm_df410_report.csv
# processed: reportlgbm_df411_report.csv
# processed: reportlgbm_df412_report.csv
# processed: reportlgbm_df413_report.csv
# processed: reportlgbm_df414_report.csv
# processed: reportlgbm_df415_report.csv
# processed: reportlgbm_df416_report.csv
# processed: reportlgbm_df417_report.csv
# processed: reportlgbm_df418_report.csv
# processed: reportlgbm_df419_report.csv
# processed: reportlgbm_df41_report.csv
# processed: reportlgbm_df420_report.csv
# processed: reportlgbm_df421_report.csv
# processed: reportlgbm_df422_report.csv
# processed: reportlgbm_df423_report.csv
# processed: reportlgbm_df424_report.csv
# processed: reportlgbm_df425_report.csv
# processed: reportlgbm_df426_report.csv
# processed: reportlgbm_df427_report.csv
# processed: reportlgbm_df428_report.csv
# processed: reportlgbm_df429_report.csv
# processed: reportlgbm_df42_report.csv
# processed: reportlgbm_df430_report.csv
# processed: reportlgbm_df431_report.csv
# processed: reportlgbm_df432_report.csv
# processed: reportlgbm_df433_report.csv
# processed: reportlgbm_df434_report.csv
# processed: reportlgbm_df435_report.csv
# processed: reportlgbm_df436_report.csv
# processed: reportlgbm_df437_report.csv
# processed: reportlgbm_df438_report.csv
# processed: reportlgbm_df439_report.csv
# processed: reportlgbm_df43_report.csv
# processed: reportlgbm_df440_report.csv
# processed: reportlgbm_df441_report.csv
# processed: reportlgbm_df442_report.csv
# processed: reportlgbm_df443_report.csv
# processed: reportlgbm_df444_report.csv
# processed: reportlgbm_df445_report.csv
# processed: reportlgbm_df446_report.csv
# processed: reportlgbm_df447_report.csv
# processed: reportlgbm_df448_report.csv
# processed: reportlgbm_df449_report.csv
# processed: reportlgbm_df44_report.csv
# processed: reportlgbm_df450_report.csv
# processed: reportlgbm_df451_report.csv
# processed: reportlgbm_df452_report.csv
# processed: reportlgbm_df453_report.csv
# processed: reportlgbm_df454_report.csv
# processed: reportlgbm_df455_report.csv
# processed: reportlgbm_df456_report.csv
# processed: reportlgbm_df457_report.csv
# processed: reportlgbm_df458_report.csv
# processed: reportlgbm_df459_report.csv
# processed: reportlgbm_df45_report.csv
# processed: reportlgbm_df460_report.csv
# processed: reportlgbm_df461_report.csv
# processed: reportlgbm_df462_report.csv
# processed: reportlgbm_df463_report.csv
# processed: reportlgbm_df464_report.csv
# processed: reportlgbm_df465_report.csv
# processed: reportlgbm_df466_report.csv
# processed: reportlgbm_df467_report.csv
# processed: reportlgbm_df468_report.csv
# processed: reportlgbm_df469_report.csv
# processed: reportlgbm_df46_report.csv
# processed: reportlgbm_df470_report.csv
# processed: reportlgbm_df471_report.csv
# processed: reportlgbm_df472_report.csv
# processed: reportlgbm_df473_report.csv
# processed: reportlgbm_df474_report.csv
# processed: reportlgbm_df475_report.csv
# processed: reportlgbm_df476_report.csv
# processed: reportlgbm_df477_report.csv
# processed: reportlgbm_df478_report.csv
# processed: reportlgbm_df479_report.csv
# processed: reportlgbm_df47_report.csv
# processed: reportlgbm_df480_report.csv
# processed: reportlgbm_df481_report.csv
# processed: reportlgbm_df482_report.csv
# processed: reportlgbm_df483_report.csv
# processed: reportlgbm_df484_report.csv
# processed: reportlgbm_df485_report.csv
# processed: reportlgbm_df486_report.csv
# processed: reportlgbm_df487_report.csv
# processed: reportlgbm_df488_report.csv
# processed: reportlgbm_df489_report.csv
# processed: reportlgbm_df48_report.csv
# processed: reportlgbm_df490_report.csv
# processed: reportlgbm_df491_report.csv
# processed: reportlgbm_df492_report.csv
# processed: reportlgbm_df493_report.csv
# processed: reportlgbm_df494_report.csv
# processed: reportlgbm_df495_report.csv
# processed: reportlgbm_df496_report.csv
# processed: reportlgbm_df497_report.csv
# processed: reportlgbm_df498_report.csv
# processed: reportlgbm_df499_report.csv
# processed: reportlgbm_df49_report.csv
# processed: reportlgbm_df4_report.csv
# processed: reportlgbm_df50_report.csv
# processed: reportlgbm_df51_report.csv
# processed: reportlgbm_df52_report.csv
# processed: reportlgbm_df53_report.csv
# processed: reportlgbm_df54_report.csv
# processed: reportlgbm_df55_report.csv
# processed: reportlgbm_df56_report.csv
# processed: reportlgbm_df57_report.csv
# processed: reportlgbm_df58_report.csv
# processed: reportlgbm_df59_report.csv
# processed: reportlgbm_df5_report.csv
# processed: reportlgbm_df60_report.csv
# processed: reportlgbm_df61_report.csv
# processed: reportlgbm_df62_report.csv
# processed: reportlgbm_df63_report.csv
# processed: reportlgbm_df64_report.csv
# processed: reportlgbm_df65_report.csv
# processed: reportlgbm_df66_report.csv
# processed: reportlgbm_df67_report.csv
# processed: reportlgbm_df68_report.csv
# processed: reportlgbm_df69_report.csv
# processed: reportlgbm_df6_report.csv
# processed: reportlgbm_df70_report.csv
# processed: reportlgbm_df71_report.csv
# processed: reportlgbm_df72_report.csv
# processed: reportlgbm_df73_report.csv
# processed: reportlgbm_df74_report.csv
# processed: reportlgbm_df75_report.csv
# processed: reportlgbm_df76_report.csv
# processed: reportlgbm_df77_report.csv
# processed: reportlgbm_df78_report.csv
# processed: reportlgbm_df79_report.csv
# processed: reportlgbm_df7_report.csv
# processed: reportlgbm_df80_report.csv
# processed: reportlgbm_df81_report.csv
# processed: reportlgbm_df82_report.csv
# processed: reportlgbm_df83_report.csv
# processed: reportlgbm_df84_report.csv
# processed: reportlgbm_df85_report.csv
# processed: reportlgbm_df86_report.csv
# processed: reportlgbm_df87_report.csv
# processed: reportlgbm_df88_report.csv
# processed: reportlgbm_df89_report.csv
# processed: reportlgbm_df8_report.csv
# processed: reportlgbm_df90_report.csv
# processed: reportlgbm_df91_report.csv
# processed: reportlgbm_df92_report.csv
# processed: reportlgbm_df93_report.csv
# processed: reportlgbm_df94_report.csv
# processed: reportlgbm_df95_report.csv
# processed: reportlgbm_df96_report.csv
# processed: reportlgbm_df97_report.csv
# processed: reportlgbm_df98_report.csv
# processed: reportlgbm_df99_report.csv
# processed: reportlgbm_df9_report.csv
# Merged saved as: ../LightGBM/metrics/report/merged_precision_report.csv

# %%
# Find the metrics and report directories.
metrics_dir = '../LightGBM/metrics/report'

# Make CSV list.
csv_files = glob.glob(os.path.join(metrics_dir, "reportlgbm_df*_report.csv"))
print(f"Found {len(csv_files)} report files.")

# Init list for data.
data = []

def extract_mcc(content, class_name):
    """ 
    Extract MCC metrics. 
    """
    match = re.search(f"{class_name}: (-?\d+\.\d+)", content)
    return float(match.group(1)) if match else None

# Iterate over each file.
for file in csv_files:
    model_number = re.search(r'df(\d+)_report', file)
    if model_number:
        model_number = int(model_number.group(1))
    else:
        print(f"Error!")
        continue
    try:
        with open(file, 'r') as f:
            content = f.read()
        
        # Get MCC for each class.
        neutral_mcc = extract_mcc(content, "Neutral")
        gof_mcc = extract_mcc(content, "GOF")
        lof_mcc = extract_mcc(content, "LOF")
        
        # Add to list.
        data.append({
            'Model': model_number,
            'Neutral MCC': neutral_mcc,
            'GOF MCC': gof_mcc,
            'LOF MCC': lof_mcc
        })
        print(f"processed: {os.path.basename(file)}")
    except Exception as e:
        print(f"Error! {os.path.basename(file)}: {str(e)}")

# Compile into df.
merged_df = pd.DataFrame(data)

if merged_df.empty:
    print("Error!")
else:
    merged_df.set_index('Model', inplace=True)
    merged_df.sort_index(inplace=True)
    output_file = os.path.join(metrics_dir, "merged_precision_report.csv")
    merged_df.to_csv(output_file)
    print(f"Merged saved as: {output_file}")
# Out:
# Found 499 report files.
# processed: reportlgbm_df100_report.csv
# processed: reportlgbm_df101_report.csv
# processed: reportlgbm_df102_report.csv
# processed: reportlgbm_df103_report.csv
# processed: reportlgbm_df104_report.csv
# processed: reportlgbm_df105_report.csv
# processed: reportlgbm_df106_report.csv
# processed: reportlgbm_df107_report.csv
# processed: reportlgbm_df108_report.csv
# processed: reportlgbm_df109_report.csv
# processed: reportlgbm_df10_report.csv
# processed: reportlgbm_df110_report.csv
# processed: reportlgbm_df111_report.csv
# processed: reportlgbm_df112_report.csv
# processed: reportlgbm_df113_report.csv
# processed: reportlgbm_df114_report.csv
# processed: reportlgbm_df115_report.csv
# processed: reportlgbm_df116_report.csv
# processed: reportlgbm_df117_report.csv
# processed: reportlgbm_df118_report.csv
# processed: reportlgbm_df119_report.csv
# processed: reportlgbm_df11_report.csv
# processed: reportlgbm_df120_report.csv
# processed: reportlgbm_df121_report.csv
# processed: reportlgbm_df122_report.csv
# processed: reportlgbm_df123_report.csv
# processed: reportlgbm_df124_report.csv
# processed: reportlgbm_df125_report.csv
# processed: reportlgbm_df126_report.csv
# processed: reportlgbm_df127_report.csv
# processed: reportlgbm_df128_report.csv
# processed: reportlgbm_df129_report.csv
# processed: reportlgbm_df12_report.csv
# processed: reportlgbm_df130_report.csv
# processed: reportlgbm_df131_report.csv
# processed: reportlgbm_df132_report.csv
# processed: reportlgbm_df133_report.csv
# processed: reportlgbm_df134_report.csv
# processed: reportlgbm_df135_report.csv
# processed: reportlgbm_df136_report.csv
# processed: reportlgbm_df137_report.csv
# processed: reportlgbm_df138_report.csv
# processed: reportlgbm_df139_report.csv
# processed: reportlgbm_df13_report.csv
# processed: reportlgbm_df140_report.csv
# processed: reportlgbm_df141_report.csv
# processed: reportlgbm_df142_report.csv
# processed: reportlgbm_df143_report.csv
# processed: reportlgbm_df144_report.csv
# processed: reportlgbm_df145_report.csv
# processed: reportlgbm_df146_report.csv
# processed: reportlgbm_df147_report.csv
# processed: reportlgbm_df148_report.csv
# processed: reportlgbm_df149_report.csv
# processed: reportlgbm_df14_report.csv
# processed: reportlgbm_df150_report.csv
# processed: reportlgbm_df151_report.csv
# processed: reportlgbm_df152_report.csv
# processed: reportlgbm_df153_report.csv
# processed: reportlgbm_df154_report.csv
# processed: reportlgbm_df155_report.csv
# processed: reportlgbm_df156_report.csv
# processed: reportlgbm_df157_report.csv
# processed: reportlgbm_df158_report.csv
# processed: reportlgbm_df159_report.csv
# processed: reportlgbm_df15_report.csv
# processed: reportlgbm_df160_report.csv
# processed: reportlgbm_df161_report.csv
# processed: reportlgbm_df162_report.csv
# processed: reportlgbm_df163_report.csv
# processed: reportlgbm_df164_report.csv
# processed: reportlgbm_df165_report.csv
# processed: reportlgbm_df166_report.csv
# processed: reportlgbm_df167_report.csv
# processed: reportlgbm_df168_report.csv
# processed: reportlgbm_df169_report.csv
# processed: reportlgbm_df16_report.csv
# processed: reportlgbm_df170_report.csv
# processed: reportlgbm_df171_report.csv
# processed: reportlgbm_df172_report.csv
# processed: reportlgbm_df173_report.csv
# processed: reportlgbm_df174_report.csv
# processed: reportlgbm_df175_report.csv
# processed: reportlgbm_df176_report.csv
# processed: reportlgbm_df177_report.csv
# processed: reportlgbm_df178_report.csv
# processed: reportlgbm_df179_report.csv
# processed: reportlgbm_df17_report.csv
# processed: reportlgbm_df180_report.csv
# processed: reportlgbm_df181_report.csv
# processed: reportlgbm_df182_report.csv
# processed: reportlgbm_df183_report.csv
# processed: reportlgbm_df184_report.csv
# processed: reportlgbm_df185_report.csv
# processed: reportlgbm_df186_report.csv
# processed: reportlgbm_df187_report.csv
# processed: reportlgbm_df188_report.csv
# processed: reportlgbm_df189_report.csv
# processed: reportlgbm_df18_report.csv
# processed: reportlgbm_df190_report.csv
# processed: reportlgbm_df191_report.csv
# processed: reportlgbm_df192_report.csv
# processed: reportlgbm_df193_report.csv
# processed: reportlgbm_df194_report.csv
# processed: reportlgbm_df195_report.csv
# processed: reportlgbm_df196_report.csv
# processed: reportlgbm_df197_report.csv
# processed: reportlgbm_df198_report.csv
# processed: reportlgbm_df199_report.csv
# processed: reportlgbm_df19_report.csv
# processed: reportlgbm_df1_report.csv
# processed: reportlgbm_df200_report.csv
# processed: reportlgbm_df201_report.csv
# processed: reportlgbm_df202_report.csv
# processed: reportlgbm_df203_report.csv
# processed: reportlgbm_df204_report.csv
# processed: reportlgbm_df205_report.csv
# processed: reportlgbm_df206_report.csv
# processed: reportlgbm_df207_report.csv
# processed: reportlgbm_df208_report.csv
# processed: reportlgbm_df209_report.csv
# processed: reportlgbm_df20_report.csv
# processed: reportlgbm_df210_report.csv
# processed: reportlgbm_df211_report.csv
# processed: reportlgbm_df212_report.csv
# processed: reportlgbm_df213_report.csv
# processed: reportlgbm_df214_report.csv
# processed: reportlgbm_df215_report.csv
# processed: reportlgbm_df216_report.csv
# processed: reportlgbm_df217_report.csv
# processed: reportlgbm_df218_report.csv
# processed: reportlgbm_df219_report.csv
# processed: reportlgbm_df21_report.csv
# processed: reportlgbm_df220_report.csv
# processed: reportlgbm_df221_report.csv
# processed: reportlgbm_df222_report.csv
# processed: reportlgbm_df223_report.csv
# processed: reportlgbm_df224_report.csv
# processed: reportlgbm_df225_report.csv
# processed: reportlgbm_df226_report.csv
# processed: reportlgbm_df227_report.csv
# processed: reportlgbm_df228_report.csv
# processed: reportlgbm_df229_report.csv
# processed: reportlgbm_df22_report.csv
# processed: reportlgbm_df230_report.csv
# processed: reportlgbm_df231_report.csv
# processed: reportlgbm_df232_report.csv
# processed: reportlgbm_df233_report.csv
# processed: reportlgbm_df234_report.csv
# processed: reportlgbm_df235_report.csv
# processed: reportlgbm_df236_report.csv
# processed: reportlgbm_df237_report.csv
# processed: reportlgbm_df238_report.csv
# processed: reportlgbm_df239_report.csv
# processed: reportlgbm_df23_report.csv
# processed: reportlgbm_df240_report.csv
# processed: reportlgbm_df241_report.csv
# processed: reportlgbm_df242_report.csv
# processed: reportlgbm_df243_report.csv
# processed: reportlgbm_df244_report.csv
# processed: reportlgbm_df245_report.csv
# processed: reportlgbm_df246_report.csv
# processed: reportlgbm_df247_report.csv
# processed: reportlgbm_df248_report.csv
# processed: reportlgbm_df249_report.csv
# processed: reportlgbm_df24_report.csv
# processed: reportlgbm_df250_report.csv
# processed: reportlgbm_df251_report.csv
# processed: reportlgbm_df252_report.csv
# processed: reportlgbm_df253_report.csv
# processed: reportlgbm_df254_report.csv
# processed: reportlgbm_df255_report.csv
# processed: reportlgbm_df256_report.csv
# processed: reportlgbm_df257_report.csv
# processed: reportlgbm_df258_report.csv
# processed: reportlgbm_df259_report.csv
# processed: reportlgbm_df25_report.csv
# processed: reportlgbm_df260_report.csv
# processed: reportlgbm_df261_report.csv
# processed: reportlgbm_df262_report.csv
# processed: reportlgbm_df263_report.csv
# processed: reportlgbm_df264_report.csv
# processed: reportlgbm_df265_report.csv
# processed: reportlgbm_df266_report.csv
# processed: reportlgbm_df267_report.csv
# processed: reportlgbm_df268_report.csv
# processed: reportlgbm_df269_report.csv
# processed: reportlgbm_df26_report.csv
# processed: reportlgbm_df270_report.csv
# processed: reportlgbm_df271_report.csv
# processed: reportlgbm_df272_report.csv
# processed: reportlgbm_df273_report.csv
# processed: reportlgbm_df274_report.csv
# processed: reportlgbm_df275_report.csv
# processed: reportlgbm_df276_report.csv
# processed: reportlgbm_df277_report.csv
# processed: reportlgbm_df278_report.csv
# processed: reportlgbm_df279_report.csv
# processed: reportlgbm_df27_report.csv
# processed: reportlgbm_df280_report.csv
# processed: reportlgbm_df281_report.csv
# processed: reportlgbm_df282_report.csv
# processed: reportlgbm_df283_report.csv
# processed: reportlgbm_df284_report.csv
# processed: reportlgbm_df285_report.csv
# processed: reportlgbm_df286_report.csv
# processed: reportlgbm_df287_report.csv
# processed: reportlgbm_df288_report.csv
# processed: reportlgbm_df289_report.csv
# processed: reportlgbm_df28_report.csv
# processed: reportlgbm_df290_report.csv
# processed: reportlgbm_df291_report.csv
# processed: reportlgbm_df292_report.csv
# processed: reportlgbm_df293_report.csv
# processed: reportlgbm_df294_report.csv
# processed: reportlgbm_df295_report.csv
# processed: reportlgbm_df296_report.csv
# processed: reportlgbm_df297_report.csv
# processed: reportlgbm_df298_report.csv
# processed: reportlgbm_df299_report.csv
# processed: reportlgbm_df29_report.csv
# processed: reportlgbm_df2_report.csv
# processed: reportlgbm_df300_report.csv
# processed: reportlgbm_df301_report.csv
# processed: reportlgbm_df302_report.csv
# processed: reportlgbm_df303_report.csv
# processed: reportlgbm_df304_report.csv
# processed: reportlgbm_df305_report.csv
# processed: reportlgbm_df306_report.csv
# processed: reportlgbm_df307_report.csv
# processed: reportlgbm_df308_report.csv
# processed: reportlgbm_df309_report.csv
# processed: reportlgbm_df30_report.csv
# processed: reportlgbm_df310_report.csv
# processed: reportlgbm_df311_report.csv
# processed: reportlgbm_df312_report.csv
# processed: reportlgbm_df313_report.csv
# processed: reportlgbm_df314_report.csv
# processed: reportlgbm_df315_report.csv
# processed: reportlgbm_df316_report.csv
# processed: reportlgbm_df317_report.csv
# processed: reportlgbm_df318_report.csv
# processed: reportlgbm_df319_report.csv
# processed: reportlgbm_df31_report.csv
# processed: reportlgbm_df320_report.csv
# processed: reportlgbm_df321_report.csv
# processed: reportlgbm_df322_report.csv
# processed: reportlgbm_df323_report.csv
# processed: reportlgbm_df324_report.csv
# processed: reportlgbm_df325_report.csv
# processed: reportlgbm_df326_report.csv
# processed: reportlgbm_df327_report.csv
# processed: reportlgbm_df328_report.csv
# processed: reportlgbm_df329_report.csv
# processed: reportlgbm_df32_report.csv
# processed: reportlgbm_df330_report.csv
# processed: reportlgbm_df331_report.csv
# processed: reportlgbm_df332_report.csv
# processed: reportlgbm_df333_report.csv
# processed: reportlgbm_df334_report.csv
# processed: reportlgbm_df335_report.csv
# processed: reportlgbm_df336_report.csv
# processed: reportlgbm_df337_report.csv
# processed: reportlgbm_df338_report.csv
# processed: reportlgbm_df339_report.csv
# processed: reportlgbm_df33_report.csv
# processed: reportlgbm_df340_report.csv
# processed: reportlgbm_df341_report.csv
# processed: reportlgbm_df342_report.csv
# processed: reportlgbm_df343_report.csv
# processed: reportlgbm_df344_report.csv
# processed: reportlgbm_df345_report.csv
# processed: reportlgbm_df346_report.csv
# processed: reportlgbm_df347_report.csv
# processed: reportlgbm_df348_report.csv
# processed: reportlgbm_df349_report.csv
# processed: reportlgbm_df34_report.csv
# processed: reportlgbm_df350_report.csv
# processed: reportlgbm_df351_report.csv
# processed: reportlgbm_df352_report.csv
# processed: reportlgbm_df353_report.csv
# processed: reportlgbm_df354_report.csv
# processed: reportlgbm_df355_report.csv
# processed: reportlgbm_df356_report.csv
# processed: reportlgbm_df357_report.csv
# processed: reportlgbm_df358_report.csv
# processed: reportlgbm_df359_report.csv
# processed: reportlgbm_df35_report.csv
# processed: reportlgbm_df360_report.csv
# processed: reportlgbm_df361_report.csv
# processed: reportlgbm_df362_report.csv
# processed: reportlgbm_df363_report.csv
# processed: reportlgbm_df364_report.csv
# processed: reportlgbm_df365_report.csv
# processed: reportlgbm_df366_report.csv
# processed: reportlgbm_df367_report.csv
# processed: reportlgbm_df368_report.csv
# processed: reportlgbm_df369_report.csv
# processed: reportlgbm_df36_report.csv
# processed: reportlgbm_df370_report.csv
# processed: reportlgbm_df371_report.csv
# processed: reportlgbm_df372_report.csv
# processed: reportlgbm_df373_report.csv
# processed: reportlgbm_df374_report.csv
# processed: reportlgbm_df375_report.csv
# processed: reportlgbm_df376_report.csv
# processed: reportlgbm_df377_report.csv
# processed: reportlgbm_df378_report.csv
# processed: reportlgbm_df379_report.csv
# processed: reportlgbm_df37_report.csv
# processed: reportlgbm_df380_report.csv
# processed: reportlgbm_df381_report.csv
# processed: reportlgbm_df382_report.csv
# processed: reportlgbm_df383_report.csv
# processed: reportlgbm_df384_report.csv
# processed: reportlgbm_df385_report.csv
# processed: reportlgbm_df386_report.csv
# processed: reportlgbm_df387_report.csv
# processed: reportlgbm_df388_report.csv
# processed: reportlgbm_df389_report.csv
# processed: reportlgbm_df38_report.csv
# processed: reportlgbm_df390_report.csv
# processed: reportlgbm_df391_report.csv
# processed: reportlgbm_df392_report.csv
# processed: reportlgbm_df393_report.csv
# processed: reportlgbm_df394_report.csv
# processed: reportlgbm_df395_report.csv
# processed: reportlgbm_df396_report.csv
# processed: reportlgbm_df397_report.csv
# processed: reportlgbm_df398_report.csv
# processed: reportlgbm_df399_report.csv
# processed: reportlgbm_df39_report.csv
# processed: reportlgbm_df3_report.csv
# processed: reportlgbm_df400_report.csv
# processed: reportlgbm_df401_report.csv
# processed: reportlgbm_df402_report.csv
# processed: reportlgbm_df403_report.csv
# processed: reportlgbm_df404_report.csv
# processed: reportlgbm_df405_report.csv
# processed: reportlgbm_df406_report.csv
# processed: reportlgbm_df407_report.csv
# processed: reportlgbm_df408_report.csv
# processed: reportlgbm_df409_report.csv
# processed: reportlgbm_df40_report.csv
# processed: reportlgbm_df410_report.csv
# processed: reportlgbm_df411_report.csv
# processed: reportlgbm_df412_report.csv
# processed: reportlgbm_df413_report.csv
# processed: reportlgbm_df414_report.csv
# processed: reportlgbm_df415_report.csv
# processed: reportlgbm_df416_report.csv
# processed: reportlgbm_df417_report.csv
# processed: reportlgbm_df418_report.csv
# processed: reportlgbm_df419_report.csv
# processed: reportlgbm_df41_report.csv
# processed: reportlgbm_df420_report.csv
# processed: reportlgbm_df421_report.csv
# processed: reportlgbm_df422_report.csv
# processed: reportlgbm_df423_report.csv
# processed: reportlgbm_df424_report.csv
# processed: reportlgbm_df425_report.csv
# processed: reportlgbm_df426_report.csv
# processed: reportlgbm_df427_report.csv
# processed: reportlgbm_df428_report.csv
# processed: reportlgbm_df429_report.csv
# processed: reportlgbm_df42_report.csv
# processed: reportlgbm_df430_report.csv
# processed: reportlgbm_df431_report.csv
# processed: reportlgbm_df432_report.csv
# processed: reportlgbm_df433_report.csv
# processed: reportlgbm_df434_report.csv
# processed: reportlgbm_df435_report.csv
# processed: reportlgbm_df436_report.csv
# processed: reportlgbm_df437_report.csv
# processed: reportlgbm_df438_report.csv
# processed: reportlgbm_df439_report.csv
# processed: reportlgbm_df43_report.csv
# processed: reportlgbm_df440_report.csv
# processed: reportlgbm_df441_report.csv
# processed: reportlgbm_df442_report.csv
# processed: reportlgbm_df443_report.csv
# processed: reportlgbm_df444_report.csv
# processed: reportlgbm_df445_report.csv
# processed: reportlgbm_df446_report.csv
# processed: reportlgbm_df447_report.csv
# processed: reportlgbm_df448_report.csv
# processed: reportlgbm_df449_report.csv
# processed: reportlgbm_df44_report.csv
# processed: reportlgbm_df450_report.csv
# processed: reportlgbm_df451_report.csv
# processed: reportlgbm_df452_report.csv
# processed: reportlgbm_df453_report.csv
# processed: reportlgbm_df454_report.csv
# processed: reportlgbm_df455_report.csv
# processed: reportlgbm_df456_report.csv
# processed: reportlgbm_df457_report.csv
# processed: reportlgbm_df458_report.csv
# processed: reportlgbm_df459_report.csv
# processed: reportlgbm_df45_report.csv
# processed: reportlgbm_df460_report.csv
# processed: reportlgbm_df461_report.csv
# processed: reportlgbm_df462_report.csv
# processed: reportlgbm_df463_report.csv
# processed: reportlgbm_df464_report.csv
# processed: reportlgbm_df465_report.csv
# processed: reportlgbm_df466_report.csv
# processed: reportlgbm_df467_report.csv
# processed: reportlgbm_df468_report.csv
# processed: reportlgbm_df469_report.csv
# processed: reportlgbm_df46_report.csv
# processed: reportlgbm_df470_report.csv
# processed: reportlgbm_df471_report.csv
# processed: reportlgbm_df472_report.csv
# processed: reportlgbm_df473_report.csv
# processed: reportlgbm_df474_report.csv
# processed: reportlgbm_df475_report.csv
# processed: reportlgbm_df476_report.csv
# processed: reportlgbm_df477_report.csv
# processed: reportlgbm_df478_report.csv
# processed: reportlgbm_df479_report.csv
# processed: reportlgbm_df47_report.csv
# processed: reportlgbm_df480_report.csv
# processed: reportlgbm_df481_report.csv
# processed: reportlgbm_df482_report.csv
# processed: reportlgbm_df483_report.csv
# processed: reportlgbm_df484_report.csv
# processed: reportlgbm_df485_report.csv
# processed: reportlgbm_df486_report.csv
# processed: reportlgbm_df487_report.csv
# processed: reportlgbm_df488_report.csv
# processed: reportlgbm_df489_report.csv
# processed: reportlgbm_df48_report.csv
# processed: reportlgbm_df490_report.csv
# processed: reportlgbm_df491_report.csv
# processed: reportlgbm_df492_report.csv
# processed: reportlgbm_df493_report.csv
# processed: reportlgbm_df494_report.csv
# processed: reportlgbm_df495_report.csv
# processed: reportlgbm_df496_report.csv
# processed: reportlgbm_df497_report.csv
# processed: reportlgbm_df498_report.csv
# processed: reportlgbm_df499_report.csv
# processed: reportlgbm_df49_report.csv
# processed: reportlgbm_df4_report.csv
# processed: reportlgbm_df50_report.csv
# processed: reportlgbm_df51_report.csv
# processed: reportlgbm_df52_report.csv
# processed: reportlgbm_df53_report.csv
# processed: reportlgbm_df54_report.csv
# processed: reportlgbm_df55_report.csv
# processed: reportlgbm_df56_report.csv
# processed: reportlgbm_df57_report.csv
# processed: reportlgbm_df58_report.csv
# processed: reportlgbm_df59_report.csv
# processed: reportlgbm_df5_report.csv
# processed: reportlgbm_df60_report.csv
# processed: reportlgbm_df61_report.csv
# processed: reportlgbm_df62_report.csv
# processed: reportlgbm_df63_report.csv
# processed: reportlgbm_df64_report.csv
# processed: reportlgbm_df65_report.csv
# processed: reportlgbm_df66_report.csv
# processed: reportlgbm_df67_report.csv
# processed: reportlgbm_df68_report.csv
# processed: reportlgbm_df69_report.csv
# processed: reportlgbm_df6_report.csv
# processed: reportlgbm_df70_report.csv
# processed: reportlgbm_df71_report.csv
# processed: reportlgbm_df72_report.csv
# processed: reportlgbm_df73_report.csv
# processed: reportlgbm_df74_report.csv
# processed: reportlgbm_df75_report.csv
# processed: reportlgbm_df76_report.csv
# processed: reportlgbm_df77_report.csv
# processed: reportlgbm_df78_report.csv
# processed: reportlgbm_df79_report.csv
# processed: reportlgbm_df7_report.csv
# processed: reportlgbm_df80_report.csv
# processed: reportlgbm_df81_report.csv
# processed: reportlgbm_df82_report.csv
# processed: reportlgbm_df83_report.csv
# processed: reportlgbm_df84_report.csv
# processed: reportlgbm_df85_report.csv
# processed: reportlgbm_df86_report.csv
# processed: reportlgbm_df87_report.csv
# processed: reportlgbm_df88_report.csv
# processed: reportlgbm_df89_report.csv
# processed: reportlgbm_df8_report.csv
# processed: reportlgbm_df90_report.csv
# processed: reportlgbm_df91_report.csv
# processed: reportlgbm_df92_report.csv
# processed: reportlgbm_df93_report.csv
# processed: reportlgbm_df94_report.csv
# processed: reportlgbm_df95_report.csv
# processed: reportlgbm_df96_report.csv
# processed: reportlgbm_df97_report.csv
# processed: reportlgbm_df98_report.csv
# processed: reportlgbm_df99_report.csv
# processed: reportlgbm_df9_report.csv
# Merged saved as: ../LightGBM/metrics/report/merged_precision_report.csv
