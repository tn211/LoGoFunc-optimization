# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import csv, os
from prettytable import PrettyTable

# %%
base_input_dir = '../LightGBM/metrics/matrix/'
output_file = '../LightGBM/metrics/merged_macro_micro_recall.csv'

def read_matrix(file_path):
    df = pd.read_csv(file_path, index_col=0)
    return df.values

def macro_rec(confusion_matrix):
    recalls = np.diag(confusion_matrix) / np.sum(confusion_matrix, axis=1)
    return np.mean(recalls)

def micro_rec(confusion_matrix):
    true_positives = np.diag(confusion_matrix)
    total_true_positives = np.sum(true_positives)
    total_actual_positives = np.sum(confusion_matrix)
    return total_true_positives / total_actual_positives

results = []

# Iterate over all confusion matrices.
for i in range(1, 500):  
    input_file = f'{base_input_dir}lgbm_df{i}_matrix.csv'

    confusion_matrix = read_matrix(input_file)
    
    # Obtain macro and micro recall.
    macro_recall = macro_rec(confusion_matrix)
    micro_recall = micro_rec(confusion_matrix)
    results.append({
        'Model': str(i),
        'micro_recall': f'{micro_recall:.4f}',
        'macro_recall': f'{macro_recall:.4f}',
        'confusion_matrix': confusion_matrix.tolist()
    })
    
    print(f"Processed model: {i}")

# Write to disk.
with open(output_file, 'w', newline='') as csvfile:
    fieldnames = ['Model', 'micro_recall', 'macro_recall', 'confusion_matrix']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()
    for row in results:
        writer.writerow(row)

print(f"Saved to {output_file}")
# Out:
# Processed model: 1
# Processed model: 2
# Processed model: 3
# Processed model: 4
# Processed model: 5
# Processed model: 6
# Processed model: 7
# Processed model: 8
# Processed model: 9
# Processed model: 10
# Processed model: 11
# Processed model: 12
# Processed model: 13
# Processed model: 14
# Processed model: 15
# Processed model: 16
# Processed model: 17
# Processed model: 18
# Processed model: 19
# Processed model: 20
# Processed model: 21
# Processed model: 22
# Processed model: 23
# Processed model: 24
# Processed model: 25
# Processed model: 26
# Processed model: 27
# Processed model: 28
# Processed model: 29
# Processed model: 30
# Processed model: 31
# Processed model: 32
# Processed model: 33
# Processed model: 34
# Processed model: 35
# Processed model: 36
# Processed model: 37
# Processed model: 38
# Processed model: 39
# Processed model: 40
# Processed model: 41
# Processed model: 42
# Processed model: 43
# Processed model: 44
# Processed model: 45
# Processed model: 46
# Processed model: 47
# Processed model: 48
# Processed model: 49
# Processed model: 50
# Processed model: 51
# Processed model: 52
# Processed model: 53
# Processed model: 54
# Processed model: 55
# Processed model: 56
# Processed model: 57
# Processed model: 58
# Processed model: 59
# Processed model: 60
# Processed model: 61
# Processed model: 62
# Processed model: 63
# Processed model: 64
# Processed model: 65
# Processed model: 66
# Processed model: 67
# Processed model: 68
# Processed model: 69
# Processed model: 70
# Processed model: 71
# Processed model: 72
# Processed model: 73
# Processed model: 74
# Processed model: 75
# Processed model: 76
# Processed model: 77
# Processed model: 78
# Processed model: 79
# Processed model: 80
# Processed model: 81
# Processed model: 82
# Processed model: 83
# Processed model: 84
# Processed model: 85
# Processed model: 86
# Processed model: 87
# Processed model: 88
# Processed model: 89
# Processed model: 90
# Processed model: 91
# Processed model: 92
# Processed model: 93
# Processed model: 94
# Processed model: 95
# Processed model: 96
# Processed model: 97
# Processed model: 98
# Processed model: 99
# Processed model: 100
# Processed model: 101
# Processed model: 102
# Processed model: 103
# Processed model: 104
# Processed model: 105
# Processed model: 106
# Processed model: 107
# Processed model: 108
# Processed model: 109
# Processed model: 110
# Processed model: 111
# Processed model: 112
# Processed model: 113
# Processed model: 114
# Processed model: 115
# Processed model: 116
# Processed model: 117
# Processed model: 118
# Processed model: 119
# Processed model: 120
# Processed model: 121
# Processed model: 122
# Processed model: 123
# Processed model: 124
# Processed model: 125
# Processed model: 126
# Processed model: 127
# Processed model: 128
# Processed model: 129
# Processed model: 130
# Processed model: 131
# Processed model: 132
# Processed model: 133
# Processed model: 134
# Processed model: 135
# Processed model: 136
# Processed model: 137
# Processed model: 138
# Processed model: 139
# Processed model: 140
# Processed model: 141
# Processed model: 142
# Processed model: 143
# Processed model: 144
# Processed model: 145
# Processed model: 146
# Processed model: 147
# Processed model: 148
# Processed model: 149
# Processed model: 150
# Processed model: 151
# Processed model: 152
# Processed model: 153
# Processed model: 154
# Processed model: 155
# Processed model: 156
# Processed model: 157
# Processed model: 158
# Processed model: 159
# Processed model: 160
# Processed model: 161
# Processed model: 162
# Processed model: 163
# Processed model: 164
# Processed model: 165
# Processed model: 166
# Processed model: 167
# Processed model: 168
# Processed model: 169
# Processed model: 170
# Processed model: 171
# Processed model: 172
# Processed model: 173
# Processed model: 174
# Processed model: 175
# Processed model: 176
# Processed model: 177
# Processed model: 178
# Processed model: 179
# Processed model: 180
# Processed model: 181
# Processed model: 182
# Processed model: 183
# Processed model: 184
# Processed model: 185
# Processed model: 186
# Processed model: 187
# Processed model: 188
# Processed model: 189
# Processed model: 190
# Processed model: 191
# Processed model: 192
# Processed model: 193
# Processed model: 194
# Processed model: 195
# Processed model: 196
# Processed model: 197
# Processed model: 198
# Processed model: 199
# Processed model: 200
# Processed model: 201
# Processed model: 202
# Processed model: 203
# Processed model: 204
# Processed model: 205
# Processed model: 206
# Processed model: 207
# Processed model: 208
# Processed model: 209
# Processed model: 210
# Processed model: 211
# Processed model: 212
# Processed model: 213
# Processed model: 214
# Processed model: 215
# Processed model: 216
# Processed model: 217
# Processed model: 218
# Processed model: 219
# Processed model: 220
# Processed model: 221
# Processed model: 222
# Processed model: 223
# Processed model: 224
# Processed model: 225
# Processed model: 226
# Processed model: 227
# Processed model: 228
# Processed model: 229
# Processed model: 230
# Processed model: 231
# Processed model: 232
# Processed model: 233
# Processed model: 234
# Processed model: 235
# Processed model: 236
# Processed model: 237
# Processed model: 238
# Processed model: 239
# Processed model: 240
# Processed model: 241
# Processed model: 242
# Processed model: 243
# Processed model: 244
# Processed model: 245
# Processed model: 246
# Processed model: 247
# Processed model: 248
# Processed model: 249
# Processed model: 250
# Processed model: 251
# Processed model: 252
# Processed model: 253
# Processed model: 254
# Processed model: 255
# Processed model: 256
# Processed model: 257
# Processed model: 258
# Processed model: 259
# Processed model: 260
# Processed model: 261
# Processed model: 262
# Processed model: 263
# Processed model: 264
# Processed model: 265
# Processed model: 266
# Processed model: 267
# Processed model: 268
# Processed model: 269
# Processed model: 270
# Processed model: 271
# Processed model: 272
# Processed model: 273
# Processed model: 274
# Processed model: 275
# Processed model: 276
# Processed model: 277
# Processed model: 278
# Processed model: 279
# Processed model: 280
# Processed model: 281
# Processed model: 282
# Processed model: 283
# Processed model: 284
# Processed model: 285
# Processed model: 286
# Processed model: 287
# Processed model: 288
# Processed model: 289
# Processed model: 290
# Processed model: 291
# Processed model: 292
# Processed model: 293
# Processed model: 294
# Processed model: 295
# Processed model: 296
# Processed model: 297
# Processed model: 298
# Processed model: 299
# Processed model: 300
# Processed model: 301
# Processed model: 302
# Processed model: 303
# Processed model: 304
# Processed model: 305
# Processed model: 306
# Processed model: 307
# Processed model: 308
# Processed model: 309
# Processed model: 310
# Processed model: 311
# Processed model: 312
# Processed model: 313
# Processed model: 314
# Processed model: 315
# Processed model: 316
# Processed model: 317
# Processed model: 318
# Processed model: 319
# Processed model: 320
# Processed model: 321
# Processed model: 322
# Processed model: 323
# Processed model: 324
# Processed model: 325
# Processed model: 326
# Processed model: 327
# Processed model: 328
# Processed model: 329
# Processed model: 330
# Processed model: 331
# Processed model: 332
# Processed model: 333
# Processed model: 334
# Processed model: 335
# Processed model: 336
# Processed model: 337
# Processed model: 338
# Processed model: 339
# Processed model: 340
# Processed model: 341
# Processed model: 342
# Processed model: 343
# Processed model: 344
# Processed model: 345
# Processed model: 346
# Processed model: 347
# Processed model: 348
# Processed model: 349
# Processed model: 350
# Processed model: 351
# Processed model: 352
# Processed model: 353
# Processed model: 354
# Processed model: 355
# Processed model: 356
# Processed model: 357
# Processed model: 358
# Processed model: 359
# Processed model: 360
# Processed model: 361
# Processed model: 362
# Processed model: 363
# Processed model: 364
# Processed model: 365
# Processed model: 366
# Processed model: 367
# Processed model: 368
# Processed model: 369
# Processed model: 370
# Processed model: 371
# Processed model: 372
# Processed model: 373
# Processed model: 374
# Processed model: 375
# Processed model: 376
# Processed model: 377
# Processed model: 378
# Processed model: 379
# Processed model: 380
# Processed model: 381
# Processed model: 382
# Processed model: 383
# Processed model: 384
# Processed model: 385
# Processed model: 386
# Processed model: 387
# Processed model: 388
# Processed model: 389
# Processed model: 390
# Processed model: 391
# Processed model: 392
# Processed model: 393
# Processed model: 394
# Processed model: 395
# Processed model: 396
# Processed model: 397
# Processed model: 398
# Processed model: 399
# Processed model: 400
# Processed model: 401
# Processed model: 402
# Processed model: 403
# Processed model: 404
# Processed model: 405
# Processed model: 406
# Processed model: 407
# Processed model: 408
# Processed model: 409
# Processed model: 410
# Processed model: 411
# Processed model: 412
# Processed model: 413
# Processed model: 414
# Processed model: 415
# Processed model: 416
# Processed model: 417
# Processed model: 418
# Processed model: 419
# Processed model: 420
# Processed model: 421
# Processed model: 422
# Processed model: 423
# Processed model: 424
# Processed model: 425
# Processed model: 426
# Processed model: 427
# Processed model: 428
# Processed model: 429
# Processed model: 430
# Processed model: 431
# Processed model: 432
# Processed model: 433
# Processed model: 434
# Processed model: 435
# Processed model: 436
# Processed model: 437
# Processed model: 438
# Processed model: 439
# Processed model: 440
# Processed model: 441
# Processed model: 442
# Processed model: 443
# Processed model: 444
# Processed model: 445
# Processed model: 446
# Processed model: 447
# Processed model: 448
# Processed model: 449
# Processed model: 450
# Processed model: 451
# Processed model: 452
# Processed model: 453
# Processed model: 454
# Processed model: 455
# Processed model: 456
# Processed model: 457
# Processed model: 458
# Processed model: 459
# Processed model: 460
# Processed model: 461
# Processed model: 462
# Processed model: 463
# Processed model: 464
# Processed model: 465
# Processed model: 466
# Processed model: 467
# Processed model: 468
# Processed model: 469
# Processed model: 470
# Processed model: 471
# Processed model: 472
# Processed model: 473
# Processed model: 474
# Processed model: 475
# Processed model: 476
# Processed model: 477
# Processed model: 478
# Processed model: 479
# Processed model: 480
# Processed model: 481
# Processed model: 482
# Processed model: 483
# Processed model: 484
# Processed model: 485
# Processed model: 486
# Processed model: 487
# Processed model: 488
# Processed model: 489
# Processed model: 490
# Processed model: 491
# Processed model: 492
# Processed model: 493
# Processed model: 494
# Processed model: 495
# Processed model: 496
# Processed model: 497
# Processed model: 498
# Processed model: 499
# Saved to ../LightGBM/metrics/merged_macro_micro_recall.csv

# %%
""" Now, merge the new metrics with the existing overall report. """

recall_file = '../LightGBM/metrics/merged_macro_micro_recall.csv'
metrics_file = '../LightGBM/metrics/merged_metrics.csv'
output_file = '../LightGBM/metrics/complete_merged_metrics.csv'

recall_df = pd.read_csv(recall_file)
metrics_df = pd.read_csv(metrics_file)

# Make sure the Model indices match, then merge.
recall_df['Model'] = recall_df['Model'].astype(str)
metrics_df['Model'] = metrics_df['Model'].astype(str)
merged_df = pd.merge(metrics_df, recall_df[['Model', 'micro_recall', 'macro_recall']], on='Model', how='left')

# Drop old 'Recall' column.
merged_df = merged_df.drop('Recall', axis=1)

# Reorder.
column_order = ['Model', 'Accuracy', 'Precision', 'micro_recall', 'macro_recall', 'F1 Score', 'ROC AUC Score', 'Overall MCC']
merged_df = merged_df[column_order]

# Save to disk.
merged_df.to_csv(output_file, index=False)

print(f"Saved to {output_file}")
# Out:
# Saved to ../LightGBM/metrics/complete_merged_metrics.csv

# %% [markdown]
# ### First, graph the overall performance metrics for all 499 models.

# %%
# Load the metrics for every model.
merged = pd.read_csv('../LightGBM/metrics/complete_merged_metrics.csv')
print(merged.shape)
print(merged.columns.tolist())
# Out:
# (499, 8)
# ['Model', 'Accuracy', 'Precision', 'micro_recall', 'macro_recall', 'F1 Score', 'ROC AUC Score', 'Overall MCC']

# %%
merged=merged.drop(columns=['micro_recall'])
merged = merged.rename(columns={'macro_recall': 'Recall (macro)'})

# %%
merged['Feature Count'] = merged['Model'].astype(int)

# Init the plot.
plt.figure(figsize=(12, 8))

# Set the seaborn style.
colors = sns.color_palette("husl", n_colors=len(merged.columns[1:-1]))

# Iterate over every model and plot the metrics.
for i, column in enumerate(merged.columns[1:-1]): 
    plt.plot(merged['Feature Count'], merged[column], label=column, color=colors[i])
    
    # Add a marker for the maximum value for each metric.
    max_value = merged[column].max()
    max_index = merged[column].idxmax()
    max_feature_count = merged.loc[max_index, 'Feature Count']
    plt.plot(max_feature_count, max_value, 'o', color=colors[i], markersize=8)
    plt.annotate(f'{max_value:.3f}\n({max_feature_count})', 
                 (max_feature_count, max_value),
                 textcoords="offset points",
                 xytext=(0,10),
                 ha='center',
                 fontsize=8)

# I chose log scale due to large range of feature counts.
plt.xscale('log') 
plt.xlabel('Number of Features (log scale)')
plt.ylabel('Metric Value')
plt.title('ENS-LGBM: Effect of Feature Count on Overall Performance Metrics')
plt.legend(title='Metrics', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True, which="both", ls="-", alpha=0.2)
for count in [10, 50, 100, 200, 400]:
    plt.axvline(x=count, color='gray', linestyle='--', alpha=0.5)
    plt.text(count, plt.ylim()[0], str(count), horizontalalignment='center')

plt.tight_layout()
plt.show()

# %%
def get_best_feature_count(data, metric):
    """
    Extract the feature count with the highest score for a given metric.
    """
    max_index = data[metric].idxmax()
    return data.loc[max_index, 'Feature Count'], data.loc[max_index, metric]

# Init the table.
table = PrettyTable()
table.field_names = ["Metric", "Best Feature Count", "Best Score"]

# List of metrics.
metrics = [col for col in merged.columns if col not in ['Model', 'Feature Count']]

# Add each one to the table.
for metric in metrics:
    best_count, best_score = get_best_feature_count(merged, metric)
    table.add_row([
        metric,
        f"{best_count}",
        f"{best_score:.3f}"
    ])

print(table)
# Out:
# +----------------+--------------------+------------+
# |     Metric     | Best Feature Count | Best Score |
# +----------------+--------------------+------------+
# |    Accuracy    |        414         |   0.870    |
# |   Precision    |         3          |   0.883    |
# | Recall (macro) |        430         |   0.824    |
# |    F1 Score    |        414         |   0.873    |
# | ROC AUC Score  |        430         |   0.935    |
# |  Overall MCC   |        414         |   0.768    |
# +----------------+--------------------+------------+

# %% [markdown]
# ### Next, plot graphs for all four class-wise metrics for each model.

# %%
""" First, need to extract the AP columns from the overall report to match format of other metrics."""
file_path = '../LightGBM/metrics/report/overall_report_with_ap.csv'
df = pd.read_csv(file_path)

# AP columns
selected_columns = ['Model', 'GOF AP', 'LOF AP', 'Neutral AP']
df_selected = df[selected_columns]

# Report.
output_path = '../LightGBM/metrics/report/merged_AP_report.csv'
df_selected.to_csv(output_path, index=False)

print(f"Saved to {output_path}")
# Out:
# Saved to ../LightGBM/metrics/report/merged_AP_report.csv

# %%
def do_columns(df, metric):
    """
    This ensures that classes appear in the same color order for each metric.
    """
    if metric == 'mcc':
        ordered_columns = ['Model', 'GOF MCC', 'LOF MCC', 'Neutral MCC']
    elif metric == 'ap':
        ordered_columns = ['Model', 'GOF AP', 'LOF AP', 'Neutral AP']
    else:
        ordered_columns = ['Model', f'GOF {metric.capitalize()}', f'LOF {metric.capitalize()}', f'Neutral {metric.capitalize()}']
    return df[ordered_columns]

def do_subplot(ax, data, title, color_dict):
    """
    This generates subplots for each metric.
    """
    class_columns = [col for col in data.columns if col != 'Model' and col != 'Feature Count']
    for column in class_columns:
        color = color_dict[column.split()[0]]
        ax.plot(data['Feature Count'], data[column], label=column, color=color)
        max_value = data[column].max()
        max_index = data[column].idxmax()
        max_feature_count = data.loc[max_index, 'Feature Count']
        ax.plot(max_feature_count, max_value, 'o', color=color, markersize=6)
        ax.annotate(f'{max_value:.3f}\n({max_feature_count})',
                    (max_feature_count, max_value),
                    textcoords="offset points",
                    xytext=(0,5),
                    ha='center',
                    fontsize=6)

    ax.set_xscale('log')
    ax.set_xlabel('Number of Features (log scale)')
    ax.set_ylabel('Metric Value')
    ax.set_title(title)
    ax.legend(title='Classes', bbox_to_anchor=(1.05, 1), loc='upper left', fontsize='x-small')
    ax.grid(True, which="both", ls="-", alpha=0.2)
    
    for count in [10, 50, 100, 200, 400]:
        ax.axvline(x=count, color='gray', linestyle='--', alpha=0.5)
        ax.text(count, ax.get_ylim()[0], str(count), horizontalalignment='center', fontsize=6)

# This draws the figure.
fig, axs = plt.subplots(2, 2, figsize=(20, 20))

# Points to the metric files.
metrics = [
    ('ap', '../LightGBM/metrics/report/merged_AP_report.csv', 'Average Precision'),
    ('recall', '../LightGBM/metrics/report/merged_recall_report.csv', 'Recall'),
    ('f1', '../LightGBM/metrics/report/merged_f1_report.csv', 'F1 Score'),
    ('mcc', '../LightGBM/metrics/report/merged_mcc_report.csv', 'MCC')
]

# Choose colors for classes.
viridis_palette = sns.color_palette('viridis', 3)  
color_dict = {
    'GOF': viridis_palette[0],
    'LOF': viridis_palette[1],
    'Neutral': viridis_palette[2]
}

# Plot each metric.
for i, (metric, file_name, title) in enumerate(metrics):
    data = pd.read_csv(file_name)
    data = do_columns(data, metric)
    data['Feature Count'] = data['Model'].astype(int)
    
    row = i // 2
    col = i % 2
    do_subplot(axs[row, col], data, f'ENS-LGBM: Effect of Feature Count on {title}', color_dict)
    
plt.tight_layout()
fig.suptitle('ENS-LGBM: Class-wise Performance Metrics', fontsize=16, y=1.02)
plt.show()

# %%
def get_best_feature_counts(data, metric):
    """
    Extract the feature counts with the highest score for each class.
    """
    class_columns = [col for col in data.columns if col.lower() not in ['model']]
    best_counts = {}
    for column in class_columns:
        max_index = data[column].idxmax()
        best_counts[column.lower()] = (data.loc[max_index, 'model'], data.loc[max_index, column])
    return best_counts

metrics = [
    ('ap', '../LightGBM/metrics/report/merged_AP_report.csv', 'Average Precision'),
    ('recall', '../LightGBM/metrics/report/merged_recall_report.csv', 'Recall'),
    ('f1', '../LightGBM/metrics/report/merged_f1_report.csv', 'F1 Score'),
    ('mcc', '../LightGBM/metrics/report/merged_mcc_report.csv', 'MCC')
]

# init table.
table = PrettyTable()
table.field_names = ["Metric", "GOF", "LOF", "Neutral"]

# add to table.
for metric, file_name, title in metrics:
    data = pd.read_csv(file_name)
    data.columns = [col.lower() for col in data.columns] 
    
    best_counts = get_best_feature_counts(data, metric)
    table.add_row([
        title,
        f"{best_counts[f'gof {metric}'][0]} ({best_counts[f'gof {metric}'][1]:.3f})",
        f"{best_counts[f'lof {metric}'][0]} ({best_counts[f'lof {metric}'][1]:.3f})",
        f"{best_counts[f'neutral {metric}'][0]} ({best_counts[f'neutral {metric}'][1]:.3f})"
    ])

print(table)
# Out:
# +-------------------+-------------+-------------+-------------+
# |       Metric      |     GOF     |     LOF     |   Neutral   |
# +-------------------+-------------+-------------+-------------+
# | Average Precision | 126 (0.600) | 436 (0.933) | 473 (0.958) |
# |       Recall      |  3 (0.910)  | 240 (0.880) |  91 (0.880) |
# |      F1 Score     | 414 (0.600) | 240 (0.880) |  91 (0.900) |
# |        MCC        | 414 (0.578) | 414 (0.772) | 316 (0.813) |
# +-------------------+-------------+-------------+-------------+
