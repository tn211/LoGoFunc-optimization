# %%
import os
import pandas as pd
import numpy as np
from itertools import combinations

# %% [markdown]
# ### This creates subsets for LOFO ranking. Each CSV is missing one of the 499 features.

# %%
# Loab both datasets.
X_train = pd.read_csv('../data/X_train_encoded.csv', low_memory=False)
X_test = pd.read_csv('../data/X_test_encoded.csv', low_memory=False)
assert len(X_train.columns) == len(X_test.columns)

# %%
# Make sure it has the correct shape.
df = X_train
print(df.shape)
# Out:
# (25546, 500)

# %%
def subsets(df):
    """ 
    Generate all possible feature sets, each missing one feature. 
    """
    all_features = df.columns.tolist()
    n_features = len(all_features)
    feat_sets = list(combinations(all_features, n_features - 1))
    return [list(feat_set) for feat_set in feat_sets]

feat_sets = subsets(df)

# Make CSV directory.
output_dir = "../data/train_subsets"
os.makedirs(output_dir, exist_ok=True)

# Iterate untill all subsets are exported to CSV.
for i, feat_set in enumerate(feat_sets):
    subset_df = df[feat_set]
    removed_feature = set(df.columns) - set(feat_set)
    filename = f"train_without_{list(removed_feature)[0]}.csv"
    filepath = os.path.join(output_dir, filename)
    subset_df.to_csv(filepath, index=False)
    print(f"Exported subset {i+1}/499 to {filepath}")
# Out:
# Exported subset 1/499 to ../data/train_subsets/train_without_feature499.csv
# Exported subset 2/499 to ../data/train_subsets/train_without_feature498.csv
# Exported subset 3/499 to ../data/train_subsets/train_without_feature497.csv
# Exported subset 4/499 to ../data/train_subsets/train_without_feature496.csv
# Exported subset 5/499 to ../data/train_subsets/train_without_feature495.csv
# Exported subset 6/499 to ../data/train_subsets/train_without_feature494.csv
# Exported subset 7/499 to ../data/train_subsets/train_without_feature493.csv
# Exported subset 8/499 to ../data/train_subsets/train_without_feature492.csv
# Exported subset 9/499 to ../data/train_subsets/train_without_feature491.csv
# Exported subset 10/499 to ../data/train_subsets/train_without_feature490.csv
# Exported subset 11/499 to ../data/train_subsets/train_without_feature489.csv
# Exported subset 12/499 to ../data/train_subsets/train_without_feature488.csv
# Exported subset 13/499 to ../data/train_subsets/train_without_feature487.csv
# Exported subset 14/499 to ../data/train_subsets/train_without_feature486.csv
# Exported subset 15/499 to ../data/train_subsets/train_without_feature485.csv
# Exported subset 16/499 to ../data/train_subsets/train_without_feature484.csv
# Exported subset 17/499 to ../data/train_subsets/train_without_feature483.csv
# Exported subset 18/499 to ../data/train_subsets/train_without_feature482.csv
# Exported subset 19/499 to ../data/train_subsets/train_without_feature481.csv
# Exported subset 20/499 to ../data/train_subsets/train_without_feature480.csv
# Exported subset 21/499 to ../data/train_subsets/train_without_feature479.csv
# Exported subset 22/499 to ../data/train_subsets/train_without_feature478.csv
# Exported subset 23/499 to ../data/train_subsets/train_without_feature477.csv
# Exported subset 24/499 to ../data/train_subsets/train_without_feature476.csv
# Exported subset 25/499 to ../data/train_subsets/train_without_feature475.csv
# Exported subset 26/499 to ../data/train_subsets/train_without_feature474.csv
# Exported subset 27/499 to ../data/train_subsets/train_without_feature473.csv
# Exported subset 28/499 to ../data/train_subsets/train_without_feature472.csv
# Exported subset 29/499 to ../data/train_subsets/train_without_feature471.csv
# Exported subset 30/499 to ../data/train_subsets/train_without_feature470.csv
# Exported subset 31/499 to ../data/train_subsets/train_without_feature469.csv
# Exported subset 32/499 to ../data/train_subsets/train_without_feature468.csv
# Exported subset 33/499 to ../data/train_subsets/train_without_feature467.csv
# Exported subset 34/499 to ../data/train_subsets/train_without_feature466.csv
# Exported subset 35/499 to ../data/train_subsets/train_without_feature465.csv
# Exported subset 36/499 to ../data/train_subsets/train_without_feature464.csv
# Exported subset 37/499 to ../data/train_subsets/train_without_feature463.csv
# Exported subset 38/499 to ../data/train_subsets/train_without_feature462.csv
# Exported subset 39/499 to ../data/train_subsets/train_without_feature461.csv
# Exported subset 40/499 to ../data/train_subsets/train_without_feature460.csv
# Exported subset 41/499 to ../data/train_subsets/train_without_feature459.csv
# Exported subset 42/499 to ../data/train_subsets/train_without_feature458.csv
# Exported subset 43/499 to ../data/train_subsets/train_without_feature457.csv
# Exported subset 44/499 to ../data/train_subsets/train_without_feature456.csv
# Exported subset 45/499 to ../data/train_subsets/train_without_feature455.csv
# Exported subset 46/499 to ../data/train_subsets/train_without_feature454.csv
# Exported subset 47/499 to ../data/train_subsets/train_without_feature453.csv
# Exported subset 48/499 to ../data/train_subsets/train_without_feature452.csv
# Exported subset 49/499 to ../data/train_subsets/train_without_feature451.csv
# Exported subset 50/499 to ../data/train_subsets/train_without_feature450.csv
# Exported subset 51/499 to ../data/train_subsets/train_without_feature449.csv
# Exported subset 52/499 to ../data/train_subsets/train_without_feature448.csv
# Exported subset 53/499 to ../data/train_subsets/train_without_feature447.csv
# Exported subset 54/499 to ../data/train_subsets/train_without_feature446.csv
# Exported subset 55/499 to ../data/train_subsets/train_without_feature445.csv
# Exported subset 56/499 to ../data/train_subsets/train_without_feature444.csv
# Exported subset 57/499 to ../data/train_subsets/train_without_feature443.csv
# Exported subset 58/499 to ../data/train_subsets/train_without_feature442.csv
# Exported subset 59/499 to ../data/train_subsets/train_without_feature441.csv
# Exported subset 60/499 to ../data/train_subsets/train_without_feature440.csv
# Exported subset 61/499 to ../data/train_subsets/train_without_feature439.csv
# Exported subset 62/499 to ../data/train_subsets/train_without_feature438.csv
# Exported subset 63/499 to ../data/train_subsets/train_without_feature437.csv
# Exported subset 64/499 to ../data/train_subsets/train_without_feature436.csv
# Exported subset 65/499 to ../data/train_subsets/train_without_feature435.csv
# Exported subset 66/499 to ../data/train_subsets/train_without_feature434.csv
# Exported subset 67/499 to ../data/train_subsets/train_without_feature433.csv
# Exported subset 68/499 to ../data/train_subsets/train_without_feature432.csv
# Exported subset 69/499 to ../data/train_subsets/train_without_feature431.csv
# Exported subset 70/499 to ../data/train_subsets/train_without_feature430.csv
# Exported subset 71/499 to ../data/train_subsets/train_without_feature429.csv
# Exported subset 72/499 to ../data/train_subsets/train_without_feature428.csv
# Exported subset 73/499 to ../data/train_subsets/train_without_feature427.csv
# Exported subset 74/499 to ../data/train_subsets/train_without_feature426.csv
# Exported subset 75/499 to ../data/train_subsets/train_without_feature425.csv
# Exported subset 76/499 to ../data/train_subsets/train_without_feature424.csv
# Exported subset 77/499 to ../data/train_subsets/train_without_feature423.csv
# Exported subset 78/499 to ../data/train_subsets/train_without_feature422.csv
# Exported subset 79/499 to ../data/train_subsets/train_without_feature421.csv
# Exported subset 80/499 to ../data/train_subsets/train_without_feature420.csv
# Exported subset 81/499 to ../data/train_subsets/train_without_feature419.csv
# Exported subset 82/499 to ../data/train_subsets/train_without_feature418.csv
# Exported subset 83/499 to ../data/train_subsets/train_without_feature417.csv
# Exported subset 84/499 to ../data/train_subsets/train_without_feature416.csv
# Exported subset 85/499 to ../data/train_subsets/train_without_feature415.csv
# Exported subset 86/499 to ../data/train_subsets/train_without_feature414.csv
# Exported subset 87/499 to ../data/train_subsets/train_without_feature413.csv
# Exported subset 88/499 to ../data/train_subsets/train_without_feature412.csv
# Exported subset 89/499 to ../data/train_subsets/train_without_feature411.csv
# Exported subset 90/499 to ../data/train_subsets/train_without_feature410.csv
# Exported subset 91/499 to ../data/train_subsets/train_without_feature409.csv
# Exported subset 92/499 to ../data/train_subsets/train_without_feature408.csv
# Exported subset 93/499 to ../data/train_subsets/train_without_feature407.csv
# Exported subset 94/499 to ../data/train_subsets/train_without_feature406.csv
# Exported subset 95/499 to ../data/train_subsets/train_without_feature405.csv
# Exported subset 96/499 to ../data/train_subsets/train_without_feature404.csv
# Exported subset 97/499 to ../data/train_subsets/train_without_feature403.csv
# Exported subset 98/499 to ../data/train_subsets/train_without_feature402.csv
# Exported subset 99/499 to ../data/train_subsets/train_without_feature401.csv
# Exported subset 100/499 to ../data/train_subsets/train_without_feature400.csv
# Exported subset 101/499 to ../data/train_subsets/train_without_feature399.csv
# Exported subset 102/499 to ../data/train_subsets/train_without_feature398.csv
# Exported subset 103/499 to ../data/train_subsets/train_without_feature397.csv
# Exported subset 104/499 to ../data/train_subsets/train_without_feature396.csv
# Exported subset 105/499 to ../data/train_subsets/train_without_feature395.csv
# Exported subset 106/499 to ../data/train_subsets/train_without_feature394.csv
# Exported subset 107/499 to ../data/train_subsets/train_without_feature393.csv
# Exported subset 108/499 to ../data/train_subsets/train_without_feature392.csv
# Exported subset 109/499 to ../data/train_subsets/train_without_feature391.csv
# Exported subset 110/499 to ../data/train_subsets/train_without_feature390.csv
# Exported subset 111/499 to ../data/train_subsets/train_without_feature389.csv
# Exported subset 112/499 to ../data/train_subsets/train_without_feature388.csv
# Exported subset 113/499 to ../data/train_subsets/train_without_feature387.csv
# Exported subset 114/499 to ../data/train_subsets/train_without_feature386.csv
# Exported subset 115/499 to ../data/train_subsets/train_without_feature385.csv
# Exported subset 116/499 to ../data/train_subsets/train_without_feature384.csv
# Exported subset 117/499 to ../data/train_subsets/train_without_feature383.csv
# Exported subset 118/499 to ../data/train_subsets/train_without_feature382.csv
# Exported subset 119/499 to ../data/train_subsets/train_without_feature381.csv
# Exported subset 120/499 to ../data/train_subsets/train_without_feature380.csv
# Exported subset 121/499 to ../data/train_subsets/train_without_feature379.csv
# Exported subset 122/499 to ../data/train_subsets/train_without_feature378.csv
# Exported subset 123/499 to ../data/train_subsets/train_without_feature377.csv
# Exported subset 124/499 to ../data/train_subsets/train_without_feature376.csv
# Exported subset 125/499 to ../data/train_subsets/train_without_feature375.csv
# Exported subset 126/499 to ../data/train_subsets/train_without_feature374.csv
# Exported subset 127/499 to ../data/train_subsets/train_without_feature373.csv
# Exported subset 128/499 to ../data/train_subsets/train_without_feature372.csv
# Exported subset 129/499 to ../data/train_subsets/train_without_feature371.csv
# Exported subset 130/499 to ../data/train_subsets/train_without_feature370.csv
# Exported subset 131/499 to ../data/train_subsets/train_without_feature369.csv
# Exported subset 132/499 to ../data/train_subsets/train_without_feature368.csv
# Exported subset 133/499 to ../data/train_subsets/train_without_feature367.csv
# Exported subset 134/499 to ../data/train_subsets/train_without_feature366.csv
# Exported subset 135/499 to ../data/train_subsets/train_without_feature365.csv
# Exported subset 136/499 to ../data/train_subsets/train_without_feature364.csv
# Exported subset 137/499 to ../data/train_subsets/train_without_feature363.csv
# Exported subset 138/499 to ../data/train_subsets/train_without_feature362.csv
# Exported subset 139/499 to ../data/train_subsets/train_without_feature361.csv
# Exported subset 140/499 to ../data/train_subsets/train_without_feature360.csv
# Exported subset 141/499 to ../data/train_subsets/train_without_feature359.csv
# Exported subset 142/499 to ../data/train_subsets/train_without_feature358.csv
# Exported subset 143/499 to ../data/train_subsets/train_without_feature357.csv
# Exported subset 144/499 to ../data/train_subsets/train_without_feature356.csv
# Exported subset 145/499 to ../data/train_subsets/train_without_feature355.csv
# Exported subset 146/499 to ../data/train_subsets/train_without_feature354.csv
# Exported subset 147/499 to ../data/train_subsets/train_without_feature353.csv
# Exported subset 148/499 to ../data/train_subsets/train_without_feature352.csv
# Exported subset 149/499 to ../data/train_subsets/train_without_feature351.csv
# Exported subset 150/499 to ../data/train_subsets/train_without_feature350.csv
# Exported subset 151/499 to ../data/train_subsets/train_without_feature349.csv
# Exported subset 152/499 to ../data/train_subsets/train_without_feature348.csv
# Exported subset 153/499 to ../data/train_subsets/train_without_feature347.csv
# Exported subset 154/499 to ../data/train_subsets/train_without_feature346.csv
# Exported subset 155/499 to ../data/train_subsets/train_without_feature345.csv
# Exported subset 156/499 to ../data/train_subsets/train_without_feature344.csv
# Exported subset 157/499 to ../data/train_subsets/train_without_feature343.csv
# Exported subset 158/499 to ../data/train_subsets/train_without_feature342.csv
# Exported subset 159/499 to ../data/train_subsets/train_without_feature341.csv
# Exported subset 160/499 to ../data/train_subsets/train_without_feature340.csv
# Exported subset 161/499 to ../data/train_subsets/train_without_feature339.csv
# Exported subset 162/499 to ../data/train_subsets/train_without_feature338.csv
# Exported subset 163/499 to ../data/train_subsets/train_without_feature337.csv
# Exported subset 164/499 to ../data/train_subsets/train_without_feature336.csv
# Exported subset 165/499 to ../data/train_subsets/train_without_feature335.csv
# Exported subset 166/499 to ../data/train_subsets/train_without_feature334.csv
# Exported subset 167/499 to ../data/train_subsets/train_without_feature333.csv
# Exported subset 168/499 to ../data/train_subsets/train_without_feature332.csv
# Exported subset 169/499 to ../data/train_subsets/train_without_feature331.csv
# Exported subset 170/499 to ../data/train_subsets/train_without_feature330.csv
# Exported subset 171/499 to ../data/train_subsets/train_without_feature329.csv
# Exported subset 172/499 to ../data/train_subsets/train_without_feature328.csv
# Exported subset 173/499 to ../data/train_subsets/train_without_feature327.csv
# Exported subset 174/499 to ../data/train_subsets/train_without_feature326.csv
# Exported subset 175/499 to ../data/train_subsets/train_without_feature325.csv
# Exported subset 176/499 to ../data/train_subsets/train_without_feature324.csv
# Exported subset 177/499 to ../data/train_subsets/train_without_feature323.csv
# Exported subset 178/499 to ../data/train_subsets/train_without_feature322.csv
# Exported subset 179/499 to ../data/train_subsets/train_without_feature321.csv
# Exported subset 180/499 to ../data/train_subsets/train_without_feature320.csv
# Exported subset 181/499 to ../data/train_subsets/train_without_feature319.csv
# Exported subset 182/499 to ../data/train_subsets/train_without_feature318.csv
# Exported subset 183/499 to ../data/train_subsets/train_without_feature317.csv
# Exported subset 184/499 to ../data/train_subsets/train_without_feature316.csv
# Exported subset 185/499 to ../data/train_subsets/train_without_feature315.csv
# Exported subset 186/499 to ../data/train_subsets/train_without_feature314.csv
# Exported subset 187/499 to ../data/train_subsets/train_without_feature313.csv
# Exported subset 188/499 to ../data/train_subsets/train_without_feature312.csv
# Exported subset 189/499 to ../data/train_subsets/train_without_feature311.csv
# Exported subset 190/499 to ../data/train_subsets/train_without_feature310.csv
# Exported subset 191/499 to ../data/train_subsets/train_without_feature309.csv
# Exported subset 192/499 to ../data/train_subsets/train_without_feature308.csv
# Exported subset 193/499 to ../data/train_subsets/train_without_feature307.csv
# Exported subset 194/499 to ../data/train_subsets/train_without_feature306.csv
# Exported subset 195/499 to ../data/train_subsets/train_without_feature305.csv
# Exported subset 196/499 to ../data/train_subsets/train_without_feature304.csv
# Exported subset 197/499 to ../data/train_subsets/train_without_feature303.csv
# Exported subset 198/499 to ../data/train_subsets/train_without_feature302.csv
# Exported subset 199/499 to ../data/train_subsets/train_without_feature301.csv
# Exported subset 200/499 to ../data/train_subsets/train_without_feature300.csv
# Exported subset 201/499 to ../data/train_subsets/train_without_feature299.csv
# Exported subset 202/499 to ../data/train_subsets/train_without_feature298.csv
# Exported subset 203/499 to ../data/train_subsets/train_without_feature297.csv
# Exported subset 204/499 to ../data/train_subsets/train_without_feature296.csv
# Exported subset 205/499 to ../data/train_subsets/train_without_feature295.csv
# Exported subset 206/499 to ../data/train_subsets/train_without_feature294.csv
# Exported subset 207/499 to ../data/train_subsets/train_without_feature293.csv
# Exported subset 208/499 to ../data/train_subsets/train_without_feature292.csv
# Exported subset 209/499 to ../data/train_subsets/train_without_feature291.csv
# Exported subset 210/499 to ../data/train_subsets/train_without_feature290.csv
# Exported subset 211/499 to ../data/train_subsets/train_without_feature289.csv
# Exported subset 212/499 to ../data/train_subsets/train_without_feature288.csv
# Exported subset 213/499 to ../data/train_subsets/train_without_feature287.csv
# Exported subset 214/499 to ../data/train_subsets/train_without_feature286.csv
# Exported subset 215/499 to ../data/train_subsets/train_without_feature285.csv
# Exported subset 216/499 to ../data/train_subsets/train_without_feature284.csv
# Exported subset 217/499 to ../data/train_subsets/train_without_feature283.csv
# Exported subset 218/499 to ../data/train_subsets/train_without_feature282.csv
# Exported subset 219/499 to ../data/train_subsets/train_without_feature281.csv
# Exported subset 220/499 to ../data/train_subsets/train_without_feature280.csv
# Exported subset 221/499 to ../data/train_subsets/train_without_feature279.csv
# Exported subset 222/499 to ../data/train_subsets/train_without_feature278.csv
# Exported subset 223/499 to ../data/train_subsets/train_without_feature277.csv
# Exported subset 224/499 to ../data/train_subsets/train_without_feature276.csv
# Exported subset 225/499 to ../data/train_subsets/train_without_feature275.csv
# Exported subset 226/499 to ../data/train_subsets/train_without_feature274.csv
# Exported subset 227/499 to ../data/train_subsets/train_without_feature273.csv
# Exported subset 228/499 to ../data/train_subsets/train_without_feature272.csv
# Exported subset 229/499 to ../data/train_subsets/train_without_feature271.csv
# Exported subset 230/499 to ../data/train_subsets/train_without_feature270.csv
# Exported subset 231/499 to ../data/train_subsets/train_without_feature269.csv
# Exported subset 232/499 to ../data/train_subsets/train_without_feature268.csv
# Exported subset 233/499 to ../data/train_subsets/train_without_feature267.csv
# Exported subset 234/499 to ../data/train_subsets/train_without_feature266.csv
# Exported subset 235/499 to ../data/train_subsets/train_without_feature265.csv
# Exported subset 236/499 to ../data/train_subsets/train_without_feature264.csv
# Exported subset 237/499 to ../data/train_subsets/train_without_feature263.csv
# Exported subset 238/499 to ../data/train_subsets/train_without_feature262.csv
# Exported subset 239/499 to ../data/train_subsets/train_without_feature261.csv
# Exported subset 240/499 to ../data/train_subsets/train_without_feature260.csv
# Exported subset 241/499 to ../data/train_subsets/train_without_feature259.csv
# Exported subset 242/499 to ../data/train_subsets/train_without_feature258.csv
# Exported subset 243/499 to ../data/train_subsets/train_without_feature257.csv
# Exported subset 244/499 to ../data/train_subsets/train_without_feature256.csv
# Exported subset 245/499 to ../data/train_subsets/train_without_feature255.csv
# Exported subset 246/499 to ../data/train_subsets/train_without_feature254.csv
# Exported subset 247/499 to ../data/train_subsets/train_without_feature253.csv
# Exported subset 248/499 to ../data/train_subsets/train_without_feature252.csv
# Exported subset 249/499 to ../data/train_subsets/train_without_feature251.csv
# Exported subset 250/499 to ../data/train_subsets/train_without_feature250.csv
# Exported subset 251/499 to ../data/train_subsets/train_without_feature249.csv
# Exported subset 252/499 to ../data/train_subsets/train_without_feature248.csv
# Exported subset 253/499 to ../data/train_subsets/train_without_feature247.csv
# Exported subset 254/499 to ../data/train_subsets/train_without_feature246.csv
# Exported subset 255/499 to ../data/train_subsets/train_without_feature245.csv
# Exported subset 256/499 to ../data/train_subsets/train_without_feature244.csv
# Exported subset 257/499 to ../data/train_subsets/train_without_feature243.csv
# Exported subset 258/499 to ../data/train_subsets/train_without_feature242.csv
# Exported subset 259/499 to ../data/train_subsets/train_without_feature241.csv
# Exported subset 260/499 to ../data/train_subsets/train_without_feature240.csv
# Exported subset 261/499 to ../data/train_subsets/train_without_feature239.csv
# Exported subset 262/499 to ../data/train_subsets/train_without_feature238.csv
# Exported subset 263/499 to ../data/train_subsets/train_without_feature237.csv
# Exported subset 264/499 to ../data/train_subsets/train_without_feature236.csv
# Exported subset 265/499 to ../data/train_subsets/train_without_feature235.csv
# Exported subset 266/499 to ../data/train_subsets/train_without_feature234.csv
# Exported subset 267/499 to ../data/train_subsets/train_without_feature233.csv
# Exported subset 268/499 to ../data/train_subsets/train_without_feature232.csv
# Exported subset 269/499 to ../data/train_subsets/train_without_feature231.csv
# Exported subset 270/499 to ../data/train_subsets/train_without_feature230.csv
# Exported subset 271/499 to ../data/train_subsets/train_without_feature229.csv
# Exported subset 272/499 to ../data/train_subsets/train_without_feature228.csv
# Exported subset 273/499 to ../data/train_subsets/train_without_feature227.csv
# Exported subset 274/499 to ../data/train_subsets/train_without_feature226.csv
# Exported subset 275/499 to ../data/train_subsets/train_without_feature225.csv
# Exported subset 276/499 to ../data/train_subsets/train_without_feature224.csv
# Exported subset 277/499 to ../data/train_subsets/train_without_feature223.csv
# Exported subset 278/499 to ../data/train_subsets/train_without_feature222.csv
# Exported subset 279/499 to ../data/train_subsets/train_without_feature221.csv
# Exported subset 280/499 to ../data/train_subsets/train_without_feature220.csv
# Exported subset 281/499 to ../data/train_subsets/train_without_feature219.csv
# Exported subset 282/499 to ../data/train_subsets/train_without_feature218.csv
# Exported subset 283/499 to ../data/train_subsets/train_without_feature217.csv
# Exported subset 284/499 to ../data/train_subsets/train_without_feature216.csv
# Exported subset 285/499 to ../data/train_subsets/train_without_feature215.csv
# Exported subset 286/499 to ../data/train_subsets/train_without_feature214.csv
# Exported subset 287/499 to ../data/train_subsets/train_without_feature213.csv
# Exported subset 288/499 to ../data/train_subsets/train_without_feature212.csv
# Exported subset 289/499 to ../data/train_subsets/train_without_feature211.csv
# Exported subset 290/499 to ../data/train_subsets/train_without_feature210.csv
# Exported subset 291/499 to ../data/train_subsets/train_without_feature209.csv
# Exported subset 292/499 to ../data/train_subsets/train_without_feature208.csv
# Exported subset 293/499 to ../data/train_subsets/train_without_feature207.csv
# Exported subset 294/499 to ../data/train_subsets/train_without_feature206.csv
# Exported subset 295/499 to ../data/train_subsets/train_without_feature205.csv
# Exported subset 296/499 to ../data/train_subsets/train_without_feature204.csv
# Exported subset 297/499 to ../data/train_subsets/train_without_feature203.csv
# Exported subset 298/499 to ../data/train_subsets/train_without_feature202.csv
# Exported subset 299/499 to ../data/train_subsets/train_without_feature201.csv
# Exported subset 300/499 to ../data/train_subsets/train_without_feature200.csv
# Exported subset 301/499 to ../data/train_subsets/train_without_feature199.csv
# Exported subset 302/499 to ../data/train_subsets/train_without_feature198.csv
# Exported subset 303/499 to ../data/train_subsets/train_without_feature197.csv
# Exported subset 304/499 to ../data/train_subsets/train_without_feature196.csv
# Exported subset 305/499 to ../data/train_subsets/train_without_feature195.csv
# Exported subset 306/499 to ../data/train_subsets/train_without_feature194.csv
# Exported subset 307/499 to ../data/train_subsets/train_without_feature193.csv
# Exported subset 308/499 to ../data/train_subsets/train_without_feature192.csv
# Exported subset 309/499 to ../data/train_subsets/train_without_feature191.csv
# Exported subset 310/499 to ../data/train_subsets/train_without_feature190.csv
# Exported subset 311/499 to ../data/train_subsets/train_without_feature189.csv
# Exported subset 312/499 to ../data/train_subsets/train_without_feature188.csv
# Exported subset 313/499 to ../data/train_subsets/train_without_feature187.csv
# Exported subset 314/499 to ../data/train_subsets/train_without_feature186.csv
# Exported subset 315/499 to ../data/train_subsets/train_without_feature185.csv
# Exported subset 316/499 to ../data/train_subsets/train_without_feature184.csv
# Exported subset 317/499 to ../data/train_subsets/train_without_feature183.csv
# Exported subset 318/499 to ../data/train_subsets/train_without_feature182.csv
# Exported subset 319/499 to ../data/train_subsets/train_without_feature181.csv
# Exported subset 320/499 to ../data/train_subsets/train_without_feature180.csv
# Exported subset 321/499 to ../data/train_subsets/train_without_feature179.csv
# Exported subset 322/499 to ../data/train_subsets/train_without_feature178.csv
# Exported subset 323/499 to ../data/train_subsets/train_without_feature177.csv
# Exported subset 324/499 to ../data/train_subsets/train_without_feature176.csv
# Exported subset 325/499 to ../data/train_subsets/train_without_feature175.csv
# Exported subset 326/499 to ../data/train_subsets/train_without_feature174.csv
# Exported subset 327/499 to ../data/train_subsets/train_without_feature173.csv
# Exported subset 328/499 to ../data/train_subsets/train_without_feature172.csv
# Exported subset 329/499 to ../data/train_subsets/train_without_feature171.csv
# Exported subset 330/499 to ../data/train_subsets/train_without_feature170.csv
# Exported subset 331/499 to ../data/train_subsets/train_without_feature169.csv
# Exported subset 332/499 to ../data/train_subsets/train_without_feature168.csv
# Exported subset 333/499 to ../data/train_subsets/train_without_feature167.csv
# Exported subset 334/499 to ../data/train_subsets/train_without_feature166.csv
# Exported subset 335/499 to ../data/train_subsets/train_without_feature165.csv
# Exported subset 336/499 to ../data/train_subsets/train_without_feature164.csv
# Exported subset 337/499 to ../data/train_subsets/train_without_feature163.csv
# Exported subset 338/499 to ../data/train_subsets/train_without_feature162.csv
# Exported subset 339/499 to ../data/train_subsets/train_without_feature161.csv
# Exported subset 340/499 to ../data/train_subsets/train_without_feature160.csv
# Exported subset 341/499 to ../data/train_subsets/train_without_feature159.csv
# Exported subset 342/499 to ../data/train_subsets/train_without_feature158.csv
# Exported subset 343/499 to ../data/train_subsets/train_without_feature157.csv
# Exported subset 344/499 to ../data/train_subsets/train_without_feature156.csv
# Exported subset 345/499 to ../data/train_subsets/train_without_feature155.csv
# Exported subset 346/499 to ../data/train_subsets/train_without_feature154.csv
# Exported subset 347/499 to ../data/train_subsets/train_without_feature153.csv
# Exported subset 348/499 to ../data/train_subsets/train_without_feature152.csv
# Exported subset 349/499 to ../data/train_subsets/train_without_feature151.csv
# Exported subset 350/499 to ../data/train_subsets/train_without_feature150.csv
# Exported subset 351/499 to ../data/train_subsets/train_without_feature149.csv
# Exported subset 352/499 to ../data/train_subsets/train_without_feature148.csv
# Exported subset 353/499 to ../data/train_subsets/train_without_feature147.csv
# Exported subset 354/499 to ../data/train_subsets/train_without_feature146.csv
# Exported subset 355/499 to ../data/train_subsets/train_without_feature145.csv
# Exported subset 356/499 to ../data/train_subsets/train_without_feature144.csv
# Exported subset 357/499 to ../data/train_subsets/train_without_feature143.csv
# Exported subset 358/499 to ../data/train_subsets/train_without_feature142.csv
# Exported subset 359/499 to ../data/train_subsets/train_without_feature141.csv
# Exported subset 360/499 to ../data/train_subsets/train_without_feature140.csv
# Exported subset 361/499 to ../data/train_subsets/train_without_feature139.csv
# Exported subset 362/499 to ../data/train_subsets/train_without_feature138.csv
# Exported subset 363/499 to ../data/train_subsets/train_without_feature137.csv
# Exported subset 364/499 to ../data/train_subsets/train_without_feature136.csv
# Exported subset 365/499 to ../data/train_subsets/train_without_feature135.csv
# Exported subset 366/499 to ../data/train_subsets/train_without_feature134.csv
# Exported subset 367/499 to ../data/train_subsets/train_without_feature133.csv
# Exported subset 368/499 to ../data/train_subsets/train_without_feature132.csv
# Exported subset 369/499 to ../data/train_subsets/train_without_feature131.csv
# Exported subset 370/499 to ../data/train_subsets/train_without_feature130.csv
# Exported subset 371/499 to ../data/train_subsets/train_without_feature129.csv
# Exported subset 372/499 to ../data/train_subsets/train_without_feature128.csv
# Exported subset 373/499 to ../data/train_subsets/train_without_feature127.csv
# Exported subset 374/499 to ../data/train_subsets/train_without_feature126.csv
# Exported subset 375/499 to ../data/train_subsets/train_without_feature125.csv
# Exported subset 376/499 to ../data/train_subsets/train_without_feature124.csv
# Exported subset 377/499 to ../data/train_subsets/train_without_feature123.csv
# Exported subset 378/499 to ../data/train_subsets/train_without_feature122.csv
# Exported subset 379/499 to ../data/train_subsets/train_without_feature121.csv
# Exported subset 380/499 to ../data/train_subsets/train_without_feature120.csv
# Exported subset 381/499 to ../data/train_subsets/train_without_feature119.csv
# Exported subset 382/499 to ../data/train_subsets/train_without_feature118.csv
# Exported subset 383/499 to ../data/train_subsets/train_without_feature117.csv
# Exported subset 384/499 to ../data/train_subsets/train_without_feature116.csv
# Exported subset 385/499 to ../data/train_subsets/train_without_feature115.csv
# Exported subset 386/499 to ../data/train_subsets/train_without_feature114.csv
# Exported subset 387/499 to ../data/train_subsets/train_without_feature113.csv
# Exported subset 388/499 to ../data/train_subsets/train_without_feature112.csv
# Exported subset 389/499 to ../data/train_subsets/train_without_feature111.csv
# Exported subset 390/499 to ../data/train_subsets/train_without_feature110.csv
# Exported subset 391/499 to ../data/train_subsets/train_without_feature109.csv
# Exported subset 392/499 to ../data/train_subsets/train_without_feature108.csv
# Exported subset 393/499 to ../data/train_subsets/train_without_feature107.csv
# Exported subset 394/499 to ../data/train_subsets/train_without_feature106.csv
# Exported subset 395/499 to ../data/train_subsets/train_without_feature105.csv
# Exported subset 396/499 to ../data/train_subsets/train_without_feature104.csv
# Exported subset 397/499 to ../data/train_subsets/train_without_feature103.csv
# Exported subset 398/499 to ../data/train_subsets/train_without_feature102.csv
# Exported subset 399/499 to ../data/train_subsets/train_without_feature101.csv
# Exported subset 400/499 to ../data/train_subsets/train_without_feature100.csv
# Exported subset 401/499 to ../data/train_subsets/train_without_feature99.csv
# Exported subset 402/499 to ../data/train_subsets/train_without_feature98.csv
# Exported subset 403/499 to ../data/train_subsets/train_without_feature97.csv
# Exported subset 404/499 to ../data/train_subsets/train_without_feature96.csv
# Exported subset 405/499 to ../data/train_subsets/train_without_feature95.csv
# Exported subset 406/499 to ../data/train_subsets/train_without_feature94.csv
# Exported subset 407/499 to ../data/train_subsets/train_without_feature93.csv
# Exported subset 408/499 to ../data/train_subsets/train_without_feature92.csv
# Exported subset 409/499 to ../data/train_subsets/train_without_feature91.csv
# Exported subset 410/499 to ../data/train_subsets/train_without_feature90.csv
# Exported subset 411/499 to ../data/train_subsets/train_without_feature89.csv
# Exported subset 412/499 to ../data/train_subsets/train_without_feature88.csv
# Exported subset 413/499 to ../data/train_subsets/train_without_feature87.csv
# Exported subset 414/499 to ../data/train_subsets/train_without_feature86.csv
# Exported subset 415/499 to ../data/train_subsets/train_without_feature85.csv
# Exported subset 416/499 to ../data/train_subsets/train_without_feature84.csv
# Exported subset 417/499 to ../data/train_subsets/train_without_feature83.csv
# Exported subset 418/499 to ../data/train_subsets/train_without_feature82.csv
# Exported subset 419/499 to ../data/train_subsets/train_without_feature81.csv
# Exported subset 420/499 to ../data/train_subsets/train_without_feature80.csv
# Exported subset 421/499 to ../data/train_subsets/train_without_feature79.csv
# Exported subset 422/499 to ../data/train_subsets/train_without_feature78.csv
# Exported subset 423/499 to ../data/train_subsets/train_without_feature77.csv
# Exported subset 424/499 to ../data/train_subsets/train_without_feature76.csv
# Exported subset 425/499 to ../data/train_subsets/train_without_feature75.csv
# Exported subset 426/499 to ../data/train_subsets/train_without_feature74.csv
# Exported subset 427/499 to ../data/train_subsets/train_without_feature73.csv
# Exported subset 428/499 to ../data/train_subsets/train_without_feature72.csv
# Exported subset 429/499 to ../data/train_subsets/train_without_feature71.csv
# Exported subset 430/499 to ../data/train_subsets/train_without_feature70.csv
# Exported subset 431/499 to ../data/train_subsets/train_without_feature69.csv
# Exported subset 432/499 to ../data/train_subsets/train_without_feature68.csv
# Exported subset 433/499 to ../data/train_subsets/train_without_feature67.csv
# Exported subset 434/499 to ../data/train_subsets/train_without_feature66.csv
# Exported subset 435/499 to ../data/train_subsets/train_without_feature65.csv
# Exported subset 436/499 to ../data/train_subsets/train_without_feature64.csv
# Exported subset 437/499 to ../data/train_subsets/train_without_feature63.csv
# Exported subset 438/499 to ../data/train_subsets/train_without_feature62.csv
# Exported subset 439/499 to ../data/train_subsets/train_without_feature61.csv
# Exported subset 440/499 to ../data/train_subsets/train_without_feature60.csv
# Exported subset 441/499 to ../data/train_subsets/train_without_feature59.csv
# Exported subset 442/499 to ../data/train_subsets/train_without_feature58.csv
# Exported subset 443/499 to ../data/train_subsets/train_without_feature57.csv
# Exported subset 444/499 to ../data/train_subsets/train_without_feature56.csv
# Exported subset 445/499 to ../data/train_subsets/train_without_feature55.csv
# Exported subset 446/499 to ../data/train_subsets/train_without_feature54.csv
# Exported subset 447/499 to ../data/train_subsets/train_without_feature53.csv
# Exported subset 448/499 to ../data/train_subsets/train_without_feature52.csv
# Exported subset 449/499 to ../data/train_subsets/train_without_feature51.csv
# Exported subset 450/499 to ../data/train_subsets/train_without_feature50.csv
# Exported subset 451/499 to ../data/train_subsets/train_without_feature49.csv
# Exported subset 452/499 to ../data/train_subsets/train_without_feature48.csv
# Exported subset 453/499 to ../data/train_subsets/train_without_feature47.csv
# Exported subset 454/499 to ../data/train_subsets/train_without_feature46.csv
# Exported subset 455/499 to ../data/train_subsets/train_without_feature45.csv
# Exported subset 456/499 to ../data/train_subsets/train_without_feature44.csv
# Exported subset 457/499 to ../data/train_subsets/train_without_feature43.csv
# Exported subset 458/499 to ../data/train_subsets/train_without_feature42.csv
# Exported subset 459/499 to ../data/train_subsets/train_without_feature41.csv
# Exported subset 460/499 to ../data/train_subsets/train_without_feature40.csv
# Exported subset 461/499 to ../data/train_subsets/train_without_feature39.csv
# Exported subset 462/499 to ../data/train_subsets/train_without_feature38.csv
# Exported subset 463/499 to ../data/train_subsets/train_without_feature37.csv
# Exported subset 464/499 to ../data/train_subsets/train_without_feature36.csv
# Exported subset 465/499 to ../data/train_subsets/train_without_feature35.csv
# Exported subset 466/499 to ../data/train_subsets/train_without_feature34.csv
# Exported subset 467/499 to ../data/train_subsets/train_without_feature33.csv
# Exported subset 468/499 to ../data/train_subsets/train_without_feature32.csv
# Exported subset 469/499 to ../data/train_subsets/train_without_feature31.csv
# Exported subset 470/499 to ../data/train_subsets/train_without_feature30.csv
# Exported subset 471/499 to ../data/train_subsets/train_without_feature29.csv
# Exported subset 472/499 to ../data/train_subsets/train_without_feature28.csv
# Exported subset 473/499 to ../data/train_subsets/train_without_feature27.csv
# Exported subset 474/499 to ../data/train_subsets/train_without_feature26.csv
# Exported subset 475/499 to ../data/train_subsets/train_without_feature25.csv
# Exported subset 476/499 to ../data/train_subsets/train_without_feature24.csv
# Exported subset 477/499 to ../data/train_subsets/train_without_feature23.csv
# Exported subset 478/499 to ../data/train_subsets/train_without_feature22.csv
# Exported subset 479/499 to ../data/train_subsets/train_without_feature21.csv
# Exported subset 480/499 to ../data/train_subsets/train_without_feature20.csv
# Exported subset 481/499 to ../data/train_subsets/train_without_feature19.csv
# Exported subset 482/499 to ../data/train_subsets/train_without_feature18.csv
# Exported subset 483/499 to ../data/train_subsets/train_without_feature17.csv
# Exported subset 484/499 to ../data/train_subsets/train_without_feature16.csv
# Exported subset 485/499 to ../data/train_subsets/train_without_feature15.csv
# Exported subset 486/499 to ../data/train_subsets/train_without_feature14.csv
# Exported subset 487/499 to ../data/train_subsets/train_without_feature13.csv
# Exported subset 488/499 to ../data/train_subsets/train_without_feature12.csv
# Exported subset 489/499 to ../data/train_subsets/train_without_feature11.csv
# Exported subset 490/499 to ../data/train_subsets/train_without_feature10.csv
# Exported subset 491/499 to ../data/train_subsets/train_without_feature9.csv
# Exported subset 492/499 to ../data/train_subsets/train_without_feature8.csv
# Exported subset 493/499 to ../data/train_subsets/train_without_feature7.csv
# Exported subset 494/499 to ../data/train_subsets/train_without_feature6.csv
# Exported subset 495/499 to ../data/train_subsets/train_without_feature5.csv
# Exported subset 496/499 to ../data/train_subsets/train_without_feature4.csv
# Exported subset 497/499 to ../data/train_subsets/train_without_feature3.csv
# Exported subset 498/499 to ../data/train_subsets/train_without_feature2.csv
# Exported subset 499/499 to ../data/train_subsets/train_without_feature1.csv
# Exported subset 500/499 to ../data/train_subsets/train_without_feature0.csv

# %%
# Make sure it has the correct shape.
df = X_test
print(df.shape)
# Out:
# (2831, 500)

# %%
def subsets(df):
    """ 
    Generate all possible feature sets, each missing one feature. 
    """
    all_features = df.columns.tolist()
    n_features = len(all_features)
    feat_sets = list(combinations(all_features, n_features - 1))
    return [list(feat_set) for feat_set in feat_sets]

feat_sets = subsets(df)

# Make CSV directory.
output_dir = "../data/test_subsets"
os.makedirs(output_dir, exist_ok=True)

# Iterate untill all subsets are exported to CSV.
for i, feat_set in enumerate(feat_sets):
    subset_df = df[feat_set]
    removed_feature = set(df.columns) - set(feat_set)
    filename = f"test_without_{list(removed_feature)[0]}.csv"
    filepath = os.path.join(output_dir, filename)
    subset_df.to_csv(filepath, index=False)
    print(f"Exported subset {i+1}/499 to {filepath}")
# Out:
# Exported subset 1/499 to ../data/test_subsets/test_without_feature499.csv
# Exported subset 2/499 to ../data/test_subsets/test_without_feature498.csv
# Exported subset 3/499 to ../data/test_subsets/test_without_feature497.csv
# Exported subset 4/499 to ../data/test_subsets/test_without_feature496.csv
# Exported subset 5/499 to ../data/test_subsets/test_without_feature495.csv
# Exported subset 6/499 to ../data/test_subsets/test_without_feature494.csv
# Exported subset 7/499 to ../data/test_subsets/test_without_feature493.csv
# Exported subset 8/499 to ../data/test_subsets/test_without_feature492.csv
# Exported subset 9/499 to ../data/test_subsets/test_without_feature491.csv
# Exported subset 10/499 to ../data/test_subsets/test_without_feature490.csv
# Exported subset 11/499 to ../data/test_subsets/test_without_feature489.csv
# Exported subset 12/499 to ../data/test_subsets/test_without_feature488.csv
# Exported subset 13/499 to ../data/test_subsets/test_without_feature487.csv
# Exported subset 14/499 to ../data/test_subsets/test_without_feature486.csv
# Exported subset 15/499 to ../data/test_subsets/test_without_feature485.csv
# Exported subset 16/499 to ../data/test_subsets/test_without_feature484.csv
# Exported subset 17/499 to ../data/test_subsets/test_without_feature483.csv
# Exported subset 18/499 to ../data/test_subsets/test_without_feature482.csv
# Exported subset 19/499 to ../data/test_subsets/test_without_feature481.csv
# Exported subset 20/499 to ../data/test_subsets/test_without_feature480.csv
# Exported subset 21/499 to ../data/test_subsets/test_without_feature479.csv
# Exported subset 22/499 to ../data/test_subsets/test_without_feature478.csv
# Exported subset 23/499 to ../data/test_subsets/test_without_feature477.csv
# Exported subset 24/499 to ../data/test_subsets/test_without_feature476.csv
# Exported subset 25/499 to ../data/test_subsets/test_without_feature475.csv
# Exported subset 26/499 to ../data/test_subsets/test_without_feature474.csv
# Exported subset 27/499 to ../data/test_subsets/test_without_feature473.csv
# Exported subset 28/499 to ../data/test_subsets/test_without_feature472.csv
# Exported subset 29/499 to ../data/test_subsets/test_without_feature471.csv
# Exported subset 30/499 to ../data/test_subsets/test_without_feature470.csv
# Exported subset 31/499 to ../data/test_subsets/test_without_feature469.csv
# Exported subset 32/499 to ../data/test_subsets/test_without_feature468.csv
# Exported subset 33/499 to ../data/test_subsets/test_without_feature467.csv
# Exported subset 34/499 to ../data/test_subsets/test_without_feature466.csv
# Exported subset 35/499 to ../data/test_subsets/test_without_feature465.csv
# Exported subset 36/499 to ../data/test_subsets/test_without_feature464.csv
# Exported subset 37/499 to ../data/test_subsets/test_without_feature463.csv
# Exported subset 38/499 to ../data/test_subsets/test_without_feature462.csv
# Exported subset 39/499 to ../data/test_subsets/test_without_feature461.csv
# Exported subset 40/499 to ../data/test_subsets/test_without_feature460.csv
# Exported subset 41/499 to ../data/test_subsets/test_without_feature459.csv
# Exported subset 42/499 to ../data/test_subsets/test_without_feature458.csv
# Exported subset 43/499 to ../data/test_subsets/test_without_feature457.csv
# Exported subset 44/499 to ../data/test_subsets/test_without_feature456.csv
# Exported subset 45/499 to ../data/test_subsets/test_without_feature455.csv
# Exported subset 46/499 to ../data/test_subsets/test_without_feature454.csv
# Exported subset 47/499 to ../data/test_subsets/test_without_feature453.csv
# Exported subset 48/499 to ../data/test_subsets/test_without_feature452.csv
# Exported subset 49/499 to ../data/test_subsets/test_without_feature451.csv
# Exported subset 50/499 to ../data/test_subsets/test_without_feature450.csv
# Exported subset 51/499 to ../data/test_subsets/test_without_feature449.csv
# Exported subset 52/499 to ../data/test_subsets/test_without_feature448.csv
# Exported subset 53/499 to ../data/test_subsets/test_without_feature447.csv
# Exported subset 54/499 to ../data/test_subsets/test_without_feature446.csv
# Exported subset 55/499 to ../data/test_subsets/test_without_feature445.csv
# Exported subset 56/499 to ../data/test_subsets/test_without_feature444.csv
# Exported subset 57/499 to ../data/test_subsets/test_without_feature443.csv
# Exported subset 58/499 to ../data/test_subsets/test_without_feature442.csv
# Exported subset 59/499 to ../data/test_subsets/test_without_feature441.csv
# Exported subset 60/499 to ../data/test_subsets/test_without_feature440.csv
# Exported subset 61/499 to ../data/test_subsets/test_without_feature439.csv
# Exported subset 62/499 to ../data/test_subsets/test_without_feature438.csv
# Exported subset 63/499 to ../data/test_subsets/test_without_feature437.csv
# Exported subset 64/499 to ../data/test_subsets/test_without_feature436.csv
# Exported subset 65/499 to ../data/test_subsets/test_without_feature435.csv
# Exported subset 66/499 to ../data/test_subsets/test_without_feature434.csv
# Exported subset 67/499 to ../data/test_subsets/test_without_feature433.csv
# Exported subset 68/499 to ../data/test_subsets/test_without_feature432.csv
# Exported subset 69/499 to ../data/test_subsets/test_without_feature431.csv
# Exported subset 70/499 to ../data/test_subsets/test_without_feature430.csv
# Exported subset 71/499 to ../data/test_subsets/test_without_feature429.csv
# Exported subset 72/499 to ../data/test_subsets/test_without_feature428.csv
# Exported subset 73/499 to ../data/test_subsets/test_without_feature427.csv
# Exported subset 74/499 to ../data/test_subsets/test_without_feature426.csv
# Exported subset 75/499 to ../data/test_subsets/test_without_feature425.csv
# Exported subset 76/499 to ../data/test_subsets/test_without_feature424.csv
# Exported subset 77/499 to ../data/test_subsets/test_without_feature423.csv
# Exported subset 78/499 to ../data/test_subsets/test_without_feature422.csv
# Exported subset 79/499 to ../data/test_subsets/test_without_feature421.csv
# Exported subset 80/499 to ../data/test_subsets/test_without_feature420.csv
# Exported subset 81/499 to ../data/test_subsets/test_without_feature419.csv
# Exported subset 82/499 to ../data/test_subsets/test_without_feature418.csv
# Exported subset 83/499 to ../data/test_subsets/test_without_feature417.csv
# Exported subset 84/499 to ../data/test_subsets/test_without_feature416.csv
# Exported subset 85/499 to ../data/test_subsets/test_without_feature415.csv
# Exported subset 86/499 to ../data/test_subsets/test_without_feature414.csv
# Exported subset 87/499 to ../data/test_subsets/test_without_feature413.csv
# Exported subset 88/499 to ../data/test_subsets/test_without_feature412.csv
# Exported subset 89/499 to ../data/test_subsets/test_without_feature411.csv
# Exported subset 90/499 to ../data/test_subsets/test_without_feature410.csv
# Exported subset 91/499 to ../data/test_subsets/test_without_feature409.csv
# Exported subset 92/499 to ../data/test_subsets/test_without_feature408.csv
# Exported subset 93/499 to ../data/test_subsets/test_without_feature407.csv
# Exported subset 94/499 to ../data/test_subsets/test_without_feature406.csv
# Exported subset 95/499 to ../data/test_subsets/test_without_feature405.csv
# Exported subset 96/499 to ../data/test_subsets/test_without_feature404.csv
# Exported subset 97/499 to ../data/test_subsets/test_without_feature403.csv
# Exported subset 98/499 to ../data/test_subsets/test_without_feature402.csv
# Exported subset 99/499 to ../data/test_subsets/test_without_feature401.csv
# Exported subset 100/499 to ../data/test_subsets/test_without_feature400.csv
# Exported subset 101/499 to ../data/test_subsets/test_without_feature399.csv
# Exported subset 102/499 to ../data/test_subsets/test_without_feature398.csv
# Exported subset 103/499 to ../data/test_subsets/test_without_feature397.csv
# Exported subset 104/499 to ../data/test_subsets/test_without_feature396.csv
# Exported subset 105/499 to ../data/test_subsets/test_without_feature395.csv
# Exported subset 106/499 to ../data/test_subsets/test_without_feature394.csv
# Exported subset 107/499 to ../data/test_subsets/test_without_feature393.csv
# Exported subset 108/499 to ../data/test_subsets/test_without_feature392.csv
# Exported subset 109/499 to ../data/test_subsets/test_without_feature391.csv
# Exported subset 110/499 to ../data/test_subsets/test_without_feature390.csv
# Exported subset 111/499 to ../data/test_subsets/test_without_feature389.csv
# Exported subset 112/499 to ../data/test_subsets/test_without_feature388.csv
# Exported subset 113/499 to ../data/test_subsets/test_without_feature387.csv
# Exported subset 114/499 to ../data/test_subsets/test_without_feature386.csv
# Exported subset 115/499 to ../data/test_subsets/test_without_feature385.csv
# Exported subset 116/499 to ../data/test_subsets/test_without_feature384.csv
# Exported subset 117/499 to ../data/test_subsets/test_without_feature383.csv
# Exported subset 118/499 to ../data/test_subsets/test_without_feature382.csv
# Exported subset 119/499 to ../data/test_subsets/test_without_feature381.csv
# Exported subset 120/499 to ../data/test_subsets/test_without_feature380.csv
# Exported subset 121/499 to ../data/test_subsets/test_without_feature379.csv
# Exported subset 122/499 to ../data/test_subsets/test_without_feature378.csv
# Exported subset 123/499 to ../data/test_subsets/test_without_feature377.csv
# Exported subset 124/499 to ../data/test_subsets/test_without_feature376.csv
# Exported subset 125/499 to ../data/test_subsets/test_without_feature375.csv
# Exported subset 126/499 to ../data/test_subsets/test_without_feature374.csv
# Exported subset 127/499 to ../data/test_subsets/test_without_feature373.csv
# Exported subset 128/499 to ../data/test_subsets/test_without_feature372.csv
# Exported subset 129/499 to ../data/test_subsets/test_without_feature371.csv
# Exported subset 130/499 to ../data/test_subsets/test_without_feature370.csv
# Exported subset 131/499 to ../data/test_subsets/test_without_feature369.csv
# Exported subset 132/499 to ../data/test_subsets/test_without_feature368.csv
# Exported subset 133/499 to ../data/test_subsets/test_without_feature367.csv
# Exported subset 134/499 to ../data/test_subsets/test_without_feature366.csv
# Exported subset 135/499 to ../data/test_subsets/test_without_feature365.csv
# Exported subset 136/499 to ../data/test_subsets/test_without_feature364.csv
# Exported subset 137/499 to ../data/test_subsets/test_without_feature363.csv
# Exported subset 138/499 to ../data/test_subsets/test_without_feature362.csv
# Exported subset 139/499 to ../data/test_subsets/test_without_feature361.csv
# Exported subset 140/499 to ../data/test_subsets/test_without_feature360.csv
# Exported subset 141/499 to ../data/test_subsets/test_without_feature359.csv
# Exported subset 142/499 to ../data/test_subsets/test_without_feature358.csv
# Exported subset 143/499 to ../data/test_subsets/test_without_feature357.csv
# Exported subset 144/499 to ../data/test_subsets/test_without_feature356.csv
# Exported subset 145/499 to ../data/test_subsets/test_without_feature355.csv
# Exported subset 146/499 to ../data/test_subsets/test_without_feature354.csv
# Exported subset 147/499 to ../data/test_subsets/test_without_feature353.csv
# Exported subset 148/499 to ../data/test_subsets/test_without_feature352.csv
# Exported subset 149/499 to ../data/test_subsets/test_without_feature351.csv
# Exported subset 150/499 to ../data/test_subsets/test_without_feature350.csv
# Exported subset 151/499 to ../data/test_subsets/test_without_feature349.csv
# Exported subset 152/499 to ../data/test_subsets/test_without_feature348.csv
# Exported subset 153/499 to ../data/test_subsets/test_without_feature347.csv
# Exported subset 154/499 to ../data/test_subsets/test_without_feature346.csv
# Exported subset 155/499 to ../data/test_subsets/test_without_feature345.csv
# Exported subset 156/499 to ../data/test_subsets/test_without_feature344.csv
# Exported subset 157/499 to ../data/test_subsets/test_without_feature343.csv
# Exported subset 158/499 to ../data/test_subsets/test_without_feature342.csv
# Exported subset 159/499 to ../data/test_subsets/test_without_feature341.csv
# Exported subset 160/499 to ../data/test_subsets/test_without_feature340.csv
# Exported subset 161/499 to ../data/test_subsets/test_without_feature339.csv
# Exported subset 162/499 to ../data/test_subsets/test_without_feature338.csv
# Exported subset 163/499 to ../data/test_subsets/test_without_feature337.csv
# Exported subset 164/499 to ../data/test_subsets/test_without_feature336.csv
# Exported subset 165/499 to ../data/test_subsets/test_without_feature335.csv
# Exported subset 166/499 to ../data/test_subsets/test_without_feature334.csv
# Exported subset 167/499 to ../data/test_subsets/test_without_feature333.csv
# Exported subset 168/499 to ../data/test_subsets/test_without_feature332.csv
# Exported subset 169/499 to ../data/test_subsets/test_without_feature331.csv
# Exported subset 170/499 to ../data/test_subsets/test_without_feature330.csv
# Exported subset 171/499 to ../data/test_subsets/test_without_feature329.csv
# Exported subset 172/499 to ../data/test_subsets/test_without_feature328.csv
# Exported subset 173/499 to ../data/test_subsets/test_without_feature327.csv
# Exported subset 174/499 to ../data/test_subsets/test_without_feature326.csv
# Exported subset 175/499 to ../data/test_subsets/test_without_feature325.csv
# Exported subset 176/499 to ../data/test_subsets/test_without_feature324.csv
# Exported subset 177/499 to ../data/test_subsets/test_without_feature323.csv
# Exported subset 178/499 to ../data/test_subsets/test_without_feature322.csv
# Exported subset 179/499 to ../data/test_subsets/test_without_feature321.csv
# Exported subset 180/499 to ../data/test_subsets/test_without_feature320.csv
# Exported subset 181/499 to ../data/test_subsets/test_without_feature319.csv
# Exported subset 182/499 to ../data/test_subsets/test_without_feature318.csv
# Exported subset 183/499 to ../data/test_subsets/test_without_feature317.csv
# Exported subset 184/499 to ../data/test_subsets/test_without_feature316.csv
# Exported subset 185/499 to ../data/test_subsets/test_without_feature315.csv
# Exported subset 186/499 to ../data/test_subsets/test_without_feature314.csv
# Exported subset 187/499 to ../data/test_subsets/test_without_feature313.csv
# Exported subset 188/499 to ../data/test_subsets/test_without_feature312.csv
# Exported subset 189/499 to ../data/test_subsets/test_without_feature311.csv
# Exported subset 190/499 to ../data/test_subsets/test_without_feature310.csv
# Exported subset 191/499 to ../data/test_subsets/test_without_feature309.csv
# Exported subset 192/499 to ../data/test_subsets/test_without_feature308.csv
# Exported subset 193/499 to ../data/test_subsets/test_without_feature307.csv
# Exported subset 194/499 to ../data/test_subsets/test_without_feature306.csv
# Exported subset 195/499 to ../data/test_subsets/test_without_feature305.csv
# Exported subset 196/499 to ../data/test_subsets/test_without_feature304.csv
# Exported subset 197/499 to ../data/test_subsets/test_without_feature303.csv
# Exported subset 198/499 to ../data/test_subsets/test_without_feature302.csv
# Exported subset 199/499 to ../data/test_subsets/test_without_feature301.csv
# Exported subset 200/499 to ../data/test_subsets/test_without_feature300.csv
# Exported subset 201/499 to ../data/test_subsets/test_without_feature299.csv
# Exported subset 202/499 to ../data/test_subsets/test_without_feature298.csv
# Exported subset 203/499 to ../data/test_subsets/test_without_feature297.csv
# Exported subset 204/499 to ../data/test_subsets/test_without_feature296.csv
# Exported subset 205/499 to ../data/test_subsets/test_without_feature295.csv
# Exported subset 206/499 to ../data/test_subsets/test_without_feature294.csv
# Exported subset 207/499 to ../data/test_subsets/test_without_feature293.csv
# Exported subset 208/499 to ../data/test_subsets/test_without_feature292.csv
# Exported subset 209/499 to ../data/test_subsets/test_without_feature291.csv
# Exported subset 210/499 to ../data/test_subsets/test_without_feature290.csv
# Exported subset 211/499 to ../data/test_subsets/test_without_feature289.csv
# Exported subset 212/499 to ../data/test_subsets/test_without_feature288.csv
# Exported subset 213/499 to ../data/test_subsets/test_without_feature287.csv
# Exported subset 214/499 to ../data/test_subsets/test_without_feature286.csv
# Exported subset 215/499 to ../data/test_subsets/test_without_feature285.csv
# Exported subset 216/499 to ../data/test_subsets/test_without_feature284.csv
# Exported subset 217/499 to ../data/test_subsets/test_without_feature283.csv
# Exported subset 218/499 to ../data/test_subsets/test_without_feature282.csv
# Exported subset 219/499 to ../data/test_subsets/test_without_feature281.csv
# Exported subset 220/499 to ../data/test_subsets/test_without_feature280.csv
# Exported subset 221/499 to ../data/test_subsets/test_without_feature279.csv
# Exported subset 222/499 to ../data/test_subsets/test_without_feature278.csv
# Exported subset 223/499 to ../data/test_subsets/test_without_feature277.csv
# Exported subset 224/499 to ../data/test_subsets/test_without_feature276.csv
# Exported subset 225/499 to ../data/test_subsets/test_without_feature275.csv
# Exported subset 226/499 to ../data/test_subsets/test_without_feature274.csv
# Exported subset 227/499 to ../data/test_subsets/test_without_feature273.csv
# Exported subset 228/499 to ../data/test_subsets/test_without_feature272.csv
# Exported subset 229/499 to ../data/test_subsets/test_without_feature271.csv
# Exported subset 230/499 to ../data/test_subsets/test_without_feature270.csv
# Exported subset 231/499 to ../data/test_subsets/test_without_feature269.csv
# Exported subset 232/499 to ../data/test_subsets/test_without_feature268.csv
# Exported subset 233/499 to ../data/test_subsets/test_without_feature267.csv
# Exported subset 234/499 to ../data/test_subsets/test_without_feature266.csv
# Exported subset 235/499 to ../data/test_subsets/test_without_feature265.csv
# Exported subset 236/499 to ../data/test_subsets/test_without_feature264.csv
# Exported subset 237/499 to ../data/test_subsets/test_without_feature263.csv
# Exported subset 238/499 to ../data/test_subsets/test_without_feature262.csv
# Exported subset 239/499 to ../data/test_subsets/test_without_feature261.csv
# Exported subset 240/499 to ../data/test_subsets/test_without_feature260.csv
# Exported subset 241/499 to ../data/test_subsets/test_without_feature259.csv
# Exported subset 242/499 to ../data/test_subsets/test_without_feature258.csv
# Exported subset 243/499 to ../data/test_subsets/test_without_feature257.csv
# Exported subset 244/499 to ../data/test_subsets/test_without_feature256.csv
# Exported subset 245/499 to ../data/test_subsets/test_without_feature255.csv
# Exported subset 246/499 to ../data/test_subsets/test_without_feature254.csv
# Exported subset 247/499 to ../data/test_subsets/test_without_feature253.csv
# Exported subset 248/499 to ../data/test_subsets/test_without_feature252.csv
# Exported subset 249/499 to ../data/test_subsets/test_without_feature251.csv
# Exported subset 250/499 to ../data/test_subsets/test_without_feature250.csv
# Exported subset 251/499 to ../data/test_subsets/test_without_feature249.csv
# Exported subset 252/499 to ../data/test_subsets/test_without_feature248.csv
# Exported subset 253/499 to ../data/test_subsets/test_without_feature247.csv
# Exported subset 254/499 to ../data/test_subsets/test_without_feature246.csv
# Exported subset 255/499 to ../data/test_subsets/test_without_feature245.csv
# Exported subset 256/499 to ../data/test_subsets/test_without_feature244.csv
# Exported subset 257/499 to ../data/test_subsets/test_without_feature243.csv
# Exported subset 258/499 to ../data/test_subsets/test_without_feature242.csv
# Exported subset 259/499 to ../data/test_subsets/test_without_feature241.csv
# Exported subset 260/499 to ../data/test_subsets/test_without_feature240.csv
# Exported subset 261/499 to ../data/test_subsets/test_without_feature239.csv
# Exported subset 262/499 to ../data/test_subsets/test_without_feature238.csv
# Exported subset 263/499 to ../data/test_subsets/test_without_feature237.csv
# Exported subset 264/499 to ../data/test_subsets/test_without_feature236.csv
# Exported subset 265/499 to ../data/test_subsets/test_without_feature235.csv
# Exported subset 266/499 to ../data/test_subsets/test_without_feature234.csv
# Exported subset 267/499 to ../data/test_subsets/test_without_feature233.csv
# Exported subset 268/499 to ../data/test_subsets/test_without_feature232.csv
# Exported subset 269/499 to ../data/test_subsets/test_without_feature231.csv
# Exported subset 270/499 to ../data/test_subsets/test_without_feature230.csv
# Exported subset 271/499 to ../data/test_subsets/test_without_feature229.csv
# Exported subset 272/499 to ../data/test_subsets/test_without_feature228.csv
# Exported subset 273/499 to ../data/test_subsets/test_without_feature227.csv
# Exported subset 274/499 to ../data/test_subsets/test_without_feature226.csv
# Exported subset 275/499 to ../data/test_subsets/test_without_feature225.csv
# Exported subset 276/499 to ../data/test_subsets/test_without_feature224.csv
# Exported subset 277/499 to ../data/test_subsets/test_without_feature223.csv
# Exported subset 278/499 to ../data/test_subsets/test_without_feature222.csv
# Exported subset 279/499 to ../data/test_subsets/test_without_feature221.csv
# Exported subset 280/499 to ../data/test_subsets/test_without_feature220.csv
# Exported subset 281/499 to ../data/test_subsets/test_without_feature219.csv
# Exported subset 282/499 to ../data/test_subsets/test_without_feature218.csv
# Exported subset 283/499 to ../data/test_subsets/test_without_feature217.csv
# Exported subset 284/499 to ../data/test_subsets/test_without_feature216.csv
# Exported subset 285/499 to ../data/test_subsets/test_without_feature215.csv
# Exported subset 286/499 to ../data/test_subsets/test_without_feature214.csv
# Exported subset 287/499 to ../data/test_subsets/test_without_feature213.csv
# Exported subset 288/499 to ../data/test_subsets/test_without_feature212.csv
# Exported subset 289/499 to ../data/test_subsets/test_without_feature211.csv
# Exported subset 290/499 to ../data/test_subsets/test_without_feature210.csv
# Exported subset 291/499 to ../data/test_subsets/test_without_feature209.csv
# Exported subset 292/499 to ../data/test_subsets/test_without_feature208.csv
# Exported subset 293/499 to ../data/test_subsets/test_without_feature207.csv
# Exported subset 294/499 to ../data/test_subsets/test_without_feature206.csv
# Exported subset 295/499 to ../data/test_subsets/test_without_feature205.csv
# Exported subset 296/499 to ../data/test_subsets/test_without_feature204.csv
# Exported subset 297/499 to ../data/test_subsets/test_without_feature203.csv
# Exported subset 298/499 to ../data/test_subsets/test_without_feature202.csv
# Exported subset 299/499 to ../data/test_subsets/test_without_feature201.csv
# Exported subset 300/499 to ../data/test_subsets/test_without_feature200.csv
# Exported subset 301/499 to ../data/test_subsets/test_without_feature199.csv
# Exported subset 302/499 to ../data/test_subsets/test_without_feature198.csv
# Exported subset 303/499 to ../data/test_subsets/test_without_feature197.csv
# Exported subset 304/499 to ../data/test_subsets/test_without_feature196.csv
# Exported subset 305/499 to ../data/test_subsets/test_without_feature195.csv
# Exported subset 306/499 to ../data/test_subsets/test_without_feature194.csv
# Exported subset 307/499 to ../data/test_subsets/test_without_feature193.csv
# Exported subset 308/499 to ../data/test_subsets/test_without_feature192.csv
# Exported subset 309/499 to ../data/test_subsets/test_without_feature191.csv
# Exported subset 310/499 to ../data/test_subsets/test_without_feature190.csv
# Exported subset 311/499 to ../data/test_subsets/test_without_feature189.csv
# Exported subset 312/499 to ../data/test_subsets/test_without_feature188.csv
# Exported subset 313/499 to ../data/test_subsets/test_without_feature187.csv
# Exported subset 314/499 to ../data/test_subsets/test_without_feature186.csv
# Exported subset 315/499 to ../data/test_subsets/test_without_feature185.csv
# Exported subset 316/499 to ../data/test_subsets/test_without_feature184.csv
# Exported subset 317/499 to ../data/test_subsets/test_without_feature183.csv
# Exported subset 318/499 to ../data/test_subsets/test_without_feature182.csv
# Exported subset 319/499 to ../data/test_subsets/test_without_feature181.csv
# Exported subset 320/499 to ../data/test_subsets/test_without_feature180.csv
# Exported subset 321/499 to ../data/test_subsets/test_without_feature179.csv
# Exported subset 322/499 to ../data/test_subsets/test_without_feature178.csv
# Exported subset 323/499 to ../data/test_subsets/test_without_feature177.csv
# Exported subset 324/499 to ../data/test_subsets/test_without_feature176.csv
# Exported subset 325/499 to ../data/test_subsets/test_without_feature175.csv
# Exported subset 326/499 to ../data/test_subsets/test_without_feature174.csv
# Exported subset 327/499 to ../data/test_subsets/test_without_feature173.csv
# Exported subset 328/499 to ../data/test_subsets/test_without_feature172.csv
# Exported subset 329/499 to ../data/test_subsets/test_without_feature171.csv
# Exported subset 330/499 to ../data/test_subsets/test_without_feature170.csv
# Exported subset 331/499 to ../data/test_subsets/test_without_feature169.csv
# Exported subset 332/499 to ../data/test_subsets/test_without_feature168.csv
# Exported subset 333/499 to ../data/test_subsets/test_without_feature167.csv
# Exported subset 334/499 to ../data/test_subsets/test_without_feature166.csv
# Exported subset 335/499 to ../data/test_subsets/test_without_feature165.csv
# Exported subset 336/499 to ../data/test_subsets/test_without_feature164.csv
# Exported subset 337/499 to ../data/test_subsets/test_without_feature163.csv
# Exported subset 338/499 to ../data/test_subsets/test_without_feature162.csv
# Exported subset 339/499 to ../data/test_subsets/test_without_feature161.csv
# Exported subset 340/499 to ../data/test_subsets/test_without_feature160.csv
# Exported subset 341/499 to ../data/test_subsets/test_without_feature159.csv
# Exported subset 342/499 to ../data/test_subsets/test_without_feature158.csv
# Exported subset 343/499 to ../data/test_subsets/test_without_feature157.csv
# Exported subset 344/499 to ../data/test_subsets/test_without_feature156.csv
# Exported subset 345/499 to ../data/test_subsets/test_without_feature155.csv
# Exported subset 346/499 to ../data/test_subsets/test_without_feature154.csv
# Exported subset 347/499 to ../data/test_subsets/test_without_feature153.csv
# Exported subset 348/499 to ../data/test_subsets/test_without_feature152.csv
# Exported subset 349/499 to ../data/test_subsets/test_without_feature151.csv
# Exported subset 350/499 to ../data/test_subsets/test_without_feature150.csv
# Exported subset 351/499 to ../data/test_subsets/test_without_feature149.csv
# Exported subset 352/499 to ../data/test_subsets/test_without_feature148.csv
# Exported subset 353/499 to ../data/test_subsets/test_without_feature147.csv
# Exported subset 354/499 to ../data/test_subsets/test_without_feature146.csv
# Exported subset 355/499 to ../data/test_subsets/test_without_feature145.csv
# Exported subset 356/499 to ../data/test_subsets/test_without_feature144.csv
# Exported subset 357/499 to ../data/test_subsets/test_without_feature143.csv
# Exported subset 358/499 to ../data/test_subsets/test_without_feature142.csv
# Exported subset 359/499 to ../data/test_subsets/test_without_feature141.csv
# Exported subset 360/499 to ../data/test_subsets/test_without_feature140.csv
# Exported subset 361/499 to ../data/test_subsets/test_without_feature139.csv
# Exported subset 362/499 to ../data/test_subsets/test_without_feature138.csv
# Exported subset 363/499 to ../data/test_subsets/test_without_feature137.csv
# Exported subset 364/499 to ../data/test_subsets/test_without_feature136.csv
# Exported subset 365/499 to ../data/test_subsets/test_without_feature135.csv
# Exported subset 366/499 to ../data/test_subsets/test_without_feature134.csv
# Exported subset 367/499 to ../data/test_subsets/test_without_feature133.csv
# Exported subset 368/499 to ../data/test_subsets/test_without_feature132.csv
# Exported subset 369/499 to ../data/test_subsets/test_without_feature131.csv
# Exported subset 370/499 to ../data/test_subsets/test_without_feature130.csv
# Exported subset 371/499 to ../data/test_subsets/test_without_feature129.csv
# Exported subset 372/499 to ../data/test_subsets/test_without_feature128.csv
# Exported subset 373/499 to ../data/test_subsets/test_without_feature127.csv
# Exported subset 374/499 to ../data/test_subsets/test_without_feature126.csv
# Exported subset 375/499 to ../data/test_subsets/test_without_feature125.csv
# Exported subset 376/499 to ../data/test_subsets/test_without_feature124.csv
# Exported subset 377/499 to ../data/test_subsets/test_without_feature123.csv
# Exported subset 378/499 to ../data/test_subsets/test_without_feature122.csv
# Exported subset 379/499 to ../data/test_subsets/test_without_feature121.csv
# Exported subset 380/499 to ../data/test_subsets/test_without_feature120.csv
# Exported subset 381/499 to ../data/test_subsets/test_without_feature119.csv
# Exported subset 382/499 to ../data/test_subsets/test_without_feature118.csv
# Exported subset 383/499 to ../data/test_subsets/test_without_feature117.csv
# Exported subset 384/499 to ../data/test_subsets/test_without_feature116.csv
# Exported subset 385/499 to ../data/test_subsets/test_without_feature115.csv
# Exported subset 386/499 to ../data/test_subsets/test_without_feature114.csv
# Exported subset 387/499 to ../data/test_subsets/test_without_feature113.csv
# Exported subset 388/499 to ../data/test_subsets/test_without_feature112.csv
# Exported subset 389/499 to ../data/test_subsets/test_without_feature111.csv
# Exported subset 390/499 to ../data/test_subsets/test_without_feature110.csv
# Exported subset 391/499 to ../data/test_subsets/test_without_feature109.csv
# Exported subset 392/499 to ../data/test_subsets/test_without_feature108.csv
# Exported subset 393/499 to ../data/test_subsets/test_without_feature107.csv
# Exported subset 394/499 to ../data/test_subsets/test_without_feature106.csv
# Exported subset 395/499 to ../data/test_subsets/test_without_feature105.csv
# Exported subset 396/499 to ../data/test_subsets/test_without_feature104.csv
# Exported subset 397/499 to ../data/test_subsets/test_without_feature103.csv
# Exported subset 398/499 to ../data/test_subsets/test_without_feature102.csv
# Exported subset 399/499 to ../data/test_subsets/test_without_feature101.csv
# Exported subset 400/499 to ../data/test_subsets/test_without_feature100.csv
# Exported subset 401/499 to ../data/test_subsets/test_without_feature99.csv
# Exported subset 402/499 to ../data/test_subsets/test_without_feature98.csv
# Exported subset 403/499 to ../data/test_subsets/test_without_feature97.csv
# Exported subset 404/499 to ../data/test_subsets/test_without_feature96.csv
# Exported subset 405/499 to ../data/test_subsets/test_without_feature95.csv
# Exported subset 406/499 to ../data/test_subsets/test_without_feature94.csv
# Exported subset 407/499 to ../data/test_subsets/test_without_feature93.csv
# Exported subset 408/499 to ../data/test_subsets/test_without_feature92.csv
# Exported subset 409/499 to ../data/test_subsets/test_without_feature91.csv
# Exported subset 410/499 to ../data/test_subsets/test_without_feature90.csv
# Exported subset 411/499 to ../data/test_subsets/test_without_feature89.csv
# Exported subset 412/499 to ../data/test_subsets/test_without_feature88.csv
# Exported subset 413/499 to ../data/test_subsets/test_without_feature87.csv
# Exported subset 414/499 to ../data/test_subsets/test_without_feature86.csv
# Exported subset 415/499 to ../data/test_subsets/test_without_feature85.csv
# Exported subset 416/499 to ../data/test_subsets/test_without_feature84.csv
# Exported subset 417/499 to ../data/test_subsets/test_without_feature83.csv
# Exported subset 418/499 to ../data/test_subsets/test_without_feature82.csv
# Exported subset 419/499 to ../data/test_subsets/test_without_feature81.csv
# Exported subset 420/499 to ../data/test_subsets/test_without_feature80.csv
# Exported subset 421/499 to ../data/test_subsets/test_without_feature79.csv
# Exported subset 422/499 to ../data/test_subsets/test_without_feature78.csv
# Exported subset 423/499 to ../data/test_subsets/test_without_feature77.csv
# Exported subset 424/499 to ../data/test_subsets/test_without_feature76.csv
# Exported subset 425/499 to ../data/test_subsets/test_without_feature75.csv
# Exported subset 426/499 to ../data/test_subsets/test_without_feature74.csv
# Exported subset 427/499 to ../data/test_subsets/test_without_feature73.csv
# Exported subset 428/499 to ../data/test_subsets/test_without_feature72.csv
# Exported subset 429/499 to ../data/test_subsets/test_without_feature71.csv
# Exported subset 430/499 to ../data/test_subsets/test_without_feature70.csv
# Exported subset 431/499 to ../data/test_subsets/test_without_feature69.csv
# Exported subset 432/499 to ../data/test_subsets/test_without_feature68.csv
# Exported subset 433/499 to ../data/test_subsets/test_without_feature67.csv
# Exported subset 434/499 to ../data/test_subsets/test_without_feature66.csv
# Exported subset 435/499 to ../data/test_subsets/test_without_feature65.csv
# Exported subset 436/499 to ../data/test_subsets/test_without_feature64.csv
# Exported subset 437/499 to ../data/test_subsets/test_without_feature63.csv
# Exported subset 438/499 to ../data/test_subsets/test_without_feature62.csv
# Exported subset 439/499 to ../data/test_subsets/test_without_feature61.csv
# Exported subset 440/499 to ../data/test_subsets/test_without_feature60.csv
# Exported subset 441/499 to ../data/test_subsets/test_without_feature59.csv
# Exported subset 442/499 to ../data/test_subsets/test_without_feature58.csv
# Exported subset 443/499 to ../data/test_subsets/test_without_feature57.csv
# Exported subset 444/499 to ../data/test_subsets/test_without_feature56.csv
# Exported subset 445/499 to ../data/test_subsets/test_without_feature55.csv
# Exported subset 446/499 to ../data/test_subsets/test_without_feature54.csv
# Exported subset 447/499 to ../data/test_subsets/test_without_feature53.csv
# Exported subset 448/499 to ../data/test_subsets/test_without_feature52.csv
# Exported subset 449/499 to ../data/test_subsets/test_without_feature51.csv
# Exported subset 450/499 to ../data/test_subsets/test_without_feature50.csv
# Exported subset 451/499 to ../data/test_subsets/test_without_feature49.csv
# Exported subset 452/499 to ../data/test_subsets/test_without_feature48.csv
# Exported subset 453/499 to ../data/test_subsets/test_without_feature47.csv
# Exported subset 454/499 to ../data/test_subsets/test_without_feature46.csv
# Exported subset 455/499 to ../data/test_subsets/test_without_feature45.csv
# Exported subset 456/499 to ../data/test_subsets/test_without_feature44.csv
# Exported subset 457/499 to ../data/test_subsets/test_without_feature43.csv
# Exported subset 458/499 to ../data/test_subsets/test_without_feature42.csv
# Exported subset 459/499 to ../data/test_subsets/test_without_feature41.csv
# Exported subset 460/499 to ../data/test_subsets/test_without_feature40.csv
# Exported subset 461/499 to ../data/test_subsets/test_without_feature39.csv
# Exported subset 462/499 to ../data/test_subsets/test_without_feature38.csv
# Exported subset 463/499 to ../data/test_subsets/test_without_feature37.csv
# Exported subset 464/499 to ../data/test_subsets/test_without_feature36.csv
# Exported subset 465/499 to ../data/test_subsets/test_without_feature35.csv
# Exported subset 466/499 to ../data/test_subsets/test_without_feature34.csv
# Exported subset 467/499 to ../data/test_subsets/test_without_feature33.csv
# Exported subset 468/499 to ../data/test_subsets/test_without_feature32.csv
# Exported subset 469/499 to ../data/test_subsets/test_without_feature31.csv
# Exported subset 470/499 to ../data/test_subsets/test_without_feature30.csv
# Exported subset 471/499 to ../data/test_subsets/test_without_feature29.csv
# Exported subset 472/499 to ../data/test_subsets/test_without_feature28.csv
# Exported subset 473/499 to ../data/test_subsets/test_without_feature27.csv
# Exported subset 474/499 to ../data/test_subsets/test_without_feature26.csv
# Exported subset 475/499 to ../data/test_subsets/test_without_feature25.csv
# Exported subset 476/499 to ../data/test_subsets/test_without_feature24.csv
# Exported subset 477/499 to ../data/test_subsets/test_without_feature23.csv
# Exported subset 478/499 to ../data/test_subsets/test_without_feature22.csv
# Exported subset 479/499 to ../data/test_subsets/test_without_feature21.csv
# Exported subset 480/499 to ../data/test_subsets/test_without_feature20.csv
# Exported subset 481/499 to ../data/test_subsets/test_without_feature19.csv
# Exported subset 482/499 to ../data/test_subsets/test_without_feature18.csv
# Exported subset 483/499 to ../data/test_subsets/test_without_feature17.csv
# Exported subset 484/499 to ../data/test_subsets/test_without_feature16.csv
# Exported subset 485/499 to ../data/test_subsets/test_without_feature15.csv
# Exported subset 486/499 to ../data/test_subsets/test_without_feature14.csv
# Exported subset 487/499 to ../data/test_subsets/test_without_feature13.csv
# Exported subset 488/499 to ../data/test_subsets/test_without_feature12.csv
# Exported subset 489/499 to ../data/test_subsets/test_without_feature11.csv
# Exported subset 490/499 to ../data/test_subsets/test_without_feature10.csv
# Exported subset 491/499 to ../data/test_subsets/test_without_feature9.csv
# Exported subset 492/499 to ../data/test_subsets/test_without_feature8.csv
# Exported subset 493/499 to ../data/test_subsets/test_without_feature7.csv
# Exported subset 494/499 to ../data/test_subsets/test_without_feature6.csv
# Exported subset 495/499 to ../data/test_subsets/test_without_feature5.csv
# Exported subset 496/499 to ../data/test_subsets/test_without_feature4.csv
# Exported subset 497/499 to ../data/test_subsets/test_without_feature3.csv
# Exported subset 498/499 to ../data/test_subsets/test_without_feature2.csv
# Exported subset 499/499 to ../data/test_subsets/test_without_feature1.csv
# Exported subset 500/499 to ../data/test_subsets/test_without_feature0.csv
