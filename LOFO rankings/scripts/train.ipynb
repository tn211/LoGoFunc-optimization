# %%
import os, time, re, json
import pandas as pd
import numpy as np
from scipy.special import softmax
import joblib
from joblib import Parallel, delayed
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split, RandomizedSearchCV, KFold, cross_val_score
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.feature_selection import VarianceThreshold
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder, OrdinalEncoder
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline
from imblearn.under_sampling import  RandomUnderSampler
from imblearn.over_sampling import SMOTE, RandomOverSampler
from sklearn.base import BaseEstimator, TransformerMixin

# %%
def subset(directory, prefix):
    """
    This function loads all training subset CSVs into a dict of DataFrames.
    """
    csv_files = [f for f in os.listdir(directory) if f.endswith('.csv')]

    def feat_num(filename):
        """
        Extract feature number from the file's name.
        """
        match = re.search(r'train_without_feature(\d+)\.csv', filename)
        return int(match.group(1)) if match else 0

    # Sort by feature number
    csv_files.sort(key=feat_num)

    # Init the dictionary.
    dfs = {}

    # Load each CSV file into a dataframe.
    for file in csv_files:
        fnumber = feat_num(file)
        if 1 <= fnumber <= 500:
            df_name = f"{prefix}_{fnumber}"
            file_path = os.path.join(directory, file)
            df = pd.read_csv(file_path, low_memory=False)
            dfs[df_name] = df
            print(f"Loaded {file} into {df_name}")
    return dfs

# Load train subsets.
train_dir = "../data/train_subsets"
train_dfs = subset(train_dir, "train")
# Out:
# Loaded train_without_feature1.csv into train_1
# Loaded train_without_feature2.csv into train_2
# Loaded train_without_feature3.csv into train_3
# Loaded train_without_feature4.csv into train_4
# Loaded train_without_feature5.csv into train_5
# Loaded train_without_feature6.csv into train_6
# Loaded train_without_feature7.csv into train_7
# Loaded train_without_feature8.csv into train_8
# Loaded train_without_feature9.csv into train_9
# Loaded train_without_feature10.csv into train_10
# Loaded train_without_feature11.csv into train_11
# Loaded train_without_feature12.csv into train_12
# Loaded train_without_feature13.csv into train_13
# Loaded train_without_feature14.csv into train_14
# Loaded train_without_feature15.csv into train_15
# Loaded train_without_feature16.csv into train_16
# Loaded train_without_feature17.csv into train_17
# Loaded train_without_feature18.csv into train_18
# Loaded train_without_feature19.csv into train_19
# Loaded train_without_feature20.csv into train_20
# Loaded train_without_feature21.csv into train_21
# Loaded train_without_feature22.csv into train_22
# Loaded train_without_feature23.csv into train_23
# Loaded train_without_feature24.csv into train_24
# Loaded train_without_feature25.csv into train_25
# Loaded train_without_feature26.csv into train_26
# Loaded train_without_feature27.csv into train_27
# Loaded train_without_feature28.csv into train_28
# Loaded train_without_feature29.csv into train_29
# Loaded train_without_feature30.csv into train_30
# Loaded train_without_feature31.csv into train_31
# Loaded train_without_feature32.csv into train_32
# Loaded train_without_feature33.csv into train_33
# Loaded train_without_feature34.csv into train_34
# Loaded train_without_feature35.csv into train_35
# Loaded train_without_feature36.csv into train_36
# Loaded train_without_feature37.csv into train_37
# Loaded train_without_feature38.csv into train_38
# Loaded train_without_feature39.csv into train_39
# Loaded train_without_feature40.csv into train_40
# Loaded train_without_feature41.csv into train_41
# Loaded train_without_feature42.csv into train_42
# Loaded train_without_feature43.csv into train_43
# Loaded train_without_feature44.csv into train_44
# Loaded train_without_feature45.csv into train_45
# Loaded train_without_feature46.csv into train_46
# Loaded train_without_feature47.csv into train_47
# Loaded train_without_feature48.csv into train_48
# Loaded train_without_feature49.csv into train_49
# Loaded train_without_feature50.csv into train_50
# Loaded train_without_feature51.csv into train_51
# Loaded train_without_feature52.csv into train_52
# Loaded train_without_feature53.csv into train_53
# Loaded train_without_feature54.csv into train_54
# Loaded train_without_feature55.csv into train_55
# Loaded train_without_feature56.csv into train_56
# Loaded train_without_feature57.csv into train_57
# Loaded train_without_feature58.csv into train_58
# Loaded train_without_feature59.csv into train_59
# Loaded train_without_feature60.csv into train_60
# Loaded train_without_feature61.csv into train_61
# Loaded train_without_feature62.csv into train_62
# Loaded train_without_feature63.csv into train_63
# Loaded train_without_feature64.csv into train_64
# Loaded train_without_feature65.csv into train_65
# Loaded train_without_feature66.csv into train_66
# Loaded train_without_feature67.csv into train_67
# Loaded train_without_feature68.csv into train_68
# Loaded train_without_feature69.csv into train_69
# Loaded train_without_feature70.csv into train_70
# Loaded train_without_feature71.csv into train_71
# Loaded train_without_feature72.csv into train_72
# Loaded train_without_feature73.csv into train_73
# Loaded train_without_feature74.csv into train_74
# Loaded train_without_feature75.csv into train_75
# Loaded train_without_feature76.csv into train_76
# Loaded train_without_feature77.csv into train_77
# Loaded train_without_feature78.csv into train_78
# Loaded train_without_feature79.csv into train_79
# Loaded train_without_feature80.csv into train_80
# Loaded train_without_feature81.csv into train_81
# Loaded train_without_feature82.csv into train_82
# Loaded train_without_feature83.csv into train_83
# Loaded train_without_feature84.csv into train_84
# Loaded train_without_feature85.csv into train_85
# Loaded train_without_feature86.csv into train_86
# Loaded train_without_feature87.csv into train_87
# Loaded train_without_feature88.csv into train_88
# Loaded train_without_feature89.csv into train_89
# Loaded train_without_feature90.csv into train_90
# Loaded train_without_feature91.csv into train_91
# Loaded train_without_feature92.csv into train_92
# Loaded train_without_feature93.csv into train_93
# Loaded train_without_feature94.csv into train_94
# Loaded train_without_feature95.csv into train_95
# Loaded train_without_feature96.csv into train_96
# Loaded train_without_feature97.csv into train_97
# Loaded train_without_feature98.csv into train_98
# Loaded train_without_feature99.csv into train_99
# Loaded train_without_feature100.csv into train_100
# Loaded train_without_feature101.csv into train_101
# Loaded train_without_feature102.csv into train_102
# Loaded train_without_feature103.csv into train_103
# Loaded train_without_feature104.csv into train_104
# Loaded train_without_feature105.csv into train_105
# Loaded train_without_feature106.csv into train_106
# Loaded train_without_feature107.csv into train_107
# Loaded train_without_feature108.csv into train_108
# Loaded train_without_feature109.csv into train_109
# Loaded train_without_feature110.csv into train_110
# Loaded train_without_feature111.csv into train_111
# Loaded train_without_feature112.csv into train_112
# Loaded train_without_feature113.csv into train_113
# Loaded train_without_feature114.csv into train_114
# Loaded train_without_feature115.csv into train_115
# Loaded train_without_feature116.csv into train_116
# Loaded train_without_feature117.csv into train_117
# Loaded train_without_feature118.csv into train_118
# Loaded train_without_feature119.csv into train_119
# Loaded train_without_feature120.csv into train_120
# Loaded train_without_feature121.csv into train_121
# Loaded train_without_feature122.csv into train_122
# Loaded train_without_feature123.csv into train_123
# Loaded train_without_feature124.csv into train_124
# Loaded train_without_feature125.csv into train_125
# Loaded train_without_feature126.csv into train_126
# Loaded train_without_feature127.csv into train_127
# Loaded train_without_feature128.csv into train_128
# Loaded train_without_feature129.csv into train_129
# Loaded train_without_feature130.csv into train_130
# Loaded train_without_feature131.csv into train_131
# Loaded train_without_feature132.csv into train_132
# Loaded train_without_feature133.csv into train_133
# Loaded train_without_feature134.csv into train_134
# Loaded train_without_feature135.csv into train_135
# Loaded train_without_feature136.csv into train_136
# Loaded train_without_feature137.csv into train_137
# Loaded train_without_feature138.csv into train_138
# Loaded train_without_feature139.csv into train_139
# Loaded train_without_feature140.csv into train_140
# Loaded train_without_feature141.csv into train_141
# Loaded train_without_feature142.csv into train_142
# Loaded train_without_feature143.csv into train_143
# Loaded train_without_feature144.csv into train_144
# Loaded train_without_feature145.csv into train_145
# Loaded train_without_feature146.csv into train_146
# Loaded train_without_feature147.csv into train_147
# Loaded train_without_feature148.csv into train_148
# Loaded train_without_feature149.csv into train_149
# Loaded train_without_feature150.csv into train_150
# Loaded train_without_feature151.csv into train_151
# Loaded train_without_feature152.csv into train_152
# Loaded train_without_feature153.csv into train_153
# Loaded train_without_feature154.csv into train_154
# Loaded train_without_feature155.csv into train_155
# Loaded train_without_feature156.csv into train_156
# Loaded train_without_feature157.csv into train_157
# Loaded train_without_feature158.csv into train_158
# Loaded train_without_feature159.csv into train_159
# Loaded train_without_feature160.csv into train_160
# Loaded train_without_feature161.csv into train_161
# Loaded train_without_feature162.csv into train_162
# Loaded train_without_feature163.csv into train_163
# Loaded train_without_feature164.csv into train_164
# Loaded train_without_feature165.csv into train_165
# Loaded train_without_feature166.csv into train_166
# Loaded train_without_feature167.csv into train_167
# Loaded train_without_feature168.csv into train_168
# Loaded train_without_feature169.csv into train_169
# Loaded train_without_feature170.csv into train_170
# Loaded train_without_feature171.csv into train_171
# Loaded train_without_feature172.csv into train_172
# Loaded train_without_feature173.csv into train_173
# Loaded train_without_feature174.csv into train_174
# Loaded train_without_feature175.csv into train_175
# Loaded train_without_feature176.csv into train_176
# Loaded train_without_feature177.csv into train_177
# Loaded train_without_feature178.csv into train_178
# Loaded train_without_feature179.csv into train_179
# Loaded train_without_feature180.csv into train_180
# Loaded train_without_feature181.csv into train_181
# Loaded train_without_feature182.csv into train_182
# Loaded train_without_feature183.csv into train_183
# Loaded train_without_feature184.csv into train_184
# Loaded train_without_feature185.csv into train_185
# Loaded train_without_feature186.csv into train_186
# Loaded train_without_feature187.csv into train_187
# Loaded train_without_feature188.csv into train_188
# Loaded train_without_feature189.csv into train_189
# Loaded train_without_feature190.csv into train_190
# Loaded train_without_feature191.csv into train_191
# Loaded train_without_feature192.csv into train_192
# Loaded train_without_feature193.csv into train_193
# Loaded train_without_feature194.csv into train_194
# Loaded train_without_feature195.csv into train_195
# Loaded train_without_feature196.csv into train_196
# Loaded train_without_feature197.csv into train_197
# Loaded train_without_feature198.csv into train_198
# Loaded train_without_feature199.csv into train_199
# Loaded train_without_feature200.csv into train_200
# Loaded train_without_feature201.csv into train_201
# Loaded train_without_feature202.csv into train_202
# Loaded train_without_feature203.csv into train_203
# Loaded train_without_feature204.csv into train_204
# Loaded train_without_feature205.csv into train_205
# Loaded train_without_feature206.csv into train_206
# Loaded train_without_feature207.csv into train_207
# Loaded train_without_feature208.csv into train_208
# Loaded train_without_feature209.csv into train_209
# Loaded train_without_feature210.csv into train_210
# Loaded train_without_feature211.csv into train_211
# Loaded train_without_feature212.csv into train_212
# Loaded train_without_feature213.csv into train_213
# Loaded train_without_feature214.csv into train_214
# Loaded train_without_feature215.csv into train_215
# Loaded train_without_feature216.csv into train_216
# Loaded train_without_feature217.csv into train_217
# Loaded train_without_feature218.csv into train_218
# Loaded train_without_feature219.csv into train_219
# Loaded train_without_feature220.csv into train_220
# Loaded train_without_feature221.csv into train_221
# Loaded train_without_feature222.csv into train_222
# Loaded train_without_feature223.csv into train_223
# Loaded train_without_feature224.csv into train_224
# Loaded train_without_feature225.csv into train_225
# Loaded train_without_feature226.csv into train_226
# Loaded train_without_feature227.csv into train_227
# Loaded train_without_feature228.csv into train_228
# Loaded train_without_feature229.csv into train_229
# Loaded train_without_feature230.csv into train_230
# Loaded train_without_feature231.csv into train_231
# Loaded train_without_feature232.csv into train_232
# Loaded train_without_feature233.csv into train_233
# Loaded train_without_feature234.csv into train_234
# Loaded train_without_feature235.csv into train_235
# Loaded train_without_feature236.csv into train_236
# Loaded train_without_feature237.csv into train_237
# Loaded train_without_feature238.csv into train_238
# Loaded train_without_feature239.csv into train_239
# Loaded train_without_feature240.csv into train_240
# Loaded train_without_feature241.csv into train_241
# Loaded train_without_feature242.csv into train_242
# Loaded train_without_feature243.csv into train_243
# Loaded train_without_feature244.csv into train_244
# Loaded train_without_feature245.csv into train_245
# Loaded train_without_feature246.csv into train_246
# Loaded train_without_feature247.csv into train_247
# Loaded train_without_feature248.csv into train_248
# Loaded train_without_feature249.csv into train_249
# Loaded train_without_feature250.csv into train_250
# Loaded train_without_feature251.csv into train_251
# Loaded train_without_feature252.csv into train_252
# Loaded train_without_feature253.csv into train_253
# Loaded train_without_feature254.csv into train_254
# Loaded train_without_feature255.csv into train_255
# Loaded train_without_feature256.csv into train_256
# Loaded train_without_feature257.csv into train_257
# Loaded train_without_feature258.csv into train_258
# Loaded train_without_feature259.csv into train_259
# Loaded train_without_feature260.csv into train_260
# Loaded train_without_feature261.csv into train_261
# Loaded train_without_feature262.csv into train_262
# Loaded train_without_feature263.csv into train_263
# Loaded train_without_feature264.csv into train_264
# Loaded train_without_feature265.csv into train_265
# Loaded train_without_feature266.csv into train_266
# Loaded train_without_feature267.csv into train_267
# Loaded train_without_feature268.csv into train_268
# Loaded train_without_feature269.csv into train_269
# Loaded train_without_feature270.csv into train_270
# Loaded train_without_feature271.csv into train_271
# Loaded train_without_feature272.csv into train_272
# Loaded train_without_feature273.csv into train_273
# Loaded train_without_feature274.csv into train_274
# Loaded train_without_feature275.csv into train_275
# Loaded train_without_feature276.csv into train_276
# Loaded train_without_feature277.csv into train_277
# Loaded train_without_feature278.csv into train_278
# Loaded train_without_feature279.csv into train_279
# Loaded train_without_feature280.csv into train_280
# Loaded train_without_feature281.csv into train_281
# Loaded train_without_feature282.csv into train_282
# Loaded train_without_feature283.csv into train_283
# Loaded train_without_feature284.csv into train_284
# Loaded train_without_feature285.csv into train_285
# Loaded train_without_feature286.csv into train_286
# Loaded train_without_feature287.csv into train_287
# Loaded train_without_feature288.csv into train_288
# Loaded train_without_feature289.csv into train_289
# Loaded train_without_feature290.csv into train_290
# Loaded train_without_feature291.csv into train_291
# Loaded train_without_feature292.csv into train_292
# Loaded train_without_feature293.csv into train_293
# Loaded train_without_feature294.csv into train_294
# Loaded train_without_feature295.csv into train_295
# Loaded train_without_feature296.csv into train_296
# Loaded train_without_feature297.csv into train_297
# Loaded train_without_feature298.csv into train_298
# Loaded train_without_feature299.csv into train_299
# Loaded train_without_feature300.csv into train_300
# Loaded train_without_feature301.csv into train_301
# Loaded train_without_feature302.csv into train_302
# Loaded train_without_feature303.csv into train_303
# Loaded train_without_feature304.csv into train_304
# Loaded train_without_feature305.csv into train_305
# Loaded train_without_feature306.csv into train_306
# Loaded train_without_feature307.csv into train_307
# Loaded train_without_feature308.csv into train_308
# Loaded train_without_feature309.csv into train_309
# Loaded train_without_feature310.csv into train_310
# Loaded train_without_feature311.csv into train_311
# Loaded train_without_feature312.csv into train_312
# Loaded train_without_feature313.csv into train_313
# Loaded train_without_feature314.csv into train_314
# Loaded train_without_feature315.csv into train_315
# Loaded train_without_feature316.csv into train_316
# Loaded train_without_feature317.csv into train_317
# Loaded train_without_feature318.csv into train_318
# Loaded train_without_feature319.csv into train_319
# Loaded train_without_feature320.csv into train_320
# Loaded train_without_feature321.csv into train_321
# Loaded train_without_feature322.csv into train_322
# Loaded train_without_feature323.csv into train_323
# Loaded train_without_feature324.csv into train_324
# Loaded train_without_feature325.csv into train_325
# Loaded train_without_feature326.csv into train_326
# Loaded train_without_feature327.csv into train_327
# Loaded train_without_feature328.csv into train_328
# Loaded train_without_feature329.csv into train_329
# Loaded train_without_feature330.csv into train_330
# Loaded train_without_feature331.csv into train_331
# Loaded train_without_feature332.csv into train_332
# Loaded train_without_feature333.csv into train_333
# Loaded train_without_feature334.csv into train_334
# Loaded train_without_feature335.csv into train_335
# Loaded train_without_feature336.csv into train_336
# Loaded train_without_feature337.csv into train_337
# Loaded train_without_feature338.csv into train_338
# Loaded train_without_feature339.csv into train_339
# Loaded train_without_feature340.csv into train_340
# Loaded train_without_feature341.csv into train_341
# Loaded train_without_feature342.csv into train_342
# Loaded train_without_feature343.csv into train_343
# Loaded train_without_feature344.csv into train_344
# Loaded train_without_feature345.csv into train_345
# Loaded train_without_feature346.csv into train_346
# Loaded train_without_feature347.csv into train_347
# Loaded train_without_feature348.csv into train_348
# Loaded train_without_feature349.csv into train_349
# Loaded train_without_feature350.csv into train_350
# Loaded train_without_feature351.csv into train_351
# Loaded train_without_feature352.csv into train_352
# Loaded train_without_feature353.csv into train_353
# Loaded train_without_feature354.csv into train_354
# Loaded train_without_feature355.csv into train_355
# Loaded train_without_feature356.csv into train_356
# Loaded train_without_feature357.csv into train_357
# Loaded train_without_feature358.csv into train_358
# Loaded train_without_feature359.csv into train_359
# Loaded train_without_feature360.csv into train_360
# Loaded train_without_feature361.csv into train_361
# Loaded train_without_feature362.csv into train_362
# Loaded train_without_feature363.csv into train_363
# Loaded train_without_feature364.csv into train_364
# Loaded train_without_feature365.csv into train_365
# Loaded train_without_feature366.csv into train_366
# Loaded train_without_feature367.csv into train_367
# Loaded train_without_feature368.csv into train_368
# Loaded train_without_feature369.csv into train_369
# Loaded train_without_feature370.csv into train_370
# Loaded train_without_feature371.csv into train_371
# Loaded train_without_feature372.csv into train_372
# Loaded train_without_feature373.csv into train_373
# Loaded train_without_feature374.csv into train_374
# Loaded train_without_feature375.csv into train_375
# Loaded train_without_feature376.csv into train_376
# Loaded train_without_feature377.csv into train_377
# Loaded train_without_feature378.csv into train_378
# Loaded train_without_feature379.csv into train_379
# Loaded train_without_feature380.csv into train_380
# Loaded train_without_feature381.csv into train_381
# Loaded train_without_feature382.csv into train_382
# Loaded train_without_feature383.csv into train_383
# Loaded train_without_feature384.csv into train_384
# Loaded train_without_feature385.csv into train_385
# Loaded train_without_feature386.csv into train_386
# Loaded train_without_feature387.csv into train_387
# Loaded train_without_feature388.csv into train_388
# Loaded train_without_feature389.csv into train_389
# Loaded train_without_feature390.csv into train_390
# Loaded train_without_feature391.csv into train_391
# Loaded train_without_feature392.csv into train_392
# Loaded train_without_feature393.csv into train_393
# Loaded train_without_feature394.csv into train_394
# Loaded train_without_feature395.csv into train_395
# Loaded train_without_feature396.csv into train_396
# Loaded train_without_feature397.csv into train_397
# Loaded train_without_feature398.csv into train_398
# Loaded train_without_feature399.csv into train_399
# Loaded train_without_feature400.csv into train_400
# Loaded train_without_feature401.csv into train_401
# Loaded train_without_feature402.csv into train_402
# Loaded train_without_feature403.csv into train_403
# Loaded train_without_feature404.csv into train_404
# Loaded train_without_feature405.csv into train_405
# Loaded train_without_feature406.csv into train_406
# Loaded train_without_feature407.csv into train_407
# Loaded train_without_feature408.csv into train_408
# Loaded train_without_feature409.csv into train_409
# Loaded train_without_feature410.csv into train_410
# Loaded train_without_feature411.csv into train_411
# Loaded train_without_feature412.csv into train_412
# Loaded train_without_feature413.csv into train_413
# Loaded train_without_feature414.csv into train_414
# Loaded train_without_feature415.csv into train_415
# Loaded train_without_feature416.csv into train_416
# Loaded train_without_feature417.csv into train_417
# Loaded train_without_feature418.csv into train_418
# Loaded train_without_feature419.csv into train_419
# Loaded train_without_feature420.csv into train_420
# Loaded train_without_feature421.csv into train_421
# Loaded train_without_feature422.csv into train_422
# Loaded train_without_feature423.csv into train_423
# Loaded train_without_feature424.csv into train_424
# Loaded train_without_feature425.csv into train_425
# Loaded train_without_feature426.csv into train_426
# Loaded train_without_feature427.csv into train_427
# Loaded train_without_feature428.csv into train_428
# Loaded train_without_feature429.csv into train_429
# Loaded train_without_feature430.csv into train_430
# Loaded train_without_feature431.csv into train_431
# Loaded train_without_feature432.csv into train_432
# Loaded train_without_feature433.csv into train_433
# Loaded train_without_feature434.csv into train_434
# Loaded train_without_feature435.csv into train_435
# Loaded train_without_feature436.csv into train_436
# Loaded train_without_feature437.csv into train_437
# Loaded train_without_feature438.csv into train_438
# Loaded train_without_feature439.csv into train_439
# Loaded train_without_feature440.csv into train_440
# Loaded train_without_feature441.csv into train_441
# Loaded train_without_feature442.csv into train_442
# Loaded train_without_feature443.csv into train_443
# Loaded train_without_feature444.csv into train_444
# Loaded train_without_feature445.csv into train_445
# Loaded train_without_feature446.csv into train_446
# Loaded train_without_feature447.csv into train_447
# Loaded train_without_feature448.csv into train_448
# Loaded train_without_feature449.csv into train_449
# Loaded train_without_feature450.csv into train_450
# Loaded train_without_feature451.csv into train_451
# Loaded train_without_feature452.csv into train_452
# Loaded train_without_feature453.csv into train_453
# Loaded train_without_feature454.csv into train_454
# Loaded train_without_feature455.csv into train_455
# Loaded train_without_feature456.csv into train_456
# Loaded train_without_feature457.csv into train_457
# Loaded train_without_feature458.csv into train_458
# Loaded train_without_feature459.csv into train_459
# Loaded train_without_feature460.csv into train_460
# Loaded train_without_feature461.csv into train_461
# Loaded train_without_feature462.csv into train_462
# Loaded train_without_feature463.csv into train_463
# Loaded train_without_feature464.csv into train_464
# Loaded train_without_feature465.csv into train_465
# Loaded train_without_feature466.csv into train_466
# Loaded train_without_feature467.csv into train_467
# Loaded train_without_feature468.csv into train_468
# Loaded train_without_feature469.csv into train_469
# Loaded train_without_feature470.csv into train_470
# Loaded train_without_feature471.csv into train_471
# Loaded train_without_feature472.csv into train_472
# Loaded train_without_feature473.csv into train_473
# Loaded train_without_feature474.csv into train_474
# Loaded train_without_feature475.csv into train_475
# Loaded train_without_feature476.csv into train_476
# Loaded train_without_feature477.csv into train_477
# Loaded train_without_feature478.csv into train_478
# Loaded train_without_feature479.csv into train_479
# Loaded train_without_feature480.csv into train_480
# Loaded train_without_feature481.csv into train_481
# Loaded train_without_feature482.csv into train_482
# Loaded train_without_feature483.csv into train_483
# Loaded train_without_feature484.csv into train_484
# Loaded train_without_feature485.csv into train_485
# Loaded train_without_feature486.csv into train_486
# Loaded train_without_feature487.csv into train_487
# Loaded train_without_feature488.csv into train_488
# Loaded train_without_feature489.csv into train_489
# Loaded train_without_feature490.csv into train_490
# Loaded train_without_feature491.csv into train_491
# Loaded train_without_feature492.csv into train_492
# Loaded train_without_feature493.csv into train_493
# Loaded train_without_feature494.csv into train_494
# Loaded train_without_feature495.csv into train_495
# Loaded train_without_feature496.csv into train_496
# Loaded train_without_feature497.csv into train_497
# Loaded train_without_feature498.csv into train_498
# Loaded train_without_feature499.csv into train_499

# %%
# Load the stored params.
with open('../models/top_27_params.json', 'r') as f:
    top_n_params = json.load(f)

# %%
file_path = '../data/negone_median.json'

# Read the JSON.
with open(file_path, 'r') as file:
    data = json.load(file)

# Extract the imputation lists.
negone_features = data.get('NEGONE_FEATURES', [])
median_features = data.get('MEDIAN_FEATURES', [])
print('NEGONE_FEATURES:', negone_features)
print('MEDIAN_FEATURES:', median_features)
# Out:
# NEGONE_FEATURES: ['feature487', 'feature489', 'feature491', 'feature492', 'feature493', 'feature494', 'feature495', 'feature496', 'feature497', 'feature498', 'feature499', 'feature458', 'feature4', 'feature6', 'feature10', 'feature13', 'feature31', 'feature35', 'feature36', 'feature46', 'feature47', 'feature48', 'feature49', 'feature45', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60', 'feature61', 'feature62', 'feature63', 'feature64', 'feature65', 'feature66', 'feature67', 'feature68', 'feature69', 'feature70', 'feature71', 'feature72', 'feature73', 'feature74', 'feature75', 'feature76', 'feature77', 'feature84', 'feature85', 'feature86', 'feature87', 'feature88', 'feature89', 'feature90', 'feature91', 'feature92', 'feature93', 'feature94', 'feature95', 'feature96', 'feature97', 'feature98', 'feature99', 'feature100', 'feature101', 'feature102', 'feature103', 'feature105', 'feature107', 'feature108', 'feature109', 'feature110', 'feature111', 'feature112', 'feature113', 'feature114', 'feature115', 'feature116', 'feature117', 'feature118', 'feature119', 'feature120', 'feature121', 'feature122', 'feature123', 'feature124', 'feature125', 'feature126', 'feature127', 'feature128', 'feature129', 'feature130', 'feature131', 'feature132', 'feature133', 'feature134', 'feature135', 'feature136', 'feature137', 'feature138', 'feature139', 'feature140', 'feature141', 'feature142', 'feature143', 'feature144', 'feature145', 'feature146', 'feature147', 'feature148', 'feature149', 'feature150', 'feature151', 'feature152', 'feature153', 'feature154', 'feature155', 'feature156', 'feature157', 'feature158', 'feature159', 'feature160', 'feature161', 'feature162', 'feature163', 'feature164', 'feature165', 'feature166', 'feature167', 'feature168', 'feature169', 'feature170', 'feature171', 'feature172', 'feature173', 'feature174', 'feature175', 'feature176', 'feature177', 'feature178', 'feature179', 'feature180', 'feature181', 'feature182', 'feature183', 'feature184', 'feature185', 'feature186', 'feature187', 'feature188', 'feature189', 'feature190', 'feature191', 'feature192', 'feature193', 'feature194', 'feature195', 'feature196', 'feature197', 'feature198', 'feature199', 'feature200', 'feature201', 'feature202', 'feature203', 'feature204', 'feature205', 'feature206', 'feature207', 'feature208', 'feature209', 'feature210', 'feature211', 'feature212', 'feature213', 'feature214', 'feature215', 'feature216', 'feature217', 'feature218', 'feature219', 'feature220', 'feature221', 'feature222', 'feature223', 'feature224', 'feature225', 'feature226', 'feature227', 'feature228', 'feature229', 'feature230', 'feature231', 'feature232', 'feature233', 'feature234', 'feature235', 'feature236', 'feature237', 'feature238', 'feature239', 'feature240', 'feature241', 'feature242', 'feature243', 'feature244', 'feature245', 'feature246', 'feature247', 'feature248', 'feature249', 'feature250', 'feature251', 'feature252', 'feature253', 'feature254', 'feature255', 'feature256', 'feature257', 'feature258', 'feature259', 'feature260', 'feature261', 'feature262', 'feature263', 'feature264', 'feature265', 'feature266', 'feature267', 'feature268', 'feature269', 'feature270', 'feature271', 'feature272', 'feature273', 'feature274', 'feature275', 'feature276', 'feature277', 'feature278', 'feature279', 'feature280', 'feature281', 'feature282', 'feature283', 'feature284', 'feature285', 'feature286', 'feature287', 'feature288', 'feature289', 'feature290', 'feature291', 'feature292', 'feature293', 'feature294', 'feature295', 'feature296', 'feature297', 'feature298', 'feature299', 'feature300', 'feature301', 'feature302', 'feature303', 'feature304', 'feature305', 'feature306', 'feature307', 'feature308', 'feature309', 'feature310', 'feature311', 'feature312', 'feature313', 'feature314', 'feature315', 'feature316', 'feature317', 'feature318', 'feature319', 'feature320', 'feature321', 'feature ...
# MEDIAN_FEATURES: ['feature3', 'feature5', 'feature7', 'feature8', 'feature9', 'feature11', 'feature12', 'feature14', 'feature15', 'feature16', 'feature17', 'feature18', 'feature19', 'feature20', 'feature21', 'feature22', 'feature23', 'feature24', 'feature25', 'feature26', 'feature27', 'feature28', 'feature29', 'feature30', 'feature32', 'feature33', 'feature34', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature42', 'feature43', 'feature79', 'feature80', 'feature81', 'feature82', 'feature350', 'feature351', 'feature352', 'feature353', 'feature354', 'feature370', 'feature371', 'feature372', 'feature378', 'feature379', 'feature380', 'feature381', 'feature382', 'feature383', 'feature384', 'feature385', 'feature386', 'feature387', 'feature388', 'feature389', 'feature390', 'feature391', 'feature392', 'feature393', 'feature394', 'feature395', 'feature396', 'feature397', 'feature398', 'feature399', 'feature400', 'feature401', 'feature402', 'feature403', 'feature404', 'feature405', 'feature406', 'feature407', 'feature408', 'feature409', 'feature410', 'feature411', 'feature412', 'feature413', 'feature414', 'feature415', 'feature416', 'feature417', 'feature418', 'feature419', 'feature420', 'feature449', 'feature450', 'feature451', 'feature452', 'feature453', 'feature454', 'feature455', 'feature456', 'feature457', 'feature469', 'feature470']

# %%
file_path = '../data/patterns.json'

# Read the JSON.
with open(file_path, 'r') as file:
    data = json.load(file)

# Extract keys and turn into integer numbers.
keys_list = [int(key.replace('feature', '')) for key in data.keys()]
drop_numbers = keys_list
print('Keys:', drop_numbers)
print('Length:', len(drop_numbers))
# Out:
# Keys: [35, 36, 60, 61, 62, 63, 64, 65, 66, 67, 68, 69, 70, 71, 87, 88, 89, 90, 91, 92, 93, 94, 95, 96, 97, 98]
# Length: 26

# %%
""" Iterate through the entire training script for each subeset DataFrame in the dictionary. """

for df_name, X_train in train_dfs.items():
    y_train = pd.read_csv('../data/y_train_id.csv')
    print(y_train.shape)

    # Encoding the labels.
    y_train_enc = []
    for lab in y_train['label']:
        if lab == 'GOF':
            y_train_enc.append(1)
        elif lab == 'LOF':
            y_train_enc.append(2)
        else:
            y_train_enc.append(0)
    y_train = y_train_enc
    print(len(y_train))

    print(f"Processing {df_name}")

    model_name = df_name.split('_')[1]
    model_directory = f'../models/{model_name}'

    # Create the directory.
    if not os.path.exists(model_directory):
        os.makedirs(model_directory)

    print(f"Directory '{model_directory}' is ready.")

    # These lists are used to determine imputation strategies for the specified features (inherited from LoGoFunc)
    NEGONE_FEATURES = ['feature487', 'feature489', 'feature491', 'feature492', 'feature493', 'feature494', 'feature495', 'feature496', 'feature497', 'feature498', 'feature499', 'feature458', 'feature4', 'feature6', 'feature10', 'feature13', 'feature31', 'feature35', 'feature36', 'feature46', 'feature47', 'feature48', 'feature49', 'feature45', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60', 'feature61', 'feature62', 'feature63', 'feature64', 'feature65', 'feature66', 'feature67', 'feature68', 'feature69', 'feature70', 'feature71', 'feature72', 'feature73', 'feature74', 'feature75', 'feature76', 'feature77', 'feature84', 'feature85', 'feature86', 'feature87', 'feature88', 'feature89', 'feature90', 'feature91', 'feature92', 'feature93', 'feature94', 'feature95', 'feature96', 'feature97', 'feature98', 'feature99', 'feature100', 'feature101', 'feature102', 'feature103', 'feature105', 'feature107', 'feature108', 'feature109', 'feature110', 'feature111', 'feature112', 'feature113', 'feature114', 'feature115', 'feature116', 'feature117', 'feature118', 'feature119', 'feature120', 'feature121', 'feature122', 'feature123', 'feature124', 'feature125', 'feature126', 'feature127', 'feature128', 'feature129', 'feature130', 'feature131', 'feature132', 'feature133', 'feature134', 'feature135', 'feature136', 'feature137', 'feature138', 'feature139', 'feature140', 'feature141', 'feature142', 'feature143', 'feature144', 'feature145', 'feature146', 'feature147', 'feature148', 'feature149', 'feature150', 'feature151', 'feature152', 'feature153', 'feature154', 'feature155', 'feature156', 'feature157', 'feature158', 'feature159', 'feature160', 'feature161', 'feature162', 'feature163', 'feature164', 'feature165', 'feature166', 'feature167', 'feature168', 'feature169', 'feature170', 'feature171', 'feature172', 'feature173', 'feature174', 'feature175', 'feature176', 'feature177', 'feature178', 'feature179', 'feature180', 'feature181', 'feature182', 'feature183', 'feature184', 'feature185', 'feature186', 'feature187', 'feature188', 'feature189', 'feature190', 'feature191', 'feature192', 'feature193', 'feature194', 'feature195', 'feature196', 'feature197', 'feature198', 'feature199', 'feature200', 'feature201', 'feature202', 'feature203', 'feature204', 'feature205', 'feature206', 'feature207', 'feature208', 'feature209', 'feature210', 'feature211', 'feature212', 'feature213', 'feature214', 'feature215', 'feature216', 'feature217', 'feature218', 'feature219', 'feature220', 'feature221', 'feature222', 'feature223', 'feature224', 'feature225', 'feature226', 'feature227', 'feature228', 'feature229', 'feature230', 'feature231', 'feature232', 'feature233', 'feature234', 'feature235', 'feature236', 'feature237', 'feature238', 'feature239', 'feature240', 'feature241', 'feature242', 'feature243', 'feature244', 'feature245', 'feature246', 'feature247', 'feature248', 'feature249', 'feature250', 'feature251', 'feature252', 'feature253', 'feature254', 'feature255', 'feature256', 'feature257', 'feature258', 'feature259', 'feature260', 'feature261', 'feature262', 'feature263', 'feature264', 'feature265', 'feature266', 'feature267', 'feature268', 'feature269', 'feature270', 'feature271', 'feature272', 'feature273', 'feature274', 'feature275', 'feature276', 'feature277', 'feature278', 'feature279', 'feature280', 'feature281', 'feature282', 'feature283', 'feature284', 'feature285', 'feature286', 'feature287', 'feature288', 'feature289', 'feature290', 'feature291', 'feature292', 'feature293', 'feature294', 'feature295', 'feature296', 'feature297', 'feature298', 'feature299', 'feature300', 'feature301', 'feature302', 'feature303', 'feature304', 'feature305', 'feature306', 'feature307', 'feature308', 'feature309', 'feature310', 'feature311', 'feature312', 'feature313', 'feature314', 'feature315', 'feature316', 'feature317', 'feature318', 'feature319', 'feature320', 'feature321', 'feature322', 'feature323', 'feature324', 'feature325', 'feature326', 'feature327', 'feature328', 'feature329', 'feature330', 'feature331', 'feature332', 'feature333', 'feature334', 'feature335', 'feature336', 'feature337', 'feature338', 'feature339', 'feature340', 'feature341', 'feature342', 'feature343', 'feature344', 'feature345', 'feature346', 'feature347', 'feature348', 'feature349', 'feature355', 'feature356', 'feature357', 'feature358', 'feature359', 'feature360', 'feature361', 'feature362', 'feature363', 'feature364', 'feature365', 'feature366', 'feature367', 'feature368', 'feature369', 'feature373', 'feature374', 'feature375', 'feature376', 'feature421', 'feature422', 'feature423', 'feature424', 'feature425', 'feature426', 'feature427', 'feature428', 'feature429', 'feature430', 'feature431', 'feature432', 'feature433', 'feature434', 'feature435', 'feature436', 'feature437', 'feature438', 'feature439', 'feature440', 'feature441', 'feature442', 'feature443', 'feature444', 'feature445', 'feature446', 'feature447', 'feature448', 'feature459', 'feature460', 'feature461', 'feature462', 'feature463', 'feature464', 'feature465', 'feature466', 'feature467', 'feature471', 'feature472', 'feature473', 'feature474', 'feature475', 'feature476', 'feature477', 'feature478', 'feature479', 'feature480', 'feature481', 'feature482', 'feature483', 'feature484', 'feature485', 'feature486']
    MEDIAN_FEATURES = ['feature3', 'feature5', 'feature7', 'feature8', 'feature9', 'feature11', 'feature12', 'feature14', 'feature15', 'feature16', 'feature17', 'feature18', 'feature19', 'feature20', 'feature21', 'feature22', 'feature23', 'feature24', 'feature25', 'feature26', 'feature27', 'feature28', 'feature29', 'feature30', 'feature32', 'feature33', 'feature34', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature42', 'feature43', 'feature79', 'feature80', 'feature81', 'feature82', 'feature350', 'feature351', 'feature352', 'feature353', 'feature354', 'feature370', 'feature371', 'feature372', 'feature378', 'feature379', 'feature380', 'feature381', 'feature382', 'feature383', 'feature384', 'feature385', 'feature386', 'feature387', 'feature388', 'feature389', 'feature390', 'feature391', 'feature392', 'feature393', 'feature394', 'feature395', 'feature396', 'feature397', 'feature398', 'feature399', 'feature400', 'feature401', 'feature402', 'feature403', 'feature404', 'feature405', 'feature406', 'feature407', 'feature408', 'feature409', 'feature410', 'feature411', 'feature412', 'feature413', 'feature414', 'feature415', 'feature416', 'feature417', 'feature418', 'feature419', 'feature420', 'feature449', 'feature450', 'feature451', 'feature452', 'feature453', 'feature454', 'feature455', 'feature456', 'feature457', 'feature469', 'feature470']

    # Filter NEGONE_FEATURES and MEDIAN_FEATURES based on current X_train columns.
    negone_features_filtered = [feature for feature in NEGONE_FEATURES if feature in X_train.columns]
    median_features_filtered = [feature for feature in MEDIAN_FEATURES if feature in X_train.columns]

    # Redefine NEGONE_FEATURES and MEDIAN_FEATURES with updated values.
    NEGONE_FEATURES = negone_features_filtered
    MEDIAN_FEATURES = median_features_filtered

    print("Filtered NEGONE_FEATURES:", NEGONE_FEATURES)
    print("Filtered MEDIAN_FEATURES:", MEDIAN_FEATURES)

    def generate_preprocessor(numeric_features, categorical_features, N_JOBS, cat_encode_type, 
                                do_specificimpute, do_featureselection, 
                                do_sampling, do_pca, var_thresh, oversample_technique, 
                                negone_features=NEGONE_FEATURES, median_features=MEDIAN_FEATURES,
                                prefix='', do_feature_subset=False, max_features=1, do_removeppi=False, do_removegtex=False):
        cat_encoders = [OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1, encoded_missing_value=-1), 
                        OneHotEncoder(sparse=False, handle_unknown='infrequent_if_exist', min_frequency=10)]
        categorical_transformer = cat_encoders[cat_encode_type]

        numeric_transformer = Pipeline(steps=[
            ('imputer', SimpleImputer(strategy='median')),
            ('scaler', MinMaxScaler(feature_range =(0, 1), clip=True))])

        median_transformer = Pipeline(steps=[
            ('imputer', SimpleImputer(strategy='median')),
            ('scaler', MinMaxScaler(feature_range =(0, 1), clip=True))])

        negone_transformer = Pipeline(steps=[
            ('scaler', MinMaxScaler(feature_range =(0, 1), clip=True)),
            ('imputer', SimpleImputer(strategy='constant', fill_value=-1)),
        ])

        preprocessor = None
        if do_specificimpute:
            preprocessor = ColumnTransformer(
                transformers=[
                    ('median', median_transformer, median_features),
                    ('negone', negone_transformer, negone_features),
                    ('cat', categorical_transformer, categorical_features),
            ])
        else:
            preprocessor = ColumnTransformer(
                transformers=[
                    ('numeric', numeric_transformer, numeric_features),
                    ('cat', categorical_transformer, categorical_features),
                ])

        vt = VarianceThreshold(threshold=var_thresh)
        steps = [('initial', preprocessor), ('removeba', RemoveBeforeAfterTransformer()), ('variance_threshold', vt)]
        if do_sampling == 1:
            steps.append(('undersampling', RandomUnderSampler(random_state=42)))
        if do_sampling == 2:
            oversamplers = [SMOTE(n_jobs=N_JOBS,random_state=42), RandomOverSampler(random_state=42)]
            steps.append(('oversampling', oversamplers[oversample_technique]))
        if do_pca:
            steps.append(('pca', PCA()))

        preprocessor = Pipeline(steps=steps)
        return preprocessor

    class RemoveBeforeAfterTransformer(BaseEstimator, TransformerMixin):
        def __init__(self):
            self.drop_cols = None

        def fit(self, X, y=None):
            """
            This is where the encoded feature numbers are used by the transformer.
            """
            print(X.shape)
            self.drop_cols = [col for col in X.columns if any(f'feature{num}' == col for num in drop_numbers)]
            print(f"Columns to be dropped: {self.drop_cols}")
            return self

        def transform(self, X, y=None):
            print(f"Columns being dropped: {[col for col in self.drop_cols if col in X.columns]}")
            X = X.drop(columns=self.drop_cols, errors='ignore')
            print(X.shape)
            return X

        def get_feature_names_out(self, input_features=None):
            return [f for f in input_features if f not in self.drop_cols]

    def preprocess(preprocessor, train_data, train_labels, quiet=False):
        for k, v in preprocessor.steps:
            print(f"Applying step: {k}")
            print(f"Input shape: {train_data.shape}")
            print(f"Input columns: {train_data.columns}")
            
            if k == 'initial':
                start = time.time()
                v.fit(train_data)
                train_data = pd.DataFrame(v.transform(train_data), columns=v.get_feature_names_out())
                end = time.time()
                if not quiet:
                    print(k + ' took ' + str(end - start) + ' to run.')
            elif k == 'oversampling' or k == 'undersampling':
                start = time.time()
                input_features = train_data.columns
                train_data, train_labels = v.fit_resample(train_data, train_labels)
                train_data = pd.DataFrame(train_data, columns=input_features)
                end = time.time()
                if not quiet:
                    print(k + ' took ' + str(end - start) + ' to run.')
            else:
                start = time.time()
                v.fit(train_data)
                input_features = train_data.columns
                train_data = pd.DataFrame(v.transform(train_data), columns=v.get_feature_names_out(input_features))
                end = time.time()
                if not quiet:
                    print(k + ' took ' + str(end - start) + ' to run.')
            
            print(f"Output shape: {train_data.shape}")
            print(f"Output columns: {train_data.columns}")
            print("---")

        for col in train_data.columns:
            try:
                train_data[col] = train_data[col].astype('float')
            except:
                train_data[col] = train_data[col].astype('category')

        return train_data, train_labels

    def transform(test_data, preprocessor, quiet=False):
        for k, v in preprocessor.steps:
            if k == 'initial':
                test_data = pd.DataFrame(v.transform(test_data), columns=v.get_feature_names_out())
            elif k == 'oversampling' or k == 'undersampling':
                continue
            else:
                test_data = v.transform(test_data)
        test_data = pd.DataFrame(test_data)

        for col in test_data.columns:
            try:
                test_data[col] = test_data[col].astype('float')
            except:
                test_data[col] = test_data[col].astype('category')

        return test_data.to_numpy()

    # Specify the paths for model, results, and metrics.
    model_path = model_directory
    output_path = f'../results/{model_name}-validation.csv'
    metrics_file = f'../metrics/{model_name}-validation-metrics.csv'

    # This is used to drop columns that only contain NaN values.
    def drop_allnan(data):
        for col in data.columns:
            if data[col].isna().sum() == len(data):
                data = data.drop(columns=col)
        return data

    # This encodes the IMPACT feature's column.
    X_train = drop_allnan(X_train)
    feature1_vals = {'LOW': 0, 'MODIFIER': 1, 'MODERATE': 1.5, 'HIGH': 2}
    for col in X_train.columns:
        if X_train[col].dtype == 'object':
            if set(X_train[col].unique()) <= set(feature1_vals.keys()):
                X_train[col] = X_train[col].map(feature1_vals).fillna(0)

    # Conditional imputation based on feature type.
    numeric_features = X_train.select_dtypes(include=['number']).columns
    categorical_features = X_train.select_dtypes(include=['object']).columns

    # Pre-processor generation with multiple parameters that can be tweaked. I used the same values as LoGoFunc
    preprocessor = generate_preprocessor(numeric_features, categorical_features, 40, 0,
                                1, 0, 2, 0, 0, 1,
                                prefix='light0', do_feature_subset=True, max_features=1)

    if isinstance(y_train, list):
        y_train = pd.DataFrame({'label': y_train})

    X_train, y_train = preprocess(preprocessor, X_train, y_train)

    # This creates a directory for the preprocessor and trained models.
    joblib.dump(preprocessor, f'{model_path}/preprocessor.joblib')
    os.makedirs(model_path, exist_ok=True)

    def train_model(params, X_train, y_train):
        """ 
        Train the XGB models.
        """
        model = XGBClassifier(random_state=42, use_label_encoder=False, eval_metric='mlogloss', **params)
        model.fit(X_train, y_train)
        return model

    # Train the ensemble in parallel.
    models = Parallel(n_jobs=-1)(delayed(train_model)(params, X_train, y_train) for params in top_n_params)

    # Export models and params.
    for i, (model, params) in enumerate(zip(models, top_n_params)):
        joblib.dump(model, f'{model_path}/xgb_model_{i}.joblib')
        with open(f'{model_path}/xgb_params_{i}.json', 'w') as f:
            json.dump(params, f, indent=2)

    print(f"Trained {df_name}. {len(models)} models trained so far.")
    print("Finished!")
