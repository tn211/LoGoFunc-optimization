# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os, sys, csv, json, re
from category_encoders import BinaryEncoder
from collections import defaultdict
import joblib

# %% [markdown]
# ### Decoding Features after 12 Algorithms

# %%
df = pd.read_csv('../data/X_train_499.csv')
original_columns = df.columns.tolist()
print(len(original_columns))
print(sorted(original_columns))
# Out:
# 500
# ['1000Gp3_AF', 'A3D_SCORE', 'ACETYLATION', 'AF_Relative_ASA', 'AF_confidence', 'AF_dssp_secondary_structure', 'ANCHOR2', 'ASA', 'ASAquick_normscore_aa', 'ASAquick_normscore_aa_window_15_next', 'ASAquick_normscore_aa_window_15_prev', 'ASAquick_normscore_aa_window_3_next', 'ASAquick_normscore_aa_window_3_prev', 'ASAquick_normscore_aa_window_8_next', 'ASAquick_normscore_aa_window_8_prev', 'ASAquick_rawscore_aa', 'ASAquick_rawscore_aa_window_15_next', 'ASAquick_rawscore_aa_window_15_prev', 'ASAquick_rawscore_aa_window_3_next', 'ASAquick_rawscore_aa_window_3_prev', 'ASAquick_rawscore_aa_window_8_next', 'ASAquick_rawscore_aa_window_8_prev', 'ATP_binding_gbind', 'Acetylation', 'BIOTYPE', 'BLOSUM62', 'C-GLYCOSYLATION', 'CADD_raw', 'CDS_len', 'COSMIC', 'COSMICvsHAPMAP', 'COSMICvsSWISSPROT', 'Ca2+_binding_gbind', 'Charge', 'Clarks_distance', 'Condel_score', 'ConsScore', 'Consequence_first', 'Conservation', 'CpG', 'DFLpredScore_aa', 'DFLpredScore_aa_window_15_next', 'DFLpredScore_aa_window_15_prev', 'DFLpredScore_aa_window_3_next', 'DFLpredScore_aa_window_3_prev', 'DFLpredScore_aa_window_8_next', 'DFLpredScore_aa_window_8_prev', 'DNA_binding_gbind', 'DRNApredDNAscore_aa', 'DRNApredDNAscore_aa_window_15_next', 'DRNApredDNAscore_aa_window_15_prev', 'DRNApredDNAscore_aa_window_3_next', 'DRNApredDNAscore_aa_window_3_prev', 'DRNApredDNAscore_aa_window_8_next', 'DRNApredDNAscore_aa_window_8_prev', 'DRNApredRNAscore_aa', 'DRNApredRNAscore_aa_window_15_next', 'DRNApredRNAscore_aa_window_15_prev', 'DRNApredRNAscore_aa_window_3_next', 'DRNApredRNAscore_aa_window_3_prev', 'DRNApredRNAscore_aa_window_8_next', 'DRNApredRNAscore_aa_window_8_prev', 'DisoDNAscore_aa', 'DisoDNAscore_aa_window_15_next', 'DisoDNAscore_aa_window_15_prev', 'DisoDNAscore_aa_window_3_next', 'DisoDNAscore_aa_window_3_prev', 'DisoDNAscore_aa_window_8_next', 'DisoDNAscore_aa_window_8_prev', 'DisoPROscore_aa', 'DisoPROscore_aa_window_15_next', 'DisoPROscore_aa_window_15_prev', 'DisoPROscore_aa_window_3_next', 'DisoPROscore_aa_window_3_prev', 'DisoPROscore_aa_window_8_next', 'DisoPROscore_aa_window_8_prev', 'DisoRNAscore_aa', 'DisoRNAscore_aa_window_15_next', 'DisoRNAscore_aa_window_15_prev', 'DisoRNAscore_aa_window_3_next', 'DisoRNAscore_aa_window_3_prev', 'DisoRNAscore_aa_window_8_next', 'DisoRNAscore_aa_window_8_prev', 'Dist2Mutation', 'Dominant_probability', 'Dst2SplType', 'Dst2Splice', 'EncodeDNase-max', 'EncodeDNase-sum', 'EncodeH2AFZ-max', 'EncodeH2AFZ-sum', 'EncodeH3K27ac-max', 'EncodeH3K27ac-sum', 'EncodeH3K27me3-max', 'EncodeH3K27me3-sum', 'EncodeH3K36me3-max', 'EncodeH3K36me3-sum', 'EncodeH3K4me1-max', 'EncodeH3K4me1-sum', 'EncodeH3K4me2-max', 'EncodeH3K4me2-sum', 'EncodeH3K4me3-max', 'EncodeH3K4me3-sum', 'EncodeH3K79me2-max', 'EncodeH3K79me2-sum', 'EncodeH3K9ac-max', 'EncodeH3K9ac-sum', 'EncodeH3K9me3-max', 'EncodeH3K9me3-sum', 'EncodeH4K20me1-max', 'EncodeH4K20me1-sum', 'EncodetotalRNA-max', 'EncodetotalRNA-sum', 'EnsembleRegulatoryFeature', 'Ex', 'FATHMM_score', 'Freq10000bp', 'Freq1000bp', 'Freq100bp', 'GC', 'GDI', 'GERPplus_plus_NR', 'GERPplus_plus_RS', 'GM12878_fitCons_score', 'GenoCanyon_score', 'GerpN', 'GerpRS', 'GerpRSpval', 'GerpS', 'Glycosylation', 'Grantham_x', 'H1_hESC_fitCons_score', 'HAPMAP', 'HEME_binding_gbind', 'HGMD2003', 'HUVEC_fitCons_score', 'Hydrophobicity', 'ID', 'IMPACT', 'INTERACTION_REGION', 'IUPRED2', 'Indispensability_score', 'JM', 'LINSIGHT', 'LIST_S2_score', 'LRT_score', 'METHYLATION', 'MMSp_acceptor', 'MMSp_acceptorIntron', 'MMSp_donor', 'MMSp_donorIntron', 'MMSp_exon', 'MMseq2_conservation_level_aa', 'MMseq2_conservation_level_aa_window_15_next', 'MMseq2_conservation_level_aa_window_15_prev', 'MMseq2_conservation_level_aa_window_3_next', 'MMseq2_conservation_level_aa_window_3_prev', 'MMseq2_conservation_level_aa_window_8_next', 'MMseq2_conservation_level_aa_window_8_prev', 'MMseq2_conservation_score_aa', 'MMseq2_conservation_score_aa_window_15_next', 'MMseq2_conservation_score_aa_window_15_prev', 'MMseq2_conservation_score_aa_window_3_ne ...

# %%
first_ranks = pd.read_csv('feature_ranks.csv')

# %%
encoded_dict = {rank + 1: feature for rank, feature in enumerate(first_ranks['Feature'])}
print(encoded_dict)
# Out:
# {1: 'Consequence_first_0', 2: 'IMPACT_HIGH', 3: 'ConsScore', 4: 'VEST4_score', 5: 'verPhyloP', 6: 'gnomAD_exomes_AF', 7: 'IMPACT_LOW', 8: 'verPhCons', 9: 'IMPACT_MODIFIER', 10: 'mamPhyloP', 11: 'mamPhCons', 12: 'Dominant_probability', 13: 'phyloP100way_vertebrate', 14: 'M_CAP_score', 15: 'Consequence_first_4', 16: 'fathmm_MKL_coding_score', 17: 'GerpS', 18: 'MPC_score', 19: 'cHmm_E15', 20: 'cHmm_E4', 21: 'IMPACT_MODERATE', 22: 'after_IUPRED_8', 23: 'priPhCons', 24: 'denovo_Zscore', 25: 'Condel_score', 26: 'MVP_score', 27: 'after_IUPRED_15', 28: 'phastCons100way_vertebrate', 29: 'Recessive_probability', 30: 'MutationTaster_score', 31: 'Number_of_paralogs', 32: 'dbscSNV-rf_score', 33: 'BIOTYPE_protein_coding', 34: 'cHmm_E7', 35: 'UK10K_AF', 36: 'before_ANCHOR_15', 37: 'Rare10000bp', 38: 'AF_confidence', 39: 'ANCHOR2', 40: 'SpliceAI-don-loss', 41: 'EncodeH3K36me3-sum', 42: 'FATHMM_score', 43: 'EncodeDNase-sum', 44: 'CADD_raw', 45: 'GerpN', 46: 'before_IUPRED_3', 47: 'BIOTYPE_nonsense_mediated_decay', 48: 'phastCons17way_primate', 49: 'cHmm_E8', 50: 'fathmm_XF_coding_score', 51: '1000Gp3_AF', 52: 'LIST_S2_score', 53: 'before_ASA_15', 54: 'Consequence_first_3', 55: 'MutationAssessor_score', 56: 'before_RSA_8', 57: 'gtex_Small_Intestine_-_Terminal_Ileum', 58: 'MSC_95CI', 59: 'EncodeH4K20me1-max', 60: 's_het', 61: 'hgmd_mutcount', 62: 'gnom_mutcount', 63: 'EncodeH3K9me3-max', 64: 'gtex_Colon_-_Transverse', 65: 'after_RSA_8', 66: 'before_ASA_8', 67: 'PROVEAN_score', 68: 'EncodeH3K4me3-max', 69: 'SpliceAI-acc-loss', 70: 'EncodeH2AFZ-sum', 71: 'EncodeH3K36me3-max', 72: 'GC', 73: 'before_RSA_15', 74: 'after_ANCHOR_8', 75: 'gtex_Spleen', 76: 'after_ANCHOR_3', 77: 'cHmm_E20', 78: 'ASA', 79: 'gtex_Esophagus_-_Mucosa', 80: 'dbscSNV-ada_score', 81: 'ppi_combined_47', 82: 'gtex_Brain_-_Putamen_(basal_ganglia)', 83: 'num_interactions', 84: 'after_ASA_8', 85: 'MoRFchibiScore_aa_window_8_next', 86: 'EncodeH3K4me2-max', 87: 'GerpRS', 88: 'after_IUPRED_3', 89: 'gtex_Cells_-_EBV-transformed_lymphocytes', 90: 'Conservation', 91: 'ppi_combined_20', 92: 'ASAquick_rawscore_aa_window_15_prev', 93: 'GERPplus_plus_NR', 94: 'cHmm_E3', 95: 'gnomAD_genomes_AF', 96: 'RSA', 97: 'Clarks_distance', 98: 'after_RSA_15', 99: 'ASAquick_normscore_aa_window_15_prev', 100: 'gtex_Brain_-_Hippocampus', 101: 'S_DDG[SEQ]', 102: 'before_IUPRED_8', 103: 'EncodetotalRNA-sum', 104: 'SpliceAI-don-gain', 105: 'before_ANCHOR_8', 106: 'Indispensability_score', 107: 'cHmm_E2', 108: 'minDistTSE', 109: 'gtex_Brain_-_Cortex', 110: 'EncodeDNase-max', 111: 'gtex_Colon_-_Sigmoid', 112: 'cHmm_E21', 113: 'gtex_Brain_-_Anterior_cingulate_cortex_(BA24)', 114: 'EncodeH3K79me2-sum', 115: 'MoRFchibiScore_aa_window_15_next', 116: 'ppi_combined_12', 117: 'RVIS', 118: 'gtex_Brain_-_Nucleus_accumbens_(basal_ganglia)', 119: 'gtex_Bladder', 120: 'gtex_Brain_-_Frontal_Cortex_(BA9)', 121: 'after_ASA_15', 122: 'EncodeH3K27me3-sum', 123: 'Sngl10000bp', 124: 'gtex_Artery_-_Aorta', 125: 'polyphen_score1', 126: 'rf_score', 127: 'EncodeH3K4me1-sum', 128: 'cHmm_E22', 129: 'before_ANCHOR_3', 130: 'gtex_Uterus', 131: 'DisoPROscore_aa_window_8_prev', 132: 'gtex_Kidney_-_Cortex', 133: 'ppi_combined_63', 134: 'gtex_Skin_-_Sun_Exposed_(Lower_leg)', 135: 'cHmm_E16', 136: 'SiPhy_29way_logOdds', 137: 'bStatistic_y', 138: 'IUPRED2', 139: 'gtex_Vagina', 140: 'AF_Relative_ASA', 141: 'cHmm_E9', 142: 'after_RSA_3', 143: 'cHmm_E17', 144: 'MoRFchibiScore_aa_window_3_next', 145: 'before_ASA_3', 146: 'ppi_combined_22', 147: 'n_contacts', 148: 'gtex_Brain_-_Amygdala', 149: 'gtex_Cells_-_Cultured_fibroblasts', 150: 'SIFT_score', 151: 'after_ASA_3', 152: 'gtex_Minor_Salivary_Gland', 153: 'gtex_Brain_-_Caudate_(basal_ganglia)', 154: 'ppi_combined_51', 155: 'gtex_Skin_-_Not_Sun_Exposed_(Suprapubic)', 156: 'EncodeH3K9ac-sum', 157: 'Freq10000bp', 158: 'ASAquick_rawscore_aa', 159: 'Consequence_first_2', 160: 'EncodeH3K4me1-max', 161: 'EncodeH3K4me3-sum', 162: 'ppi_combined_28', 163: 'MaxEntScan_diff', 164: 'gtex_Brain_-_Cerebellar_Hemi ...

# %%
encoded_dict = {value: key for key, value in encoded_dict.items()}
print(encoded_dict)
# Out:
# {'Consequence_first_0': 1, 'IMPACT_HIGH': 2, 'ConsScore': 3, 'VEST4_score': 4, 'verPhyloP': 5, 'gnomAD_exomes_AF': 6, 'IMPACT_LOW': 7, 'verPhCons': 8, 'IMPACT_MODIFIER': 9, 'mamPhyloP': 10, 'mamPhCons': 11, 'Dominant_probability': 12, 'phyloP100way_vertebrate': 13, 'M_CAP_score': 14, 'Consequence_first_4': 15, 'fathmm_MKL_coding_score': 16, 'GerpS': 17, 'MPC_score': 18, 'cHmm_E15': 19, 'cHmm_E4': 20, 'IMPACT_MODERATE': 21, 'after_IUPRED_8': 22, 'priPhCons': 23, 'denovo_Zscore': 24, 'Condel_score': 25, 'MVP_score': 26, 'after_IUPRED_15': 27, 'phastCons100way_vertebrate': 28, 'Recessive_probability': 29, 'MutationTaster_score': 30, 'Number_of_paralogs': 31, 'dbscSNV-rf_score': 32, 'BIOTYPE_protein_coding': 33, 'cHmm_E7': 34, 'UK10K_AF': 35, 'before_ANCHOR_15': 36, 'Rare10000bp': 37, 'AF_confidence': 38, 'ANCHOR2': 39, 'SpliceAI-don-loss': 40, 'EncodeH3K36me3-sum': 41, 'FATHMM_score': 42, 'EncodeDNase-sum': 43, 'CADD_raw': 44, 'GerpN': 45, 'before_IUPRED_3': 46, 'BIOTYPE_nonsense_mediated_decay': 47, 'phastCons17way_primate': 48, 'cHmm_E8': 49, 'fathmm_XF_coding_score': 50, '1000Gp3_AF': 51, 'LIST_S2_score': 52, 'before_ASA_15': 53, 'Consequence_first_3': 54, 'MutationAssessor_score': 55, 'before_RSA_8': 56, 'gtex_Small_Intestine_-_Terminal_Ileum': 57, 'MSC_95CI': 58, 'EncodeH4K20me1-max': 59, 's_het': 60, 'hgmd_mutcount': 61, 'gnom_mutcount': 62, 'EncodeH3K9me3-max': 63, 'gtex_Colon_-_Transverse': 64, 'after_RSA_8': 65, 'before_ASA_8': 66, 'PROVEAN_score': 67, 'EncodeH3K4me3-max': 68, 'SpliceAI-acc-loss': 69, 'EncodeH2AFZ-sum': 70, 'EncodeH3K36me3-max': 71, 'GC': 72, 'before_RSA_15': 73, 'after_ANCHOR_8': 74, 'gtex_Spleen': 75, 'after_ANCHOR_3': 76, 'cHmm_E20': 77, 'ASA': 78, 'gtex_Esophagus_-_Mucosa': 79, 'dbscSNV-ada_score': 80, 'ppi_combined_47': 81, 'gtex_Brain_-_Putamen_(basal_ganglia)': 82, 'num_interactions': 83, 'after_ASA_8': 84, 'MoRFchibiScore_aa_window_8_next': 85, 'EncodeH3K4me2-max': 86, 'GerpRS': 87, 'after_IUPRED_3': 88, 'gtex_Cells_-_EBV-transformed_lymphocytes': 89, 'Conservation': 90, 'ppi_combined_20': 91, 'ASAquick_rawscore_aa_window_15_prev': 92, 'GERPplus_plus_NR': 93, 'cHmm_E3': 94, 'gnomAD_genomes_AF': 95, 'RSA': 96, 'Clarks_distance': 97, 'after_RSA_15': 98, 'ASAquick_normscore_aa_window_15_prev': 99, 'gtex_Brain_-_Hippocampus': 100, 'S_DDG[SEQ]': 101, 'before_IUPRED_8': 102, 'EncodetotalRNA-sum': 103, 'SpliceAI-don-gain': 104, 'before_ANCHOR_8': 105, 'Indispensability_score': 106, 'cHmm_E2': 107, 'minDistTSE': 108, 'gtex_Brain_-_Cortex': 109, 'EncodeDNase-max': 110, 'gtex_Colon_-_Sigmoid': 111, 'cHmm_E21': 112, 'gtex_Brain_-_Anterior_cingulate_cortex_(BA24)': 113, 'EncodeH3K79me2-sum': 114, 'MoRFchibiScore_aa_window_15_next': 115, 'ppi_combined_12': 116, 'RVIS': 117, 'gtex_Brain_-_Nucleus_accumbens_(basal_ganglia)': 118, 'gtex_Bladder': 119, 'gtex_Brain_-_Frontal_Cortex_(BA9)': 120, 'after_ASA_15': 121, 'EncodeH3K27me3-sum': 122, 'Sngl10000bp': 123, 'gtex_Artery_-_Aorta': 124, 'polyphen_score1': 125, 'rf_score': 126, 'EncodeH3K4me1-sum': 127, 'cHmm_E22': 128, 'before_ANCHOR_3': 129, 'gtex_Uterus': 130, 'DisoPROscore_aa_window_8_prev': 131, 'gtex_Kidney_-_Cortex': 132, 'ppi_combined_63': 133, 'gtex_Skin_-_Sun_Exposed_(Lower_leg)': 134, 'cHmm_E16': 135, 'SiPhy_29way_logOdds': 136, 'bStatistic_y': 137, 'IUPRED2': 138, 'gtex_Vagina': 139, 'AF_Relative_ASA': 140, 'cHmm_E9': 141, 'after_RSA_3': 142, 'cHmm_E17': 143, 'MoRFchibiScore_aa_window_3_next': 144, 'before_ASA_3': 145, 'ppi_combined_22': 146, 'n_contacts': 147, 'gtex_Brain_-_Amygdala': 148, 'gtex_Cells_-_Cultured_fibroblasts': 149, 'SIFT_score': 150, 'after_ASA_3': 151, 'gtex_Minor_Salivary_Gland': 152, 'gtex_Brain_-_Caudate_(basal_ganglia)': 153, 'ppi_combined_51': 154, 'gtex_Skin_-_Not_Sun_Exposed_(Suprapubic)': 155, 'EncodeH3K9ac-sum': 156, 'Freq10000bp': 157, 'ASAquick_rawscore_aa': 158, 'Consequence_first_2': 159, 'EncodeH3K4me1-max': 160, 'EncodeH3K4me3-sum': 161, 'ppi_combined_28': 162, 'MaxEntScan_diff': 163, 'gtex_Brain_-_Cerebellar_Hemispher ...

# %%
with open('decoding_template.json', 'r') as file:
    loo_dict = json.load(file)
print(loo_dict)
# Out:
# {'1': 'gnomAD_exomes_AF', '2': 'before_ANCHOR_15', '3': 'Recessive_probability', '4': 'MMSp_acceptorIntron', '5': 'Dist2Mutation', '6': 'TSSDistance', '7': 'before_ANCHOR_3', '8': 'REQUIRED_FOR_INTER', '9': 'after_ANCHOR_8', '10': 'before_RSA_3', '11': 'cHmm_E14', '12': 'before_ASA_3', '13': 'before_ASA_8', '14': 'Mn2+_binding_gbind', '15': 'distance_com', '16': 'after_ANCHOR_3', '17': 'after_IUPRED_15', '18': 'before_IUPRED_8', '19': 'gnomAD_genomes_AF', '20': 'before_ASA_15', '21': 'RNA_binding_gbind', '22': 'A3D_SCORE', '23': 'Rare100bp', '24': 'REGION', '25': 'ATP_binding_gbind', '26': 'PTM', '27': 'DNA_binding_gbind', '28': 'after_RSA_15', '29': 'after_RSA_8', '30': 'UK10K_AF', '31': 'VEST4_score', '32': 'MMSp_exon', '33': 'MMSp_donor', '34': 'IUPRED2', '35': 'before_IUPRED_3', '36': 'SpliceAI-don-gain', '37': 'ppi_combined_22', '38': 'RVIS', '39': 'RSA_Zfit', '40': 'DisoRNAscore_aa_window_8_next', '41': 'BLOSUM62', '42': 'after_ASA_15', '43': 'Consequence_first', '44': 'SpliceAI-don-loss', '45': 'before_ANCHOR_8', '46': 'Glycosylation', '47': 'Ubiquitination', '48': 'ppi_combined_13', '49': 'cHmm_E11', '50': 'cHmm_E24', '51': 'cHmm_E23', '52': 'concavity_score', '53': 'cHmm_E15', '54': 'after_ANCHOR_15', '55': 'cHmm_E22', '56': 'cHmm_E25', '57': 'ppi_combined_34', '58': '1000Gp3_AF', '59': 'verPhyloP', '60': 'cHmm_E20', '61': 'STABILITY[SEQ]', '62': 'tOverlapMotifs', '63': 'Methylation', '64': 'ppi_combined_9', '65': 'n_contacts', '66': 'Mg2+_binding_gbind', '67': 'DRNApredDNAscore_aa_window_15_prev', '68': 'ppi_combined_20', '69': 'ppi_combined_31', '70': 'num_interactions', '71': 'ppi_combined_7', '72': 'before_IUPRED_15', '73': 'ppi_combined_23', '74': 'ppi_combined_18', '75': 'ppi_combined_50', '76': 'AF_confidence', '77': 'MMseq2_conservation_level_aa_window_3_next', '78': 'cHmm_E6', '79': 'cHmm_E9', '80': 'Acetylation', '81': 'MMSp_acceptor', '82': 'MMSp_donorIntron', '83': 'dbscSNV-ada_score', '84': 'gtex_Bladder', '85': 'dbscSNV-rf_score', '86': 'MMseq2_conservation_level_aa_window_15_prev', '87': 'DisoRNAscore_aa_window_8_prev', '88': 'INTERACTION_REGION', '89': 'after_ASA_8', '90': 'Ca2+_binding_gbind', '91': 'ppi_combined_1', '92': 'cHmm_E19', '93': 'MOD_RES', '94': 'ppi_combined_8', '95': 'GerpN', '96': 'ppi_combined_11', '97': 'SpliceAI-acc-gain', '98': 'EncodeH3K4me1-sum', '99': 'ppi_combined_6', '100': 'DRNApredRNAscore_aa_window_8_next', '101': 'cHmm_E18', '102': 'cHmm_E4', '103': 'mirSVR-E', '104': 'motifEScoreChng', '105': 'gtex_Prostate', '106': 'gtex_Brain_-_Hypothalamus', '107': 'SignalP_score_aa_window_15_next', '108': 'PSIPRED_strand_aa_window_3_prev', '109': 'MMseq2_conservation_score_aa_window_3_prev', '110': 'ppi_combined_27', '111': 'DisoDNAscore_aa', '112': 'DRNApredDNAscore_aa', '113': 'ASAquick_rawscore_aa_window_3_prev', '114': 'cHmm_E21', '115': 'ppi_combined_5', '116': 'IMPACT', '117': 'CDS_len', '118': 'Number_of_paralogs', '119': 'isHomomultimer', '120': 'after_IUPRED_3', '121': 'after_IUPRED_8', '122': 'before_RSA_8', '123': 'ASA', '124': 'AF_Relative_ASA', '125': 'mirSVR-Score', '126': 'Selective_pressure', '127': 'DRNApredDNAscore_aa_window_8_prev', '128': 'motifDist', '129': 'SpliceAI-acc-loss', '130': 'Phosphorylation', '131': 'Indispensability_score', '132': 'gtex_Fallopian_Tube', '133': 'ppi_combined_47', '134': 'ppi_combined_48', '135': 'cHmm_E16', '136': 'ppi_combined_3', '137': 'cHmm_E2', '138': 'cHmm_E1', '139': 'gtex_Colon_-_Transverse', '140': 'gtex_Nerve_-_Tibial', '141': 'LINSIGHT', '142': 'MMseq2_conservation_level_aa_window_8_next', '143': 'SignalP_score_aa_window_3_prev', '144': 'ppi_combined_2', '145': 'ppi_combined_0', '146': 'cHmm_E5', '147': 'ASAquick_normscore_aa_window_3_next', '148': 'gtex_Brain_-_Spinal_cord_(cervical_c-1)', '149': 'HEME_binding_gbind', '150': 'ProteinLengthChange', '151': 'ppi_combined_14', '152': 'gtex_Small_Intestine_-_Terminal_Ileum', '153': 'ppi_combined_29', '154': 'ppi_combined_16', '155': 'bStatistic_y', '156': 'targetScan', '157': 'PSI ...

# %%
inverted_dict = {value: key for key, value in loo_dict.items()}
print(inverted_dict)
# Out:
# {'gnomAD_exomes_AF': '1', 'before_ANCHOR_15': '2', 'Recessive_probability': '3', 'MMSp_acceptorIntron': '4', 'Dist2Mutation': '5', 'TSSDistance': '6', 'before_ANCHOR_3': '7', 'REQUIRED_FOR_INTER': '8', 'after_ANCHOR_8': '9', 'before_RSA_3': '10', 'cHmm_E14': '11', 'before_ASA_3': '12', 'before_ASA_8': '13', 'Mn2+_binding_gbind': '14', 'distance_com': '15', 'after_ANCHOR_3': '16', 'after_IUPRED_15': '17', 'before_IUPRED_8': '18', 'gnomAD_genomes_AF': '19', 'before_ASA_15': '20', 'RNA_binding_gbind': '21', 'A3D_SCORE': '22', 'Rare100bp': '23', 'REGION': '24', 'ATP_binding_gbind': '25', 'PTM': '26', 'DNA_binding_gbind': '27', 'after_RSA_15': '28', 'after_RSA_8': '29', 'UK10K_AF': '30', 'VEST4_score': '31', 'MMSp_exon': '32', 'MMSp_donor': '33', 'IUPRED2': '34', 'before_IUPRED_3': '35', 'SpliceAI-don-gain': '36', 'ppi_combined_22': '37', 'RVIS': '38', 'RSA_Zfit': '39', 'DisoRNAscore_aa_window_8_next': '40', 'BLOSUM62': '41', 'after_ASA_15': '42', 'Consequence_first': '43', 'SpliceAI-don-loss': '44', 'before_ANCHOR_8': '45', 'Glycosylation': '46', 'Ubiquitination': '47', 'ppi_combined_13': '48', 'cHmm_E11': '49', 'cHmm_E24': '50', 'cHmm_E23': '51', 'concavity_score': '52', 'cHmm_E15': '53', 'after_ANCHOR_15': '54', 'cHmm_E22': '55', 'cHmm_E25': '56', 'ppi_combined_34': '57', '1000Gp3_AF': '58', 'verPhyloP': '59', 'cHmm_E20': '60', 'STABILITY[SEQ]': '61', 'tOverlapMotifs': '62', 'Methylation': '63', 'ppi_combined_9': '64', 'n_contacts': '65', 'Mg2+_binding_gbind': '66', 'DRNApredDNAscore_aa_window_15_prev': '67', 'ppi_combined_20': '68', 'ppi_combined_31': '69', 'num_interactions': '70', 'ppi_combined_7': '71', 'before_IUPRED_15': '72', 'ppi_combined_23': '73', 'ppi_combined_18': '74', 'ppi_combined_50': '75', 'AF_confidence': '76', 'MMseq2_conservation_level_aa_window_3_next': '77', 'cHmm_E6': '78', 'cHmm_E9': '79', 'Acetylation': '80', 'MMSp_acceptor': '81', 'MMSp_donorIntron': '82', 'dbscSNV-ada_score': '83', 'gtex_Bladder': '84', 'dbscSNV-rf_score': '85', 'MMseq2_conservation_level_aa_window_15_prev': '86', 'DisoRNAscore_aa_window_8_prev': '87', 'INTERACTION_REGION': '88', 'after_ASA_8': '89', 'Ca2+_binding_gbind': '90', 'ppi_combined_1': '91', 'cHmm_E19': '92', 'MOD_RES': '93', 'ppi_combined_8': '94', 'GerpN': '95', 'ppi_combined_11': '96', 'SpliceAI-acc-gain': '97', 'EncodeH3K4me1-sum': '98', 'ppi_combined_6': '99', 'DRNApredRNAscore_aa_window_8_next': '100', 'cHmm_E18': '101', 'cHmm_E4': '102', 'mirSVR-E': '103', 'motifEScoreChng': '104', 'gtex_Prostate': '105', 'gtex_Brain_-_Hypothalamus': '106', 'SignalP_score_aa_window_15_next': '107', 'PSIPRED_strand_aa_window_3_prev': '108', 'MMseq2_conservation_score_aa_window_3_prev': '109', 'ppi_combined_27': '110', 'DisoDNAscore_aa': '111', 'DRNApredDNAscore_aa': '112', 'ASAquick_rawscore_aa_window_3_prev': '113', 'cHmm_E21': '114', 'ppi_combined_5': '115', 'IMPACT': '116', 'CDS_len': '117', 'Number_of_paralogs': '118', 'isHomomultimer': '119', 'after_IUPRED_3': '120', 'after_IUPRED_8': '121', 'before_RSA_8': '122', 'ASA': '123', 'AF_Relative_ASA': '124', 'mirSVR-Score': '125', 'Selective_pressure': '126', 'DRNApredDNAscore_aa_window_8_prev': '127', 'motifDist': '128', 'SpliceAI-acc-loss': '129', 'Phosphorylation': '130', 'Indispensability_score': '131', 'gtex_Fallopian_Tube': '132', 'ppi_combined_47': '133', 'ppi_combined_48': '134', 'cHmm_E16': '135', 'ppi_combined_3': '136', 'cHmm_E2': '137', 'cHmm_E1': '138', 'gtex_Colon_-_Transverse': '139', 'gtex_Nerve_-_Tibial': '140', 'LINSIGHT': '141', 'MMseq2_conservation_level_aa_window_8_next': '142', 'SignalP_score_aa_window_3_prev': '143', 'ppi_combined_2': '144', 'ppi_combined_0': '145', 'cHmm_E5': '146', 'ASAquick_normscore_aa_window_3_next': '147', 'gtex_Brain_-_Spinal_cord_(cervical_c-1)': '148', 'HEME_binding_gbind': '149', 'ProteinLengthChange': '150', 'ppi_combined_14': '151', 'gtex_Small_Intestine_-_Terminal_Ileum': '152', 'ppi_combined_29': '153', 'ppi_combined_16': '154', 'bStatistic_y': '155', 'targetScan': '156', 'PSIPRED_he ...

# %%
inverted_dict = dict(sorted(inverted_dict.items()))
print(inverted_dict)
# Out:
# {'1000Gp3_AF': '58', 'A3D_SCORE': '22', 'ACETYLATION': '456', 'AF_Relative_ASA': '124', 'AF_confidence': '76', 'AF_dssp_secondary_structure': '372', 'ANCHOR2': '194', 'ASA': '123', 'ASAquick_normscore_aa': '424', 'ASAquick_normscore_aa_window_15_next': '351', 'ASAquick_normscore_aa_window_15_prev': '277', 'ASAquick_normscore_aa_window_3_next': '147', 'ASAquick_normscore_aa_window_3_prev': '198', 'ASAquick_normscore_aa_window_8_next': '195', 'ASAquick_normscore_aa_window_8_prev': '279', 'ASAquick_rawscore_aa': '297', 'ASAquick_rawscore_aa_window_15_next': '430', 'ASAquick_rawscore_aa_window_15_prev': '236', 'ASAquick_rawscore_aa_window_3_next': '169', 'ASAquick_rawscore_aa_window_3_prev': '113', 'ASAquick_rawscore_aa_window_8_next': '237', 'ASAquick_rawscore_aa_window_8_prev': '394', 'ATP_binding_gbind': '25', 'Acetylation': '80', 'BIOTYPE': '477', 'BLOSUM62': '41', 'C-GLYCOSYLATION': '322', 'CADD_raw': '440', 'CDS_len': '117', 'COSMIC': '221', 'COSMICvsHAPMAP': '321', 'COSMICvsSWISSPROT': '222', 'Ca2+_binding_gbind': '90', 'Charge': '323', 'Clarks_distance': '480', 'Condel_score': '465', 'ConsScore': '405', 'Consequence_first': '43', 'Conservation': '441', 'CpG': '233', 'DFLpredScore_aa': '380', 'DFLpredScore_aa_window_15_next': '299', 'DFLpredScore_aa_window_15_prev': '302', 'DFLpredScore_aa_window_3_next': '242', 'DFLpredScore_aa_window_3_prev': '435', 'DFLpredScore_aa_window_8_next': '354', 'DFLpredScore_aa_window_8_prev': '166', 'DNA_binding_gbind': '27', 'DRNApredDNAscore_aa': '112', 'DRNApredDNAscore_aa_window_15_next': '205', 'DRNApredDNAscore_aa_window_15_prev': '67', 'DRNApredDNAscore_aa_window_3_next': '244', 'DRNApredDNAscore_aa_window_3_prev': '365', 'DRNApredDNAscore_aa_window_8_next': '347', 'DRNApredDNAscore_aa_window_8_prev': '127', 'DRNApredRNAscore_aa': '382', 'DRNApredRNAscore_aa_window_15_next': '167', 'DRNApredRNAscore_aa_window_15_prev': '446', 'DRNApredRNAscore_aa_window_3_next': '344', 'DRNApredRNAscore_aa_window_3_prev': '488', 'DRNApredRNAscore_aa_window_8_next': '100', 'DRNApredRNAscore_aa_window_8_prev': '355', 'DisoDNAscore_aa': '111', 'DisoDNAscore_aa_window_15_next': '305', 'DisoDNAscore_aa_window_15_prev': '444', 'DisoDNAscore_aa_window_3_next': '164', 'DisoDNAscore_aa_window_3_prev': '307', 'DisoDNAscore_aa_window_8_next': '360', 'DisoDNAscore_aa_window_8_prev': '491', 'DisoPROscore_aa': '189', 'DisoPROscore_aa_window_15_next': '301', 'DisoPROscore_aa_window_15_prev': '384', 'DisoPROscore_aa_window_3_next': '362', 'DisoPROscore_aa_window_3_prev': '381', 'DisoPROscore_aa_window_8_next': '439', 'DisoPROscore_aa_window_8_prev': '304', 'DisoRNAscore_aa': '234', 'DisoRNAscore_aa_window_15_next': '235', 'DisoRNAscore_aa_window_15_prev': '275', 'DisoRNAscore_aa_window_3_next': '256', 'DisoRNAscore_aa_window_3_prev': '438', 'DisoRNAscore_aa_window_8_next': '40', 'DisoRNAscore_aa_window_8_prev': '87', 'Dist2Mutation': '5', 'Dominant_probability': '478', 'Dst2SplType': '412', 'Dst2Splice': '338', 'EncodeDNase-max': '280', 'EncodeDNase-sum': '334', 'EncodeH2AFZ-max': '495', 'EncodeH2AFZ-sum': '427', 'EncodeH3K27ac-max': '481', 'EncodeH3K27ac-sum': '403', 'EncodeH3K27me3-max': '393', 'EncodeH3K27me3-sum': '392', 'EncodeH3K36me3-max': '165', 'EncodeH3K36me3-sum': '239', 'EncodeH3K4me1-max': '496', 'EncodeH3K4me1-sum': '98', 'EncodeH3K4me2-max': '331', 'EncodeH3K4me2-sum': '497', 'EncodeH3K4me3-max': '333', 'EncodeH3K4me3-sum': '332', 'EncodeH3K79me2-max': '395', 'EncodeH3K79me2-sum': '186', 'EncodeH3K9ac-max': '243', 'EncodeH3K9ac-sum': '474', 'EncodeH3K9me3-max': '390', 'EncodeH3K9me3-sum': '389', 'EncodeH4K20me1-max': '298', 'EncodeH4K20me1-sum': '191', 'EncodetotalRNA-max': '158', 'EncodetotalRNA-sum': '431', 'EnsembleRegulatoryFeature': '423', 'Ex': '490', 'FATHMM_score': '214', 'Freq10000bp': '391', 'Freq1000bp': '486', 'Freq100bp': '288', 'GC': '426', 'GDI': '262', 'GERPplus_plus_NR': '337', 'GERPplus_plus_RS': '401', 'GM12878_fitCons_score': '493', 'GenoCanyon_score': '473', 'GerpN': '95', 'GerpRS':  ...

# %%
encoded_dict = dict(sorted(encoded_dict.items()))
print(encoded_dict)
# Out:
# {'1000Gp3_AF': 51, 'A3D_SCORE': 418, 'ACETYLATION': 523, 'AF_Relative_ASA': 140, 'AF_confidence': 38, 'AF_dssp_secondary_structure_-': 464, 'AF_dssp_secondary_structure_B': 528, 'AF_dssp_secondary_structure_E': 439, 'AF_dssp_secondary_structure_G': 527, 'AF_dssp_secondary_structure_H': 453, 'AF_dssp_secondary_structure_I': 533, 'AF_dssp_secondary_structure_S': 505, 'AF_dssp_secondary_structure_T': 497, 'ANCHOR2': 39, 'ASA': 78, 'ASAquick_normscore_aa': 279, 'ASAquick_normscore_aa_window_15_next': 271, 'ASAquick_normscore_aa_window_15_prev': 99, 'ASAquick_normscore_aa_window_3_next': 373, 'ASAquick_normscore_aa_window_3_prev': 291, 'ASAquick_normscore_aa_window_8_next': 362, 'ASAquick_normscore_aa_window_8_prev': 252, 'ASAquick_rawscore_aa': 158, 'ASAquick_rawscore_aa_window_15_next': 238, 'ASAquick_rawscore_aa_window_15_prev': 92, 'ASAquick_rawscore_aa_window_3_next': 310, 'ASAquick_rawscore_aa_window_3_prev': 343, 'ASAquick_rawscore_aa_window_8_next': 451, 'ASAquick_rawscore_aa_window_8_prev': 398, 'ATP_binding_gbind': 490, 'Acetylation': 508, 'BIOTYPE_lncRNA': 342, 'BIOTYPE_nonsense_mediated_decay': 47, 'BIOTYPE_promoter_flanking_region': 446, 'BIOTYPE_protein_coding': 33, 'BIOTYPE_unprocessed_pseudogene': 447, 'BLOSUM62': 479, 'C-GLYCOSYLATION': 536, 'CADD_raw': 44, 'CDS_len': 199, 'COSMIC': 274, 'COSMICvsHAPMAP': 240, 'COSMICvsSWISSPROT': 436, 'Ca2+_binding_gbind': 434, 'Charge': 340, 'Clarks_distance': 97, 'Condel_score': 25, 'ConsScore': 3, 'Consequence_first_0': 1, 'Consequence_first_1': 286, 'Consequence_first_2': 159, 'Consequence_first_3': 54, 'Consequence_first_4': 15, 'Conservation': 90, 'CpG': 317, 'DFLpredScore_aa': 494, 'DFLpredScore_aa_window_15_next': 259, 'DFLpredScore_aa_window_15_prev': 331, 'DFLpredScore_aa_window_3_next': 391, 'DFLpredScore_aa_window_3_prev': 181, 'DFLpredScore_aa_window_8_next': 308, 'DFLpredScore_aa_window_8_prev': 359, 'DNA_binding_gbind': 385, 'DRNApredDNAscore_aa': 399, 'DRNApredDNAscore_aa_window_15_next': 366, 'DRNApredDNAscore_aa_window_15_prev': 432, 'DRNApredDNAscore_aa_window_3_next': 290, 'DRNApredDNAscore_aa_window_3_prev': 426, 'DRNApredDNAscore_aa_window_8_next': 348, 'DRNApredDNAscore_aa_window_8_prev': 388, 'DRNApredRNAscore_aa': 443, 'DRNApredRNAscore_aa_window_15_next': 380, 'DRNApredRNAscore_aa_window_15_prev': 201, 'DRNApredRNAscore_aa_window_3_next': 204, 'DRNApredRNAscore_aa_window_3_prev': 207, 'DRNApredRNAscore_aa_window_8_next': 225, 'DRNApredRNAscore_aa_window_8_prev': 171, 'DisoDNAscore_aa': 449, 'DisoDNAscore_aa_window_15_next': 319, 'DisoDNAscore_aa_window_15_prev': 386, 'DisoDNAscore_aa_window_3_next': 406, 'DisoDNAscore_aa_window_3_prev': 349, 'DisoDNAscore_aa_window_8_next': 188, 'DisoDNAscore_aa_window_8_prev': 402, 'DisoPROscore_aa': 424, 'DisoPROscore_aa_window_15_next': 326, 'DisoPROscore_aa_window_15_prev': 191, 'DisoPROscore_aa_window_3_next': 298, 'DisoPROscore_aa_window_3_prev': 220, 'DisoPROscore_aa_window_8_next': 292, 'DisoPROscore_aa_window_8_prev': 131, 'DisoRNAscore_aa': 370, 'DisoRNAscore_aa_window_15_next': 184, 'DisoRNAscore_aa_window_15_prev': 477, 'DisoRNAscore_aa_window_3_next': 318, 'DisoRNAscore_aa_window_3_prev': 244, 'DisoRNAscore_aa_window_8_next': 255, 'DisoRNAscore_aa_window_8_prev': 289, 'Dist2Mutation': 265, 'Dominant_probability': 12, 'Dst2SplType_ACCEPTOR': 499, 'Dst2SplType_DONOR': 429, 'Dst2Splice': 461, 'EncodeDNase-max': 110, 'EncodeDNase-sum': 43, 'EncodeH2AFZ-max': 241, 'EncodeH2AFZ-sum': 70, 'EncodeH3K27ac-max': 183, 'EncodeH3K27ac-sum': 288, 'EncodeH3K27me3-max': 276, 'EncodeH3K27me3-sum': 122, 'EncodeH3K36me3-max': 71, 'EncodeH3K36me3-sum': 41, 'EncodeH3K4me1-max': 160, 'EncodeH3K4me1-sum': 127, 'EncodeH3K4me2-max': 86, 'EncodeH3K4me2-sum': 180, 'EncodeH3K4me3-max': 68, 'EncodeH3K4me3-sum': 161, 'EncodeH3K79me2-max': 257, 'EncodeH3K79me2-sum': 114, 'EncodeH3K9ac-max': 193, 'EncodeH3K9ac-sum': 156, 'EncodeH3K9me3-max': 63, 'EncodeH3K9me3-sum': 287, 'EncodeH4K20me1-max': 59, 'EncodeH4K20me1-sum': 266, 'EncodetotalRNA-m ...

# %% [markdown]
# ##### Compare the length of the original dataset with the encoded dataset.

# %%
original = inverted_dict
encoded = encoded_dict
print(len(original))
print(len(encoded))
# Out:
# 499
# 539

# %%
# Display the keys (feature names) not found in the original.
not_in_original = set(encoded.keys()) - set(original.keys())
encoded_keys = list(not_in_original)
print(sorted(encoded_keys))
print(len(encoded_keys))
# Out:
# ['AF_dssp_secondary_structure_-', 'AF_dssp_secondary_structure_B', 'AF_dssp_secondary_structure_E', 'AF_dssp_secondary_structure_G', 'AF_dssp_secondary_structure_H', 'AF_dssp_secondary_structure_I', 'AF_dssp_secondary_structure_S', 'AF_dssp_secondary_structure_T', 'BIOTYPE_lncRNA', 'BIOTYPE_nonsense_mediated_decay', 'BIOTYPE_promoter_flanking_region', 'BIOTYPE_protein_coding', 'BIOTYPE_unprocessed_pseudogene', 'Consequence_first_0', 'Consequence_first_1', 'Consequence_first_2', 'Consequence_first_3', 'Consequence_first_4', 'Dst2SplType_ACCEPTOR', 'Dst2SplType_DONOR', 'EnsembleRegulatoryFeature_CTCF Binding Site', 'EnsembleRegulatoryFeature_Enhancer', 'EnsembleRegulatoryFeature_Open chromatin', 'EnsembleRegulatoryFeature_Promoter', 'EnsembleRegulatoryFeature_Promoter Flanking Region', 'EnsembleRegulatoryFeature_TF binding site', 'IMPACT_HIGH', 'IMPACT_LOW', 'IMPACT_MODERATE', 'IMPACT_MODIFIER', 'MOD_RES_DESCRIPTION_0', 'MOD_RES_DESCRIPTION_1', 'MOD_RES_DESCRIPTION_2', 'MOD_RES_DESCRIPTION_3', 'MOD_RES_DESCRIPTION_4', 'NMD_NMD_escaping_variant', 'REGION_DESCRIPTION_0', 'REGION_DESCRIPTION_1', 'REGION_DESCRIPTION_2', 'REGION_DESCRIPTION_3', 'REGION_DESCRIPTION_4', 'REGION_DESCRIPTION_5', 'REGION_DESCRIPTION_6', 'REGION_DESCRIPTION_7', 'REGION_DESCRIPTION_8', 'STABILITY[3D]_Decrease', 'STABILITY[3D]_Increase', 'STABILITY[3D]_Neutral', 'STABILITY[SEQ]_Decrease', 'STABILITY[SEQ]_Increase', 'STABILITY[SEQ]_Neutral']
# 51

# %%
# Display the keys (feature names) not found in the encoded set.
not_in_encoded = set(original.keys()) - set(encoded.keys())
original_keys = list(not_in_encoded)
print(sorted(original_keys))
print(len(original_keys))
# Out:
# ['AF_dssp_secondary_structure', 'BIOTYPE', 'Consequence_first', 'Dst2SplType', 'EnsembleRegulatoryFeature', 'IMPACT', 'MOD_RES_DESCRIPTION', 'NMD', 'REGION_DESCRIPTION', 'STABILITY[3D]', 'STABILITY[SEQ]']
# 11

# %%
not_in_original = set(encoded.keys()) - set(original.keys())
combi_dict = {}

for orig_key in original.keys():
    combi_val = []
    for encoded_key in not_in_original:
        if encoded_key.startswith(orig_key):
            combi_val.append(encoded[encoded_key])
    if combi_val:
        combi_dict[orig_key] = combi_val

for key in combi_dict:
    combi_dict[key] = ', '.join(map(str, combi_dict[key]))

df_combined = pd.DataFrame(list(combi_dict.items()), columns=['Original Key', 'Combined Values'])

# drop rows with the keys 'MOD_RES' or 'REGION' due to dupliate names.
df_combined = df_combined[~df_combined['Original Key'].isin(['MOD_RES', 'REGION'])]

df_combined
# Out:
#                    Original Key                              Combined Values
# 0   AF_dssp_secondary_structure       439, 453, 505, 528, 527, 497, 464, 533
# 1                       BIOTYPE                        33, 447, 446, 342, 47
# 2             Consequence_first                          1, 15, 54, 286, 159
# 3                   Dst2SplType                                     499, 429
# 4     EnsembleRegulatoryFeature                 459, 438, 433, 493, 531, 503
# 5                        IMPACT                                  21, 7, 2, 9
# 7           MOD_RES_DESCRIPTION                      484, 458, 473, 495, 381
# 8                           NMD                                          415
# 10           REGION_DESCRIPTION  272, 325, 368, 409, 423, 397, 284, 462, 428
# 11                STABILITY[3D]                                411, 452, 309
# 12               STABILITY[SEQ]                                393, 401, 269

# %%
not_in_original = set(encoded.keys()) - set(original.keys())
combi_dict = {}

for orig_key in original.keys():
    combi_val = []
    for encoded_key in not_in_original:
        if encoded_key.startswith(orig_key):
            combi_val.append(encoded[encoded_key])
    if combi_val:
        combi_dict[orig_key] = combi_val

for key in combi_dict:
    combi_dict[key] = ', '.join(map(str, combi_dict[key]))
for key in not_in_original:
    if any(key.startswith(original_key) for original_key in original.keys()):
        del encoded[key]

encoded.update(combi_dict)
encoded
# Out:
# {'1000Gp3_AF': 51,
#  'A3D_SCORE': 418,
#  'ACETYLATION': 523,
#  'AF_Relative_ASA': 140,
#  'AF_confidence': 38,
#  'ANCHOR2': 39,
#  'ASA': 78,
#  'ASAquick_normscore_aa': 279,
#  'ASAquick_normscore_aa_window_15_next': 271,
#  'ASAquick_normscore_aa_window_15_prev': 99,
#  'ASAquick_normscore_aa_window_3_next': 373,
#  'ASAquick_normscore_aa_window_3_prev': 291,
#  'ASAquick_normscore_aa_window_8_next': 362,
#  'ASAquick_normscore_aa_window_8_prev': 252,
#  'ASAquick_rawscore_aa': 158,
#  'ASAquick_rawscore_aa_window_15_next': 238,
#  'ASAquick_rawscore_aa_window_15_prev': 92,
#  'ASAquick_rawscore_aa_window_3_next': 310,
#  'ASAquick_rawscore_aa_window_3_prev': 343,
#  'ASAquick_rawscore_aa_window_8_next': 451,
#  'ASAquick_rawscore_aa_window_8_prev': 398,
#  'ATP_binding_gbind': 490,
#  'Acetylation': 508,
#  'BLOSUM62': 479,
#  'C-GLYCOSYLATION': 536,
#  'CADD_raw': 44,
#  'CDS_len': 199,
#  'COSMIC': 274,
#  'COSMICvsHAPMAP': 240,
#  'COSMICvsSWISSPROT': 436,
#  'Ca2+_binding_gbind': 434,
#  'Charge': 340,
#  'Clarks_distance': 97,
#  'Condel_score': 25,
#  'ConsScore': 3,
#  'Conservation': 90,
#  'CpG': 317,
#  'DFLpredScore_aa': 494,
#  'DFLpredScore_aa_window_15_next': 259,
#  'DFLpredScore_aa_window_15_prev': 331,
#  'DFLpredScore_aa_window_3_next': 391,
#  'DFLpredScore_aa_window_3_prev': 181,
#  'DFLpredScore_aa_window_8_next': 308,
#  'DFLpredScore_aa_window_8_prev': 359,
#  'DNA_binding_gbind': 385,
#  'DRNApredDNAscore_aa': 399,
#  'DRNApredDNAscore_aa_window_15_next': 366,
#  'DRNApredDNAscore_aa_window_15_prev': 432,
#  'DRNApredDNAscore_aa_window_3_next': 290,
#  'DRNApredDNAscore_aa_window_3_prev': 426,
#  'DRNApredDNAscore_aa_window_8_next': 348,
#  'DRNApredDNAscore_aa_window_8_prev': 388,
#  'DRNApredRNAscore_aa': 443,
#  'DRNApredRNAscore_aa_window_15_next': 380,
#  'DRNApredRNAscore_aa_window_15_prev': 201,
#  'DRNApredRNAscore_aa_window_3_next': 204,
#  'DRNApredRNAscore_aa_window_3_prev': 207,
#  'DRNApredRNAscore_aa_window_8_next': 225,
#  'DRNApredRNAscore_aa_window_8_prev': 171,
#  'DisoDNAscore_aa': 449,
#  'DisoDNAscore_aa_window_15_next': 319,
#  'DisoDNAscore_aa_window_15_prev': 386,
#  'DisoDNAscore_aa_window_3_next': 406,
#  'DisoDNAscore_aa_window_3_prev': 349,
#  'DisoDNAscore_aa_window_8_next': 188,
#  'DisoDNAscore_aa_window_8_prev': 402,
#  'DisoPROscore_aa': 424,
#  'DisoPROscore_aa_window_15_next': 326,
#  'DisoPROscore_aa_window_15_prev': 191,
#  'DisoPROscore_aa_window_3_next': 298,
#  'DisoPROscore_aa_window_3_prev': 220,
#  'DisoPROscore_aa_window_8_next': 292,
#  'DisoPROscore_aa_window_8_prev': 131,
#  'DisoRNAscore_aa': 370,
#  'DisoRNAscore_aa_window_15_next': 184,
#  'DisoRNAscore_aa_window_15_prev': 477,
#  'DisoRNAscore_aa_window_3_next': 318,
#  'DisoRNAscore_aa_window_3_prev': 244,
#  'DisoRNAscore_aa_window_8_next': 255,
#  'DisoRNAscore_aa_window_8_prev': 289,
#  'Dist2Mutation': 265,
#  'Dominant_probability': 12,
#  'Dst2Splice': 461,
#  'EncodeDNase-max': 110,
#  'EncodeDNase-sum': 43,
#  'EncodeH2AFZ-max': 241,
#  'EncodeH2AFZ-sum': 70,
#  'EncodeH3K27ac-max': 183,
#  'EncodeH3K27ac-sum': 288,
#  'EncodeH3K27me3-max': 276,
#  'EncodeH3K27me3-sum': 122,
#  'EncodeH3K36me3-max': 71,
#  'EncodeH3K36me3-sum': 41,
#  'EncodeH3K4me1-max': 160,
#  'EncodeH3K4me1-sum': 127,
#  'EncodeH3K4me2-max': 86,
#  'EncodeH3K4me2-sum': 180,
#  'EncodeH3K4me3-max': 68,
#  'EncodeH3K4me3-sum': 161,
#  'EncodeH3K79me2-max': 257,
#  'EncodeH3K79me2-sum': 114,
#  'EncodeH3K9ac-max': 193,
#  'EncodeH3K9ac-sum': 156,
#  'EncodeH3K9me3-max': 63,
#  'EncodeH3K9me3-sum': 287,
#  'EncodeH4K20me1-max': 59,
#  'EncodeH4K20me1-sum': 266,
#  'EncodetotalRNA-max': 172,
#  'EncodetotalRNA-sum': 103,
#  'Ex': 353,
#  'FATHMM_score': 42,
#  'Freq10000bp': 157,
#  'Freq1000bp': 425,
#  'Freq100bp': 488,
#  'GC': 72,
#  'GDI': 198,
#  'GERPplus_plus_NR': 93,
#  'GERPplus_plus_RS': 178,
#  'GM12878_fitCons_score': 206,
#  'GenoCanyon_score': 253,
#  'GerpN': 45,
#  'GerpRS': 87,
#  'GerpRSpval': 478,
#  'GerpS': 17,
#  'Glycosylation': 511,
#  'Grantham_x': 321,
#  'H1_hESC_fitCons_score': 333,
#  'HAPMAP': 280,
#  'HEME_binding_gbind': 457,
#  'HGMD2003': 281,
#  'HUVEC_fitCons_score': 227,
#  'Hydrophobicity': 382,
#  'INTERACTION_REGION': 509,
#  'IUPRED2': 138,
#  'Indispensability_score': 106,
#  'JM': 367,
#  'LINSIGHT': 501,
#  'LIST_S2_score': 52,
#  'LRT_score': 177,
#  'METHYLATION': 481,
#  'MMSp_acceptor': 192,
#  'MMSp_acceptorIntron': 356,
#  'MMSp_donor': 258,
#  'MMSp_donorIntron': 400,
#  'MMSp_exon': 190,
#  'MMseq2_conservation_level_aa': 365,
#  'MMseq2_conservation_level_aa_window_15_next': 346,
#  'MMseq2_conservation_level_aa_window_15_prev': 435,
#  'MMseq2_conservation_level_aa_window_3_next': 383,
#  'MMseq2_conservation_level_aa_window_3_prev': 410,
#  'MMseq2_conservation_level_aa_window_8_next': 336,
#  'MMseq2_conservation_level_aa_window_8_prev': 299,
#  'MMseq2_conservation_score_aa': 431,
#  'MMseq2_conservation_score_aa_window_15_next': 270,
#  'MMseq2_conservation_score_aa_window_15_prev': 379,
#  'MMseq2_conservation_score_aa_window_3_next': 334,
#  'MMseq2_conservation_score_aa_window_3_prev': 320,
#  'MMseq2_conservation_score_aa_window_8_next': 210,
#  'MMseq2_conservation_score_aa_window_8_prev': 189,
#  'MOD_RES': '484, 458, 473, 495, 381',
#  'MPC_score': 18,
#  'MSC_95CI': 58,
#  'MVP_score': 26,
#  'MYRISTOYLATION': 539,
#  'M_CAP_score': 14,
#  'MaxEntScan_alt': 390,
#  'MaxEntScan_diff': 163,
#  'MaxEntScan_ref': 487,
#  'Methylation': 466,
#  'Mg2+_binding_gbind': 412,
#  'Mn2+_binding_gbind': 470,
#  'MoRFchibiScore_aa': 202,
#  'MoRFchibiScore_aa_window_15_next': 115,
#  'MoRFchibiScore_aa_window_15_prev': 389,
#  'MoRFchibiScore_aa_window_3_next': 144,
#  'MoRFchibiScore_aa_window_3_prev': 221,
#  'MoRFchibiScore_aa_window_8_next': 85,
#  'MoRFchibiScore_aa_window_8_prev': 226,
#  'MutationAssessor_score': 55,
#  'MutationTaster_score': 30,
#  'N-GLYCOSYLATION': 510,
#  'NearestExonJB_distance': 187,
#  'NearestExonJB_len': 239,
#  'Number_of_paralogs': 31,
#  'O-GLYCOSYLATION': 507,
#  'PAM250': 293,
#  'PHOSPHORYLATION': 519,
#  'PROVEAN_score': 67,
#  'PSIPRED_helix_aa': 496,
#  'PSIPRED_helix_aa_window_15_next': 217,
#  'PSIPRED_helix_aa_window_15_prev': 208,
#  'PSIPRED_helix_aa_window_3_next': 492,
#  'PSIPRED_helix_aa_window_3_prev': 482,
#  'PSIPRED_helix_aa_window_8_next': 456,
#  'PSIPRED_helix_aa_window_8_prev': 422,
#  'PSIPRED_strand_aa': 465,
#  'PSIPRED_strand_aa_window_15_next': 296,
#  'PSIPRED_strand_aa_window_15_prev': 394,
#  'PSIPRED_strand_aa_window_3_next': 485,
#  'PSIPRED_strand_aa_window_3_prev': 520,
#  'PSIPRED_strand_aa_window_8_next': 491,
#  'PSIPRED_strand_aa_window_8_prev': 414,
#  'PTM': 363,
#  'Phosphorylation': 384,
#  'Polarity': 442,
#  'ProteinLengthChange': 378,
#  'REGION': '272, 325, 368, 409, 423, 397, 284, 462, 428',
#  'REQUIRED_FOR_INTER': 440,
#  'RNA_binding_gbind': 249,
#  'RSA': 96,
#  'RSA_Zfit': 262,
#  'RVIS': 117,
#  'Rare10000bp': 37,
#  'Rare1000bp': 352,
#  'Rare100bp': 469,
#  'Recessive_probability': 29,
#  'RemapOverlapCL': 448,
#  'RemapOverlapTF': 273,
#  'S-GLYCOSYLATION': 535,
#  'S-NITROSYLATION': 524,
#  'SCRIBERscore_aa': 472,
#  'SCRIBERscore_aa_window_15_next': 407,
#  'SCRIBERscore_aa_window_15_prev': 374,
#  'SCRIBERscore_aa_window_3_next': 219,
#  'SCRIBERscore_aa_window_3_prev': 282,
#  'SCRIBERscore_aa_window_8_next': 165,
#  'SCRIBERscore_aa_window_8_prev': 396,
#  'SIFT_score': 150,
#  'SUMOYLATION': 537,
#  'S_DDG[3D]': 387,
#  'S_DDG[SEQ]': 101,
#  'Selective_pressure': 203,
#  'SiPhy_29way_logOdds': 136,
#  'SignalP_score_aa': 525,
#  'SignalP_score_aa_window_15_next': 504,
#  'SignalP_score_aa_window_15_prev': 530,
#  'SignalP_score_aa_window_3_next': 514,
#  'SignalP_score_aa_window_3_prev': 538,
#  'SignalP_score_aa_window_8_next': 532,
#  'SignalP_score_aa_window_8_prev': 534,
#  'Sngl10000bp': 123,
#  'Sngl1000bp': 176,
#  'Sngl100bp': 268,
#  'SpliceAI-acc-gain': 170,
#  'SpliceAI-acc-loss': 69,
#  'SpliceAI-don-gain': 104,
#  'SpliceAI-don-loss': 40,
#  'TSSDistance': 445,
#  'Transition': 427,
#  'UBIQUITINATION': 513,
#  'UK10K_AF': 35,
#  'Ubiquitination': 395,
#  'VB': 263,
#  'VEST4_score': 4,
#  'Volume': 444,
#  'ada_score': 260,
#  'after_ANCHOR_15': 185,
#  'after_ANCHOR_3': 76,
#  'after_ANCHOR_8': 74,
#  'after_ASA_15': 121,
#  'after_ASA_3': 151,
#  'after_ASA_8': 84,
#  'after_IUPRED_15': 27,
#  'after_IUPRED_3': 88,
#  'after_IUPRED_8': 22,
#  'after_RSA_15': 98,
#  'after_RSA_3': 142,
#  'after_RSA_8': 65,
#  'bStatistic_y': 137,
#  'before_ANCHOR_15': 36,
#  'before_ANCHOR_3': 129,
#  'before_ANCHOR_8': 105,
#  'before_ASA_15': 53,
#  'before_ASA_3': 145,
#  'before_ASA_8': 66,
#  'before_IUPRED_15': 256,
#  'before_IUPRED_3': 46,
#  'before_IUPRED_8': 102,
#  'before_RSA_15': 73,
#  'before_RSA_3': 306,
#  'before_RSA_8': 56,
#  'cHmm_E1': 254,
#  'cHmm_E10': 215,
#  'cHmm_E11': 285,
#  'cHmm_E12': 205,
#  'cHmm_E13': 173,
#  'cHmm_E14': 209,
#  'cHmm_E15': 19,
#  'cHmm_E16': 135,
#  'cHmm_E17': 143,
#  'cHmm_E18': 186,
#  'cHmm_E19': 218,
#  'cHmm_E2': 107,
#  'cHmm_E20': 77,
#  'cHmm_E21': 112,
#  'cHmm_E22': 128,
#  'cHmm_E23': 222,
#  'cHmm_E24': 277,
#  'cHmm_E25': 214,
#  'cHmm_E3': 94,
#  'cHmm_E4': 20,
#  'cHmm_E5': 328,
#  'cHmm_E6': 223,
#  'cHmm_E7': 34,
#  'cHmm_E8': 49,
#  'cHmm_E9': 141,
#  'concavity_score': 475,
#  'dbscSNV-ada_score': 80,
#  'dbscSNV-rf_score': 32,
#  'denovo_Zscore': 24,
#  'distance_com': 302,
#  'fathmm_MKL_coding_score': 16,
#  'fathmm_XF_coding_score': 50,
#  'gnomAD_exomes_AF': 6,
#  'gnomAD_genomes_AF': 95,
#  'gnom_mutcount': 62,
#  'gnomsingle_mutcount': 441,
#  'gtex_Adipose_-_Subcutaneous': 195,
#  'gtex_Adipose_-_Visceral_(Omentum)': 175,
#  'gtex_Adrenal_Gland': 437,
#  'gtex_Artery_-_Aorta': 124,
#  'gtex_Artery_-_Coronary': 421,
#  'gtex_Artery_-_Tibial': 174,
#  'gtex_Bladder': 119,
#  'gtex_Brain_-_Amygdala': 148,
#  'gtex_Brain_-_Anterior_cingulate_cortex_(BA24)': 113,
#  'gtex_Brain_-_Caudate_(basal_ganglia)': 153,
#  'gtex_Brain_-_Cerebellar_Hemisphere': 164,
#  'gtex_Brain_-_Cerebellum': 264,
#  'gtex_Brain_-_Cortex': 109,
#  'gtex_Brain_-_Frontal_Cortex_(BA9)': 120,
#  'gtex_Brain_-_Hippocampus': 100,
#  'gtex_Brain_-_Hypothalamus': 196,
#  'gtex_Brain_-_Nucleus_accumbens_(basal_ganglia)': 118,
#  'gtex_Brain_-_Putamen_(basal_ganglia)': 82,
#  'gtex_Brain_-_Spinal_cord_(cervical_c-1)': 267,
#  'gtex_Brain_-_Substantia_nigra': 168,
#  'gtex_Breast_-_Mammary_Tissue': 237,
#  'gtex_Cells_-_Cultured_fibroblasts': 149,
#  'gtex_Cells_-_EBV-transformed_lymphocytes': 89,
#  'gtex_Cervix_-_Ectocervix': 182,
#  'gtex_Cervix_-_Endocervix': 169,
#  'gtex_Colon_-_Sigmoid': 111,
#  'gtex_Colon_-_Transverse': 64,
#  'gtex_Esophagus_-_Gastroesophageal_Junction': 234,
#  'gtex_Esophagus_-_Mucosa': 79,
#  'gtex_Esophagus_-_Muscularis': 235,
#  'gtex_Fallopian_Tube': 229,
#  'gtex_Heart_-_Atrial_Appendage': 361,
#  'gtex_Heart_-_Left_Ventricle': 403,
#  'gtex_Kidney_-_Cortex': 132,
#  'gtex_Kidney_-_Medulla': 213,
#  'gtex_Liver': 467,
#  'gtex_Lung': 300,
#  'gtex_Minor_Salivary_Gland': 152,
#  'gtex_Muscle_-_Skeletal': 351,
#  'gtex_Nerve_-_Tibial': 311,
#  'gtex_Ovary': 315,
#  'gtex_Pancreas': 330,
#  'gtex_Pituitary': 250,
#  'gtex_Prostate': 295,
#  'gtex_Skin_-_Not_Sun_Exposed_(Suprapubic)': 155,
#  'gtex_Skin_-_Sun_Exposed_(Lower_leg)': 134,
#  'gtex_Small_Intestine_-_Terminal_Ileum': 57,
#  'gtex_Spleen': 75,
#  'gtex_Stomach': 197,
#  'gtex_Testis': 228,
#  'gtex_Thyroid': 450,
#  'gtex_Uterus': 130,
#  'gtex_Vagina': 139,
#  'gtex_Whole_Blood': 242,
#  'haplo': 354,
#  'haplo_imputed': 224,
#  'hgmd_mutcount': 61,
#  'integrated_fitCons_score': 297,
#  'isHomomultimer': 312,
#  'mamPhCons': 11,
#  'mamPhyloP': 10,
#  'minDistTSE': 108,
#  'minDistTSS': 248,
#  'mirSVR-Aln': 489,
#  'mirSVR-E': 480,
#  'mirSVR-Score': 364,
#  'motifDist': 430,
#  'motifECount': 518,
#  'motifEHIPos': 417,
#  'motifEScoreChng': 500,
#  'n_contacts': 147,
#  'num_interactions': 83,
#  'phastCons100way_vertebrate': 28,
#  'phastCons17way_primate': 48,
#  'phastCons30way_mammalian': 338,
#  'phyloP100way_vertebrate': 13,
#  'phyloP17way_primate': 358,
#  'phyloP30way_mammalian': 341,
#  'polyphen_avenhet': 474,
#  'polyphen_avenint': 517,
#  'polyphen_avensit': 516,
#  'polyphen_bfact': 486,
#  'polyphen_dprop': 506,
#  'polyphen_dscore': 167,
#  'polyphen_dvol': 515,
#  'polyphen_hbonds': 521,
#  'polyphen_idpmax': 332,
#  'polyphen_idpsnp': 416,
#  'polyphen_idqmin': 251,
#  'polyphen_mindhet': 522,
#  'polyphen_mindint': 526,
#  'polyphen_mindsit': 529,
#  'polyphen_nobs': 408,
#  'polyphen_normasa': 512,
#  'polyphen_score1': 125,
#  'polyphen_score2': 231,
#  'ppi_combined_0': 460,
#  'ppi_combined_1': 377,
#  'ppi_combined_10': 344,
#  'ppi_combined_11': 360,
#  'ppi_combined_12': 116,
#  'ppi_combined_13': 278,
#  'ppi_combined_14': 236,
#  'ppi_combined_15': 347,
#  'ppi_combined_16': 275,
#  'ppi_combined_17': 337,
#  'ppi_combined_18': 301,
#  'ppi_combined_19': 230,
#  'ppi_combined_2': 233,
#  'ppi_combined_20': 91,
#  'ppi_combined_21': 372,
#  'ppi_combined_22': 146,
#  'ppi_combined_23': 305,
#  'ppi_combined_24': 261,
#  'ppi_combined_25': 350,
#  'ppi_combined_26': 314,
#  'ppi_combined_27': 179,
#  'ppi_combined_28': 162,
#  'ppi_combined_29': 247,
#  'ppi_combined_3': 371,
#  'ppi_combined_30': 243,
#  'ppi_combined_31': 246,
#  'ppi_combined_32': 216,
#  'ppi_combined_33': 245,
#  'ppi_combined_34': 194,
#  'ppi_combined_35': 376,
#  'ppi_combined_36': 339,
#  'ppi_combined_37': 463,
#  'ppi_combined_38': 166,
#  'ppi_combined_39': 468,
#  'ppi_combined_4': 357,
#  'ppi_combined_40': 455,
#  'ppi_combined_41': 413,
#  'ppi_combined_42': 369,
#  'ppi_combined_43': 303,
#  'ppi_combined_44': 471,
#  'ppi_combined_45': 324,
#  'ppi_combined_46': 392,
#  'ppi_combined_47': 81,
#  'ppi_combined_48': 476,
#  'ppi_combined_49': 212,
#  'ppi_combined_5': 200,
#  'ppi_combined_50': 454,
#  'ppi_combined_51': 154,
#  'ppi_combined_52': 345,
#  'ppi_combined_53': 335,
#  'ppi_combined_54': 316,
#  'ppi_combined_55': 329,
#  'ppi_combined_56': 327,
#  'ppi_combined_57': 404,
#  'ppi_combined_58': 283,
#  'ppi_combined_59': 313,
#  'ppi_combined_6': 322,
#  'ppi_combined_60': 304,
#  'ppi_combined_61': 405,
#  'ppi_combined_62': 211,
#  'ppi_combined_63': 133,
#  'ppi_combined_7': 307,
#  'ppi_combined_8': 420,
#  'ppi_combined_9': 419,
#  'priPhCons': 23,
#  'priPhyloP': 232,
#  'rel_CDS_pos': 294,
#  'rel_cDNA_pos': 502,
#  'rel_prot_pos': 323,
#  'rf_score': 126,
#  's_het': 60,
#  'tOverlapMotifs': 355,
#  'targetScan': 483,
#  'verPhCons': 8,
#  'verPhyloP': 5,
#  'AF_dssp_secondary_structure': '439, 453, 505, 528, 527, 497, 464, 533',
#  'BIOTYPE': '33, 447, 446, 342, 47',
#  'Consequence_first': '1, 15, 54, 286, 159',
#  'Dst2SplType': '499, 429',
#  'EnsembleRegulatoryFeature': '459, 438, 433, 493, 531, 503',
#  'IMPACT': '21, 7, 2, 9',
#  'MOD_RES_DESCRIPTION': '484, 458, 473, 495, 381',
#  'NMD': '415',
#  'REGION_DESCRIPTION': '272, 325, 368, 409, 423, 397, 284, 462, 428',
#  'STABILITY[3D]': '411, 452, 309',
#  'STABILITY[SEQ]': '393, 401, 269'}

# %%
def process_encoded(encoded):
    def lowest_number(value):
        if isinstance(value, str):
            numbers = [int(num.strip()) for num in value.split(',')]
            return min(numbers)
        return value

    processed = {}
    mod_res_value = None
    region_value = None

    # Ignore MOD_RES_DESCRIPTION and REGION_DESCRIPTION due to duplicates.
    for key, value in encoded.items():
        if key == 'MOD_RES':
            mod_res_value = int(lowest_number(value))
            processed[key] = mod_res_value
        elif key == 'REGION':
            region_value = int(lowest_number(value))
            processed[key] = region_value
        elif key not in ['MOD_RES_DESCRIPTION', 'REGION_DESCRIPTION']:
            processed[key] = int(lowest_number(value))

    # Handle MOD_RES_DESCRIPTION and REGION_DESCRIPTION.
    if 'MOD_RES_DESCRIPTION' in encoded:
        numbers = [int(num.strip()) for num in encoded['MOD_RES_DESCRIPTION'].split(',')]
        numbers = [num for num in numbers if num != mod_res_value]
        if numbers:
            processed['MOD_RES_DESCRIPTION'] = min(numbers)

    if 'REGION_DESCRIPTION' in encoded:
        numbers = [int(num.strip()) for num in encoded['REGION_DESCRIPTION'].split(',')]
        numbers = [num for num in numbers if num != region_value]
        if numbers:
            processed['REGION_DESCRIPTION'] = min(numbers)

    return processed

processed_encoded = process_encoded(encoded)

print("MOD_RES:", processed_encoded.get('MOD_RES'))
print("MOD_RES_DESCRIPTION:", processed_encoded.get('MOD_RES_DESCRIPTION'))
print("REGION:", processed_encoded.get('REGION'))
print("REGION_DESCRIPTION:", processed_encoded.get('REGION_DESCRIPTION'))

def invert_dict(dictionary):
    return {value: key for key, value in dictionary.items()}

inverted_encoded = invert_dict(processed_encoded)

def sort_by_keys(dictionary):
    return dict(sorted(dictionary.items()))

sorted_encoded = sort_by_keys(inverted_encoded)

# Ensure they are the correct length (same as original dataset).
print(f'processed keys: {len(processed_encoded)}')
print(f'inverted keys: {len(inverted_encoded)}')
print(f'sorted keys: {len(sorted_encoded)}')
# Out:
# MOD_RES: 381
# MOD_RES_DESCRIPTION: 458
# REGION: 272
# REGION_DESCRIPTION: 284
# processed keys: 499
# inverted keys: 499
# sorted keys: 499

# %%
orig_dict = sorted_encoded

def renumber(original_dict):
    items = list(original_dict.items())
    renumbered_dict = {str(i+1): value for i, (_, value) in enumerate(items)}
    return renumbered_dict
renumbered_dict = renumber(orig_dict)

for i, (key, value) in enumerate(renumbered_dict.items()):
    if i < 5:
        print(f"{key}: {value}")
    elif i > len(renumbered_dict) - 6:
        if i == 5:
            print("...")
        print(f"{key}: {value}")

# %%
# Deposit the final rankings into a JSON file.
file_path = "decoded_ranks.json"
with open(file_path, 'w') as file:
    json.dump(renumbered_dict, file, indent=4)
